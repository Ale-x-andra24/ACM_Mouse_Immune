# %% [markdown]
# ### Notebook for `merging` the Pkp2 and Ttn datasets of ACM murine cardiac leucocytes 6 month post MCMV infection
#
# #### Environment: Scanpy
#
# - **Developed by**: Alexandra Cirnu
# - **Modified by**: Alexandra Cirnu
# - **Würzburg Institute for Systems Immunology & Julius-Maximilian-Universität Würzburg**
# - **Date of creation**: 240220
# - **Date of modification**: 240220

# %% [markdown]
# ### Import required modules

# %%
import anndata
import numpy as np
import pandas as pd
import scanpy as sc

# %% [markdown]
# ## Read in all datasets

# %%
def X_is_raw(adata): return np.array_equal(adata.X.sum(axis=0).astype(int), adata.X.sum(axis=0))

# %%
A1 = sc.read_h5ad('/Users/alex/data/ACM_cardiac_leuco/Pkp2/C6_Pkp2_Exp1_Library1/processed/Pkp2_A1_demux_QCed_ac240219.raw.h5ad')
A2 = sc.read_h5ad('/Users/alex/data/ACM_cardiac_leuco/Pkp2/C5_Pkp2_Exp1_Library2/processed/Pkp2_A2_demux_QCed_ac240219.raw.h5ad')
A3 = sc.read_h5ad('/Users/alex/data/ACM_cardiac_leuco/Pkp2/E9_Pkp2_Exp2_Library1/processed/Pkp2_A3_demux_QCed_ac240219.raw.h5ad')
A4 = sc.read_h5ad('/Users/alex/data/ACM_cardiac_leuco/Pkp2/E10_Pkp2_Exp2_Library2/processed/Pkp2_A4_demux_QCed_ac240219.raw.h5ad')
B1 = sc.read_h5ad('/Users/alex/data/ACM_cardiac_leuco/Ttn/C11_Ttn_Library1/C11/processed/Ttn_B1_demux_QCed_ac240219.raw.h5ad')
B2 = sc.read_h5ad('/Users/alex/data/ACM_cardiac_leuco/Ttn/C12_Ttn_Library2/C12/processed/Ttn_B2_demux_QCed_ac240219.raw.h5ad')
B2
# Out:
# AnnData object with n_obs × n_vars = 6892 × 32285
#     obs: 'sample', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'sample_colors'
#     layers: 'counts', 'sqrt_norm'

# %%
#adata = A1.concat(A2, A3, A4, B1, B2, keys = ['A1', 'A2', 'A3', 'A4', 'B1', 'B2'], join = 'inner') 
adata = A1.concatenate(A2, A3, A4, B1, B2, batch_key = 'library', batch_categories = ['A1', 'A2', 'A3', 'A4', 'B1', 'B2'], join = 'inner')              #as genes are the common feature in all datasets inner has to be chosen to create the interscetion of everz gene and not add the same gene 6 times
adata
# Out:
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_3321/1197282698.py:2: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata = A1.concatenate(A2, A3, A4, B1, B2, batch_key = 'library', batch_categories = ['A1', 'A2', 'A3', 'A4', 'B1', 'B2'], join = 'inner')              #as genes are the common feature in all datasets inner has to be chosen to create the interscetion of everz gene and not add the same gene 6 times
# AnnData object with n_obs × n_vars = 44594 × 32285
#     obs: 'sample', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score'
# ...

# %%
adata.obs
# Out:
#                                     sample          condition    genotype  \
# AAACCCAAGAAGCGAA-1-A1  Pkp2_HetKO_noninf_1  Pkp2_HetKO_noninf  Pkp2_HetKO
# AAACCCAAGATACAGT-1-A1    Pkp2_Ctr_noninf_2    Pkp2_Ctr_noninf    Pkp2_Ctr
# AAACCCAAGTCTAACC-1-A1    Pkp2_HetKO_MCMV_2    Pkp2_HetKO_MCMV  Pkp2_HetKO
# AAACCCACAACCACGC-1-A1    Pkp2_HetKO_MCMV_3    Pkp2_HetKO_MCMV  Pkp2_HetKO
# AAACCCAGTGCTCTCT-1-A1    Pkp2_HetKO_MCMV_3    Pkp2_HetKO_MCMV  Pkp2_HetKO
# ...                                    ...                ...         ...
# TTTGTTGCAAGCTCTA-1-B2     Ttn_Ctr_noninf_1     Ttn_Ctr_noninf     Ttn_Ctr
# TTTGTTGGTACAGGTG-1-B2       Ttn_Ctr_MCMV_2       Ttn_Ctr_MCMV     Ttn_Ctr
# TTTGTTGGTAGTAAGT-1-B2     Ttn_HetKO_MCMV_2     Ttn_HetKO_MCMV   Ttn_HetKO
# TTTGTTGTCCCAGGAC-1-B2     Ttn_Ctr_noninf_2     Ttn_Ctr_noninf     Ttn_Ctr
# TTTGTTGTCCGGGACT-1-B2     Ttn_Ctr_noninf_2     Ttn_Ctr_noninf     Ttn_Ctr
#
#                       infection library model  n_genes  doublet_scores  \
# ...

# %% [markdown]
# ### Check if raw data is stored in merged adata object

# %%
X_is_raw(adata)
# Out:
# True

# %%
adata.obs["sample"].cat.categories
# Out:
# Index(['Pkp2_Ctr_MCMV_1', 'Pkp2_Ctr_MCMV_2', 'Pkp2_Ctr_MCMV_3',
#        'Pkp2_Ctr_MCMV_4', 'Pkp2_Ctr_MCMV_5', 'Pkp2_Ctr_MCMV_6',
#        'Pkp2_Ctr_noninf_1', 'Pkp2_Ctr_noninf_2', 'Pkp2_Ctr_noninf_3',
#        'Pkp2_Ctr_noninf_4', 'Pkp2_HetKO_MCMV_1', 'Pkp2_HetKO_MCMV_2',
#        'Pkp2_HetKO_MCMV_3', 'Pkp2_HetKO_MCMV_4', 'Pkp2_HetKO_MCMV_5',
#        'Pkp2_HetKO_MCMV_6', 'Pkp2_HetKO_noninf_1', 'Pkp2_HetKO_noninf_2',
#        'Pkp2_HetKO_noninf_3', 'Pkp2_HetKO_noninf_4', 'Ttn_Ctr_MCMV_1',
#        'Ttn_Ctr_MCMV_2', 'Ttn_Ctr_MCMV_3', 'Ttn_Ctr_noninf_1',
#        'Ttn_Ctr_noninf_2', 'Ttn_HetKO_MCMV_1', 'Ttn_HetKO_MCMV_2',
#        'Ttn_HetKO_MCMV_3', 'Ttn_HetKO_noninf_1', 'Ttn_HetKO_noninf_2'],
#       dtype='object')

# %% [markdown]
# ## Save merged object

# %%
adata.write("/Users/alex/data/ACM_cardiac_leuco/processed_merged/Merge_demux_QCed_ac240220.raw.h5ad")
