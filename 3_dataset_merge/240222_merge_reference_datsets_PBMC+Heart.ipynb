# %% [markdown]
# ### Notebook for `merging` the reference data sets of human PBMCs and human heart
#
# #### Environment: Scanpy
#
# - **Developed by**: Alexandra Cirnu
# - **Modified by**: Alexandra Cirnu
# - **Würzburg Institute for Systems Immunology & Julius-Maximilian-Universität Würzburg**
# - **Date of creation**: 240222
# - **Date of modification**: 240222

# %% [markdown]
# ### Import required modules

# %%
import anndata
import numpy as np
import pandas as pd
import scanpy as sc

# %% [markdown]
# ## Read in all datasets

# %%
def X_is_raw(adata): return np.array_equal(adata.X.sum(axis=0).astype(int), adata.X.sum(axis=0))

# %% [markdown]
# ### Read in PBMC data set - keep only healthy donors
#
# COVID-19 airway and matched PBMCs H5AD(raw) downloaded from [here](https://www.covid19cellatlas.org/index.patient.html)

# %%
pbmc = sc.read_h5ad('/Users/alex/data/ACM_cardiac_leuco/Reference_data/Annotated_PBMC/meyer_nikolic_covid_pbmc_raw.h5ad')
pbmc
# Out:
# AnnData object with n_obs × n_vars = 422220 × 33559
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_ADT', 'nFeature_ADT', 'Age_group', 'BMI', 'COVID_severity', 'COVID_status', 'Ethnicity', 'Group', 'Sex', 'Smoker', 'annotation_broad', 'annotation_detailed', 'annotation_detailed_fullNames', 'patient_id', 'sample_id', 'sequencing_library', 'Protein_modality_weight'
#     var: 'name'

# %%
pbmc.obs
# Out:
#                                                                            orig.ident  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...  CV001_KM10202384-CV001_KM10202394
# ...                                                                               ...
# CV001_KM9294396-CV001_KM9294404_TTTGTCAGTTCTGTTT-1    CV001_KM9294396-CV001_KM9294404
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCAACCAAC-1    CV001_KM9294396-CV001_KM9294404
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCATTATCC-1    CV001_KM9294396-CV001_KM9294404
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCCTATGTT-1    CV001_KM9294396-CV001_KM9294404
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCTCAAGTG-1    CV001_KM9294396-CV001_KM9294404
#
#                                                     nCount_RNA  nFeature_RNA  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...      5493.0          1767
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...      4868.0          1577
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...      3178.0          1257
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...      4745.0          1477
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...      1902.0           954
# ...                                                        ...           ...
# CV001_KM9294396-CV001_KM9294404_TTTGTCAGTTCTGTTT-1      1001.0           554
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCAACCAAC-1       838.0           430
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCATTATCC-1       641.0           405
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCCTATGTT-1       551.0           341
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCTCAAGTG-1       518.0           328
#
#                                                     nCount_ADT  nFeature_ADT  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...      5297.0           184
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...      2169.0           165
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...      1330.0           163
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...      1255.0           161
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...      1711.0           166
# ...                                                        ...           ...
# CV001_KM9294396-CV001_KM9294404_TTTGTCAGTTCTGTTT-1       876.0           147
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCAACCAAC-1      1287.0           162
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCATTATCC-1      1245.0           160
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCCTATGTT-1      1199.0           170
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCTCAAGTG-1       851.0           144
#
#                                                    Age_group      BMI  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...     Adult  Unknown
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...     Adult  Unknown
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...     Adult  Unknown
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...     Adult  Unknown
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...     Adult  Unknown
# ...                                                      ...      ...
# CV001_KM9294396-CV001_KM9294404_TTTGTCAGTTCTGTTT-1     Adult    27.17
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCAACCAAC-1     Adult    27.17
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCATTATCC-1     Adult    27.17
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCCTATGTT-1     Adult    27.17
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCTCAAGTG-1     Adult     36.9
#
#                                                    COVID_severity  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...        Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...        Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...        Healthy
# ...                                                           ...
# CV001_KM9294396-CV001_KM9294404_TTTGTCAGTTCTGTTT-1         Severe
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCAACCAAC-1         Severe
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCATTATCC-1         Severe
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCCTATGTT-1         Severe
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCTCAAGTG-1         Severe
#
#                                                      COVID_status Ethnicity  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...        Healthy       EUR
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        Healthy       EUR
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        Healthy       EUR
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...        Healthy       EUR
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...        Healthy       EUR
# ...                                                           ...       ...
# CV001_KM9294396-CV001_KM9294404_TTTGTCAGTTCTGTTT-1  Post-COVID-19       EUR
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCAACCAAC-1  Post-COVID-19       EUR
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCATTATCC-1  Post-COVID-19       EUR
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCCTATGTT-1  Post-COVID-19       EUR
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCTCAAGTG-1  Post-COVID-19       EUR
#
#                                                     Group     Sex      Smoker  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  Adult  Female  Non-smoker
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...  Adult  Female  Non-smoker
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...  Adult    Male  Non-smoker
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...  Adult  Female  Non-smoker
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...  Adult  Female  Non-smoker
# ...                                                   ...     ...         ...
# CV001_KM9294396-CV001_KM9294404_TTTGTCAGTTCTGTTT-1  Adult    Male  Non-smoker
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCAACCAAC-1  Adult    Male  Non-smoker
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCATTATCC-1  Adult    Male  Non-smoker
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCCTATGTT-1  Adult    Male  Non-smoker
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCTCAAGTG-1  Adult    Male  Non-smoker
#
#                                                    annotation_broad  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...         Monocyte
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...           T CD8+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...           T CD4+
# ...                                                             ...
# CV001_KM9294396-CV001_KM9294404_TTTGTCAGTTCTGTTT-1               NK
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCAACCAAC-1         Monocyte
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCATTATCC-1         Monocyte
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCCTATGTT-1               DC
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCTCAAGTG-1           T CD8+
#
#                                                    annotation_detailed  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...       Monocyte CD14
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...         T CD8 naive
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...         T CD4 naive
# ...                                                                ...
# CV001_KM9294396-CV001_KM9294404_TTTGTCAGTTCTGTTT-1                  NK
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCAACCAAC-1       Monocyte CD14
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCATTATCC-1       Monocyte CD14
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCCTATGTT-1                 pDC
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCTCAAGTG-1           T CD8 CTL
#
#                                                    annotation_detailed_fullNames  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...            Classical monocyte
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...                  T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...                  T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...                   T CD8 naive
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...                   T CD4 naive
# ...                                                                          ...
# CV001_KM9294396-CV001_KM9294404_TTTGTCAGTTCTGTTT-1                            NK
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCAACCAAC-1            Classical monocyte
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCATTATCC-1            Classical monocyte
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCCTATGTT-1                           pDC
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCTCAAGTG-1                     T CD8 CTL
#
#                                                    patient_id sample_id  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...        AN5       AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        AN5       AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        AN3       AN3
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...        AN5       AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...        AN5       AN5
# ...                                                       ...       ...
# CV001_KM9294396-CV001_KM9294404_TTTGTCAGTTCTGTTT-1        PC9       PC9
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCAACCAAC-1        PC9       PC9
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCATTATCC-1        PC9       PC9
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCCTATGTT-1        PC9       PC9
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCTCAAGTG-1        PC2       PC2
#
#                                                                    sequencing_library  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...  CV001_KM10202384-CV001_KM10202394
# ...                                                                               ...
# CV001_KM9294396-CV001_KM9294404_TTTGTCAGTTCTGTTT-1    CV001_KM9294396-CV001_KM9294404
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCAACCAAC-1    CV001_KM9294396-CV001_KM9294404
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCATTATCC-1    CV001_KM9294396-CV001_KM9294404
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCCTATGTT-1    CV001_KM9294396-CV001_KM9294404
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCTCAAGTG-1    CV001_KM9294396-CV001_KM9294404
#
#                                                     Protein_modality_weight
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...                 0.359517
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...                 0.577522
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...                 0.369143
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...                 0.785563
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...                 0.564174
# ...                                                                     ...
# CV001_KM9294396-CV001_KM9294404_TTTGTCAGTTCTGTTT-1                 0.429398
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCAACCAAC-1                 0.677910
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCATTATCC-1                 0.422796
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCCTATGTT-1                 0.471905
# CV001_KM9294396-CV001_KM9294404_TTTGTCATCTCAAGTG-1                 0.313640
#
# [422220 rows x 20 columns]

# %%
X_is_raw(pbmc)
# Out:
# True

# %%
pbmc.obs['COVID_status'].value_counts()
# Out:
# COVID_status
# Healthy          173684
# COVID-19         151312
# Post-COVID-19     97224
# Name: count, dtype: int64

# %%
pbmc.obs['n_counts'] = pbmc.obs['nCount_RNA'].copy()
pbmc.obs['n_genes'] = pbmc.obs['nFeature_RNA'].copy()
pbmc.obs['age_group'] = pbmc.obs['Age_group'].copy()
pbmc.obs['donor'] = pbmc.obs['patient_id'].copy()
pbmc.obs['sample'] = pbmc.obs['sample_id'].copy()
pbmc.obs["cell_source"] = "Yoshida"
pbmc.obs['cell_states'] = pbmc.obs['annotation_detailed_fullNames'].copy()
pbmc.obs['gender'] = pbmc.obs['Sex'].copy()

pbmc = pbmc[pbmc.obs['COVID_status'].isin(["Healthy"])]

pbmc.obs
# Out:
#                                                                            orig.ident  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC
...
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTCGCATCG-1  Adolescent  NP32   NP32
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTGTAAGTA-1  Adolescent  NP32   NP32
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCATGTCCC-1       Child  NP31   NP31
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCGAGGTAG-1       Child  NP31   NP31
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCTGCTGCT-1  Adolescent  NP32   NP32
#
#                                                    cell_source  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...     Yoshida
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...     Yoshida
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...     Yoshida
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...     Yoshida
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...     Yoshida
# ...                                                        ...
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTCGCATCG-1     Yoshida
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTGTAAGTA-1     Yoshida
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCATGTCCC-1     Yoshida
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCGAGGTAG-1     Yoshida
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCTGCTGCT-1     Yoshida
#
#                                                            cell_states  gender
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  Classical monocyte  Female
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        T CD4 helper  Female
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        T CD4 helper    Male
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...         T CD8 naive  Female
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...         T CD4 naive  Female
# ...                                                                ...     ...
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTCGCATCG-1         T CD8 naive    Male
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTGTAAGTA-1         NK IFN stim    Male
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCATGTCCC-1  Classical monocyte    Male
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCGAGGTAG-1         T CD8 naive    Male
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCTGCTGCT-1                  NK    Male
#
# [173684 rows x 28 columns]

# %%
pbmc
# Out:
# View of AnnData object with n_obs × n_vars = 173684 × 33559
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_ADT', 'nFeature_ADT', 'Age_group', 'BMI', 'COVID_severity', 'COVID_status', 'Ethnicity', 'Group', 'Sex', 'Smoker', 'annotation_broad', 'annotation_detailed', 'annotation_detailed_fullNames', 'patient_id', 'sample_id', 'sequencing_library', 'Protein_modality_weight', 'n_counts', 'n_genes', 'age_group', 'donor', 'sample', 'cell_source', 'cell_states', 'gender'
#     var: 'name'

# %%
del(pbmc.obs['orig.ident'])
del(pbmc.obs['nCount_RNA'])
del(pbmc.obs['nFeature_RNA'])
del(pbmc.obs['Age_group'])
del(pbmc.obs['patient_id'])
del(pbmc.obs['sample_id'])
del(pbmc.obs['annotation_detailed_fullNames'])
del(pbmc.obs['Sex'])
del(pbmc.obs['BMI'])
del(pbmc.obs['COVID_severity'])
del(pbmc.obs['Ethnicity'])
del(pbmc.obs['Group'])
del(pbmc.obs['Smoker'])
del(pbmc.obs['sequencing_library'])
del(pbmc.obs['Protein_modality_weight'])
del(pbmc.obs['nCount_ADT'])
del(pbmc.obs['nFeature_ADT'])

# %%
pbmc.obs
# Out:
#                                                    COVID_status  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...      Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...      Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...      Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...      Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...      Healthy
# ...                                                         ...
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTCGCATCG-1      Healthy
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTGTAAGTA-1      Healthy
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCATGTCCC-1      Healthy
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCGAGGTAG-1      Healthy
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCTGCTGCT-1      Healthy
#
#                                                    annotation_broad  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...         Monocyte
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...           T CD8+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...           T CD4+
# ...                                                             ...
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTCGCATCG-1           T CD8+
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTGTAAGTA-1               NK
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCATGTCCC-1         Monocyte
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCGAGGTAG-1           T CD8+
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCTGCTGCT-1               NK
#
#                                                    annotation_detailed  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...       Monocyte CD14
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...         T CD8 naive
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...         T CD4 naive
# ...                                                                ...
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTCGCATCG-1         T CD8 naive
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTGTAAGTA-1         NK IFN stim
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCATGTCCC-1       Monocyte CD14
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCGAGGTAG-1         T CD8 naive
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCTGCTGCT-1                  NK
#
#                                                     n_counts  n_genes  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...    5493.0     1767
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...    4868.0     1577
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...    3178.0     1257
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...    4745.0     1477
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...    1902.0      954
# ...                                                      ...      ...
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTCGCATCG-1    3513.0     1297
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTGTAAGTA-1    1888.0     1296
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCATGTCCC-1    1798.0      814
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCGAGGTAG-1    4407.0     1351
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCTGCTGCT-1    2676.0     1297
#
#                                                      age_group donor sample  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...       Adult   AN5    AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...       Adult   AN5    AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...       Adult   AN3    AN3
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...       Adult   AN5    AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...       Adult   AN5    AN5
# ...                                                        ...   ...    ...
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTCGCATCG-1  Adolescent  NP32   NP32
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTGTAAGTA-1  Adolescent  NP32   NP32
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCATGTCCC-1       Child  NP31   NP31
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCGAGGTAG-1       Child  NP31   NP31
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCTGCTGCT-1  Adolescent  NP32   NP32
#
#                                                    cell_source  \
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...     Yoshida
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...     Yoshida
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...     Yoshida
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...     Yoshida
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...     Yoshida
# ...                                                        ...
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTCGCATCG-1     Yoshida
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTGTAAGTA-1     Yoshida
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCATGTCCC-1     Yoshida
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCGAGGTAG-1     Yoshida
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCTGCTGCT-1     Yoshida
#
#                                                            cell_states  gender
# index
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  Classical monocyte  Female
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        T CD4 helper  Female
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        T CD4 helper    Male
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...         T CD8 naive  Female
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...         T CD4 naive  Female
# ...                                                                ...     ...
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTCGCATCG-1         T CD8 naive    Male
# CV001_KM9166642-CV001_KM9166650_TTTGTCAGTGTAAGTA-1         NK IFN stim    Male
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCATGTCCC-1  Classical monocyte    Male
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCGAGGTAG-1         T CD8 naive    Male
# CV001_KM9166642-CV001_KM9166650_TTTGTCATCTGCTGCT-1                  NK    Male
#
# [173684 rows x 11 columns]

# %% [markdown]
# ### Read in Human Cell Atlas Cardiac Leucocytes data set
#
# Data downloaded from [here](https://cellgeni.cog.sanger.ac.uk/heartcellatlas/data/hca_heart_immune_download.h5ad)

# %%
heart = sc.read_h5ad('/Users/alex/data/ACM_cardiac_leuco/Reference_data/Heart/hca_heart_immune_download.h5ad')
heart
# Out:
# AnnData object with n_obs × n_vars = 40868 × 33538
#     obs: 'NRP', 'age_group', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'percent_mito', 'percent_ribo', 'region', 'sample', 'scrublet_score', 'type', 'version', 'scNym', 'scNym_confidence'
#     uns: 'cell_states_colors', 'scNym_colors', 'scNym_probabilities'
#     obsm: 'X_pca', 'X_scnym', 'X_umap'

# %%
del(heart.obs['age_group'])
del(heart.obs['percent_mito'])
del(heart.obs['percent_ribo'])
del(heart.obs['scrublet_score'])
del(heart.obs['type'])
del(heart.obs['version'])

# %%
heart.obs
# Out:
#                                     NRP     cell_source  cell_states donor  \
# AAAGTGAAGTCGGCCT-1-H0015_apex        No  Harvard-Nuclei  CD4+T_cytox    H5
# AAATGGAAGGTCCCTG-1-H0015_apex        No  Harvard-Nuclei  CD4+T_cytox    H5
# AAATGGAGTTGTCTAG-1-H0015_apex        No  Harvard-Nuclei     doublets    H5
# AACAACCGTAATTGGA-1-H0015_apex        No  Harvard-Nuclei    DOCK4+MØ1    H5
# AAGACTCTCAGGACGA-1-H0015_apex        No  Harvard-Nuclei         Mast    H5
# ...                                 ...             ...          ...   ...
# TTTGATCGTGTCATGT-1-HCAHeart8102862  Yes     Sanger-CD45  CD4+T_cytox   D11
# TTTGATCGTTCTCCTG-1-HCAHeart8102862  Yes     Sanger-CD45    LYVE1+MØ1   D11
# TTTGGAGGTCGCTCGA-1-HCAHeart8102862  Yes     Sanger-CD45       MØ_AgP   D11
# TTTGGTTTCAGTGTTG-1-HCAHeart8102862  Yes     Sanger-CD45    LYVE1+MØ3   D11
# TTTGTTGAGTCGCCCA-1-HCAHeart8102862  Yes     Sanger-CD45       MØ_mod   D11
#
#                                     gender    n_counts  n_genes region  \
# AAAGTGAAGTCGGCCT-1-H0015_apex       Female  724.717285      588     AX
# AAATGGAAGGTCCCTG-1-H0015_apex       Female  668.059509      515     AX
# AAATGGAGTTGTCTAG-1-H0015_apex       Female  670.216309      504     AX
# AACAACCGTAATTGGA-1-H0015_apex       Female  730.082947      578     AX
# AAGACTCTCAGGACGA-1-H0015_apex       Female  612.323425      428     AX
# ...                                    ...         ...      ...    ...
# TTTGATCGTGTCATGT-1-HCAHeart8102862  Female  631.149170      715     AX
# TTTGATCGTTCTCCTG-1-HCAHeart8102862  Female  819.040100     2526     AX
# TTTGGAGGTCGCTCGA-1-HCAHeart8102862  Female  757.455505     1350     AX
# TTTGGTTTCAGTGTTG-1-HCAHeart8102862  Female  815.372131     2507     AX
# TTTGTTGAGTCGCCCA-1-HCAHeart8102862  Female  868.168457     2115     AX
#
#                                              sample          scNym  \
# AAAGTGAAGTCGGCCT-1-H0015_apex            H0015_apex     CD4+T_cell
# AAATGGAAGGTCCCTG-1-H0015_apex            H0015_apex     CD4+T_cell
# AAATGGAGTTGTCTAG-1-H0015_apex            H0015_apex             NK
# AACAACCGTAATTGGA-1-H0015_apex            H0015_apex  CD14+Monocyte
# AAGACTCTCAGGACGA-1-H0015_apex            H0015_apex           Mast
# ...                                             ...            ...
# TTTGATCGTGTCATGT-1-HCAHeart8102862  HCAHeart8102862     CD8+T_cell
# TTTGATCGTTCTCCTG-1-HCAHeart8102862  HCAHeart8102862     CD8+T_cell
# TTTGGAGGTCGCTCGA-1-HCAHeart8102862  HCAHeart8102862             M3
# TTTGGTTTCAGTGTTG-1-HCAHeart8102862  HCAHeart8102862             MØ
# TTTGTTGAGTCGCCCA-1-HCAHeart8102862  HCAHeart8102862             MØ
#
#                                     scNym_confidence
# AAAGTGAAGTCGGCCT-1-H0015_apex               0.797180
# AAATGGAAGGTCCCTG-1-H0015_apex               0.999248
# AAATGGAGTTGTCTAG-1-H0015_apex               0.680673
# AACAACCGTAATTGGA-1-H0015_apex               0.538159
# AAGACTCTCAGGACGA-1-H0015_apex               0.990977
# ...                                              ...
# TTTGATCGTGTCATGT-1-HCAHeart8102862          0.756579
# TTTGATCGTTCTCCTG-1-HCAHeart8102862          0.269561
# TTTGGAGGTCGCTCGA-1-HCAHeart8102862          0.585436
# TTTGGTTTCAGTGTTG-1-HCAHeart8102862          0.968681
# TTTGTTGAGTCGCCCA-1-HCAHeart8102862          0.998978
#
# [40868 rows x 11 columns]

# %%
X_is_raw(heart)
# Out:
# True

# %%
heart.obs['cell_source'].value_counts()
# Out:
# cell_source
# Sanger-CD45       19587
# Harvard-Nuclei    10536
# Sanger-Nuclei      8567
# Sanger-Cells       2178
# Name: count, dtype: int64

# %% [markdown]
# ### Merge datasetsa to one reference data set

# %%
#reference = pbmc.concat(heart, join = 'inner')
reference = pbmc.concatenate(heart, batch_key = 'cell_source', batch_categories = ['Yoshida', 'Sanger-CD45', 'Harvard-Nuclei', 'Sanger-Nuclei', 'Sanger-Cells'], join = 'inner') 
reference.obs
# Out:
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/1344764595.py:2: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   reference = pbmc.concatenate(heart, batch_key = 'cell_source', batch_categories = ['Yoshida', 'Sanger-CD45', 'Harvard-Nuclei', 'Sanger-Nuclei', 'Sanger-Cells'], join = 'inner')
#                                                    COVID_status  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...      Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...      Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...      Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...      Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...      Healthy
# ...                                                         ...
# TTTGATCGTGTCATGT-1-HCAHeart8102862-Sanger-CD45              NaN
# TTTGATCGTTCTCCTG-1-HCAHeart8102862-Sanger-CD45              NaN
# TTTGGAGGTCGCTCGA-1-HCAHeart8102862-Sanger-CD45              NaN
# TTTGGTTTCAGTGTTG-1-HCAHeart8102862-Sanger-CD45              NaN
# TTTGTTGAGTCGCCCA-1-HCAHeart8102862-Sanger-CD45              NaN
#
#                                                    annotation_broad  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...         Monocyte
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...           T CD8+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...           T CD4+
# ...                                                             ...
# TTTGATCGTGTCATGT-1-HCAHeart8102
# TTTGTTGAGTCGCCCA-1-HCAHeart8102862-Sanger-CD45      Female  Yes     AX
#
#                                                          scNym  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...         NaN
# ...                                                        ...
# TTTGATCGTGTCATGT-1-HCAHeart8102862-Sanger-CD45      CD8+T_cell
# TTTGATCGTTCTCCTG-1-HCAHeart8102862-Sanger-CD45      CD8+T_cell
# TTTGGAGGTCGCTCGA-1-HCAHeart8102862-Sanger-CD45              M3
# TTTGGTTTCAGTGTTG-1-HCAHeart8102862-Sanger-CD45              MØ
# TTTGTTGAGTCGCCCA-1-HCAHeart8102862-Sanger-CD45              MØ
#
#                                                     scNym_confidence
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...               NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...               NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...               NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...               NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...               NaN
# ...                                                              ...
# TTTGATCGTGTCATGT-1-HCAHeart8102862-Sanger-CD45              0.756579
# TTTGATCGTTCTCCTG-1-HCAHeart8102862-Sanger-CD45              0.269561
# TTTGGAGGTCGCTCGA-1-HCAHeart8102862-Sanger-CD45              0.585436
# TTTGGTTTCAGTGTTG-1-HCAHeart8102862-Sanger-CD45              0.968681
# TTTGTTGAGTCGCCCA-1-HCAHeart8102862-Sanger-CD45              0.998978
#
# [214552 rows x 15 columns]

# %%
reference
# Out:
# AnnData object with n_obs × n_vars = 214552 × 33514
#     obs: 'COVID_status', 'annotation_broad', 'annotation_detailed', 'n_counts', 'n_genes', 'age_group', 'donor', 'sample', 'cell_source', 'cell_states', 'gender', 'NRP', 'region', 'scNym', 'scNym_confidence'
#     var: 'name-Yoshida'

# %%
X_is_raw(reference)
# Out:
# True

# %%
reference.obs['seed_labels'] = reference.obs['cell_states'].copy()

# %%
reference.obs['cell_states'].cat.categories
# Out:
# Index(['AS-DC', 'B invariant', 'B naive', 'B naive IFN stim',
#        'B non-switched mem', 'B non-switched mem IFN stim', 'B switched mem',
#        'B_cells', 'Basophils & Eosinophils', 'CD4+T_cytox', 'CD4+T_tem',
#        'CD8+T_cytox', 'CD8+T_tem', 'CD14+Mo', 'CD16+Mo', 'Classical monocyte',
#        'Classical monocyte IFN stim', 'Classical monocyte IL6+', 'Cycling',
#        'DC', 'DOCK4+MØ1', 'DOCK4+MØ2', 'Hematopoietic progenitors',
#        'Hematopoietic progenitors IFN stim', 'IL17RA+Mo', 'ILC', 'LYVE1+MØ1',
#        'LYVE1+MØ2', 'LYVE1+MØ3', 'MAIT', 'Mast', 'Mo_pi', 'MØ_AgP', 'MØ_mod',
#        'NK', 'NK CD56 bright', 'NK IFN stim', 'NKT', 'Non-classical monocyte',
#        'Non-classical monocyte IFN stim', 'Non-classical monocyte complement+',
#        'NØ', 'Plasma cells', 'Plasmablasts', 'Platelets', 'Red blood cells',
#        'T CD4 CTL', 'T CD4 helper', 'T CD4 naive', 'T CD4 naive IFN stim',
#        'T CD8 CTL', 'T CD8 CTL IFN stim', 'T CD8 central mem',
#        'T CD8 effector mem', 'T CD8 effector mem CD45RA+', 'T CD8 naive',
#        'T gamma/delta', 'T regulatory', 'cDC1', 'cDC2', 'doublets', 'pDC'],
#       dtype='object')

# %%
trans_from = [['T CD4 naive IFN stim', 'T CD4 CTL', 'T CD4 helper','T CD4 naive','CD4+T_cytox', 'CD4+T_tem'],             #CD4
              ['T CD8 CTL IFN stim', 'MAIT', 'T CD8 CTL', 'T CD8 effector mem CD45RA+', 'T CD8 effector mem', 'T CD8 central mem', 'T CD8 naive', 'CD8+T_tem', 'CD8+T_cytox'],             #CD8
              ['T regulatory', 'T gamma/delta'],                                               #Treg
              ['NK IFN stim', 'NK CD56 bright', 'NK'],                                         #NK
              ['NKT'],                                                                         #NKT
              ['ILC'],                                                                         #ILC   
              ['Non-classical monocyte IFN stim', 'Classical monocyte IFN stim', 'Non-classical monocyte complement+', 'Non-classical monocyte', 'Classical monocyte IL6+', 'Classical monocyte', 'CD16+Mo', 'CD14+Mo', 'Mo_pi', 'IL17RA+Mo'],             #Monocytes
              ['DOCK4+MØ1','LYVE1+MØ1', 'LYVE1+MØ2', 'LYVE1+MØ3', 'DOCK4+MØ2', 'MØ_mod', 'MØ_AgP'],                #Macrophages
              ['B non-switched mem IFN stim', 'B naive IFN stim', 'B invariant', 'B switched mem', 'B non-switched mem', 'B naive', 'B_cells'],             #B cells
              ['Mast'],                                                                         #Mast_cells
              ['pDC'],                                                                         #pDCs
              ['cDC2', 'cDC1', 'AS-DC', 'DC'],                                                       #DC
              ['Plasmablasts', 'Plasma cells'],                                                #Plasma cells
              ['Hematopoietic progenitors IFN stim', 'Red blood cells', 'Cycling','Hematopoietic progenitors'],  #Hematopoetic
              ['Platelets'],                                                                   #Platelets
              ['Basophils & Eosinophils'],                                                      #Basophils_Eosinophils
              ['NØ'],                                                                           #Neutrophils
              ['doublets']]                                                                    #Doublets

trans_to = ['CD4+T', 'CD8+T', 'Treg', 'NK', 'NKT', 'ILC','Monocytes', 'Macrophages', 'B_cells', 'Mast_cells', 'pDC', 'DC', 'Plasma_cells', 'Hematopoetic', 'Platelets','Baso_Eosino', 'Neutrophils', 'Doublets']

reference.obs['seed_labels'] = [str(i) for i in reference.obs['cell_states']]
for leiden,celltype in zip(trans_from, trans_to):
    for leiden_from in leiden:
        reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# Out:
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype
# /var/folders/gv/f1jp14394j18ml09qq30lpv80000gn/T/ipykernel_8816/2223439336.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reference.obs['seed_labels'][reference.obs['seed_labels'] == leiden_from] = celltype

# %%
reference.obs['seed_labels'].value_counts()
# Out:
# seed_labels
# CD4+T           53575
# CD8+T           42060
# Monocytes       35482
# B_cells         27327
# NK              25499
# Macrophages     14519
# Treg             6434
# DC               2259
# NKT              1683
# Mast_cells       1543
# Hematopoetic     1534
# pDC               706
# Platelets         626
# Doublets          623
# Plasma_cells      352
# ILC               199
# Neutrophils       121
# Baso_Eosino        10
# Name: count, dtype: int64

# %%
X_is_raw(reference)
# Out:
# True

# %% [markdown]
# ## Save merged object

# %%
reference.write("/Users/alex/data/ACM_cardiac_leuco/Reference_data/Merged_healthy_reference_PBMC_Heart_ac240222.raw.h5ad")
