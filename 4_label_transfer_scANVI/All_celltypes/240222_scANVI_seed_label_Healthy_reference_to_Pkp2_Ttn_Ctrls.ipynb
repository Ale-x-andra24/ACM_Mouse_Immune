# %% [markdown]
# ### Notebook for the label transfer of Healthy Human Reference to mouse ACM heart (merged Pkp2+Ttn dataset) using `scANVI`
#
# #### Environment: scANVI
#
# - **Developed by:** Carlos Talavera-López Ph.D
# - **Modified by:** Alexandra Cirnu
# - **Würzburg Institute for Systems Immunology & Julius-Maximilian-Universität Würzburg**
# - **Date of creation:** 230918
# - **Date of modification:** 240226
#
# Yoshida PBMC dataset (subsetted to contain only healthy donors) and healthy human heart leucocytes (from Human cell atlas) were combined to generate a reference for seed labelling

# %% [markdown]
# ### Import required modules

# %%
import scvi
import torch
import anndata
import warnings
import numpy as np
import scanpy as sc
import pandas as pd
import plotnine as p
from pywaffle import Waffle
import matplotlib.pyplot as plt
#from scib_metrics.benchmark import Benchmarker

# %% [markdown]
# ### Set up working environment

# %%
sc.settings.verbosity = 3
sc.logging.print_versions()
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# Out:
# -----
# anndata     0.10.5.post1
# scanpy      1.9.8
# -----
# PIL                 9.4.0
# absl                NA
# asttokens           NA
# attr                23.2.0
# chex                0.1.85
# colorama            0.4.6
# comm                0.2.1
# contextlib2         NA
# cycler              0.12.1
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.8.1
# decorator           5.1.1
# docrep              0.3.2
# etils               1.7.0
# exceptiongroup      1.2.0
# executing           2.0.1
# flax                0.8.1
# fsspec              2024.2.0
# h5py                3.10.0
# importlib_resources NA
# ipykernel           6.29.2
# ipywidgets          8.1.2
# jax                 0.4.24
# jaxlib              0.4.24
# jedi                0.19.1
# joblib              1.3.2
# kiwisolver          1.4.5
# lightning           2.1.4
# lightning_utilities 0.10.1
# llvmlite            0.42.0
# matplotlib          3.8.3
# mizani              0.9.3
# ml_collections      NA
# ml_dtypes           0.3.2
# mpl_toolkits        NA
# msgpack             1.0.7
# mudata              0.2.3
# multipledispatch    0.6.0
# natsort             8.4.0
# numba               0.59.0
# numpy               1.26.4
# numpyro             0.13.2
# opt_einsum          v3.3.0
# optax               0.1.9
# packaging           23.2
# pandas              2.2.0
# parso               0.8.3
# pkg_resources       NA
# platformdirs        4.2.0
# plotnine            0.12.4
# prompt_toolkit      3.0.43
# psutil              5.9.8
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.17.2
# pyparsing           3.1.1
# pyro                1.9.0
# pytz                2024.1
# pywaffle            NA
# rich                NA
# scipy               1.12.0
# scvi                1.1.1
# session_info        1.0.0
# six                 1.16.0
# sklearn             1.4.1.post1
# stack_data          0.6.3
# threadpoolctl       3.3.0
# toolz               0.12.1
# torch               2.2.0
# torchgen            NA
# torchmetrics        1.3.1
# tornado             6.4
# tqdm                4.66.2
# traitlets           5.14.1
# typing_extensions   NA
# wcwidth             0.2.13
# yaml                6.0.1
# zmq                 25.1.2
# zoneinfo            NA
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-6.6.14-100.fc38.x86_64-x86_64-with-glibc2.37
# -----
# Session information updated at 2024-02-26 10:57

# %%
def X_is_raw(adata): return np.array_equal(adata.X.sum(axis=0).astype(int), adata.X.sum(axis=0))

# %%
torch.set_float32_matmul_precision('high')

# %%
warnings.simplefilter(action = 'ignore')
scvi.settings.seed = 1712
# %config InlineBackend.print_figure_kwargs = {'facecolor' : "w"}
# %config InlineBackend.figure_format = 'retina'
# Out:
# Seed set to 1712

# %%
arches_params = dict(
    use_layer_norm = "both",
    use_batch_norm = "none",
    encode_covariates = True,
    dropout_rate = 0.2,
    n_layers = 2,
)

# %% [markdown]
# ### Read in Healthy data

# %%
#Merged Healthy reference = Yoshida_PBMC_data_from_healthy_human_donors + Human_Cell_Atlas_Cardiac_leucocytes_from_healthy_human_donors

reference = sc.read_h5ad('/home/acirnu/data/ACM_cardiac_leuco/Reference_data/Merged_healthy_reference_PBMC_Heart_ac240222.raw.h5ad')
reference
# Out:
# AnnData object with n_obs × n_vars = 214552 × 33514
#     obs: 'COVID_status', 'annotation_broad', 'annotation_detailed', 'n_counts', 'n_genes', 'age_group', 'donor', 'sample', 'cell_source', 'cell_states', 'gender', 'NRP', 'region', 'scNym', 'scNym_confidence', 'seed_labels'
#     var: 'name-Yoshida'

# %%
X_is_raw(reference)
# Out:
# True

# %%
reference.obs['seed_labels'].value_counts()             #seed_labels, that we want to transfer to unannotated data set
# Out:
# seed_labels
# CD4+T           53575
# CD8+T           42060
# Monocytes       35482
# B_cells         27327
# NK              25499
# Macrophages     14519
# Treg             6434
# DC               2259
# NKT              1683
# Mast_cells       1543
# Hematopoetic     1534
# pDC               706
# Platelets         626
# Doublets          623
# Plasma_cells      352
# ILC               199
# Neutrophils       121
# Baso_Eosino        10
# Name: count, dtype: int64

# %%
reference.obs['seed_labels'].cat.categories
# Out:
# Index(['B_cells', 'Baso_Eosino', 'CD4+T', 'CD8+T', 'DC', 'Doublets',
#        'Hematopoetic', 'ILC', 'Macrophages', 'Mast_cells', 'Monocytes', 'NK',
#        'NKT', 'Neutrophils', 'Plasma_cells', 'Platelets', 'Treg', 'pDC'],
#       dtype='object')

# %% [markdown]
# ### Subset populations of interest

# %%
reference = reference[~reference.obs['seed_labels'].isin(['nan'])]              # = filter out not assigned cells, keep everything that is not 'nan'
reference.obs['seed_labels'].value_counts()
# Out:
# seed_labels
# CD4+T           53575
# CD8+T           42060
# Monocytes       35482
# B_cells         27327
# NK              25499
# Macrophages     14519
# Treg             6434
# DC               2259
# NKT              1683
# Mast_cells       1543
# Hematopoetic     1534
# pDC               706
# Platelets         626
# Doublets          623
# Plasma_cells      352
# ILC               199
# Neutrophils       121
# Baso_Eosino        10
# Name: count, dtype: int64

# %%
sc.pp.filter_cells(reference, min_genes = 200)              #to remove empty cells from table
sc.pp.filter_cells(reference, min_counts = 100)
# Out:
# filtered out 1 cells that have less than 200 genes expressed

# %% [markdown]
# ### Read in other query

# %%
#Merged Pkp2+Ttn Libraries subsetted to contain only control mice (Pkp_Ctr_noninf and Ttn_Ctr_noninf)

query = sc.read_h5ad('/home/acirnu/data/ACM_cardiac_leuco/processed_merged/Merge+Subset_Ctrls_demux_QCed_ac240221.raw.h5ad')
query.obs['cell_source'] = 'AG_Gerull'
query.obs['seed_labels'] = 'Unknown'
query.obs['donor'] = query.obs['sample'].copy()
query
# Out:
# AnnData object with n_obs × n_vars = 7847 × 32285
#     obs: 'sample', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'cell_source', 'seed_labels', 'donor'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'
#     layers: 'counts', 'sqrt_norm'

# %%
X_is_raw(query)
# Out:
# True

# %%
sc.pp.filter_cells(query, min_genes = 200)
sc.pp.filter_cells(query, min_counts = 100)

# %% [markdown]
# ### Change gene symbols for label transfer

# %%
query.var_names = [gene_name.upper() for gene_name in query.var_names]                      #capitalize gene names to match with the human genes from reference
query.var_names
# Out:
# Index(['XKR4', 'GM1992', 'GM19938', 'GM37381', 'RP1', 'SOX17', 'GM37587',
#        'GM37323', 'MRPL15', 'LYPLA1',
#        ...
#        'GM16367', 'AC163611.1', 'AC163611.2', 'AC140365.1', 'AC124606.2',
#        'AC124606.1', 'AC133095.2', 'AC133095.1', 'AC234645.1', 'AC149090.1'],
#       dtype='object', length=32285)

# %%
adata = reference.concatenate(query, batch_key = 'batch', batch_categories = ['reference', 'query'], join = 'inner')                #merge to one adata object
adata
# Out:
# AnnData object with n_obs × n_vars = 222398 × 16209
#     obs: 'COVID_status', 'annotation_broad', 'annotation_detailed', 'n_counts', 'n_genes', 'age_group', 'donor', 'sample', 'cell_source', 'cell_states', 'gender', 'NRP', 'region', 'scNym', 'scNym_confidence', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'batch'
#     var: 'gene_ids-query', 'feature_types-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-A1-query', 'mean_counts-A1-query', 'pct_dropout_by_counts-A1-query', 'total_counts-A1-query', 'n_cells_by_counts-A2-query', 'mean_counts-A2-query', 'pct_dropout_by_counts-A2-query', 'total_counts-A2-query', 'n_cells_by_counts-A3-query', 'mean_counts-A3-query', 'pct_dropout_by_counts-A3-query', 'total_counts-A3-query', 'n_cells_by_counts-A4-query', 'mean_counts-A4-query', 'pct_dropout_by_counts-A4-query', 'total_counts-A4-query', 'n_cells_by_counts-B1-query', 'mean_counts-B1-query', 'pct_dropout_by_counts-B1-query', 'total_counts-B1-query', 'n_cells_by_counts-B2-query', 'mean_counts-B2-query', 'pct_dropout_by_counts-B2-query', 'total_counts-B2-query', 'name-Yoshida-reference'

# %%
adata.obs['seed_labels'] = adata.obs['seed_labels'].astype('category')
adata.obs['seed_labels'].cat.categories
# Out:
# Index(['B_cells', 'Baso_Eosino', 'CD4+T', 'CD8+T', 'DC', 'Doublets',
#        'Hematopoetic', 'ILC', 'Macrophages', 'Mast_cells', 'Monocytes', 'NK',
#        'NKT', 'Neutrophils', 'Plasma_cells', 'Platelets', 'Treg', 'Unknown',
#        'pDC'],
#       dtype='object')

# %%
adata.obs['batch'].value_counts()
# Out:
# batch
# reference    214551
# query          7847
# Name: count, dtype: int64

# %% [markdown]
# ### Select HVGs

# %%
adata.obs['donor'] = adata.obs['donor'].astype('str') 
adata.obs['donor'].value_counts()
# Out:
# donor
# NP18                 9799
# D6                   9362
# NP13                 8945
# D7                   8461
# AN13                 8244
# NP23                 8038
# NP24                 7376
# AN12                 7219
# AN7                  7105
# NP19                 7050
# NP28                 6894
# NP17                 6377
# NP39                 6115
# AN2                  5973
# NP44                 5906
# NP36                 5891
# D11                  5635
# NP22                 5535
# NP27                 5300
# NP31                 5029
# NP21                 4833
# NP37                 4654
# AN6                  4296
# AN9                  4150
# AN5                  3943
# NP30                 3916
# NP41                 3898
# NP32                 3778
# NP15                 3700
# NP26                 3539
# NP20                 3374
# NP38                 3218
# H2                   2655
# AN14                 2260
# D3                   2119
# D2                   2034
# H3                   1965
# NP16                 1851
# AN11                 1847
# Ttn_Ctr_noninf_1     1821
# H7                   1799
# NP35                 1674
# Pkp2_Ctr_noninf_2    1649
# Ttn_Ctr_noninf_2     1548
# H5                   1473
# H6                   1366
# H4                   1278
# Pkp2_Ctr_noninf_4    1236
# D5                   1138
# D4                   1120
# AN3                  1041
# AN1                   915
# Pkp2_Ctr_noninf_3     909
# Pkp2_Ctr_noninf_1     684
# D1                    463
# Name: count, dtype: int64

# %%
adata_raw = adata.copy()
adata.layers['counts'] = adata.X.copy()

sc.pp.highly_variable_genes(
    adata,
    flavor = "seurat_v3",
    n_top_genes = 7000,
    layer = "counts",
    batch_key = "donor",
    subset = True,
    span = 1
    )

adata
# Out:
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'highly_variable_rank', float vector (adata.var)
#     'means', float vector (adata.var)
#     'variances', float vector (adata.var)
#     'variances_norm', float vector (adata.var)
# AnnData object with n_obs × n_vars = 222398 × 7000
#     obs: 'COVID_status', 'annotation_broad', 'annotation_detailed', 'n_counts', 'n_genes', 'age_group', 'donor', 'sample', 'cell_source', 'cell_states', 'gender', 'NRP', 'region', 'scNym', 'scNym_confidence', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'batch'
#     var: 'gene_ids-query', 'feature_types-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-A1-query', 'mean_counts-A1-query', 'pct_dropout_by_counts-A1-query', 'total_counts-A1-query', 'n_cells_by_counts-A2-query', 'mean_counts-A2-query', 'pct_dropout_by_counts-A2-query', 'total_counts-A2-query', 'n_cells_by_counts-A3-query', 'mean_counts-A3-query', 'pct_dropout_by_counts-A3-query', 'total_counts-A3-query', 'n_cells_by_counts-A4-query', 'mean_counts-A4-query', 'pct_dropout_by_counts-A4-query', 'total_counts-A4-query', 'n_cells_by_counts-B1-query', 'mean_counts-B1-query', 'pct_dropout_by_counts-B1-query', 'total_counts-B1-query', 'n_cells_by_counts-B2-query', 'mean_counts-B2-query', 'pct_dropout_by_counts-B2-query', 'total_counts-B2-query', 'name-Yoshida-reference', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg'
#     layers: 'counts'

# %% [markdown]
# ### Transfer of annotation with scANVI

# %%
scvi.model.SCVI.setup_anndata(adata, 
                              batch_key = 'donor', 
                              labels_key = 'seed_labels',
                              layer = 'counts',
                              categorical_covariate_keys = ['donor', 'cell_source'])
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
scvi_model = scvi.model.SCVI(adata, 
                             n_latent = 50, 
                             n_layers = 3, 
                             dispersion = 'gene-batch', 
                             gene_likelihood = 'nb')

# %%
scvi_model.train(15, 
                 check_val_every_n_epoch = 1, 
                 enable_progress_bar = True,
                 accelerator = "gpu",
                 devices = [1]                                        
                 )
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Epoch 15/15: 100%|██████████| 15/15 [02:25<00:00,  8.68s/it, v_num=1, train_loss_step=2.05e+3, train_loss_epoch=2.14e+3]
# `Trainer.fit` stopped: `max_epochs=15` reached.
# Epoch 15/15: 100%|██████████| 15/15 [02:25<00:00,  9.72s/it, v_num=1, train_loss_step=2.05e+3, train_loss_epoch=2.14e+3]

# %% [markdown]
# ### Evaluate model performance a la _Sevensson_

# %%
history_df = (
    scvi_model.history['elbo_train'].astype(float)
    .join(scvi_model.history['elbo_validation'].astype(float))
    .reset_index()
    .melt(id_vars = ['epoch'])
)

p.options.figure_size = 12, 6

p_ = (
    p.ggplot(p.aes(x = 'epoch', y = 'value', color = 'variable'), history_df.query('epoch > 0'))
    + p.geom_line()
    + p.geom_point()
    + p.scale_color_manual({'elbo_train': 'black', 'elbo_validation': 'red'})
    + p.theme_minimal()
)

p_.save('fig1.png', dpi = 300)

print(p_)

# %% [markdown]
# ### Label transfer with `scANVI`

# %%
scanvi_model = scvi.model.SCANVI.from_scvi_model(scvi_model, 'Unknown')

# %%
scanvi_model.train(14, 
                   check_val_every_n_epoch = 1, 
                   enable_progress_bar = True,
                   accelerator = "gpu",
                   devices = [1]                            
)
# Out:
# INFO     Training for 14 epochs.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Epoch 14/14: 100%|██████████| 14/14 [05:51<00:00, 26.27s/it, v_num=1, train_loss_step=2.14e+3, train_loss_epoch=2.13e+3]
# `Trainer.fit` stopped: `max_epochs=14` reached.
# Epoch 14/14: 100%|██████████| 14/14 [05:51<00:00, 25.10s/it, v_num=1, train_loss_step=2.14e+3, train_loss_epoch=2.13e+3]

# %% [markdown]
# ### Evaluate model performance a la Svensson

# %%
history_df = (
    scanvi_model.history['elbo_train'].astype(float)
    .join(scanvi_model.history['elbo_validation'].astype(float))
    .reset_index()
    .melt(id_vars = ['epoch'])
)

p.options.figure_size = 12, 6

p_ = (
    p.ggplot(p.aes(x = 'epoch', y = 'value', color = 'variable'), history_df.query('epoch > 0'))
    + p.geom_line()
    + p.geom_point()
    + p.scale_color_manual({'elbo_train': 'black', 'elbo_validation': 'red'})
    + p.theme_minimal()
)

p_.save('fig2.png', dpi = 300)

print(p_)

# %%
adata.obs["C_scANVI"] = scanvi_model.predict(adata)

# %% [markdown]
# - Extract latent representation

# %%
adata.obsm["X_scANVI"] = scanvi_model.get_latent_representation(adata)

# %%
adata.obs
# Out:
#                                                    COVID_status  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...      Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...      Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...      Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...      Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...      Healthy
# ...                                                         ...
# TTTGGTTCACGCAGTC-1-B2-query                                 NaN
# TTTGGTTTCCTGTACC-1-B2-query                                 NaN
# TTTGTTGCAAGCTCTA-1-B2-query                                 NaN
# TTTGTTGTCCCAGGAC-1-B2-query                                 NaN
# TTTGTTGTCCGGGACT-1-B2-query                                 NaN
#
#                                                    annotation_broad  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...         Monocyte
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...           T CD8+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...           T CD4+
# ...                                                             ...
# TTTGGTTCACGCAGTC-1-B2-query                                     NaN
# TTTGGTTTCCTGTACC-1-B2-query                                     NaN
# TTTGTTGCAAGCTCTA-1-B2-query                                     NaN
# TTTGTTGTCCCAGGAC-1-B2-query                                     NaN
# TTTGTTGTCCGGGACT-1-B2-query                                     NaN
#
#                                                    annotation_detailed  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...       Monocyte CD14
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...         T CD8 naive
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...         T CD4 naive
# ...                                                                ...
# TTTGGTTCACGCAGTC-1-B2-query                                        NaN
# TTTGGTTTCCTGTACC-1-B2-query                                        NaN
# TTTGTTGCAAGCTCTA-1-B2-query                                        NaN
# TTTGTTGTCCCAGGAC-1-B2-query                                        NaN
# TTTGTTGTCCGGGACT-1-B2-query                                        NaN
#
#                                                     n_counts  n_genes  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...    5493.0     1767
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...    4866.0     1575
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...    3176.0     1255
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...    4743.0     1476
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...    1902.0      954
# ...                                                      ...      ...
# TTTGGTTCACGCAGTC-1-B2-query                          18844.0     4219
# TTTGGTTTCCTGTACC-1-B2-query                          11805.0     3321
# TTTGTTGCAAGCTCTA-1-B2-query                           3733.0     1849
# TTTGTTGTCCCAGGAC-1-B2-query                           6388.0     2559
# TTTGTTGTCCGGGACT-1-B2-query                          10124.0     3333
#
#                                                    age_group  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...     Adult
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...     Adult
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...     Adult
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...     Adult
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...     Adult
# ...                                                      ...
# TTTGGTTCACGCAGTC-1-B2-query                              NaN
# TTTGGTTTCCTGTACC-1-B2-query                              NaN
# TTTGTTGCAAGCTCTA-1-B2-query                              NaN
# TTTGTTGTCCCAGGAC-1-B2-query                              NaN
# TTTGTTGTCCGGGACT-1-B2-query                              NaN
#
#                                                                donor  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...               AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...               AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...               AN3
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...               AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...               AN5
# ...                                                              ...
# TTTGGTTCACGCAGTC-1-B2-query                         Ttn_Ctr_noninf_2
# TTTGGTTTCCTGTACC-1-B2-query                         Ttn_Ctr_noninf_2
# TTTGTTGCAAGCTCTA-1-B2-query                         Ttn_Ctr_noninf_1
# TTTGTTGTCCCAGGAC-1-B2-query                         Ttn_Ctr_noninf_2
# TTTGTTGTCCGGGACT-1-B2-query                         Ttn_Ctr_noninf_2
#
#                                                               sample  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...               AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...               AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...               AN3
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...               AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...               AN5
# ...                                                              ...
# TTTGGTTCACGCAGTC-1-B2-query                         Ttn_Ctr_noninf_2
# TTTGGTTTCCTGTACC-1-B2-query                         Ttn_Ctr_noninf_2
# TTTGTTGCAAGCTCTA-1-B2-query                         Ttn_Ctr_noninf_1
# TTTGTTGTCCCAGGAC-1-B2-query                         Ttn_Ctr_noninf_2
# TTTGTTGTCCGGGACT-1-B2-query                         Ttn_Ctr_noninf_2
#
#                                                    cell_source  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...     Yoshida
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...     Yoshida
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...     Yoshida
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...     Yoshida
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...     Yoshida
# ...                                                        ...
# TTTGGTTCACGCAGTC-1-B2-query                          AG_Gerull
# TTTGGTTTCCTGTACC-1-B2-query                          AG_Gerull
# TTTGTTGCAAGCTCTA-1-B2-query                          AG_Gerull
# TTTGTTGTCCCAGGAC-1-B2-query                          AG_Gerull
# TTTGTTGTCCGGGACT-1-B2-query                          AG_Gerull
#
#                                                            cell_states  ...  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  Classical monocyte  ...
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        T CD4 helper  ...
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        T CD4 helper  ...
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...         T CD8 naive  ...
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...         T CD4 naive  ...
# ...                                                                ...  ...
# TTTGGTTCACGCAGTC-1-B2-query                                        NaN  ...
# TTTGGTTTCCTGTACC-1-B2-query                                        NaN  ...
# TTTGTTGCAAGCTCTA-1-B2-query                                        NaN  ...
# TTTGTTGTCCCAGGAC-1-B2-query                                        NaN  ...
# TTTGTTGTCCGGGACT-1-B2-query                                        NaN  ...
#
#                                                    pct_counts_ribo percent_mt  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...             NaN        NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...             NaN        NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...             NaN        NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...             NaN        NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...             NaN        NaN
# ...                                                            ...        ...
# TTTGGTTCACGCAGTC-1-B2-query                              15.219699   0.036245
# TTTGGTTTCCTGTACC-1-B2-query                              12.443880   0.022279
# TTTGTTGCAAGCTCTA-1-B2-query                               5.062952   0.017412
# TTTGTTGTCCCAGGAC-1-B2-query                               7.247965   0.023168
# TTTGTTGTCCGGGACT-1-B2-query                               5.432635   0.018372
#
#                                                    percent_chrY XIST-counts  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...          NaN         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...          NaN         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...          NaN         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...          NaN         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...          NaN         NaN
# ...                                                         ...         ...
# TTTGGTTCACGCAGTC-1-B2-query                            0.000000         0.0
# TTTGGTTTCCTGTACC-1-B2-query                            0.025413         1.0
# TTTGTTGCAAGCTCTA-1-B2-query                            0.000000         0.0
# TTTGTTGTCCCAGGAC-1-B2-query                            0.140889         0.0
# TTTGTTGTCCGGGACT-1-B2-query                            0.000000         0.0
#
#                                                      S_score G2M_score  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...       NaN       NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...       NaN       NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...       NaN       NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...       NaN       NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...       NaN       NaN
# ...                                                      ...       ...
# TTTGGTTCACGCAGTC-1-B2-query                        -0.901389 -1.291862
# TTTGGTTTCCTGTACC-1-B2-query                        -0.277671 -0.184796
# TTTGTTGCAAGCTCTA-1-B2-query                        -0.179842 -0.495021
# TTTGTTGTCCCAGGAC-1-B2-query                         0.080642 -0.877899
# TTTGTTGTCCGGGACT-1-B2-query                        -0.865321 -0.612683
#
#                                                         batch _scvi_batch  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  reference           7
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...  reference           7
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...  reference           6
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...  reference           7
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...  reference           7
# ...                                                       ...         ...
# TTTGGTTCACGCAGTC-1-B2-query                             query          54
# TTTGGTTTCCTGTACC-1-B2-query                             query          54
# TTTGTTGCAAGCTCTA-1-B2-query                             query          53
# TTTGTTGTCCCAGGAC-1-B2-query                             query          54
# TTTGTTGTCCGGGACT-1-B2-query                             query          54
#
#                                                    _scvi_labels     C_scANVI
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...           10    Monocytes
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...            2        CD4+T
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...            2        CD4+T
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...            3        CD8+T
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...            2        CD4+T
# ...                                                         ...          ...
# TTTGGTTCACGCAGTC-1-B2-query                                  18  Macrophages
# TTTGGTTTCCTGTACC-1-B2-query                                  18  Macrophages
# TTTGTTGCAAGCTCTA-1-B2-query                                  18  Macrophages
# TTTGTTGTCCCAGGAC-1-B2-query                                  18  Macrophages
# TTTGTTGTCCGGGACT-1-B2-query                                  18  Macrophages
#
# [222398 rows x 37 columns]

# %% [markdown]
# - Visualise corrected dataset

# %%
sc.pp.neighbors(adata, use_rep = "X_scANVI", n_neighbors = 50, metric = 'minkowski')
sc.tl.umap(adata, min_dist = 0.3, spread = 4, random_state = 1712)
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:01:17)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:02:12)

# %%
sc.pl.umap(adata, frameon = False, color = ['C_scANVI', 'seed_labels', 'condition', 'batch', 'model'], size = 1, legend_fontsize = 5, ncols = 1)

# %% [markdown]
# ### Export annotated object

# %%
adata_export_merged = anndata.AnnData(X = adata_raw.X, var = adata_raw.var, obs = adata.obs)            #export a merged AnnData object with raw values from X and raw genes but modified observations
adata_export_merged
# Out:
# AnnData object with n_obs × n_vars = 222398 × 16209
#     obs: 'COVID_status', 'annotation_broad', 'annotation_detailed', 'n_counts', 'n_genes', 'age_group', 'donor', 'sample', 'cell_source', 'cell_states', 'gender', 'NRP', 'region', 'scNym', 'scNym_confidence', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'batch', '_scvi_batch', '_scvi_labels', 'C_scANVI'
#     var: 'gene_ids-query', 'feature_types-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-A1-query', 'mean_counts-A1-query', 'pct_dropout_by_counts-A1-query', 'total_counts-A1-query', 'n_cells_by_counts-A2-query', 'mean_counts-A2-query', 'pct_dropout_by_counts-A2-query', 'total_counts-A2-query', 'n_cells_by_counts-A3-query', 'mean_counts-A3-query', 'pct_dropout_by_counts-A3-query', 'total_counts-A3-query', 'n_cells_by_counts-A4-query', 'mean_counts-A4-query', 'pct_dropout_by_counts-A4-query', 'total_counts-A4-query', 'n_cells_by_counts-B1-query', 'mean_counts-B1-query', 'pct_dropout_by_counts-B1-query', 'total_counts-B1-query', 'n_cells_by_counts-B2-query', 'mean_counts-B2-query', 'pct_dropout_by_counts-B2-query', 'total_counts-B2-query', 'name-Yoshida-reference'

# %%
adata_export = adata_export_merged[adata_export_merged.obs['batch'].isin(['query'])]                    #subset merged data set to keep only query
adata_export
# Out:
# View of AnnData object with n_obs × n_vars = 7847 × 16209
#     obs: 'COVID_status', 'annotation_broad', 'annotation_detailed', 'n_counts', 'n_genes', 'age_group', 'donor', 'sample', 'cell_source', 'cell_states', 'gender', 'NRP', 'region', 'scNym', 'scNym_confidence', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'batch', '_scvi_batch', '_scvi_labels', 'C_scANVI'
#     var: 'gene_ids-query', 'feature_types-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-A1-query', 'mean_counts-A1-query', 'pct_dropout_by_counts-A1-query', 'total_counts-A1-query', 'n_cells_by_counts-A2-query', 'mean_counts-A2-query', 'pct_dropout_by_counts-A2-query', 'total_counts-A2-query', 'n_cells_by_counts-A3-query', 'mean_counts-A3-query', 'pct_dropout_by_counts-A3-query', 'total_counts-A3-query', 'n_cells_by_counts-A4-query', 'mean_counts-A4-query', 'pct_dropout_by_counts-A4-query', 'total_counts-A4-query', 'n_cells_by_counts-B1-query', 'mean_counts-B1-query', 'pct_dropout_by_counts-B1-query', 'total_counts-B1-query', 'n_cells_by_counts-B2-query', 'mean_counts-B2-query', 'pct_dropout_by_counts-B2-query', 'total_counts-B2-query', 'name-Yoshida-reference'

# %% [markdown]
# ### Add new gene symbols

# %%
query_export = anndata.AnnData(X = query.X, var = query.var, obs = adata_export.obs)                    #make sure to store the raw X values and the raw genes together with modified observations
query_export
# Out:
# AnnData object with n_obs × n_vars = 7847 × 32285
#     obs: 'COVID_status', 'annotation_broad', 'annotation_detailed', 'n_counts', 'n_genes', 'age_group', 'donor', 'sample', 'cell_source', 'cell_states', 'gender', 'NRP', 'region', 'scNym', 'scNym_confidence', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'batch', '_scvi_batch', '_scvi_labels', 'C_scANVI'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'

# %% [markdown]
# ### Revert gene symbols

# %%
query_export.var_names = [gene_name.capitalize() for gene_name in query_export.var_names]           #restore mouse nomenclature
query_export.var_names
# Out:
# Index(['Xkr4', 'Gm1992', 'Gm19938', 'Gm37381', 'Rp1', 'Sox17', 'Gm37587',
#        'Gm37323', 'Mrpl15', 'Lypla1',
#        ...
#        'Gm16367', 'Ac163611.1', 'Ac163611.2', 'Ac140365.1', 'Ac124606.2',
#        'Ac124606.1', 'Ac133095.2', 'Ac133095.1', 'Ac234645.1', 'Ac149090.1'],
#       dtype='object', length=32285)

# %%
query_export.obs['C_scANVI'].value_counts()
# Out:
# C_scANVI
# Macrophages     4648
# Monocytes       1338
# DC               453
# CD8+T            418
# B_cells          324
# CD4+T            284
# Neutrophils      130
# Doublets          71
# Platelets         44
# NKT               40
# NK                38
# Hematopoetic      31
# Mast_cells        13
# pDC               12
# Treg               2
# Plasma_cells       1
# Name: count, dtype: int64

# %%
query_export
# Out:
# AnnData object with n_obs × n_vars = 7847 × 32285
#     obs: 'COVID_status', 'annotation_broad', 'annotation_detailed', 'n_counts', 'n_genes', 'age_group', 'donor', 'sample', 'cell_source', 'cell_states', 'gender', 'NRP', 'region', 'scNym', 'scNym_confidence', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'batch', '_scvi_batch', '_scvi_labels', 'C_scANVI'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'

# %%
#Clean up metadata - delete all columns that came from merging with reference data set

del(query_export.obs['COVID_status'])
del(query_export.obs['annotation_broad'])
del(query_export.obs['annotation_detailed'])
del(query_export.obs['age_group'])
del(query_export.obs['cell_states'])
del(query_export.obs['gender'])
del(query_export.obs['NRP'])
del(query_export.obs['region'])
del(query_export.obs['scNym'])
del(query_export.obs['scNym_confidence'])

# %%
query_export.obs
# Out:
#                              n_counts  n_genes              donor  \
# AAACCCAAGATACAGT-1-A1-query    8562.0     2769  Pkp2_Ctr_noninf_2
# AAACGCTGTTGTGTTG-1-A1-query     750.0      365  Pkp2_Ctr_noninf_1
# AAACGCTTCTCGCTCA-1-A1-query    3855.0     1599  Pkp2_Ctr_noninf_1
# AAAGGTACAGAACATA-1-A1-query   17536.0     3854  Pkp2_Ctr_noninf_2
# AAAGTCCAGGGACACT-1-A1-query   14174.0     3788  Pkp2_Ctr_noninf_2
# ...                               ...      ...                ...
# TTTGGTTCACGCAGTC-1-B2-query   18844.0     4219   Ttn_Ctr_noninf_2
# TTTGGTTTCCTGTACC-1-B2-query   11805.0     3321   Ttn_Ctr_noninf_2
# TTTGTTGCAAGCTCTA-1-B2-query    3733.0     1849   Ttn_Ctr_noninf_1
# TTTGTTGTCCCAGGAC-1-B2-query    6388.0     2559   Ttn_Ctr_noninf_2
# TTTGTTGTCCGGGACT-1-B2-query   10124.0     3333   Ttn_Ctr_noninf_2
#
#                                         sample cell_source seed_labels  \
# AAACCCAAGATACAGT-1-A1-query  Pkp2_Ctr_noninf_2   AG_Gerull     Unknown
# AAACGCTGTTGTGTTG-1-A1-query  Pkp2_Ctr_noninf_1   AG_Gerull     Unknown
# AAACGCTTCTCGCTCA-1-A1-query  Pkp2_Ctr_noninf_1   AG_Gerull     Unknown
# AAAGGTACAGAACATA-1-A1-query  Pkp2_Ctr_noninf_2   AG_Gerull     Unknown
# AAAGTCCAGGGACACT-1-A1-query  Pkp2_Ctr_noninf_2   AG_Gerull     Unknown
# ...                                        ...         ...         ...
# TTTGGTTCACGCAGTC-1-B2-query   Ttn_Ctr_noninf_2   AG_Gerull     Unknown
# TTTGGTTTCCTGTACC-1-B2-query   Ttn_Ctr_noninf_2   AG_Gerull     Unknown
# TTTGTTGCAAGCTCTA-1-B2-query   Ttn_Ctr_noninf_1   AG_Gerull     Unknown
# TTTGTTGTCCCAGGAC-1-B2-query   Ttn_Ctr_noninf_2   AG_Gerull     Unknown
# TTTGTTGTCCGGGACT-1-B2-query   Ttn_Ctr_noninf_2   AG_Gerull     Unknown
#
#                                    condition  genotype infection library  ...  \
# AAACCCAAGATACAGT-1-A1-query  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf      A1  ...
# AAACGCTGTTGTGTTG-1-A1-query  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf      A1  ...
# AAACGCTTCTCGCTCA-1-A1-query  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf      A1  ...
# AAAGGTACAGAACATA-1-A1-query  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf      A1  ...
# AAAGTCCAGGGACACT-1-A1-query  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf      A1  ...
# ...                                      ...       ...       ...     ...  ...
# TTTGGTTCACGCAGTC-1-B2-query   Ttn_Ctr_noninf   Ttn_Ctr    noninf      B2  ...
# TTTGGTTTCCTGTACC-1-B2-query   Ttn_Ctr_noninf   Ttn_Ctr    noninf      B2  ...
# TTTGTTGCAAGCTCTA-1-B2-query   Ttn_Ctr_noninf   Ttn_Ctr    noninf      B2  ...
# TTTGTTGTCCCAGGAC-1-B2-query   Ttn_Ctr_noninf   Ttn_Ctr    noninf      B2  ...
# TTTGTTGTCCGGGACT-1-B2-query   Ttn_Ctr_noninf   Ttn_Ctr    noninf      B2  ...
#
#                             pct_counts_ribo  percent_mt  percent_chrY  \
# AAACCCAAGATACAGT-1-A1-query       23.662696    0.019038      0.000000
# AAACGCTGTTGTGTTG-1-A1-query        4.533333    0.346667      0.000000
# AAACGCTTCTCGCTCA-1-A1-query        1.815824    0.043320      0.025940
# AAAGGTACAGAACATA-1-A1-query       10.213276    0.027315      0.051323
# AAAGTCCAGGGACACT-1-A1-query       14.456046    0.023282      0.014110
# ...                                     ...         ...           ...
# TTTGGTTCACGCAGTC-1-B2-query       15.219699    0.036245      0.000000
# TTTGGTTTCCTGTACC-1-B2-query       12.443880    0.022279      0.025413
# TTTGTTGCAAGCTCTA-1-B2-query        5.062952    0.017412      0.000000
# TTTGTTGTCCCAGGAC-1-B2-query        7.247965    0.023168      0.140889
# TTTGTTGTCCGGGACT-1-B2-query        5.432635    0.018372      0.000000
#
#                              XIST-counts   S_score  G2M_score  batch  \
# AAACCCAAGATACAGT-1-A1-query          0.0 -0.339369  -0.496060  query
# AAACGCTGTTGTGTTG-1-A1-query          0.0 -0.019995  -0.083225  query
# AAACGCTTCTCGCTCA-1-A1-query          0.0 -0.169221  -0.390143  query
# AAAGGTACAGAACATA-1-A1-query          0.0 -0.317632  -0.578954  query
# AAAGTCCAGGGACACT-1-A1-query          0.0 -0.370103  -0.370084  query
# ...                                  ...       ...        ...    ...
# TTTGGTTCACGCAGTC-1-B2-query          0.0 -0.901389  -1.291862  query
# TTTGGTTTCCTGTACC-1-B2-query          1.0 -0.277671  -0.184796  query
# TTTGTTGCAAGCTCTA-1-B2-query          0.0 -0.179842  -0.495021  query
# TTTGTTGTCCCAGGAC-1-B2-query          0.0  0.080642  -0.877899  query
# TTTGTTGTCCGGGACT-1-B2-query          0.0 -0.865321  -0.612683  query
#
#                              _scvi_batch  _scvi_labels     C_scANVI
# AAACCCAAGATACAGT-1-A1-query           50            18        CD4+T
# AAACGCTGTTGTGTTG-1-A1-query           49            18  Macrophages
# AAACGCTTCTCGCTCA-1-A1-query           49            18    Monocytes
# AAAGGTACAGAACATA-1-A1-query           50            18    Monocytes
# AAAGTCCAGGGACACT-1-A1-query           50            18  Macrophages
# ...                                  ...           ...          ...
# TTTGGTTCACGCAGTC-1-B2-query           54            18  Macrophages
# TTTGGTTTCCTGTACC-1-B2-query           54            18  Macrophages
# TTTGTTGCAAGCTCTA-1-B2-query           53            18  Macrophages
# TTTGTTGTCCCAGGAC-1-B2-query           54            18  Macrophages
# TTTGTTGTCCGGGACT-1-B2-query           54            18  Macrophages
#
# [7847 rows x 27 columns]

# %%
query_export.write('/home/acirnu/data/ACM_cardiac_leuco/processed_merged/Merge+Subset_Ctrls_scANVI_cellstates_from_healthy_reference_ac240222.raw.h5ad')
