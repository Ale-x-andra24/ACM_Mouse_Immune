# %% [markdown]
# ### Notebook for the label transfer of Healthy Human Reference to mouse ACM heart (merged Pkp2+Ttn dataset) using `scANVI`
#
# #### Environment: scANVI
#
# - **Developed by:** Carlos Talavera-López Ph.D
# - **Modified by:** Alexandra Cirnu
# - **Würzburg Institute for Systems Immunology & Julius-Maximilian-Universität Würzburg**
# - **Date of creation:** 230918
# - **Date of modification:** 240308
#
# #### 5000 HVGs of **myeloids** from Healthy human heart leucocytes (from Human cell atlas) are used as a reference for seed labelling

# %% [markdown]
# ### Import required modules

# %%
import scvi
import torch
import anndata
import warnings
import numpy as np
import scanpy as sc
import pandas as pd
import plotnine as p
from pywaffle import Waffle
import matplotlib.pyplot as plt
from scib_metrics.benchmark import Benchmarker

# %% [markdown]
# ### Set up working environment

# %%
sc.settings.verbosity = 3
sc.logging.print_versions()
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# Out:
# -----
# anndata     0.10.5.post1
# scanpy      1.9.8
# -----
# PIL                 10.2.0
# absl                NA
# array_api_compat    1.4.1
# asttokens           NA
# attr                23.2.0
# chex                0.1.85
# colorama            0.4.6
# comm                0.2.1
# contextlib2         NA
# cycler              0.12.1
# cython_runtime      NA
# dateutil            2.9.0
# debugpy             1.8.1
# decorator           5.1.1
# docrep              0.3.2
# etils               1.7.0
# exceptiongroup      1.2.0
# executing           2.0.1
# flax                0.8.1
# fsspec              2024.2.0
# h5py                3.10.0
# igraph              0.11.4
# importlib_resources NA
# ipykernel           6.29.3
# ipywidgets          8.1.2
# jax                 0.4.25
# jaxlib              0.4.25
# jedi                0.19.1
# joblib              1.3.2
# kiwisolver          1.4.5
# lightning           2.1.4
# lightning_utilities 0.10.1
# llvmlite            0.42.0
# matplotlib          3.8.3
# matplotlib_inline   0.1.6
# mizani              0.11.0
# ml_collections      NA
# ml_dtypes           0.3.2
# mpl_toolkits        NA
# mpmath              1.3.0
# msgpack             1.0.8
# mudata              0.2.3
# multipledispatch    0.6.0
# natsort             8.4.0
# numba               0.59.0
# numpy               1.26.4
# numpyro             0.14.0
# opt_einsum          v3.3.0
# optax               0.1.9
# packaging           23.2
# pandas              2.2.1
# parso               0.8.3
# pkg_resources       NA
# platformdirs        4.2.0
# plotnine            0.13.0
# plottable           0.1.5
# prompt_toolkit      3.0.43
# psutil              5.9.8
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.17.2
# pynndescent         0.5.11
# pyparsing           3.1.1
# pyro                1.9.0
# pytz                2024.1
# pywaffle            NA
# rich                NA
# scib_metrics        0.5.1
# scipy               1.12.0
# scvi                1.1.2
# session_info        1.0.0
# six                 1.16.0
# sklearn             1.4.1.post1
# skmisc              0.3.1
# stack_data          0.6.3
# sympy               1.12
# texttable           1.7.0
# threadpoolctl       3.3.0
# toolz               0.12.1
# torch               2.2.1+cu121
# torchgen            NA
# torchmetrics        1.3.1
# tornado             6.4
# tqdm                4.66.2
# traitlets           5.14.1
# typing_extensions   NA
# umap                0.5.5
# vscode              NA
# wcwidth             0.2.13
# yaml                6.0.1
# zmq                 25.1.2
# zoneinfo            NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-6.6.14-100.fc38.x86_64-x86_64-with-glibc2.37
# -----
# Session information updated at 2024-03-08 11:44

# %%
def X_is_raw(adata): return np.array_equal(adata.X.sum(axis=0).astype(int), adata.X.sum(axis=0))

# %%
torch.set_float32_matmul_precision('high')

# %%
warnings.simplefilter(action = 'ignore')
scvi.settings.seed = 1712
# %config InlineBackend.print_figure_kwargs = {'facecolor' : "w"}
# %config InlineBackend.figure_format = 'retina'
# Out:
# Seed set to 1712

# %%
arches_params = dict(
    use_layer_norm = "both",
    use_batch_norm = "none",
    encode_covariates = True,
    dropout_rate = 0.2,
    n_layers = 2,
)

# %% [markdown]
# ### Read in Healthy data

# %%
# Data set with 5000 HVGs of myeloids from Healthy human heart leucocytes (from Human cell atlas) 

reference = sc.read_h5ad('/home/acirnu/data/ACM_cardiac_leuco/Reference_data/HCA_myeloids_healthy_reference_HVG5000_ac240308.raw.h5ad')
reference
# Out:
# AnnData object with n_obs × n_vars = 23842 × 5000
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage'
#     var: 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'cell_states_colors', 'hvg', 'scNym_colors', 'scNym_probabilities'
#     obsm: 'X_pca', 'X_scnym', 'X_umap'
#     layers: 'counts'

# %%
X_is_raw(reference)
# Out:
# True

# %%
reference.obs['seed_labels'] = reference.obs['cell_states'].copy()
reference.obs['seed_labels'].cat.categories
# Out:
# Index(['CD16+Mo', 'DOCK4+MØ1', 'LYVE1+MØ1', 'LYVE1+MØ2', 'LYVE1+MØ3',
#        'CD14+Mo', 'Mo_pi', 'DOCK4+MØ2', 'Mast', 'MØ_mod', 'MØ_AgP', 'DC', 'NØ',
#        'IL17RA+Mo'],
#       dtype='object')

# %%
reference.obs['seed_labels'].value_counts()
# Out:
# seed_labels
# CD16+Mo      3278
# DOCK4+MØ1    3239
# LYVE1+MØ1    3018
# LYVE1+MØ2    2088
# LYVE1+MØ3    1957
# CD14+Mo      1883
# Mo_pi        1652
# DOCK4+MØ2    1626
# Mast         1543
# MØ_mod       1313
# MØ_AgP       1278
# DC            814
# NØ            121
# IL17RA+Mo      32
# Name: count, dtype: int64

# %% [markdown]
# ### Subset populations of interest

# %%
reference = reference[~reference.obs['seed_labels'].isin(['nan'])]              # = filter out not assigned cells, keep everything that is not 'nan'
reference.obs['seed_labels'].value_counts()
# Out:
# seed_labels
# CD16+Mo      3278
# DOCK4+MØ1    3239
# LYVE1+MØ1    3018
# LYVE1+MØ2    2088
# LYVE1+MØ3    1957
# CD14+Mo      1883
# Mo_pi        1652
# DOCK4+MØ2    1626
# Mast         1543
# MØ_mod       1313
# MØ_AgP       1278
# DC            814
# NØ            121
# IL17RA+Mo      32
# Name: count, dtype: int64

# %%
sc.pp.filter_cells(reference, min_genes = 200)              #to remove empty cells from table
sc.pp.filter_cells(reference, min_counts = 100)
# Out:
# filtered out 7592 cells that have less than 200 genes expressed

# %% [markdown]
# ### Read in query

# %%
#Merged Pkp2+Ttn Libraries subsetted to contain only control mice (Pkp_Ctr_noninf and Ttn_Ctr_noninf)

query = sc.read_h5ad('/home/acirnu/data/ACM_cardiac_leuco/processed_merged/Merge+Subset_Ctrls_demux_QCed_ac240221.raw.h5ad')
query.obs['cell_source'] = 'AG_Gerull'
query.obs['seed_labels'] = 'Unknown'
query.obs['donor'] = query.obs['sample'].copy()
query
# Out:
# AnnData object with n_obs × n_vars = 7847 × 32285
#     obs: 'sample', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'cell_source', 'seed_labels', 'donor'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'
#     layers: 'counts', 'sqrt_norm'

# %%
X_is_raw(query)
# Out:
# True

# %%
sc.pp.filter_cells(query, min_genes = 200)
sc.pp.filter_cells(query, min_counts = 100)

# %% [markdown]
# ### Change gene symbols for label transfer

# %%
query.var_names = [gene_name.upper() for gene_name in query.var_names]                      #capitalize gene names to match with the human genes from reference
query.var_names
# Out:
# Index(['XKR4', 'GM1992', 'GM19938', 'GM37381', 'RP1', 'SOX17', 'GM37587',
#        'GM37323', 'MRPL15', 'LYPLA1',
#        ...
#        'GM16367', 'AC163611.1', 'AC163611.2', 'AC140365.1', 'AC124606.2',
#        'AC124606.1', 'AC133095.2', 'AC133095.1', 'AC234645.1', 'AC149090.1'],
#       dtype='object', length=32285)

# %% [markdown]
# ### Merge reference and query (make sure the seed_labels of query are 'Unknown')

# %%
adata = reference.concatenate(query, batch_key = 'batch', batch_categories = ['reference', 'query'], join = 'inner')                #merge to one adata object
adata
# Out:
# AnnData object with n_obs × n_vars = 24097 × 3290
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'batch'
#     var: 'gene_ids-query', 'feature_types-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-A1-query', 'mean_counts-A1-query', 'pct_dropout_by_counts-A1-query', 'total_counts-A1-query', 'n_cells_by_counts-A2-query', 'mean_counts-A2-query', 'pct_dropout_by_counts-A2-query', 'total_counts-A2-query', 'n_cells_by_counts-A3-query', 'mean_counts-A3-query', 'pct_dropout_by_counts-A3-query', 'total_counts-A3-query', 'n_cells_by_counts-A4-query', 'mean_counts-A4-query', 'pct_dropout_by_counts-A4-query', 'total_counts-A4-query', 'n_cells_by_counts-B1-query', 'mean_counts-B1-query', 'pct_dropout_by_counts-B1-query', 'total_counts-B1-query', 'n_cells_by_counts-B2-query', 'mean_counts-B2-query', 'pct_dropout_by_counts-B2-query', 'total_counts-B2-query', 'highly_variable-reference', 'highly_variable_rank-reference', 'means-reference', 'variances-reference', 'variances_norm-reference', 'highly_variable_nbatches-reference'
#     layers: 'counts'

# %%
adata.obs['seed_labels'] = adata.obs['seed_labels'].astype('category')
adata.obs['seed_labels'].cat.categories
# Out:
# Index(['CD14+Mo', 'CD16+Mo', 'DC', 'DOCK4+MØ1', 'DOCK4+MØ2', 'IL17RA+Mo',
#        'LYVE1+MØ1', 'LYVE1+MØ2', 'LYVE1+MØ3', 'Mast', 'Mo_pi', 'MØ_AgP',
#        'MØ_mod', 'NØ', 'Unknown'],
#       dtype='object')

# %%
adata.obs['batch'].value_counts()
# Out:
# batch
# reference    16250
# query         7847
# Name: count, dtype: int64

# %% [markdown]
# ### Select HVGs

# %%
adata.obs['donor'] = adata.obs['donor'].astype('str') 
adata.obs['donor'].value_counts()
# Out:
# donor
# D7                   3881
# D6                   3819
# D11                  3384
# Ttn_Ctr_noninf_1     1821
# Pkp2_Ctr_noninf_2    1649
# Ttn_Ctr_noninf_2     1548
# Pkp2_Ctr_noninf_4    1236
# Pkp2_Ctr_noninf_3     909
# H7                    817
# H3                    768
# Pkp2_Ctr_noninf_1     684
# D3                    645
# H2                    595
# H5                    506
# H4                    469
# D2                    444
# H6                    422
# D5                    222
# D4                    215
# D1                     63
# Name: count, dtype: int64

# %%
adata_raw = adata.copy()
adata.layers['counts'] = adata.X.copy()

sc.pp.highly_variable_genes(
    adata,
    flavor = "seurat_v3",
    n_top_genes = 5000,
    layer = "counts",
    batch_key = "donor",
    subset = True,
    span = 1
    )

adata
# Out:
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'highly_variable_rank', float vector (adata.var)
#     'means', float vector (adata.var)
#     'variances', float vector (adata.var)
#     'variances_norm', float vector (adata.var)
# AnnData object with n_obs × n_vars = 24097 × 3290
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'batch'
#     var: 'gene_ids-query', 'feature_types-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-A1-query', 'mean_counts-A1-query', 'pct_dropout_by_counts-A1-query', 'total_counts-A1-query', 'n_cells_by_counts-A2-query', 'mean_counts-A2-query', 'pct_dropout_by_counts-A2-query', 'total_counts-A2-query', 'n_cells_by_counts-A3-query', 'mean_counts-A3-query', 'pct_dropout_by_counts-A3-query', 'total_counts-A3-query', 'n_cells_by_counts-A4-query', 'mean_counts-A4-query', 'pct_dropout_by_counts-A4-query', 'total_counts-A4-query', 'n_cells_by_counts-B1-query', 'mean_counts-B1-query', 'pct_dropout_by_counts-B1-query', 'total_counts-B1-query', 'n_cells_by_counts-B2-query', 'mean_counts-B2-query', 'pct_dropout_by_counts-B2-query', 'total_counts-B2-query', 'highly_variable-reference', 'highly_variable_rank-reference', 'means-reference', 'variances-reference', 'variances_norm-reference', 'highly_variable_nbatches-reference', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg'
#     layers: 'counts'

# %% [markdown]
# ### Transfer of annotation with scANVI

# %%
scvi.model.SCVI.setup_anndata(adata, 
                              batch_key = 'donor', 
                              labels_key = 'seed_labels',
                              layer = 'counts',
                              categorical_covariate_keys = ['donor', 'cell_source'])

# %%
scvi_model = scvi.model.SCVI(adata, 
                             n_latent = 50, 
                             n_layers = 3, 
                             dispersion = 'gene-batch', 
                             gene_likelihood = 'nb')

# %%
scvi_model.train(50, 
                 check_val_every_n_epoch = 1, 
                 enable_progress_bar = True,
                 accelerator = "gpu",
                 devices = [1]                                        
                 )
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Epoch 50/50: 100%|██████████| 50/50 [01:03<00:00,  1.27s/it, v_num=1, train_loss_step=1.27e+3, train_loss_epoch=1.4e+3]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 50/50: 100%|██████████| 50/50 [01:03<00:00,  1.27s/it, v_num=1, train_loss_step=1.27e+3, train_loss_epoch=1.4e+3]

# %% [markdown]
# ### Evaluate model performance a la _Sevensson_

# %%
history_df = (
    scvi_model.history['elbo_train'].astype(float)
    .join(scvi_model.history['elbo_validation'].astype(float))
    .reset_index()
    .melt(id_vars = ['epoch'])
)

p.options.figure_size = 12, 6

p_ = (
    p.ggplot(p.aes(x = 'epoch', y = 'value', color = 'variable'), history_df.query('epoch > 0'))
    + p.geom_line()
    + p.geom_point()
    + p.scale_color_manual({'elbo_train': 'black', 'elbo_validation': 'red'})
    + p.theme_minimal()
)

p_.save('fig1.png', dpi = 300)

print(p_)

# %% [markdown]
# ### Label transfer with `scANVI`

# %%
scanvi_model = scvi.model.SCANVI.from_scvi_model(scvi_model, 'Unknown')

# %%
scanvi_model.train(21, 
                   check_val_every_n_epoch = 1, 
                   enable_progress_bar = True,
                   accelerator = "gpu",
                   devices = [1]                            
)
# Out:
# INFO     Training for 21 epochs.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Epoch 21/21: 100%|██████████| 21/21 [01:13<00:00,  3.38s/it, v_num=1, train_loss_step=1.37e+3, train_loss_epoch=1.4e+3]
# `Trainer.fit` stopped: `max_epochs=21` reached.
# Epoch 21/21: 100%|██████████| 21/21 [01:13<00:00,  3.50s/it, v_num=1, train_loss_step=1.37e+3, train_loss_epoch=1.4e+3]

# %% [markdown]
# ### Evaluate model performance a la Svensson

# %%
history_df = (
    scanvi_model.history['elbo_train'].astype(float)
    .join(scanvi_model.history['elbo_validation'].astype(float))
    .reset_index()
    .melt(id_vars = ['epoch'])
)

p.options.figure_size = 12, 6

p_ = (
    p.ggplot(p.aes(x = 'epoch', y = 'value', color = 'variable'), history_df.query('epoch > 0'))
    + p.geom_line()
    + p.geom_point()
    + p.scale_color_manual({'elbo_train': 'black', 'elbo_validation': 'red'})
    + p.theme_minimal()
)

p_.save('fig2.png', dpi = 300)

print(p_)

# %%
adata.obs["C_scANVI"] = scanvi_model.predict(adata)

# %% [markdown]
# - Extract latent representation

# %%
adata.obsm["X_scANVI"] = scanvi_model.get_latent_representation(adata)

# %%
adata.obs
# Out:
#                                          NRP     cell_source cell_states  \
# AAGCATCGTTCGCGTG-1-H0015_apex-reference   No  Harvard-Nuclei   LYVE1+MØ2
# AAGCCATCAGCACAGA-1-H0015_apex-reference   No  Harvard-Nuclei   LYVE1+MØ3
# AAGTACCTCGTTCTAT-1-H0015_apex-reference   No  Harvard-Nuclei   LYVE1+MØ3
# ACCTGTCTCAAAGACA-1-H0015_apex-reference   No  Harvard-Nuclei   DOCK4+MØ1
# ATCCATTCACTGGCGT-1-H0015_apex-reference   No  Harvard-Nuclei   DOCK4+MØ1
# ...                                      ...             ...         ...
# TTTGGTTCACGCAGTC-1-B2-query              NaN       AG_Gerull         NaN
# TTTGGTTTCCTGTACC-1-B2-query              NaN       AG_Gerull         NaN
# TTTGTTGCAAGCTCTA-1-B2-query              NaN       AG_Gerull         NaN
# TTTGTTGTCCCAGGAC-1-B2-query              NaN       AG_Gerull         NaN
# TTTGTTGTCCGGGACT-1-B2-query              NaN       AG_Gerull         NaN
#
#                                                     donor  gender  n_counts  \
# AAGCATCGTTCGCGTG-1-H0015_apex-reference                H5  Female     560.0
# AAGCCATCAGCACAGA-1-H0015_apex-reference                H5  Female     715.0
# AAGTACCTCGTTCTAT-1-H0015_apex-reference                H5  Female     560.0
# ACCTGTCTCAAAGACA-1-H0015_apex-reference                H5  Female     416.0
# ATCCATTCACTGGCGT-1-H0015_apex-reference                H5  Female     371.0
# ...                                                   ...     ...       ...
# TTTGGTTCACGCAGTC-1-B2-query              Ttn_Ctr_noninf_2     NaN   18844.0
# TTTGGTTTCCTGTACC-1-B2-query              Ttn_Ctr_noninf_2     NaN   11805.0
# TTTGTTGCAAGCTCTA-1-B2-query              Ttn_Ctr_noninf_1     NaN    3733.0
# TTTGTTGTCCCAGGAC-1-B2-query              Ttn_Ctr_noninf_2     NaN    6388.0
# TTTGTTGTCCGGGACT-1-B2-query              Ttn_Ctr_noninf_2     NaN   10124.0
#
#                                          n_genes region            sample  \
# AAGCATCGTTCGCGTG-1-H0015_apex-reference      263     AX        H0015_apex
# AAGCCATCAGCACAGA-1-H0015_apex-reference      316     AX        H0015_apex
# AAGTACCTCGTTCTAT-1-H0015_apex-reference      278     AX        H0015_apex
# ACCTGTCTCAAAGACA-1-H0015_apex-reference      288     AX        H0015_apex
# ATCCATTCACTGGCGT-1-H0015_apex-reference      227     AX        H0015_apex
# ...                                          ...    ...               ...
# TTTGGTTCACGCAGTC-1-B2-query                 4219    NaN  Ttn_Ctr_noninf_2
# TTTGGTTTCCTGTACC-1-B2-query                 3321    NaN  Ttn_Ctr_noninf_2
# TTTGTTGCAAGCTCTA-1-B2-query                 1849    NaN  Ttn_Ctr_noninf_1
# TTTGTTGTCCCAGGAC-1-B2-query                 2559    NaN  Ttn_Ctr_noninf_2
# TTTGTTGTCCGGGACT-1-B2-query                 3333    NaN  Ttn_Ctr_noninf_2
#
#                                         scNym  ...  pct_counts_ribo  \
# AAGCATCGTTCGCGTG-1-H0015_apex-reference    MØ  ...              NaN
# AAGCCATCAGCACAGA-1-H0015_apex-reference    MØ  ...              NaN
# AAGTACCTCGTTCTAT-1-H0015_apex-reference    MØ  ...              NaN
# ACCTGTCTCAAAGACA-1-H0015_apex-reference    MØ  ...              NaN
# ATCCATTCACTGGCGT-1-H0015_apex-reference    MØ  ...              NaN
# ...                                       ...  ...              ...
# TTTGGTTCACGCAGTC-1-B2-query               NaN  ...        15.219699
# TTTGGTTTCCTGTACC-1-B2-query               NaN  ...        12.443880
# TTTGTTGCAAGCTCTA-1-B2-query               NaN  ...         5.062952
# TTTGTTGTCCCAGGAC-1-B2-query               NaN  ...         7.247965
# TTTGTTGTCCGGGACT-1-B2-query               NaN  ...         5.432635
#
#                                         percent_mt percent_chrY XIST-counts  \
# AAGCATCGTTCGCGTG-1-H0015_apex-reference        NaN          NaN         NaN
# AAGCCATCAGCACAGA-1-H0015_apex-reference        NaN          NaN         NaN
# AAGTACCTCGTTCTAT-1-H0015_apex-reference        NaN          NaN         NaN
# ACCTGTCTCAAAGACA-1-H0015_apex-reference        NaN          NaN         NaN
# ATCCATTCACTGGCGT-1-H0015_apex-reference        NaN          NaN         NaN
# ...                                            ...          ...         ...
# TTTGGTTCACGCAGTC-1-B2-query               0.036245     0.000000         0.0
# TTTGGTTTCCTGTACC-1-B2-query               0.022279     0.025413         1.0
# TTTGTTGCAAGCTCTA-1-B2-query               0.017412     0.000000         0.0
# TTTGTTGTCCCAGGAC-1-B2-query               0.023168     0.140889         0.0
# TTTGTTGTCCGGGACT-1-B2-query               0.018372     0.000000         0.0
#
#                                           S_score G2M_score      batch  \
# AAGCATCGTTCGCGTG-1-H0015_apex-reference       NaN       NaN  reference
# AAGCCATCAGCACAGA-1-H0015_apex-reference       NaN       NaN  reference
# AAGTACCTCGTTCTAT-1-H0015_apex-reference       NaN       NaN  reference
# ACCTGTCTCAAAGACA-1-H0015_apex-reference       NaN       NaN  reference
# ATCCATTCACTGGCGT-1-H0015_apex-reference       NaN       NaN  reference
# ...                                           ...       ...        ...
# TTTGGTTCACGCAGTC-1-B2-query             -0.901389 -1.291862      query
# TTTGGTTTCCTGTACC-1-B2-query             -0.277671 -0.184796      query
# TTTGTTGCAAGCTCTA-1-B2-query             -0.179842 -0.495021      query
# TTTGTTGTCCCAGGAC-1-B2-query              0.080642 -0.877899      query
# TTTGTTGTCCGGGACT-1-B2-query             -0.865321 -0.612683      query
#
#                                         _scvi_batch  _scvi_labels   C_scANVI
# AAGCATCGTTCGCGTG-1-H0015_apex-reference          11             7  LYVE1+MØ2
# AAGCCATCAGCACAGA-1-H0015_apex-reference          11             8  LYVE1+MØ3
# AAGTACCTCGTTCTAT-1-H0015_apex-reference          11             8  LYVE1+MØ1
# ACCTGTCTCAAAGACA-1-H0015_apex-reference          11             3  DOCK4+MØ1
# ATCCATTCACTGGCGT-1-H0015_apex-reference          11             3  DOCK4+MØ1
# ...                                             ...           ...        ...
# TTTGGTTCACGCAGTC-1-B2-query                      19            14  LYVE1+MØ1
# TTTGGTTTCCTGTACC-1-B2-query                      19            14  LYVE1+MØ1
# TTTGTTGCAAGCTCTA-1-B2-query                      18            14  DOCK4+MØ1
# TTTGTTGTCCCAGGAC-1-B2-query                      19            14  LYVE1+MØ1
# TTTGTTGTCCGGGACT-1-B2-query                      19            14  LYVE1+MØ1
#
# [24097 rows x 34 columns]

# %% [markdown]
# - Visualise corrected dataset

# %%
sc.pp.neighbors(adata, use_rep = "X_scANVI", n_neighbors = 50, metric = 'minkowski')
sc.tl.umap(adata, min_dist = 0.3, spread = 4, random_state = 1712)
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:06)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:11)

# %%
sc.pl.umap(adata, frameon = False, color = ['C_scANVI', 'seed_labels', 'condition', 'batch', 'model'], size = 1, legend_fontsize = 5, ncols = 1)

# %% [markdown]
# ### Export annotated object

# %%
adata_export_merged = anndata.AnnData(X = adata_raw.X, var = adata_raw.var, obs = adata.obs)            #export a merged AnnData object with raw values from X and raw genes but modified observations
adata_export_merged
# Out:
# AnnData object with n_obs × n_vars = 24097 × 3290
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'batch', '_scvi_batch', '_scvi_labels', 'C_scANVI'
#     var: 'gene_ids-query', 'feature_types-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-A1-query', 'mean_counts-A1-query', 'pct_dropout_by_counts-A1-query', 'total_counts-A1-query', 'n_cells_by_counts-A2-query', 'mean_counts-A2-query', 'pct_dropout_by_counts-A2-query', 'total_counts-A2-query', 'n_cells_by_counts-A3-query', 'mean_counts-A3-query', 'pct_dropout_by_counts-A3-query', 'total_counts-A3-query', 'n_cells_by_counts-A4-query', 'mean_counts-A4-query', 'pct_dropout_by_counts-A4-query', 'total_counts-A4-query', 'n_cells_by_counts-B1-query', 'mean_counts-B1-query', 'pct_dropout_by_counts-B1-query', 'total_counts-B1-query', 'n_cells_by_counts-B2-query', 'mean_counts-B2-query', 'pct_dropout_by_counts-B2-query', 'total_counts-B2-query', 'highly_variable-reference', 'highly_variable_rank-reference', 'means-reference', 'variances-reference', 'variances_norm-reference', 'highly_variable_nbatches-reference'

# %%
adata_export = adata_export_merged[adata_export_merged.obs['batch'].isin(['query'])]                    #subset merged data set to keep only query
adata_export
# Out:
# View of AnnData object with n_obs × n_vars = 7847 × 3290
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'batch', '_scvi_batch', '_scvi_labels', 'C_scANVI'
#     var: 'gene_ids-query', 'feature_types-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-A1-query', 'mean_counts-A1-query', 'pct_dropout_by_counts-A1-query', 'total_counts-A1-query', 'n_cells_by_counts-A2-query', 'mean_counts-A2-query', 'pct_dropout_by_counts-A2-query', 'total_counts-A2-query', 'n_cells_by_counts-A3-query', 'mean_counts-A3-query', 'pct_dropout_by_counts-A3-query', 'total_counts-A3-query', 'n_cells_by_counts-A4-query', 'mean_counts-A4-query', 'pct_dropout_by_counts-A4-query', 'total_counts-A4-query', 'n_cells_by_counts-B1-query', 'mean_counts-B1-query', 'pct_dropout_by_counts-B1-query', 'total_counts-B1-query', 'n_cells_by_counts-B2-query', 'mean_counts-B2-query', 'pct_dropout_by_counts-B2-query', 'total_counts-B2-query', 'highly_variable-reference', 'highly_variable_rank-reference', 'means-reference', 'variances-reference', 'variances_norm-reference', 'highly_variable_nbatches-reference'

# %% [markdown]
# ### Add new gene symbols

# %%
query_export = anndata.AnnData(X = query.X, var = query.var, obs = adata_export.obs)                    #make sure to store the raw X values and the raw genes together with modified observations
query_export
# Out:
# AnnData object with n_obs × n_vars = 7847 × 32285
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'batch', '_scvi_batch', '_scvi_labels', 'C_scANVI'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'

# %% [markdown]
# ### Revert gene symbols

# %%
query_export.var_names = [gene_name.capitalize() for gene_name in query_export.var_names]           #restore mouse nomenclature
query_export.var_names
# Out:
# Index(['Xkr4', 'Gm1992', 'Gm19938', 'Gm37381', 'Rp1', 'Sox17', 'Gm37587',
#        'Gm37323', 'Mrpl15', 'Lypla1',
#        ...
#        'Gm16367', 'Ac163611.1', 'Ac163611.2', 'Ac140365.1', 'Ac124606.2',
#        'Ac124606.1', 'Ac133095.2', 'Ac133095.1', 'Ac234645.1', 'Ac149090.1'],
#       dtype='object', length=32285)

# %%
query_export.obs['C_scANVI'].value_counts()
# Out:
# C_scANVI
# LYVE1+MØ3    1723
# LYVE1+MØ1    1709
# CD14+Mo       803
# Mo_pi         709
# CD16+Mo       524
# MØ_AgP        463
# LYVE1+MØ2     436
# MØ_mod        389
# DOCK4+MØ1     339
# DOCK4+MØ2     283
# DC            233
# Mast          216
# NØ             14
# IL17RA+Mo       6
# Name: count, dtype: int64

# %%
query_export
# Out:
# AnnData object with n_obs × n_vars = 7847 × 32285
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'batch', '_scvi_batch', '_scvi_labels', 'C_scANVI'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'

# %%
#Clean up metadata - delete all columns that came from merging with reference data set

del(query_export.obs['cell_states'])
del(query_export.obs['gender'])
del(query_export.obs['NRP'])
del(query_export.obs['region'])
del(query_export.obs['scNym'])
del(query_export.obs['scNym_confidence'])
del(query_export.obs['lineage'])

# %%
query_export.obs
# Out:
#                             cell_source              donor  n_counts  n_genes  \
# AAACCCAAGATACAGT-1-A1-query   AG_Gerull  Pkp2_Ctr_noninf_2    8562.0     2769
# AAACGCTGTTGTGTTG-1-A1-query   AG_Gerull  Pkp2_Ctr_noninf_1     750.0      365
# AAACGCTTCTCGCTCA-1-A1-query   AG_Gerull  Pkp2_Ctr_noninf_1    3855.0     1599
# AAAGGTACAGAACATA-1-A1-query   AG_Gerull  Pkp2_Ctr_noninf_2   17536.0     3854
# AAAGTCCAGGGACACT-1-A1-query   AG_Gerull  Pkp2_Ctr_noninf_2   14174.0     3788
# ...                                 ...                ...       ...      ...
# TTTGGTTCACGCAGTC-1-B2-query   AG_Gerull   Ttn_Ctr_noninf_2   18844.0     4219
# TTTGGTTTCCTGTACC-1-B2-query   AG_Gerull   Ttn_Ctr_noninf_2   11805.0     3321
# TTTGTTGCAAGCTCTA-1-B2-query   AG_Gerull   Ttn_Ctr_noninf_1    3733.0     1849
# TTTGTTGTCCCAGGAC-1-B2-query   AG_Gerull   Ttn_Ctr_noninf_2    6388.0     2559
# TTTGTTGTCCGGGACT-1-B2-query   AG_Gerull   Ttn_Ctr_noninf_2   10124.0     3333
#
#                                         sample seed_labels        condition  \
# AAACCCAAGATACAGT-1-A1-query  Pkp2_Ctr_noninf_2     Unknown  Pkp2_Ctr_noninf
# AAACGCTGTTGTGTTG-1-A1-query  Pkp2_Ctr_noninf_1     Unknown  Pkp2_Ctr_noninf
# AAACGCTTCTCGCTCA-1-A1-query  Pkp2_Ctr_noninf_1     Unknown  Pkp2_Ctr_noninf
# AAAGGTACAGAACATA-1-A1-query  Pkp2_Ctr_noninf_2     Unknown  Pkp2_Ctr_noninf
# AAAGTCCAGGGACACT-1-A1-query  Pkp2_Ctr_noninf_2     Unknown  Pkp2_Ctr_noninf
# ...                                        ...         ...              ...
# TTTGGTTCACGCAGTC-1-B2-query   Ttn_Ctr_noninf_2     Unknown   Ttn_Ctr_noninf
# TTTGGTTTCCTGTACC-1-B2-query   Ttn_Ctr_noninf_2     Unknown   Ttn_Ctr_noninf
# TTTGTTGCAAGCTCTA-1-B2-query   Ttn_Ctr_noninf_1     Unknown   Ttn_Ctr_noninf
# TTTGTTGTCCCAGGAC-1-B2-query   Ttn_Ctr_noninf_2     Unknown   Ttn_Ctr_noninf
# TTTGTTGTCCGGGACT-1-B2-query   Ttn_Ctr_noninf_2     Unknown   Ttn_Ctr_noninf
#
#                              genotype infection library  ... pct_counts_ribo  \
# AAACCCAAGATACAGT-1-A1-query  Pkp2_Ctr    noninf      A1  ...       23.662696
# AAACGCTGTTGTGTTG-1-A1-query  Pkp2_Ctr    noninf      A1  ...        4.533333
# AAACGCTTCTCGCTCA-1-A1-query  Pkp2_Ctr    noninf      A1  ...        1.815824
# AAAGGTACAGAACATA-1-A1-query  Pkp2_Ctr    noninf      A1  ...       10.213276
# AAAGTCCAGGGACACT-1-A1-query  Pkp2_Ctr    noninf      A1  ...       14.456046
# ...                               ...       ...     ...  ...             ...
# TTTGGTTCACGCAGTC-1-B2-query   Ttn_Ctr    noninf      B2  ...       15.219699
# TTTGGTTTCCTGTACC-1-B2-query   Ttn_Ctr    noninf      B2  ...       12.443880
# TTTGTTGCAAGCTCTA-1-B2-query   Ttn_Ctr    noninf      B2  ...        5.062952
# TTTGTTGTCCCAGGAC-1-B2-query   Ttn_Ctr    noninf      B2  ...        7.247965
# TTTGTTGTCCGGGACT-1-B2-query   Ttn_Ctr    noninf      B2  ...        5.432635
#
#                              percent_mt  percent_chrY  XIST-counts   S_score  \
# AAACCCAAGATACAGT-1-A1-query    0.019038      0.000000          0.0 -0.339369
# AAACGCTGTTGTGTTG-1-A1-query    0.346667      0.000000          0.0 -0.019995
# AAACGCTTCTCGCTCA-1-A1-query    0.043320      0.025940          0.0 -0.169221
# AAAGGTACAGAACATA-1-A1-query    0.027315      0.051323          0.0 -0.317632
# AAAGTCCAGGGACACT-1-A1-query    0.023282      0.014110          0.0 -0.370103
# ...                                 ...           ...          ...       ...
# TTTGGTTCACGCAGTC-1-B2-query    0.036245      0.000000          0.0 -0.901389
# TTTGGTTTCCTGTACC-1-B2-query    0.022279      0.025413          1.0 -0.277671
# TTTGTTGCAAGCTCTA-1-B2-query    0.017412      0.000000          0.0 -0.179842
# TTTGTTGTCCCAGGAC-1-B2-query    0.023168      0.140889          0.0  0.080642
# TTTGTTGTCCGGGACT-1-B2-query    0.018372      0.000000          0.0 -0.865321
#
#                              G2M_score  batch  _scvi_batch  _scvi_labels  \
# AAACCCAAGATACAGT-1-A1-query  -0.496060  query           15            14
# AAACGCTGTTGTGTTG-1-A1-query  -0.083225  query           14            14
# AAACGCTTCTCGCTCA-1-A1-query  -0.390143  query           14            14
# AAAGGTACAGAACATA-1-A1-query  -0.578954  query           15            14
# AAAGTCCAGGGACACT-1-A1-query  -0.370084  query           15            14
# ...                                ...    ...          ...           ...
# TTTGGTTCACGCAGTC-1-B2-query  -1.291862  query           19            14
# TTTGGTTTCCTGTACC-1-B2-query  -0.184796  query           19            14
# TTTGTTGCAAGCTCTA-1-B2-query  -0.495021  query           18            14
# TTTGTTGTCCCAGGAC-1-B2-query  -0.877899  query           19            14
# TTTGTTGTCCGGGACT-1-B2-query  -0.612683  query           19            14
#
#                               C_scANVI
# AAACCCAAGATACAGT-1-A1-query       Mast
# AAACGCTGTTGTGTTG-1-A1-query  LYVE1+MØ2
# AAACGCTTCTCGCTCA-1-A1-query  DOCK4+MØ1
# AAAGGTACAGAACATA-1-A1-query    CD14+Mo
# AAAGTCCAGGGACACT-1-A1-query  LYVE1+MØ3
# ...                                ...
# TTTGGTTCACGCAGTC-1-B2-query  LYVE1+MØ1
# TTTGGTTTCCTGTACC-1-B2-query  LYVE1+MØ1
# TTTGTTGCAAGCTCTA-1-B2-query  DOCK4+MØ1
# TTTGTTGTCCCAGGAC-1-B2-query  LYVE1+MØ1
# TTTGTTGTCCGGGACT-1-B2-query  LYVE1+MØ1
#
# [7847 rows x 27 columns]

# %%
query_export.write('/home/acirnu/data/ACM_cardiac_leuco/scANVI/Pkp2+Ttn_Ctrls_scANVI_cellstates_from_HCA_myeloid5000_reference_ac240308.raw.h5ad')

# %%
pd.crosstab(query_export.obs['C_scANVI'], query_export.obs['condition'])
# Out:
# condition  Pkp2_Ctr_noninf  Ttn_Ctr_noninf
# C_scANVI
# CD14+Mo                532             271
# CD16+Mo                296             228
# DC                     142              91
# DOCK4+MØ1              166             173
# DOCK4+MØ2              162             121
# IL17RA+Mo                3               3
# LYVE1+MØ1              968             741
# LYVE1+MØ2              251             185
# LYVE1+MØ3              919             804
# Mast                   139              77
# Mo_pi                  429             280
# MØ_AgP                 289             174
# MØ_mod                 171             218
# NØ                      11               3
