# %% [markdown]
# ### Notebook for `leiden` clustering of 6mpi myeloids of Pkp2 Ctr noninf
#
# #### Environment: SCCAF
#
# - **Developed by**: Alexandra Cirnu
# - **Modified by**: Alexandra Cirnu
# - **Talavera-López Lab - Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg**
# - **Created on**: 240320
# - **Last modified**: 240325

# %% [markdown]
# #### Load required modules

# %%
import SCCAF
from SCCAF import SCCAF_assessment, plot_roc
import scanpy as sc
import anndata
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.sparse import csr_matrix
import warnings; warnings.simplefilter('ignore')

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()

sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# %matplotlib inline
# Out:
# -----
# anndata     0.10.6
# scanpy      1.9.8
# -----
# PIL                 10.2.0
# SCCAF               NA
# asttokens           NA
# attr                23.2.0
# comm                0.2.2
# cycler              0.12.1
# cython_runtime      NA
# dateutil            2.9.0
# debugpy             1.8.1
# decorator           5.1.1
# exceptiongroup      1.2.0
# executing           2.0.1
# h5py                3.10.0
# igraph              0.11.4
# ipykernel           6.29.3
# ipywidgets          8.1.2
# jedi                0.19.1
# joblib              1.3.2
# kiwisolver          1.4.5
# leidenalg           0.10.2
# llvmlite            0.42.0
# louvain             0.8.2
# matplotlib          3.8.3
# mpl_toolkits        NA
# natsort             8.4.0
# numba               0.59.1
# numexpr             2.9.0
# numpy               1.26.4
# packaging           24.0
# pandas              2.2.1
# parso               0.8.3
# patsy               0.5.6
# pickleshare         0.7.5
# pkg_resources       NA
# platformdirs        4.2.0
# prompt_toolkit      3.0.42
# psutil              5.9.8
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.17.2
# pyparsing           3.1.2
# pytz                2024.1
# rich                NA
# scipy               1.12.0
# seaborn             0.13.2
# session_info        1.0.0
# setuptools          69.2.0
# setuptools_scm      NA
# six                 1.16.0
# sklearn             1.4.1.post1
# stack_data          0.6.2
# statsmodels         0.14.1
# texttable           1.7.0
# threadpoolctl       3.4.0
# tomli               2.0.1
# torch               2.2.1+cu121
# torchgen            NA
# tornado             6.4
# tqdm                4.66.2
# traitlets           5.14.2
# typing_extensions   NA
# vscode              NA
# wcwidth             0.2.13
# yaml                6.0.1
# zmq                 25.1.2
# zoneinfo            NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.1
# jupyter_core        5.7.2
# -----
# Python 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# Linux-6.6.14-100.fc38.x86_64-x86_64-with-glibc2.37
# -----
# Session information updated at 2024-03-25 22:08

# %%
warnings.simplefilter(action = 'ignore')
# %config InlineBackend.print_figure_kwargs = {'facecolor' : "w"}
# %config InlineBackend.figure_format = 'retina'

# %%
arches_params = dict(
    use_layer_norm = "both",
    use_batch_norm = "none",
    encode_covariates = True,
    dropout_rate = 0.2,
    n_layers = 2,
)

# %%
def X_is_raw(adata): return np.array_equal(adata.X.sum(axis=0).astype(int), adata.X.sum(axis=0))

# %% [markdown]
# #### Load data set

# %%
input = '/home/acirnu/data/ACM_cardiac_leuco/scANVI/ACM_myeloids_scANVI_general_celltypes_from_HCA_myeloids_ac240320.raw.h5ad'
adata = sc.read_h5ad(input)
adata
# Out:
# AnnData object with n_obs × n_vars = 34482 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'n_genes', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'

# %% [markdown]
# Make sure to use raw counts

# %%
X_is_raw(adata)
# Out:
# True

# %%
#Look at adata.X  -> seems like the data is normalized already!

X_data = adata.X.copy()
X_data_sparse = csr_matrix(X_data)
X_data_df = pd.DataFrame.sparse.from_spmatrix(X_data_sparse, index=adata.obs.index, columns=adata.var.index)
print("Shape of counts DataFrame:", X_data_df.shape)
print(X_data_df)
# Out:
# Shape of counts DataFrame: (34482, 29378)
#                        Xkr4  Gm1992  Gm19938  Gm37381  Rp1  Sox17  Gm37587  \
# AAACGCTGTTGTGTTG-1-A1     0       0        0        0    0      0        0
# AAACGCTTCTCGCTCA-1-A1     0       0        0        0    0      0        0
# AAAGGTACAGAACATA-1-A1     0       0        0        0    0      0        0
# AAAGTCCAGGGACACT-1-A1     0       0        0        0    0      0        0
# AAAGTCCCAGTAGGAC-1-A1     0       0        0        0    0      0        0
# ...                     ...     ...      ...      ...  ...    ...      ...
# TTTGTTGAGGTTAGTA-1-B2     0       0        0        0    0      0        0
# TTTGTTGCAAGCTCTA-1-B2     0       0        0        0    0      0        0
# TTTGTTGGTACAGGTG-1-B2     0       0        0        0    0      0        0
# TTTGTTGTCCCAGGAC-1-B2     0       0        0        0    0      0        0
# TTTGTTGTCCGGGACT-1-B2     0       0        0        0    0      0        0
#
#                        Gm37323  Mrpl15  Lypla1  ...  Vmn2r122  Il11ra2-1  \
# AAACGCTGTTGTGTTG-1-A1        0       0       0  ...         0          0
# AAACGCTTCTCGCTCA-1-A1        0       0       0  ...         0          0
# AAAGGTACAGAACATA-1-A1        0       0       3  ...         0          0
# AAAGTCCAGGGACACT-1-A1        0       1       2  ...         0          0
# AAAGTCCCAGTAGGAC-1-A1        0       0       0  ...         0          0
# ...                        ...     ...     ...  ...       ...        ...
# TTTGTTGAGGTTAGTA-1-B2        0       0       0  ...         0          0
# TTTGTTGCAAGCTCTA-1-B2        0       0       0  ...         0          0
# TTTGTTGGTACAGGTG-1-B2        0       0       1  ...         0          0
# TTTGTTGTCCCAGGAC-1-B2        0       0       0  ...         0          0
# TTTGTTGTCCGGGACT-1-B2        0       1       0  ...         0          0
#
#                        Ccl27a-1  Ccl21c-1  Ccl27a-2  Il11ra2-2  Ccl19-1  \
# AAACGCTGTTGTGTTG-1-A1         0         0         0          0        0
# AAACGCTTCTCGCTCA-1-A1         0         0         0          0        0
# AAAGGTACAGAACATA-1-A1         0         0         0          0        0
# AAAGTCCAGGGACACT-1-A1         0         0         0          0        0
# AAAGTCCCAGTAGGAC-1-A1         0         0         0          0        0
# ...                         ...       ...       ...        ...      ...
# TTTGTTGAGGTTAGTA-1-B2         0         0         0          0        0
# TTTGTTGCAAGCTCTA-1-B2         0         0         0          0        0
# TTTGTTGGTACAGGTG-1-B2         0         0         0          0        0
# TTTGTTGTCCCAGGAC-1-B2         0         0         0          0        0
# TTTGTTGTCCGGGACT-1-B2         0         0         0          0        0
#
#                        Ccl21a-1  Gm10931  Gm16367
# AAACGCTGTTGTGTTG-1-A1         0        0        0
# AAACGCTTCTCGCTCA-1-A1         0        0        0
# AAAGGTACAGAACATA-1-A1         0        0        0
# AAAGTCCAGGGACACT-1-A1         0        0        0
# AAAGTCCCAGTAGGAC-1-A1         0        0        0
# ...                         ...      ...      ...
# TTTGTTGAGGTTAGTA-1-B2         0        0        0
# TTTGTTGCAAGCTCTA-1-B2         0        0        0
# TTTGTTGGTACAGGTG-1-B2         0        0        0
# TTTGTTGTCCCAGGAC-1-B2         0        0        0
# TTTGTTGTCCGGGACT-1-B2         0        0        0
#
# [34482 rows x 29378 columns]

# %% [markdown]
# Save raw counts

# %%
adata.raw = adata

# %% [markdown]
# ### Subset data set to contain only Pkp2 Ctr noninf

# %%
adata_Ctr = adata[adata.obs['condition'].isin(['Pkp2_Ctr_noninf'])].copy()
adata_Ctr
# Out:
# AnnData object with n_obs × n_vars = 3760 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'n_genes', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'

# %% [markdown]
# #### Define neighbors after subsetting
# After subsetting the neighbor data is also subsetted, however the UMAP representation still uses the info from the whole data set, that's why the neighbors have to be identiefied again

# %%
sc.pp.neighbors(adata_Ctr, use_rep = "X_scANVI", n_neighbors = 50, metric = 'minkowski')
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:07)

# %%
sc.pl.umap(adata_Ctr, color=['C_scANVI'], size = 5, frameon = False)

# %% [markdown]
# #### Normalize and log transform data (modify adata.X), raw counts are still stored in adata.raw

# %%
sc.pp.normalize_total(adata_Ctr, target_sum = 1e6, exclude_highly_expressed = True)
sc.pp.log1p(adata_Ctr)
# Out:
# normalizing counts per cell The following highly-expressed genes are not considered during normalization factor computation:
# ['S100a8', 'S100a9', 'Prdx1', 'Cxcl2', 'Myl2', 'Actb', 'Apoe', 'Ftl1', 'Hbb-bt', 'Hbb-bs', 'Lyz2', 'Hba-a1', 'Hba-a2', 'Ccl4', 'Ctla2a', 'Cma1', 'Mcpt4', 'Retnla', 'Retnlg', 'Gm42418', 'Cd74', 'Malat1', 'Fth1', 'Tmsb4x']
#     finished (0:00:00)

# %% [markdown]
# The matrix is already normalized:

# %%
X_data = adata_Ctr.X.copy()
X_data_sparse = csr_matrix(X_data)
X_data_df = pd.DataFrame.sparse.from_spmatrix(X_data_sparse, index=adata_Ctr.obs.index, columns=adata_Ctr.var.index)
print("Shape of counts DataFrame:", X_data_df.shape)
print(X_data_df)
# Out:
# Shape of counts DataFrame: (3760, 29378)
#                        Xkr4  Gm1992  Gm19938  Gm37381  Rp1  Sox17  Gm37587  \
# AAACGCTGTTGTGTTG-1-A1     0       0        0        0    0      0        0
# AAACGCTTCTCGCTCA-1-A1     0       0        0        0    0      0        0
# AAAGGTACAGAACATA-1-A1     0       0        0        0    0      0        0
# AAAGTCCAGGGACACT-1-A1     0       0        0        0    0      0        0
# AAAGTCCCAGTAGGAC-1-A1     0       0        0        0    0      0        0
# ...                     ...     ...      ...      ...  ...    ...      ...
# TTTGATCCAGCAGGAT-1-A4     0       0        0        0    0      0        0
# TTTGGAGGTCAAGGCA-1-A4     0       0        0        0    0      0        0
# TTTGGAGGTTTATGCG-1-A4     0       0        0        0    0      0        0
# TTTGGAGTCCTACGGG-1-A4     0       0        0        0    0      0        0
# TTTGGTTCACGCGTCA-1-A4     0       0        0        0    0      0        0
#
#                        Gm37323    Mrpl15    Lypla1  ...  Vmn2r122  Il11ra2-1  \
# AAACGCTGTTGTGTTG-1-A1        0         0         0  ...         0          0
# AAACGCTTCTCGCTCA-1-A1        0         0         0  ...         0          0
# AAAGGTACAGAACATA-1-A1        0         0  5.289537  ...         0          0
# AAAGTCCAGGGACACT-1-A1        0  4.469733  5.157139  ...         0          0
# AAAGTCCCAGTAGGAC-1-A1        0         0         0  ...         0          0
# ...                        ...       ...       ...  ...       ...        ...
# TTTGATCCAGCAGGAT-1-A4        0         0         0  ...         0          0
# TTTGGAGGTCAAGGCA-1-A4        0         0         0  ...         0          0
# TTTGGAGGTTTATGCG-1-A4        0  4.738616         0  ...         0          0
# TTTGGAGTCCTACGGG-1-A4        0         0         0  ...         0          0
# TTTGGTTCACGCGTCA-1-A4        0         0         0  ...         0          0
#
#                        Ccl27a-1  Ccl21c-1  Ccl27a-2  Il11ra2-2  Ccl19-1  \
# AAACGCTGTTGTGTTG-1-A1         0         0         0          0        0
# AAACGCTTCTCGCTCA-1-A1         0         0         0          0        0
# AAAGGTACAGAACATA-1-A1         0         0         0          0        0
# AAAGTCCAGGGACACT-1-A1         0         0         0          0        0
# AAAGTCCCAGTAGGAC-1-A1         0         0         0          0        0
# ...                         ...       ...       ...        ...      ...
# TTTGATCCAGCAGGAT-1-A4         0         0         0          0        0
# TTTGGAGGTCAAGGCA-1-A4         0         0         0          0        0
# TTTGGAGGTTTATGCG-1-A4         0         0         0          0        0
# TTTGGAGTCCTACGGG-1-A4         0         0         0          0        0
# TTTGGTTCACGCGTCA-1-A4         0         0         0          0        0
#
#                        Ccl21a-1  Gm10931  Gm16367
# AAACGCTGTTGTGTTG-1-A1         0        0        0
# AAACGCTTCTCGCTCA-1-A1         0        0        0
# AAAGGTACAGAACATA-1-A1         0        0        0
# AAAGTCCAGGGACACT-1-A1         0        0        0
# AAAGTCCCAGTAGGAC-1-A1         0        0        0
# ...                         ...      ...      ...
# TTTGATCCAGCAGGAT-1-A4         0        0        0
# TTTGGAGGTCAAGGCA-1-A4         0        0        0
# TTTGGAGGTTTATGCG-1-A4         0        0        0
# TTTGGAGTCCTACGGG-1-A4         0        0        0
# TTTGGTTCACGCGTCA-1-A4         0        0        0
#
# [3760 rows x 29378 columns]

# %% [markdown]
# #### Perform leiden clustering with resolution 0.1 and assess with SCCAF

# %%
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# %matplotlib inline

# %%
#Plotting code
sc.tl.leiden(adata_Ctr, resolution = 0.1, random_state = 1786)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(adata_Ctr.X, adata_Ctr.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)

# Reset all Matplotlib parameters to their defaults
plt.rcParams.update(plt.rcParamsDefault)

#Show plot
sc.set_figure_params(dpi=300)
plt.rcParams["figure.figsize"] = (1,1)
plt.show()
# Out:
# running Leiden clustering
#     finished: found 3 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:01)
# Mean CV accuracy: 0.9433
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.9251

# %% [markdown]
# #### Perform leiden clustering with resolution 0.2 and assess with SCCAF

# %%
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# %matplotlib inline

# %%
#Plotting code
sc.tl.leiden(adata_Ctr, resolution = 0.2, random_state = 1786)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(adata_Ctr.X, adata_Ctr.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)

# Reset all Matplotlib parameters to their defaults
plt.rcParams.update(plt.rcParamsDefault)

#Show plot
sc.set_figure_params(dpi=300)
plt.rcParams["figure.figsize"] = (1,1)
plt.show()
# Out:
# running Leiden clustering
#     finished: found 6 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:01)
# Mean CV accuracy: 0.8133
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.7456

# %% [markdown]
# #### Perform leiden clustering with resolution 0.3 and assess with SCCAF

# %%
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# %matplotlib inline

# %%
#Plotting code
sc.tl.leiden(adata_Ctr, resolution = 0.3, random_state = 1786)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(adata_Ctr.X, adata_Ctr.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)

# Reset all Matplotlib parameters to their defaults
plt.rcParams.update(plt.rcParamsDefault)

#Show plot
sc.set_figure_params(dpi=300)
plt.rcParams["figure.figsize"] = (1,1)
plt.show()
# Out:
# running Leiden clustering
#     finished: found 6 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:01)
# Mean CV accuracy: 0.7567
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.7345

# %% [markdown]
# #### Perform leiden clustering with resolution 0.4 and assess with SCCAF

# %%
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# %matplotlib inline

# %%
#Plotting code
sc.tl.leiden(adata_Ctr, resolution = 0.4, random_state = 1786)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(adata_Ctr.X, adata_Ctr.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)

# Reset all Matplotlib parameters to their defaults
plt.rcParams.update(plt.rcParamsDefault)

#Show plot
sc.set_figure_params(dpi=300)
plt.rcParams["figure.figsize"] = (1,1)
plt.show()
# Out:
# running Leiden clustering
#     finished: found 8 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:02)
# Mean CV accuracy: 0.7333
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.6871

# %% [markdown]
# #### Perform leiden clustering with resolution 0.5 and assess with SCCAF

# %%
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# %matplotlib inline

# %%
#Plotting code
sc.tl.leiden(adata_Ctr, resolution = 0.5, random_state = 1786)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(adata_Ctr.X, adata_Ctr.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)

# Reset all Matplotlib parameters to their defaults
plt.rcParams.update(plt.rcParamsDefault)

#Show plot
sc.set_figure_params(dpi=300)
plt.rcParams["figure.figsize"] = (1,1)
plt.show()
# Out:
# running Leiden clustering
#     finished: found 9 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:01)
# Mean CV accuracy: 0.7547
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.6838

# %% [markdown]
# #### Perform leiden clustering with resolution 0.6 and assess with SCCAF

# %%
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# %matplotlib inline

# %%
#Plotting code
sc.tl.leiden(adata_Ctr, resolution = 0.6, random_state = 1786)
y_prob, y_pred, y_test, clf, cvsm, acc = SCCAF_assessment(adata_Ctr.X, adata_Ctr.obs['leiden'], n = 100)
plot_roc(y_prob, y_test, clf, cvsm = cvsm, acc = acc)

# Reset all Matplotlib parameters to their defaults
plt.rcParams.update(plt.rcParamsDefault)

#Show plot
sc.set_figure_params(dpi=300)
plt.rcParams["figure.figsize"] = (1,1)
plt.show()
# Out:
# running Leiden clustering
#     finished: found 10 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:01)
# Mean CV accuracy: 0.7647
# Accuracy on the training set: 1.0000
# Accuracy on the hold-out set: 0.6787

# %% [markdown]
# ### Choose Resolution for `leiden` clustering
# Chosen: 0.4

# %%
sc.tl.leiden(adata_Ctr, resolution = 0.4, random_state = 1786)
# Out:
# running Leiden clustering
#     finished: found 8 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:02)

# %%
adata_Ctr
# Out:
# AnnData object with n_obs × n_vars = 3760 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'n_genes', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'
#     uns: 'neighbors', 'C_scANVI_colors', 'log1p', 'leiden'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'
#     obsp: 'distances', 'connectivities'

# %%
sc.pl.umap(adata_Ctr, color=['leiden'], size = 3, frameon = False, legend_loc="right margin", legend_fontsize= 5, title='')

# %% [markdown]
# Save results

# %%
#Save the results
adata_Ctr.write_h5ad('/home/acirnu/data/ACM_cardiac_leuco/scANVI/ACM_myeloids_leiden_clustering_on_Pkp2_Ctr_noninf_ac240325.raw.h5ad')
