# %% [markdown]
# # Compositional analysis of the ACM cardiac leucocytes 6mpi dataset (Pkp2+Ttn) - all celltypes - using scCoda `pertpy`:
# - **Developed by**: Christian Eger
# - **Modified by**: Alexandra Cirnu
# - **Talavera-López Lab - Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg**
# - **Created on**: 231214
# - **Last modified**: 240227

# %% [markdown]
# #### Environment: scCoda
#
# To install `pertpy` on MacOS create a new mamba environment and activte it. Then go int 'github' folder and type 'git clone https://github.com/theislab/pertpy.git'. Change directory to 'pertpy' and type 'pip install .'
#
# Look at website to solve problem at the end: https://www.sc-best-practices.org/conditions/compositional.html

# %%
import warnings

import pandas as pd

warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")

import numpy as np
            #import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import altair as alt

import scanpy as sc
import pertpy as pt
from statannot import add_stat_annotation
from scipy import stats

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.5.post1
# scanpy      1.9.8
# -----
# PIL                         10.2.0
# absl                        NA
# adjustText                  1.0.4
# altair                      4.2.2
# arrow                       1.3.0
# arviz                       0.17.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# blitzgsea                   NA
# certifi                     2024.02.02
# cffi                        1.16.0
# chardet                     5.2.0
# charset_normalizer          3.3.2
# chex                        0.1.85
# colorama                    0.4.6
# comm                        0.2.1
# contextlib2                 NA
# custom_inherit              2.4.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.9.0
# debugpy                     1.8.1
# decorator                   5.1.1
# decoupler                   1.6.0
# docrep                      0.3.2
# entrypoints                 0.4
# etils                       1.7.0
# exceptiongroup              1.2.0
# executing                   2.0.1
# flax                        0.8.1
# fsspec                      2024.2.0
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# importlib_resources         NA
# ipykernel                   6.29.3
# ipywidgets                  8.1.2
# jax                         0.4.25
# jaxlib                      0.4.25
# jaxopt                      NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# lightning                   2.1.4
# lightning_fabric            2.2.0.post0
# lightning_utilities         0.10.1
# llvmlite                    0.42.0
# markupsafe                  2.1.5
# matplotlib                  3.8.3
# matplotlib_inline           0.1.6
# ml_collections              NA
# ml_dtypes                   0.3.2
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.8
# mudata                      0.2.3
# multipledispatch            0.6.0
# natsort                     8.4.0
# numba                       0.59.0
# numpy                       1.26.4
# numpyro                     0.14.0
# opt_einsum                  v3.3.0
# optax                       0.1.9
# ott                         0.4.5
# packaging                   23.2
# pandas                      2.2.1
# parso                       0.8.3
# patsy                       0.5.6
# pertpy                      0.7.0
# pkg_resources               NA
# platformdirs                4.2.0
# ply                         3.11
# png                         0.20220715.0
# prompt_toolkit              3.0.43
# psutil                      5.9.8
# pubchempy                   1.0.4
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynndescent                 0.5.11
# pyomo                       6.7.1
# pyparsing                   3.1.1
# pyro                        1.9.0
# pytorch_lightning           2.2.0.post0
# pytz                        2024.1
# referencing                 NA
# reportlab                   4.1.0
# requests                    2.31.0
# rich                        NA
# rpds                        NA
# rpy2                        3.5.11
# scipy                       1.12.0
# scvi                        1.1.2
# seaborn                     0.13.2
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.4.1.post1
# skmisc                      0.3.1
# sparsecca                   0.3.1
# stack_data                  0.6.3
# statannot                   0.2.3
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# toolz                       0.12.1
# torch                       2.2.1+cu121
# torchgen                    NA
# torchmetrics                1.3.1
# tornado                     6.4
# toyplot                     1.0.3
# toytree                     2.0.1
# tqdm                        4.66.2
# traitlets                   5.14.1
# typing_extensions           NA
# tzlocal                     NA
# urllib3                     2.2.1
# vscode                      NA
# wcwidth                     0.2.13
# xarray                      2024.2.0
# xarray_einstats             0.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-6.6.14-100.fc38.x86_64-x86_64-with-glibc2.37
# -----
# Session information updated at 2024-03-28 12:38

# %% [markdown]
# Manual git installation of pertpy necessary due to Apple silicon
# $ git clone https://github.com/theislab/pertpy.git
# $ cd pertpy
# $ pip install .

# %%
adata = sc.read_h5ad("/home/acirnu/data/ACM_cardiac_leuco/scANVI/ACM_myeloids_clustered_ac240327.raw.h5ad")
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 34482 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'n_genes', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'

# %%
adata.obs
# Out:
#                       cell_source              donor  n_counts  n_genes  \
# AAACGCTGTTGTGTTG-1-A1   AG_Gerull  Pkp2_Ctr_noninf_1     478.0      343
# AAACGCTTCTCGCTCA-1-A1   AG_Gerull  Pkp2_Ctr_noninf_1    3581.0     1540
# AAAGGTACAGAACATA-1-A1   AG_Gerull  Pkp2_Ctr_noninf_2   16539.0     3763
# AAAGTCCAGGGACACT-1-A1   AG_Gerull  Pkp2_Ctr_noninf_2   13389.0     3678
# AAAGTCCCAGTAGGAC-1-A1   AG_Gerull  Pkp2_Ctr_noninf_2   12092.0     3410
# ...                           ...                ...       ...      ...
# TTTGTTGAGGTTAGTA-1-B2   AG_Gerull   Ttn_HetKO_MCMV_1    4226.0     1453
# TTTGTTGCAAGCTCTA-1-B2   AG_Gerull   Ttn_Ctr_noninf_1    3733.0     1849
# TTTGTTGGTACAGGTG-1-B2   AG_Gerull     Ttn_Ctr_MCMV_2   24293.0     4744
# TTTGTTGTCCCAGGAC-1-B2   AG_Gerull   Ttn_Ctr_noninf_2    6388.0     2559
# TTTGTTGTCCGGGACT-1-B2   AG_Gerull   Ttn_Ctr_noninf_2   10124.0     3333
#
#                                   sample seed_labels        condition  \
# AAACGCTGTTGTGTTG-1-A1  Pkp2_Ctr_noninf_1    LYVE1+MØ  Pkp2_Ctr_noninf
# AAACGCTTCTCGCTCA-1-A1  Pkp2_Ctr_noninf_1    DOCK4+MØ  Pkp2_Ctr_noninf
# AAAGGTACAGAACATA-1-A1  Pkp2_Ctr_noninf_2   Monocytes  Pkp2_Ctr_noninf
# AAAGTCCAGGGACACT-1-A1  Pkp2_Ctr_noninf_2    LYVE1+MØ  Pkp2_Ctr_noninf
# AAAGTCCCAGTAGGAC-1-A1  Pkp2_Ctr_noninf_2    LYVE1+MØ  Pkp2_Ctr_noninf
# ...                                  ...         ...              ...
# TTTGTTGAGGTTAGTA-1-B2   Ttn_HetKO_MCMV_1     Unknown   Ttn_HetKO_MCMV
# TTTGTTGCAAGCTCTA-1-B2   Ttn_Ctr_noninf_1     Unknown   Ttn_Ctr_noninf
# TTTGTTGGTACAGGTG-1-B2     Ttn_Ctr_MCMV_2     Unknown     Ttn_Ctr_MCMV
# TTTGTTGTCCCAGGAC-1-B2   Ttn_Ctr_noninf_2     Unknown   Ttn_Ctr_noninf
# TTTGTTGTCCGGGACT-1-B2   Ttn_Ctr_noninf_2     Unknown   Ttn_Ctr_noninf
#
#                         genotype infection library  ... percent_chrY  \
# AAACGCTGTTGTGTTG-1-A1   Pkp2_Ctr    noninf      A1  ...     0.000000
# AAACGCTTCTCGCTCA-1-A1   Pkp2_Ctr    noninf      A1  ...     0.025940
# AAAGGTACAGAACATA-1-A1   Pkp2_Ctr    noninf      A1  ...     0.051323
# AAAGTCCAGGGACACT-1-A1   Pkp2_Ctr    noninf      A1  ...     0.014110
# AAAGTCCCAGTAGGAC-1-A1   Pkp2_Ctr    noninf      A1  ...     0.040006
# ...                          ...       ...     ...  ...          ...
# TTTGTTGAGGTTAGTA-1-B2  Ttn_HetKO      MCMV      B2  ...     0.141978
# TTTGTTGCAAGCTCTA-1-B2    Ttn_Ctr    noninf      B2  ...     0.000000
# TTTGTTGGTACAGGTG-1-B2    Ttn_Ctr      MCMV      B2  ...     0.000000
# TTTGTTGTCCCAGGAC-1-B2    Ttn_Ctr    noninf      B2  ...     0.140889
# TTTGTTGTCCGGGACT-1-B2    Ttn_Ctr    noninf      B2  ...     0.000000
#
#                        XIST-counts   S_score  G2M_score  _scvi_batch  \
# AAACGCTGTTGTGTTG-1-A1          0.0 -0.019995  -0.083225            6
# AAACGCTTCTCGCTCA-1-A1          0.0 -0.169221  -0.390143            6
# AAAGGTACAGAACATA-1-A1          0.0 -0.317632  -0.578954            7
# AAAGTCCAGGGACACT-1-A1          0.0 -0.370103  -0.370084            7
# AAAGTCCCAGTAGGAC-1-A1          0.0 -0.142503  -0.357287            7
# ...                            ...       ...        ...          ...
# TTTGTTGAGGTTAGTA-1-B2          0.0 -0.373712  -0.402608           25
# TTTGTTGCAAGCTCTA-1-B2          0.0 -0.179842  -0.495021           23
# TTTGTTGGTACAGGTG-1-B2         13.0 -0.435458  -0.744327           21
# TTTGTTGTCCCAGGAC-1-B2          0.0  0.080642  -0.877899           24
# TTTGTTGTCCGGGACT-1-B2          0.0 -0.865321  -0.612683           24
#
#                        _scvi_labels      batch     C_scANVI  leiden  \
# AAACGCTGTTGTGTTG-1-A1             2  reference     LYVE1+MØ       7
# AAACGCTTCTCGCTCA-1-A1             1  reference     DOCK4+MØ       3
# AAAGGTACAGAACATA-1-A1             4  reference    Monocytes       5
# AAAGTCCAGGGACACT-1-A1             2  reference     LYVE1+MØ       2
# AAAGTCCCAGTAGGAC-1-A1             2  reference     LYVE1+MØ       2
# ...                             ...        ...          ...     ...
# TTTGTTGAGGTTAGTA-1-B2             7      query  Neutrophils       6
# TTTGTTGCAAGCTCTA-1-B2             7      query     DOCK4+MØ      10
# TTTGTTGGTACAGGTG-1-B2             7      query   MØ_general       0
# TTTGTTGTCCCAGGAC-1-B2             7      query   MØ_general       0
# TTTGTTGTCCGGGACT-1-B2             7      query     LYVE1+MØ       2
#
#                        classification
# AAACGCTGTTGTGTTG-1-A1      LYVE1+MØ_7
# AAACGCTTCTCGCTCA-1-A1      DOCK4+MØ_3
# AAAGGTACAGAACATA-1-A1     Monocytes_5
# AAAGTCCAGGGACACT-1-A1      LYVE1+MØ_2
# AAAGTCCCAGTAGGAC-1-A1      LYVE1+MØ_2
# ...                               ...
# TTTGTTGAGGTTAGTA-1-B2   Neutrophils_6
# TTTGTTGCAAGCTCTA-1-B2     DOCK4+MØ_10
# TTTGTTGGTACAGGTG-1-B2    MØ_general_0
# TTTGTTGTCCCAGGAC-1-B2    MØ_general_0
# TTTGTTGTCCGGGACT-1-B2      LYVE1+MØ_2
#
# [34482 rows x 29 columns]

# %%
adata.obs["genotype"].cat.categories
# Out:
# Index(['Pkp2_Ctr', 'Pkp2_HetKO', 'Ttn_Ctr', 'Ttn_HetKO'], dtype='object')

# %%
adata.obs["infection"].cat.categories
# Out:
# Index(['MCMV', 'noninf'], dtype='object')

# %%
adata.obs["condition"].cat.categories
# Out:
# Index(['Pkp2_Ctr_MCMV', 'Pkp2_Ctr_noninf', 'Pkp2_HetKO_MCMV',
#        'Pkp2_HetKO_noninf', 'Ttn_Ctr_MCMV', 'Ttn_Ctr_noninf', 'Ttn_HetKO_MCMV',
#        'Ttn_HetKO_noninf'],
#       dtype='object')

# %% [markdown]
# create notebook for every compartment and compare across cell states
# visualization improvement
# reference to ctrl healthy

# %%
sccoda_model = pt.tl.Sccoda()
sccoda_data = sccoda_model.load(
    adata,
    type="cell_level",
    generate_sample_level=True,
    cell_type_identifier="classification",
    sample_identifier="sample",
    covariate_obs=["condition"],
)
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 34512 × 29454
#   2 modalities
#     rna:	34482 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'n_genes', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'
#     coda:	30 x 76
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="condition",
    y_scale="count",
    figsize=(25, 10),
    add_dots=True,
    args_swarmplot={"palette": ["red"]},
)
plt.show()

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="condition",
    plot_facets=True,
    y_scale="log",
    add_dots=True,
    cmap="Reds",
)
plt.xticks(rotation=90)
plt.show()

# %%
pt.pl.coda.stacked_barplot(
    sccoda_data, modality_key="coda", feature_name="condition", figsize=(15, 9) 
)
plt.legend(ncol=3, loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
sccoda_data = sccoda_model.prepare(
    sccoda_data,
    modality_key="coda",
    formula="condition",
    reference_cell_type="automatic",
)
sccoda_model.run_nuts(sccoda_data, modality_key="coda", rng_key=1234)
# Out:
# Automatic reference selection! Reference cell type set to LYVE1+MØ_9
# Zero counts encountered in data! Added a pseudocount of 0.5.
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# warmup:   9%|▊         | 945/11000 [02:40<28:24,  5.90it/s, 255 steps of size 1.33e-02. acc. prob=0.79]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 7
#       1 sccoda_data = sccoda_model.prepare(
#       2     sccoda_data,
#       3     modality_key="coda",
#       4     formula="condition",
#       5     reference_cell_type="automatic",
#       6 )
# ----> 7 sccoda_model.run_nuts(sccoda_data, modality_key="coda", rng_key=1234)
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/pertpy/tools/_coda/_sccoda.py:439, in Sccoda.run_nuts(self, data, modality_key, num_samples, num_warmup, rng_key, copy, *args, **kwargs)
#     414 def run_nuts(
#     415     self,
#     416     data: AnnData | MuData,
#    (...)
#     423     **kwargs,
#     424 ):
#     425     """
#     426     Examples:
#     427         >>> import pertpy as pt
#    (...)
#     437         >>> sccoda.run_nuts(mdata, num_warmup=100, num_samples=1000, rng_key=42)
#     438     """
# --> 439     return super().run_nuts(data, modality_key, num_samples, num_warmup, rng_key, copy, *args, **kwargs)
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/pertpy/tools/_coda/_base_coda.py:319, in CompositionalModel2.run_nuts(self, data, modality_key, num_samples, num_warmup, rng_key, copy, *args, **kwargs)
#     316 sample_adata.uns["scCODA_params"]["mcmc"]["num_warmup"] = num_warmup
#     317 sample_adata.uns["scCODA_params"]["mcmc"]["algorithm"] = "NUTS"
# --> 319 return self.__run_mcmc(
#     320     sample_adata, nuts_kernel, num_samples=num_samples, num_warmup=num_warmup, rng_key=rng_key_array, copy=copy
#     321 )
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/pertpy/tools/_coda/_base_coda.py:224, in CompositionalModel2.__run_mcmc(self, sample_adata, kernel, rng_key, copy, *args, **kwargs)
#     222 # Create mcmc attribute and run inference
#     223 self.mcmc = MCMC(kernel, *args, **kwargs)
# --> 224 self.mcmc.run(
#     225     rng_key,
#     226     numpyro_counts,
#     227     numpyro_covariates,
#     228     numpyro_n_total,
#     229     jnp.array(sample_adata.uns["scCODA_params"]["reference_index"]),
#     230     sample_adata,
#     231     extra_fields=extra_fields,
#     232 )
#     234 acc_rate = np.array(self.mcmc.last_state.mean_accept_prob)
#     235 if acc_rate < 0.6:
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/numpyro/infer/mcmc.py:644, in MCMC.run(self, rng_key, extra_fields, init_params, *args, **kwargs)
#     642 map_args = (rng_key, init_state, init_params)
#     643 if self.num_chains == 1:
# --> 644     states_flat, last_state = partial_map_fn(map_args)
#     645     states = tree_map(lambda x: x[jnp.newaxis, ...], states_flat)
#     646 else:
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/numpyro/infer/mcmc.py:450, in MCMC._single_chain_mcmc(self, init, args, kwargs, collect_fields)
#     444 collection_size = self._collection_params["collection_size"]
#     445 collection_size = (
#     446     collection_size
#     447     if collection_size is None
#     448     else collection_size // self.thinning
#     449 )
# --> 450 collect_vals = fori_collect(
#     451     lower_idx,
#     452     upper_idx,
#     453     sample_fn,
#     454     init_val,
#     455     transform=_collect_fn(collect_fields),
#     456     progbar=self.progress_bar,
#     457     return_last_val=True,
#     458     thinning=self.thinning,
#     459     collection_size=collection_size,
#     460     progbar_desc=partial(_get_progbar_desc_str, lower_idx, phase),
#     461     diagnostics_fn=diagnostics,
#     462     num_chains=self.num_chains if self.chain_method == "parallel" else 1,
#     463 )
#     464 states, last_val = collect_vals
#     465 # Get first argument of type `HMCState`
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/numpyro/util.py:367, in fori_collect(lower, upper, body_fun, init_val, transform, progbar, return_last_val, collection_size, thinning, **progbar_opts)
#     365 with tqdm.trange(upper) as t:
#     366     for i in t:
# --> 367         vals = jit(_body_fn)(i, vals)
#     368         t.set_description(progbar_desc(i), refresh=False)
#     369         if diagnostics_fn:
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/jax/_src/prng.py:300, in prngkeyarray_unflatten(impl, children)
#     297 def prngkeyarray_flatten(x):
#     298   return (x._base_array,), x._impl
# --> 300 def prngkeyarray_unflatten(impl, children):
#     301   base_array, = children
#     302   return PRNGKeyArray(impl, base_array)
#
# KeyboardInterrupt:

# %%
sccoda_data

# %%
sccoda_model.set_fdr(sccoda_data, 0.2)

# %%
sccoda_model.credible_effects(sccoda_data, modality_key="coda")

# %%
sccoda_data["coda"].varm["effect_df_genotype[T.Pkp2_HetKO]"]

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=sccoda_data["coda"].varm["effect_df_genotype[T.Pkp2_HetKO]"], x="Cell Type", y="log2-fold change", hue="Cell Type")

# %%
pt.pl.coda.effects_barplot(sccoda_data, "coda", "genotype")
plt.show()
