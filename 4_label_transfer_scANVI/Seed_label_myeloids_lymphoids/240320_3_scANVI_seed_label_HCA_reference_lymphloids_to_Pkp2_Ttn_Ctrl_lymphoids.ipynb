# %% [markdown]
# ### Notebook for the label transfer of Healthy Human Reference to mouse ACM heart (merged Pkp2+Ttn dataset) using `scANVI`
#
# #### Environment: scANVI
#
# - **Developed by:** Carlos Talavera-López Ph.D
# - **Modified by:** Alexandra Cirnu
# - **Würzburg Institute for Systems Immunology & Julius-Maximilian-Universität Würzburg**
# - **Date of creation:** 230918
# - **Date of modification:** 240320
#
# #### Transfer the **lypmphloids** from Healthy Human cell atlas to **lymphoids** of ACM Ctr noninf mice (Pkp2 + Ttn)

# %% [markdown]
# ### Import required modules

# %%
import scvi
import torch
import anndata
import warnings
import numpy as np
import scanpy as sc
import pandas as pd
import plotnine as p
from pywaffle import Waffle
import matplotlib.pyplot as plt
from scib_metrics.benchmark import Benchmarker

# %% [markdown]
# ### Set up working environment

# %%
sc.settings.verbosity = 3
sc.logging.print_versions()
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# Out:
# -----
# anndata     0.10.5.post1
# scanpy      1.9.8
# -----
# PIL                 10.2.0
# absl                NA
# array_api_compat    1.4.1
# asttokens           NA
# attr                23.2.0
# chex                0.1.85
# colorama            0.4.6
# comm                0.2.1
# contextlib2         NA
# cycler              0.12.1
# cython_runtime      NA
# dateutil            2.9.0
# debugpy             1.8.1
# decorator           5.1.1
# docrep              0.3.2
# etils               1.7.0
# exceptiongroup      1.2.0
# executing           2.0.1
# flax                0.8.1
# fsspec              2024.2.0
# h5py                3.10.0
# igraph              0.11.4
# importlib_resources NA
# ipykernel           6.29.3
# ipywidgets          8.1.2
# jax                 0.4.25
# jaxlib              0.4.25
# jedi                0.19.1
# joblib              1.3.2
# kiwisolver          1.4.5
# lightning           2.1.4
# lightning_utilities 0.10.1
# llvmlite            0.42.0
# matplotlib          3.8.3
# matplotlib_inline   0.1.6
# mizani              0.11.0
# ml_collections      NA
# ml_dtypes           0.3.2
# mpl_toolkits        NA
# mpmath              1.3.0
# msgpack             1.0.8
# mudata              0.2.3
# multipledispatch    0.6.0
# natsort             8.4.0
# numba               0.59.0
# numpy               1.26.4
# numpyro             0.14.0
# opt_einsum          v3.3.0
# optax               0.1.9
# packaging           23.2
# pandas              2.2.1
# parso               0.8.3
# pkg_resources       NA
# platformdirs        4.2.0
# plotnine            0.13.0
# plottable           0.1.5
# prompt_toolkit      3.0.43
# psutil              5.9.8
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.17.2
# pynndescent         0.5.11
# pyparsing           3.1.1
# pyro                1.9.0
# pytz                2024.1
# pywaffle            NA
# rich                NA
# scib_metrics        0.5.1
# scipy               1.12.0
# scvi                1.1.2
# session_info        1.0.0
# six                 1.16.0
# sklearn             1.4.1.post1
# skmisc              0.3.1
# stack_data          0.6.3
# sympy               1.12
# texttable           1.7.0
# threadpoolctl       3.3.0
# toolz               0.12.1
# torch               2.2.1+cu121
# torchgen            NA
# torchmetrics        1.3.1
# tornado             6.4
# tqdm                4.66.2
# traitlets           5.14.1
# typing_extensions   NA
# umap                0.5.5
# vscode              NA
# wcwidth             0.2.13
# yaml                6.0.1
# zmq                 25.1.2
# zoneinfo            NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-6.6.14-100.fc38.x86_64-x86_64-with-glibc2.37
# -----
# Session information updated at 2024-03-20 16:24

# %%
def X_is_raw(adata): return np.array_equal(adata.X.sum(axis=0).astype(int), adata.X.sum(axis=0))

# %%
torch.set_float32_matmul_precision('high')

# %%
warnings.simplefilter(action = 'ignore')
scvi.settings.seed = 1712
# %config InlineBackend.print_figure_kwargs = {'facecolor' : "w"}
# %config InlineBackend.figure_format = 'retina'
# Out:
# Seed set to 1712

# %%
arches_params = dict(
    use_layer_norm = "both",
    use_batch_norm = "none",
    encode_covariates = True,
    dropout_rate = 0.2,
    n_layers = 2,
)

# %% [markdown]
# ### Read in Healthy data

# %%
# Data set with lineage information from Healthy human heart leucocytes (from Human cell atlas) 

reference = sc.read_h5ad('/home/acirnu/data/ACM_cardiac_leuco/Reference_data/HCA_lymphoids_healthy_reference_ac240319.raw.h5ad')
reference
# Out:
# AnnData object with n_obs × n_vars = 16403 × 33538
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage'
#     uns: 'cell_states_colors', 'scNym_colors', 'scNym_probabilities'
#     obsm: 'X_pca', 'X_scnym', 'X_umap'
#     layers: 'counts'

# %%
X_is_raw(reference)
# Out:
# True

# %%
reference.obs
# Out:
#                                     NRP     cell_source  cell_states donor  \
# AAAGTGAAGTCGGCCT-1-H0015_apex        No  Harvard-Nuclei  CD4+T_cytox    H5
# AAATGGAAGGTCCCTG-1-H0015_apex        No  Harvard-Nuclei  CD4+T_cytox    H5
# AAGTTCGCAGTGTATC-1-H0015_apex        No  Harvard-Nuclei  CD4+T_cytox    H5
# AATCACGTCCCGTAAA-1-H0015_apex        No  Harvard-Nuclei    CD8+T_tem    H5
# AATGACCGTGTTGCCG-1-H0015_apex        No  Harvard-Nuclei           NK    H5
# ...                                 ...             ...          ...   ...
# TTTCACATCGAACACT-1-HCAHeart8102862  Yes     Sanger-CD45      B_cells   D11
# TTTCAGTCAGTACTAC-1-HCAHeart8102862  Yes     Sanger-CD45          NKT   D11
# TTTCGATAGCGCGTTC-1-HCAHeart8102862  Yes     Sanger-CD45           NK   D11
# TTTGACTGTATGAGAT-1-HCAHeart8102862  Yes     Sanger-CD45    CD8+T_tem   D11
# TTTGATCGTGTCATGT-1-HCAHeart8102862  Yes     Sanger-CD45  CD4+T_cytox   D11
#
#                                     gender    n_counts  n_genes region  \
# AAAGTGAAGTCGGCCT-1-H0015_apex       Female  724.717285      588     AX
# AAATGGAAGGTCCCTG-1-H0015_apex       Female  668.059509      515     AX
# AAGTTCGCAGTGTATC-1-H0015_apex       Female  759.100281      633     AX
# AATCACGTCCCGTAAA-1-H0015_apex       Female  715.088623      604     AX
# AATGACCGTGTTGCCG-1-H0015_apex       Female  743.207153      645     AX
# ...                                    ...         ...      ...    ...
# TTTCACATCGAACACT-1-HCAHeart8102862  Female  736.678040     1991     AX
# TTTCAGTCAGTACTAC-1-HCAHeart8102862  Female  774.458374     1108     AX
# TTTCGATAGCGCGTTC-1-HCAHeart8102862  Female  778.039612     1215     AX
# TTTGACTGTATGAGAT-1-HCAHeart8102862  Female  707.116882      957     AX
# TTTGATCGTGTCATGT-1-HCAHeart8102862  Female  631.149170      715     AX
#
#                                              sample       scNym  \
# AAAGTGAAGTCGGCCT-1-H0015_apex            H0015_apex  CD4+T_cell
# AAATGGAAGGTCCCTG-1-H0015_apex            H0015_apex  CD4+T_cell
# AAGTTCGCAGTGTATC-1-H0015_apex            H0015_apex  CD4+T_cell
# AATCACGTCCCGTAAA-1-H0015_apex            H0015_apex  CD4+T_cell
# AATGACCGTGTTGCCG-1-H0015_apex            H0015_apex          NK
# ...                                             ...         ...
# TTTCACATCGAACACT-1-HCAHeart8102862  HCAHeart8102862          DC
# TTTCAGTCAGTACTAC-1-HCAHeart8102862  HCAHeart8102862          NK
# TTTCGATAGCGCGTTC-1-HCAHeart8102862  HCAHeart8102862          NK
# TTTGACTGTATGAGAT-1-HCAHeart8102862  HCAHeart8102862  CD8+T_cell
# TTTGATCGTGTCATGT-1-HCAHeart8102862  HCAHeart8102862  CD8+T_cell
#
#                                     scNym_confidence   lineage
# AAAGTGAAGTCGGCCT-1-H0015_apex               0.797180  lymphoid
# AAATGGAAGGTCCCTG-1-H0015_apex               0.999248  lymphoid
# AAGTTCGCAGTGTATC-1-H0015_apex               0.979933  lymphoid
# AATCACGTCCCGTAAA-1-H0015_apex               0.987953  lymphoid
# AATGACCGTGTTGCCG-1-H0015_apex               0.759773  lymphoid
# ...                                              ...       ...
# TTTCACATCGAACACT-1-HCAHeart8102862          0.999435  lymphoid
# TTTCAGTCAGTACTAC-1-HCAHeart8102862          0.985920  lymphoid
# TTTCGATAGCGCGTTC-1-HCAHeart8102862          0.984224  lymphoid
# TTTGACTGTATGAGAT-1-HCAHeart8102862          0.982434  lymphoid
# TTTGATCGTGTCATGT-1-HCAHeart8102862          0.756579  lymphoid
#
# [16403 rows x 12 columns]

# %%
reference.obs["general_cell_types"] = reference.obs['cell_states'].copy()
reference.obs["general_cell_types"].cat.categories
# Out:
# Index(['NK', 'CD4+T_cytox', 'CD8+T_tem', 'CD8+T_cytox', 'NKT', 'B_cells',
#        'CD4+T_tem'],
#       dtype='object')

# %%
trans_from = [  
              ['NK'],                                                   #NK
              ['CD4+T_cytox', 'CD4+T_tem'],                             #CD4
              ['CD8+T_tem', 'CD8+T_cytox'],                             #CD8
              ['NKT'],                                                  #NKT
              ['B_cells']                                               #B

]

trans_to = ['NK', 'CD4', 'CD8', 'NKT', 'B']

reference.obs['general_cell_types'] = [str(i) for i in reference.obs['cell_states']]
for leiden,celltype in zip(trans_from, trans_to):
    for leiden_from in leiden:
        reference.obs['general_cell_types'][reference.obs['general_cell_types'] == leiden_from] = celltype

# %%
reference.obs
# Out:
#                                     NRP     cell_source  cell_states donor  \
# AAAGTGAAGTCGGCCT-1-H0015_apex        No  Harvard-Nuclei  CD4+T_cytox    H5
# AAATGGAAGGTCCCTG-1-H0015_apex        No  Harvard-Nuclei  CD4+T_cytox    H5
# AAGTTCGCAGTGTATC-1-H0015_apex        No  Harvard-Nuclei  CD4+T_cytox    H5
# AATCACGTCCCGTAAA-1-H0015_apex        No  Harvard-Nuclei    CD8+T_tem    H5
# AATGACCGTGTTGCCG-1-H0015_apex        No  Harvard-Nuclei           NK    H5
# ...                                 ...             ...          ...   ...
# TTTCACATCGAACACT-1-HCAHeart8102862  Yes     Sanger-CD45      B_cells   D11
# TTTCAGTCAGTACTAC-1-HCAHeart8102862  Yes     Sanger-CD45          NKT   D11
# TTTCGATAGCGCGTTC-1-HCAHeart8102862  Yes     Sanger-CD45           NK   D11
# TTTGACTGTATGAGAT-1-HCAHeart8102862  Yes     Sanger-CD45    CD8+T_tem   D11
# TTTGATCGTGTCATGT-1-HCAHeart8102862  Yes     Sanger-CD45  CD4+T_cytox   D11
#
#                                     gender    n_counts  n_genes region  \
# AAAGTGAAGTCGGCCT-1-H0015_apex       Female  724.717285      588     AX
# AAATGGAAGGTCCCTG-1-H0015_apex       Female  668.059509      515     AX
# AAGTTCGCAGTGTATC-1-H0015_apex       Female  759.100281      633     AX
# AATCACGTCCCGTAAA-1-H0015_apex       Female  715.088623      604     AX
# AATGACCGTGTTGCCG-1-H0015_apex       Female  743.207153      645     AX
# ...                                    ...         ...      ...    ...
# TTTCACATCGAACACT-1-HCAHeart8102862  Female  736.678040     1991     AX
# TTTCAGTCAGTACTAC-1-HCAHeart8102862  Female  774.458374     1108     AX
# TTTCGATAGCGCGTTC-1-HCAHeart8102862  Female  778.039612     1215     AX
# TTTGACTGTATGAGAT-1-HCAHeart8102862  Female  707.116882      957     AX
# TTTGATCGTGTCATGT-1-HCAHeart8102862  Female  631.149170      715     AX
#
#                                              sample       scNym  \
# AAAGTGAAGTCGGCCT-1-H0015_apex            H0015_apex  CD4+T_cell
# AAATGGAAGGTCCCTG-1-H0015_apex            H0015_apex  CD4+T_cell
# AAGTTCGCAGTGTATC-1-H0015_apex            H0015_apex  CD4+T_cell
# AATCACGTCCCGTAAA-1-H0015_apex            H0015_apex  CD4+T_cell
# AATGACCGTGTTGCCG-1-H0015_apex            H0015_apex          NK
# ...                                             ...         ...
# TTTCACATCGAACACT-1-HCAHeart8102862  HCAHeart8102862          DC
# TTTCAGTCAGTACTAC-1-HCAHeart8102862  HCAHeart8102862          NK
# TTTCGATAGCGCGTTC-1-HCAHeart8102862  HCAHeart8102862          NK
# TTTGACTGTATGAGAT-1-HCAHeart8102862  HCAHeart8102862  CD8+T_cell
# TTTGATCGTGTCATGT-1-HCAHeart8102862  HCAHeart8102862  CD8+T_cell
#
#                                     scNym_confidence   lineage  \
# AAAGTGAAGTCGGCCT-1-H0015_apex               0.797180  lymphoid
# AAATGGAAGGTCCCTG-1-H0015_apex               0.999248  lymphoid
# AAGTTCGCAGTGTATC-1-H0015_apex               0.979933  lymphoid
# AATCACGTCCCGTAAA-1-H0015_apex               0.987953  lymphoid
# AATGACCGTGTTGCCG-1-H0015_apex               0.759773  lymphoid
# ...                                              ...       ...
# TTTCACATCGAACACT-1-HCAHeart8102862          0.999435  lymphoid
# TTTCAGTCAGTACTAC-1-HCAHeart8102862          0.985920  lymphoid
# TTTCGATAGCGCGTTC-1-HCAHeart8102862          0.984224  lymphoid
# TTTGACTGTATGAGAT-1-HCAHeart8102862          0.982434  lymphoid
# TTTGATCGTGTCATGT-1-HCAHeart8102862          0.756579  lymphoid
#
#                                    general_cell_types
# AAAGTGAAGTCGGCCT-1-H0015_apex                     CD4
# AAATGGAAGGTCCCTG-1-H0015_apex                     CD4
# AAGTTCGCAGTGTATC-1-H0015_apex                     CD4
# AATCACGTCCCGTAAA-1-H0015_apex                     CD8
# AATGACCGTGTTGCCG-1-H0015_apex                      NK
# ...                                               ...
# TTTCACATCGAACACT-1-HCAHeart8102862                  B
# TTTCAGTCAGTACTAC-1-HCAHeart8102862                NKT
# TTTCGATAGCGCGTTC-1-HCAHeart8102862                 NK
# TTTGACTGTATGAGAT-1-HCAHeart8102862                CD8
# TTTGATCGTGTCATGT-1-HCAHeart8102862                CD4
#
# [16403 rows x 13 columns]

# %%
reference.obs['seed_labels'] = reference.obs['general_cell_types'].copy()

# %%
reference.obs['seed_labels'].value_counts()
# Out:
# seed_labels
# CD8    5957
# CD4    4160
# NK     3628
# NKT    1463
# B      1195
# Name: count, dtype: int64

# %% [markdown]
# ### Subset populations of interest

# %%
reference = reference[~reference.obs['seed_labels'].isin(['nan'])]              # = filter out not assigned cells, keep everything that is not 'nan'
reference.obs['seed_labels'].value_counts()
# Out:
# seed_labels
# CD8    5957
# CD4    4160
# NK     3628
# NKT    1463
# B      1195
# Name: count, dtype: int64

# %%
sc.pp.filter_cells(reference, min_genes = 200)            
sc.pp.filter_cells(reference, min_counts = 100)

# %% [markdown]
# ### Read in query

# %%
#Merged Pkp2+Ttn Libraries subsetted to contain only control mice (Pkp_Ctr_noninf and Ttn_Ctr_noninf)

query = sc.read_h5ad('/home/acirnu/data/ACM_cardiac_leuco/scANVI/ACM_scANVI_extracted_lymphoids_ac240319.raw.h5ad')
query.obs['cell_source'] = 'AG_Gerull'
query.obs['seed_labels'] = 'Unknown'
query.obs['donor'] = query.obs['sample'].copy()
query
# Out:
# AnnData object with n_obs × n_vars = 10104 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'n_genes', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'batch', '_scvi_batch', '_scvi_labels', 'C_scANVI'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'

# %%
query = query[query.obs['condition'].isin(["Pkp2_Ctr_noninf", "Ttn_Ctr_noninf"]) , :]
del(query.obs['batch'])
query.obs
# Out:
#                       cell_source              donor  n_counts  n_genes  \
# AAACCCAAGATACAGT-1-A1   AG_Gerull  Pkp2_Ctr_noninf_2    8562.0     2769
# AACCCAATCAGCTGAT-1-A1   AG_Gerull  Pkp2_Ctr_noninf_1   14129.0     3741
# AACCTGAAGATAGCAT-1-A1   AG_Gerull  Pkp2_Ctr_noninf_1   14171.0     3170
# AACGTCAAGCTACTGT-1-A1   AG_Gerull  Pkp2_Ctr_noninf_2    2057.0     1147
# AACTTCTCAAGCGCTC-1-A1   AG_Gerull  Pkp2_Ctr_noninf_2    9940.0     2786
# ...                           ...                ...       ...      ...
# TTGGTTTGTAAGTAGT-1-B2   AG_Gerull   Ttn_Ctr_noninf_2    8900.0     2912
# TTGTGGAGTATTGAGA-1-B2   AG_Gerull   Ttn_Ctr_noninf_2    2299.0     1251
# TTGTTCAGTGGCAGAT-1-B2   AG_Gerull   Ttn_Ctr_noninf_1    6256.0     2130
# TTTACTGAGTGTTCCA-1-B2   AG_Gerull   Ttn_Ctr_noninf_1    2371.0     1268
# TTTCACAAGCTAAACA-1-B2   AG_Gerull   Ttn_Ctr_noninf_1    9368.0     3140
#
#                                   sample seed_labels        condition  \
# AAACCCAAGATACAGT-1-A1  Pkp2_Ctr_noninf_2     Unknown  Pkp2_Ctr_noninf
# AACCCAATCAGCTGAT-1-A1  Pkp2_Ctr_noninf_1     Unknown  Pkp2_Ctr_noninf
# AACCTGAAGATAGCAT-1-A1  Pkp2_Ctr_noninf_1     Unknown  Pkp2_Ctr_noninf
# AACGTCAAGCTACTGT-1-A1  Pkp2_Ctr_noninf_2     Unknown  Pkp2_Ctr_noninf
# AACTTCTCAAGCGCTC-1-A1  Pkp2_Ctr_noninf_2     Unknown  Pkp2_Ctr_noninf
# ...                                  ...         ...              ...
# TTGGTTTGTAAGTAGT-1-B2   Ttn_Ctr_noninf_2     Unknown   Ttn_Ctr_noninf
# TTGTGGAGTATTGAGA-1-B2   Ttn_Ctr_noninf_2     Unknown   Ttn_Ctr_noninf
# TTGTTCAGTGGCAGAT-1-B2   Ttn_Ctr_noninf_1     Unknown   Ttn_Ctr_noninf
# TTTACTGAGTGTTCCA-1-B2   Ttn_Ctr_noninf_1     Unknown   Ttn_Ctr_noninf
# TTTCACAAGCTAAACA-1-B2   Ttn_Ctr_noninf_1     Unknown   Ttn_Ctr_noninf
#
#                        genotype infection library  ... total_counts_ribo  \
# AAACCCAAGATACAGT-1-A1  Pkp2_Ctr    noninf      A1  ...            2026.0
# AACCCAATCAGCTGAT-1-A1  Pkp2_Ctr    noninf      A1  ...            3231.0
# AACCTGAAGATAGCAT-1-A1  Pkp2_Ctr    noninf      A1  ...            3172.0
# AACGTCAAGCTACTGT-1-A1  Pkp2_Ctr    noninf      A1  ...              39.0
# AACTTCTCAAGCGCTC-1-A1  Pkp2_Ctr    noninf      A1  ...            2949.0
# ...                         ...       ...     ...  ...               ...
# TTGGTTTGTAAGTAGT-1-B2   Ttn_Ctr    noninf      B2  ...            1436.0
# TTGTGGAGTATTGAGA-1-B2   Ttn_Ctr    noninf      B2  ...              67.0
# TTGTTCAGTGGCAGAT-1-B2   Ttn_Ctr    noninf      B2  ...            1839.0
# TTTACTGAGTGTTCCA-1-B2   Ttn_Ctr    noninf      B2  ...              52.0
# TTTCACAAGCTAAACA-1-B2   Ttn_Ctr    noninf      B2  ...            1807.0
#
#                        pct_counts_ribo  percent_mt  percent_chrY  XIST-counts  \
# AAACCCAAGATACAGT-1-A1        23.662696    0.019038      0.000000          0.0
# AACCCAATCAGCTGAT-1-A1        22.867860    0.019817      0.021233          0.0
# AACCTGAAGATAGCAT-1-A1        22.383741    0.016230      0.063510          0.0
# AACGTCAAGCTACTGT-1-A1         1.895965    0.074866      0.194458          0.0
# AACTTCTCAAGCGCTC-1-A1        29.668008    0.022233      0.000000          0.0
# ...                                ...         ...           ...          ...
# TTGGTTTGTAAGTAGT-1-B2        16.134831    0.031573      0.033708          0.0
# TTGTGGAGTATTGAGA-1-B2         2.914311    0.058286      0.130492          0.0
# TTGTTCAGTGGCAGAT-1-B2        29.395780    0.025575      0.015985          0.0
# TTTACTGAGTGTTCCA-1-B2         2.193167    0.035428      0.210881          0.0
# TTTCACAAGCTAAACA-1-B2        19.289069    0.030209      0.032024          0.0
#
#                         S_score  G2M_score  _scvi_batch  _scvi_labels  \
# AAACCCAAGATACAGT-1-A1 -0.339369  -0.496060            7             1
# AACCCAATCAGCTGAT-1-A1  0.525671  -0.137838            6             1
# AACCTGAAGATAGCAT-1-A1 -0.268815  -0.516689            6             1
# AACGTCAAGCTACTGT-1-A1 -0.270605  -0.340320            7             1
# AACTTCTCAAGCGCTC-1-A1 -0.414867  -0.271517            7             1
# ...                         ...        ...          ...           ...
# TTGGTTTGTAAGTAGT-1-B2 -0.518748  -0.153977           24             2
# TTGTGGAGTATTGAGA-1-B2 -0.117061  -0.443566           24             2
# TTGTTCAGTGGCAGAT-1-B2  0.373745  -0.350468           23             2
# TTTACTGAGTGTTCCA-1-B2  0.327349  -0.098295           23             2
# TTTCACAAGCTAAACA-1-B2 -0.658761  -0.670969           23             2
#
#                        C_scANVI
# AAACCCAAGATACAGT-1-A1  lymphoid
# AACCCAATCAGCTGAT-1-A1  lymphoid
# AACCTGAAGATAGCAT-1-A1  lymphoid
# AACGTCAAGCTACTGT-1-A1  lymphoid
# AACTTCTCAAGCGCTC-1-A1  lymphoid
# ...                         ...
# TTGGTTTGTAAGTAGT-1-B2  lymphoid
# TTGTGGAGTATTGAGA-1-B2  lymphoid
# TTGTTCAGTGGCAGAT-1-B2  lymphoid
# TTTACTGAGTGTTCCA-1-B2  lymphoid
# TTTCACAAGCTAAACA-1-B2  lymphoid
#
# [1128 rows x 26 columns]

# %%
X_is_raw(query)
# Out:
# True

# %%
sc.pp.filter_cells(query, min_genes = 200)
sc.pp.filter_cells(query, min_counts = 100)

# %% [markdown]
# ### Change gene symbols for label transfer

# %%
query.var_names = [gene_name.upper() for gene_name in query.var_names]                      #capitalize gene names to match with the human genes from reference
query.var_names
# Out:
# Index(['XKR4', 'GM1992', 'GM19938', 'GM37381', 'RP1', 'SOX17', 'GM37587',
#        'GM37323', 'MRPL15', 'LYPLA1',
#        ...
#        'VMN2R122', 'IL11RA2-1', 'CCL27A-1', 'CCL21C-1', 'CCL27A-2',
#        'IL11RA2-2', 'CCL19-1', 'CCL21A-1', 'GM10931', 'GM16367'],
#       dtype='object', length=29378)

# %% [markdown]
# ### Merge reference and query (make sure the seed_labels of query are 'Unknown')

# %%
adata = reference.concatenate(query, batch_key = 'batch', batch_categories = ['reference', 'query'], join = 'inner')                #merge to one adata object
adata
# Out:
# AnnData object with n_obs × n_vars = 17531 × 16194
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage', 'general_cell_types', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'C_scANVI', 'batch'
#     var: 'gene_ids-query', 'feature_types-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-A1-query', 'mean_counts-A1-query', 'pct_dropout_by_counts-A1-query', 'total_counts-A1-query', 'n_cells_by_counts-A2-query', 'mean_counts-A2-query', 'pct_dropout_by_counts-A2-query', 'total_counts-A2-query', 'n_cells_by_counts-A3-query', 'mean_counts-A3-query', 'pct_dropout_by_counts-A3-query', 'total_counts-A3-query', 'n_cells_by_counts-A4-query', 'mean_counts-A4-query', 'pct_dropout_by_counts-A4-query', 'total_counts-A4-query', 'n_cells_by_counts-B1-query', 'mean_counts-B1-query', 'pct_dropout_by_counts-B1-query', 'total_counts-B1-query', 'n_cells_by_counts-B2-query', 'mean_counts-B2-query', 'pct_dropout_by_counts-B2-query', 'total_counts-B2-query'
#     obsm: 'X_umap'

# %%
adata.obs['seed_labels'] = adata.obs['seed_labels'].astype('category')
adata.obs['seed_labels'].cat.categories
# Out:
# Index(['B', 'CD4', 'CD8', 'NK', 'NKT', 'Unknown'], dtype='object')

# %%
adata.obs['batch'].value_counts()
# Out:
# batch
# reference    16403
# query         1128
# Name: count, dtype: int64

# %% [markdown]
# ### Select HVGs

# %%
adata.obs['donor'] = adata.obs['donor'].astype('str') 
adata.obs['donor'].value_counts()
# Out:
# donor
# D6                   4753
# D7                   3809
# D11                  2049
# H2                   1511
# H3                    707
# H5                    619
# H6                    578
# H4                    551
# H7                    526
# D2                    462
# D3                    376
# Pkp2_Ctr_noninf_2     298
# Ttn_Ctr_noninf_1      245
# D5                    220
# Ttn_Ctr_noninf_2      173
# D4                    168
# Pkp2_Ctr_noninf_4     163
# Pkp2_Ctr_noninf_1     136
# Pkp2_Ctr_noninf_3     113
# D1                     74
# Name: count, dtype: int64

# %%
adata_raw = adata.copy()
adata.layers['counts'] = adata.X.copy()

sc.pp.highly_variable_genes(
    adata,
    flavor = "seurat_v3",
    n_top_genes = 7000,
    layer = "counts",
    batch_key = "donor",
    subset = True,
    span = 1
    )

adata
# Out:
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'highly_variable_rank', float vector (adata.var)
#     'means', float vector (adata.var)
#     'variances', float vector (adata.var)
#     'variances_norm', float vector (adata.var)
# AnnData object with n_obs × n_vars = 17531 × 7000
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage', 'general_cell_types', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'C_scANVI', 'batch'
#     var: 'gene_ids-query', 'feature_types-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-A1-query', 'mean_counts-A1-query', 'pct_dropout_by_counts-A1-query', 'total_counts-A1-query', 'n_cells_by_counts-A2-query', 'mean_counts-A2-query', 'pct_dropout_by_counts-A2-query', 'total_counts-A2-query', 'n_cells_by_counts-A3-query', 'mean_counts-A3-query', 'pct_dropout_by_counts-A3-query', 'total_counts-A3-query', 'n_cells_by_counts-A4-query', 'mean_counts-A4-query', 'pct_dropout_by_counts-A4-query', 'total_counts-A4-query', 'n_cells_by_counts-B1-query', 'mean_counts-B1-query', 'pct_dropout_by_counts-B1-query', 'total_counts-B1-query', 'n_cells_by_counts-B2-query', 'mean_counts-B2-query', 'pct_dropout_by_counts-B2-query', 'total_counts-B2-query', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg'
#     obsm: 'X_umap'
#     layers: 'counts'

# %% [markdown]
# ### Transfer of annotation with scANVI

# %%
scvi.model.SCVI.setup_anndata(adata, 
                              batch_key = 'donor', 
                              labels_key = 'seed_labels',
                              layer = 'counts',
                              categorical_covariate_keys = ['donor', 'cell_source'])

# %%
scvi_model = scvi.model.SCVI(adata, 
                             n_latent = 50, 
                             n_layers = 3, 
                             dispersion = 'gene-batch', 
                             gene_likelihood = 'nb')

# %%
scvi_model.train(7, 
                 check_val_every_n_epoch = 1, 
                 enable_progress_bar = True,
                 accelerator = "gpu",
                 devices = [1]                                        
                 )
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Epoch 7/7: 100%|██████████| 7/7 [00:06<00:00,  1.01it/s, v_num=1, train_loss_step=1.89e+3, train_loss_epoch=1.9e+3]
# `Trainer.fit` stopped: `max_epochs=7` reached.
# Epoch 7/7: 100%|██████████| 7/7 [00:06<00:00,  1.01it/s, v_num=1, train_loss_step=1.89e+3, train_loss_epoch=1.9e+3]

# %% [markdown]
# ### Evaluate model performance a la _Sevensson_

# %%
history_df = (
    scvi_model.history['elbo_train'].astype(float)
    .join(scvi_model.history['elbo_validation'].astype(float))
    .reset_index()
    .melt(id_vars = ['epoch'])
)

p.options.figure_size = 12, 6

p_ = (
    p.ggplot(p.aes(x = 'epoch', y = 'value', color = 'variable'), history_df.query('epoch > 0'))
    + p.geom_line()
    + p.geom_point()
    + p.scale_color_manual({'elbo_train': 'black', 'elbo_validation': 'red'})
    + p.theme_minimal()
)

p_.save('fig1.png', dpi = 300)

print(p_)

# %% [markdown]
# - get latent representation

# %%
adata.obsm["X_scVI"] = scvi_model.get_latent_representation()

# %% [markdown]
# ### Label transfer with `scANVI`

# %%
scanvi_model = scvi.model.SCANVI.from_scvi_model(scvi_model, 'Unknown')

# %%
scanvi_model.train(6, 
                   check_val_every_n_epoch = 1, 
                   enable_progress_bar = True,
                   accelerator = "gpu",
                   devices = [1]                            
)
# Out:
# INFO     Training for 6 epochs.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Epoch 6/6: 100%|██████████| 6/6 [00:15<00:00,  2.55s/it, v_num=1, train_loss_step=1.8e+3, train_loss_epoch=1.87e+3]
# `Trainer.fit` stopped: `max_epochs=6` reached.
# Epoch 6/6: 100%|██████████| 6/6 [00:15<00:00,  2.57s/it, v_num=1, train_loss_step=1.8e+3, train_loss_epoch=1.87e+3]

# %% [markdown]
# ### Evaluate model performance a la Svensson

# %%
history_df = (
    scanvi_model.history['elbo_train'].astype(float)
    .join(scanvi_model.history['elbo_validation'].astype(float))
    .reset_index()
    .melt(id_vars = ['epoch'])
)

p.options.figure_size = 12, 6

p_ = (
    p.ggplot(p.aes(x = 'epoch', y = 'value', color = 'variable'), history_df.query('epoch > 0'))
    + p.geom_line()
    + p.geom_point()
    + p.scale_color_manual({'elbo_train': 'black', 'elbo_validation': 'red'})
    + p.theme_minimal()
)

p_.save('fig2.png', dpi = 300)

print(p_)

# %%
adata.obs["C_scANVI"] = scanvi_model.predict(adata)

# %% [markdown]
# - Extract latent representation

# %%
adata.obsm["X_scANVI"] = scanvi_model.get_latent_representation(adata)

# %%
adata.obs
# Out:
#                                          NRP     cell_source  cell_states  \
# AAAGTGAAGTCGGCCT-1-H0015_apex-reference   No  Harvard-Nuclei  CD4+T_cytox
# AAATGGAAGGTCCCTG-1-H0015_apex-reference   No  Harvard-Nuclei  CD4+T_cytox
# AAGTTCGCAGTGTATC-1-H0015_apex-reference   No  Harvard-Nuclei  CD4+T_cytox
# AATCACGTCCCGTAAA-1-H0015_apex-reference   No  Harvard-Nuclei    CD8+T_tem
# AATGACCGTGTTGCCG-1-H0015_apex-reference   No  Harvard-Nuclei           NK
# ...                                      ...             ...          ...
# TTGGTTTGTAAGTAGT-1-B2-query              NaN       AG_Gerull          NaN
# TTGTGGAGTATTGAGA-1-B2-query              NaN       AG_Gerull          NaN
# TTGTTCAGTGGCAGAT-1-B2-query              NaN       AG_Gerull          NaN
# TTTACTGAGTGTTCCA-1-B2-query              NaN       AG_Gerull          NaN
# TTTCACAAGCTAAACA-1-B2-query              NaN       AG_Gerull          NaN
#
#                                                     donor  gender  n_counts  \
# AAAGTGAAGTCGGCCT-1-H0015_apex-reference                H5  Female     724.0
# AAATGGAAGGTCCCTG-1-H0015_apex-reference                H5  Female     636.0
# AAGTTCGCAGTGTATC-1-H0015_apex-reference                H5  Female     769.0
# AATCACGTCCCGTAAA-1-H0015_apex-reference                H5  Female     797.0
# AATGACCGTGTTGCCG-1-H0015_apex-reference                H5  Female     820.0
# ...                                                   ...     ...       ...
# TTGGTTTGTAAGTAGT-1-B2-query              Ttn_Ctr_noninf_2     NaN    8435.0
# TTGTGGAGTATTGAGA-1-B2-query              Ttn_Ctr_noninf_2     NaN    2125.0
# TTGTTCAGTGGCAGAT-1-B2-query              Ttn_Ctr_noninf_1     NaN    5997.0
# TTTACTGAGTGTTCCA-1-B2-query              Ttn_Ctr_noninf_1     NaN    2251.0
# TTTCACAAGCTAAACA-1-B2-query              Ttn_Ctr_noninf_1     NaN    8955.0
#
#                                          n_genes region            sample  \
# AAAGTGAAGTCGGCCT-1-H0015_apex-reference      588     AX        H0015_apex
# AAATGGAAGGTCCCTG-1-H0015_apex-reference      515     AX        H0015_apex
# AAGTTCGCAGTGTATC-1-H0015_apex-reference      633     AX        H0015_apex
# AATCACGTCCCGTAAA-1-H0015_apex-reference      604     AX        H0015_apex
# AATGACCGTGTTGCCG-1-H0015_apex-reference      645     AX        H0015_apex
# ...                                          ...    ...               ...
# TTGGTTTGTAAGTAGT-1-B2-query                 2831    NaN  Ttn_Ctr_noninf_2
# TTGTGGAGTATTGAGA-1-B2-query                 1214    NaN  Ttn_Ctr_noninf_2
# TTGTTCAGTGGCAGAT-1-B2-query                 2071    NaN  Ttn_Ctr_noninf_1
# TTTACTGAGTGTTCCA-1-B2-query                 1230    NaN  Ttn_Ctr_noninf_1
# TTTCACAAGCTAAACA-1-B2-query                 3064    NaN  Ttn_Ctr_noninf_1
#
#                                               scNym  ...  pct_counts_ribo  \
# AAAGTGAAGTCGGCCT-1-H0015_apex-reference  CD4+T_cell  ...              NaN
# AAATGGAAGGTCCCTG-1-H0015_apex-reference  CD4+T_cell  ...              NaN
# AAGTTCGCAGTGTATC-1-H0015_apex-reference  CD4+T_cell  ...              NaN
# AATCACGTCCCGTAAA-1-H0015_apex-reference  CD4+T_cell  ...              NaN
# AATGACCGTGTTGCCG-1-H0015_apex-reference          NK  ...              NaN
# ...                                             ...  ...              ...
# TTGGTTTGTAAGTAGT-1-B2-query                     NaN  ...        16.134831
# TTGTGGAGTATTGAGA-1-B2-query                     NaN  ...         2.914311
# TTGTTCAGTGGCAGAT-1-B2-query                     NaN  ...        29.395780
# TTTACTGAGTGTTCCA-1-B2-query                     NaN  ...         2.193167
# TTTCACAAGCTAAACA-1-B2-query                     NaN  ...        19.289069
#
#                                         percent_mt percent_chrY XIST-counts  \
# AAAGTGAAGTCGGCCT-1-H0015_apex-reference        NaN          NaN         NaN
# AAATGGAAGGTCCCTG-1-H0015_apex-reference        NaN          NaN         NaN
# AAGTTCGCAGTGTATC-1-H0015_apex-reference        NaN          NaN         NaN
# AATCACGTCCCGTAAA-1-H0015_apex-reference        NaN          NaN         NaN
# AATGACCGTGTTGCCG-1-H0015_apex-reference        NaN          NaN         NaN
# ...                                            ...          ...         ...
# TTGGTTTGTAAGTAGT-1-B2-query               0.031573     0.033708         0.0
# TTGTGGAGTATTGAGA-1-B2-query               0.058286     0.130492         0.0
# TTGTTCAGTGGCAGAT-1-B2-query               0.025575     0.015985         0.0
# TTTACTGAGTGTTCCA-1-B2-query               0.035428     0.210881         0.0
# TTTCACAAGCTAAACA-1-B2-query               0.030209     0.032024         0.0
#
#                                           S_score G2M_score _scvi_batch  \
# AAAGTGAAGTCGGCCT-1-H0015_apex-reference       NaN       NaN          11
# AAATGGAAGGTCCCTG-1-H0015_apex-reference       NaN       NaN          11
# AAGTTCGCAGTGTATC-1-H0015_apex-reference       NaN       NaN          11
# AATCACGTCCCGTAAA-1-H0015_apex-reference       NaN       NaN          11
# AATGACCGTGTTGCCG-1-H0015_apex-reference       NaN       NaN          11
# ...                                           ...       ...         ...
# TTGGTTTGTAAGTAGT-1-B2-query             -0.518748 -0.153977          19
# TTGTGGAGTATTGAGA-1-B2-query             -0.117061 -0.443566          19
# TTGTTCAGTGGCAGAT-1-B2-query              0.373745 -0.350468          18
# TTTACTGAGTGTTCCA-1-B2-query              0.327349 -0.098295          18
# TTTCACAAGCTAAACA-1-B2-query             -0.658761 -0.670969          18
#
#                                         _scvi_labels C_scANVI      batch
# AAAGTGAAGTCGGCCT-1-H0015_apex-reference            1      CD4  reference
# AAATGGAAGGTCCCTG-1-H0015_apex-reference            1      CD4  reference
# AAGTTCGCAGTGTATC-1-H0015_apex-reference            1      CD8  reference
# AATCACGTCCCGTAAA-1-H0015_apex-reference            2      CD8  reference
# AATGACCGTGTTGCCG-1-H0015_apex-reference            3       NK  reference
# ...                                              ...      ...        ...
# TTGGTTTGTAAGTAGT-1-B2-query                        5      CD8      query
# TTGTGGAGTATTGAGA-1-B2-query                        5      CD4      query
# TTGTTCAGTGGCAGAT-1-B2-query                        5      CD8      query
# TTTACTGAGTGTTCCA-1-B2-query                        5      CD8      query
# TTTCACAAGCTAAACA-1-B2-query                        5      CD4      query
#
# [17531 rows x 35 columns]

# %% [markdown]
# - Visualise corrected dataset

# %%
sc.pp.neighbors(adata, use_rep = "X_scANVI", n_neighbors = 50, metric = 'minkowski')
sc.tl.umap(adata, min_dist = 0.3, spread = 4, random_state = 1712)
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:15)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:08)

# %%
sc.pl.umap(adata, frameon = False, color = ['C_scANVI', 'seed_labels', 'condition', 'batch', 'model'], size = 1, legend_fontsize = 5, ncols = 1)

# %% [markdown]
# ### Compute `scib-metrics`

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 17531 × 7000
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage', 'general_cell_types', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'C_scANVI', 'batch'
#     var: 'gene_ids-query', 'feature_types-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-A1-query', 'mean_counts-A1-query', 'pct_dropout_by_counts-A1-query', 'total_counts-A1-query', 'n_cells_by_counts-A2-query', 'mean_counts-A2-query', 'pct_dropout_by_counts-A2-query', 'total_counts-A2-query', 'n_cells_by_counts-A3-query', 'mean_counts-A3-query', 'pct_dropout_by_counts-A3-query', 'total_counts-A3-query', 'n_cells_by_counts-A4-query', 'mean_counts-A4-query', 'pct_dropout_by_counts-A4-query', 'total_counts-A4-query', 'n_cells_by_counts-B1-query', 'mean_counts-B1-query', 'pct_dropout_by_counts-B1-query', 'total_counts-B1-query', 'n_cells_by_counts-B2-query', 'mean_counts-B2-query', 'pct_dropout_by_counts-B2-query', 'total_counts-B2-query', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'hvg', '_scvi_uuid', '_scvi_manager_uuid', 'neighbors', 'umap', 'C_scANVI_colors', 'seed_labels_colors', 'condition_colors', 'batch_colors', 'model_colors'
#     obsm: 'X_umap', '_scvi_extra_categorical_covs', 'X_scVI', 'X_scANVI'
#     layers: 'counts'
#     obsp: 'distances', 'connectivities'

# %%
bm = Benchmarker(
    adata,
    batch_key="donor",
    label_key="seed_labels",                                       
    embedding_obsm_keys=["X_scVI", "X_scANVI", "X_pca"],
    n_jobs=-1,
)
bm.benchmark()
# Out:
# computing PCA
#     with n_comps=50
#     finished (0:00:04)
# Computing neighbors: 100%|██████████| 3/3 [00:22<00:00,  7.41s/it]
# Embeddings: 100%|██████████| 3/3 [01:40<00:00, 33.49s/it]

# %%
print(adata.X.dtype)
# Out:
# float64

# %%
bm.plot_results_table(min_max_scale=False)

# %%
df = bm.get_results(min_max_scale=False)
df.transpose()
# Out:
# Embedding             X_scVI  X_scANVI     X_pca       Metric Type
# Isolated labels     0.460512  0.374936  0.373969  Bio conservation
# KMeans NMI          0.329124  0.497113  0.061159  Bio conservation
# KMeans ARI          0.239871  0.398832  0.030797  Bio conservation
# Silhouette label    0.497371      0.57  0.422244  Bio conservation
# cLISI               0.923361  0.998519  0.820964  Bio conservation
# Silhouette batch    0.833703  0.841239  0.753557  Batch correction
# iLISI               0.053906  0.078877  0.044106  Batch correction
# KBET                0.163502  0.217075  0.179361  Batch correction
# Graph connectivity  0.769995  0.881659  0.537949  Batch correction
# PCR comparison             0         0       0.0  Batch correction
# Batch correction    0.364221   0.40377  0.302995   Aggregate score
# Bio conservation    0.490048   0.56788  0.341827   Aggregate score
# Total               0.439717  0.502236  0.326294   Aggregate score

# %% [markdown]
# ### Export annotated object

# %%
adata_export_merged = anndata.AnnData(X = adata_raw.X, var = adata_raw.var, obs = adata.obs)            #export a merged AnnData object with raw values from X and raw genes but modified observations
adata_export_merged
# Out:
# AnnData object with n_obs × n_vars = 17531 × 16194
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage', 'general_cell_types', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'C_scANVI', 'batch'
#     var: 'gene_ids-query', 'feature_types-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-A1-query', 'mean_counts-A1-query', 'pct_dropout_by_counts-A1-query', 'total_counts-A1-query', 'n_cells_by_counts-A2-query', 'mean_counts-A2-query', 'pct_dropout_by_counts-A2-query', 'total_counts-A2-query', 'n_cells_by_counts-A3-query', 'mean_counts-A3-query', 'pct_dropout_by_counts-A3-query', 'total_counts-A3-query', 'n_cells_by_counts-A4-query', 'mean_counts-A4-query', 'pct_dropout_by_counts-A4-query', 'total_counts-A4-query', 'n_cells_by_counts-B1-query', 'mean_counts-B1-query', 'pct_dropout_by_counts-B1-query', 'total_counts-B1-query', 'n_cells_by_counts-B2-query', 'mean_counts-B2-query', 'pct_dropout_by_counts-B2-query', 'total_counts-B2-query'

# %%
adata_export = adata_export_merged[adata_export_merged.obs['batch'].isin(['query'])]                    #subset merged data set to keep only query
adata_export
# Out:
# View of AnnData object with n_obs × n_vars = 1128 × 16194
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage', 'general_cell_types', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'C_scANVI', 'batch'
#     var: 'gene_ids-query', 'feature_types-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-A1-query', 'mean_counts-A1-query', 'pct_dropout_by_counts-A1-query', 'total_counts-A1-query', 'n_cells_by_counts-A2-query', 'mean_counts-A2-query', 'pct_dropout_by_counts-A2-query', 'total_counts-A2-query', 'n_cells_by_counts-A3-query', 'mean_counts-A3-query', 'pct_dropout_by_counts-A3-query', 'total_counts-A3-query', 'n_cells_by_counts-A4-query', 'mean_counts-A4-query', 'pct_dropout_by_counts-A4-query', 'total_counts-A4-query', 'n_cells_by_counts-B1-query', 'mean_counts-B1-query', 'pct_dropout_by_counts-B1-query', 'total_counts-B1-query', 'n_cells_by_counts-B2-query', 'mean_counts-B2-query', 'pct_dropout_by_counts-B2-query', 'total_counts-B2-query'

# %% [markdown]
# ### Add new gene symbols

# %%
query_export = anndata.AnnData(X = query.X, var = query.var, obs = adata_export.obs)                    #make sure to store the raw X values and the raw genes together with modified observations
query_export
# Out:
# AnnData object with n_obs × n_vars = 1128 × 29378
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage', 'general_cell_types', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'C_scANVI', 'batch'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'

# %% [markdown]
# ### Revert gene symbols

# %%
query_export.var_names = [gene_name.capitalize() for gene_name in query_export.var_names]           #restore mouse nomenclature
query_export.var_names
# Out:
# Index(['Xkr4', 'Gm1992', 'Gm19938', 'Gm37381', 'Rp1', 'Sox17', 'Gm37587',
#        'Gm37323', 'Mrpl15', 'Lypla1',
#        ...
#        'Vmn2r122', 'Il11ra2-1', 'Ccl27a-1', 'Ccl21c-1', 'Ccl27a-2',
#        'Il11ra2-2', 'Ccl19-1', 'Ccl21a-1', 'Gm10931', 'Gm16367'],
#       dtype='object', length=29378)

# %%
query_export.obs['C_scANVI'].value_counts()
# Out:
# C_scANVI
# CD4    550
# B      315
# CD8    205
# NKT     43
# NK      15
# Name: count, dtype: int64

# %%
query_export
# Out:
# AnnData object with n_obs × n_vars = 1128 × 29378
#     obs: 'NRP', 'cell_source', 'cell_states', 'donor', 'gender', 'n_counts', 'n_genes', 'region', 'sample', 'scNym', 'scNym_confidence', 'lineage', 'general_cell_types', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'C_scANVI', 'batch'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'

# %%
#Clean up metadata - delete all columns that came from merging with reference data set

del(query_export.obs['cell_states'])
del(query_export.obs['gender'])
del(query_export.obs['NRP'])
del(query_export.obs['region'])
del(query_export.obs['scNym'])
del(query_export.obs['scNym_confidence'])
del(query_export.obs['lineage'])

# %%
query_export.obs
# Out:
#                             cell_source              donor  n_counts  n_genes  \
# AAACCCAAGATACAGT-1-A1-query   AG_Gerull  Pkp2_Ctr_noninf_2    8265.0     2689
# AACCCAATCAGCTGAT-1-A1-query   AG_Gerull  Pkp2_Ctr_noninf_1   13594.0     3640
# AACCTGAAGATAGCAT-1-A1-query   AG_Gerull  Pkp2_Ctr_noninf_1   13182.0     3085
# AACGTCAAGCTACTGT-1-A1-query   AG_Gerull  Pkp2_Ctr_noninf_2    1860.0     1106
# AACTTCTCAAGCGCTC-1-A1-query   AG_Gerull  Pkp2_Ctr_noninf_2    9586.0     2703
# ...                                 ...                ...       ...      ...
# TTGGTTTGTAAGTAGT-1-B2-query   AG_Gerull   Ttn_Ctr_noninf_2    8435.0     2831
# TTGTGGAGTATTGAGA-1-B2-query   AG_Gerull   Ttn_Ctr_noninf_2    2125.0     1214
# TTGTTCAGTGGCAGAT-1-B2-query   AG_Gerull   Ttn_Ctr_noninf_1    5997.0     2071
# TTTACTGAGTGTTCCA-1-B2-query   AG_Gerull   Ttn_Ctr_noninf_1    2251.0     1230
# TTTCACAAGCTAAACA-1-B2-query   AG_Gerull   Ttn_Ctr_noninf_1    8955.0     3064
#
#                                         sample general_cell_types seed_labels  \
# AAACCCAAGATACAGT-1-A1-query  Pkp2_Ctr_noninf_2                NaN     Unknown
# AACCCAATCAGCTGAT-1-A1-query  Pkp2_Ctr_noninf_1                NaN     Unknown
# AACCTGAAGATAGCAT-1-A1-query  Pkp2_Ctr_noninf_1                NaN     Unknown
# AACGTCAAGCTACTGT-1-A1-query  Pkp2_Ctr_noninf_2                NaN     Unknown
# AACTTCTCAAGCGCTC-1-A1-query  Pkp2_Ctr_noninf_2                NaN     Unknown
# ...                                        ...                ...         ...
# TTGGTTTGTAAGTAGT-1-B2-query   Ttn_Ctr_noninf_2                NaN     Unknown
# TTGTGGAGTATTGAGA-1-B2-query   Ttn_Ctr_noninf_2                NaN     Unknown
# TTGTTCAGTGGCAGAT-1-B2-query   Ttn_Ctr_noninf_1                NaN     Unknown
# TTTACTGAGTGTTCCA-1-B2-query   Ttn_Ctr_noninf_1                NaN     Unknown
# TTTCACAAGCTAAACA-1-B2-query   Ttn_Ctr_noninf_1                NaN     Unknown
#
#                                    condition  genotype infection  ...  \
# AAACCCAAGATACAGT-1-A1-query  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf  ...
# AACCCAATCAGCTGAT-1-A1-query  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf  ...
# AACCTGAAGATAGCAT-1-A1-query  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf  ...
# AACGTCAAGCTACTGT-1-A1-query  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf  ...
# AACTTCTCAAGCGCTC-1-A1-query  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf  ...
# ...                                      ...       ...       ...  ...
# TTGGTTTGTAAGTAGT-1-B2-query   Ttn_Ctr_noninf   Ttn_Ctr    noninf  ...
# TTGTGGAGTATTGAGA-1-B2-query   Ttn_Ctr_noninf   Ttn_Ctr    noninf  ...
# TTGTTCAGTGGCAGAT-1-B2-query   Ttn_Ctr_noninf   Ttn_Ctr    noninf  ...
# TTTACTGAGTGTTCCA-1-B2-query   Ttn_Ctr_noninf   Ttn_Ctr    noninf  ...
# TTTCACAAGCTAAACA-1-B2-query   Ttn_Ctr_noninf   Ttn_Ctr    noninf  ...
#
#                             pct_counts_ribo percent_mt  percent_chrY  \
# AAACCCAAGATACAGT-1-A1-query       23.662696   0.019038      0.000000
# AACCCAATCAGCTGAT-1-A1-query       22.867860   0.019817      0.021233
# AACCTGAAGATAGCAT-1-A1-query       22.383741   0.016230      0.063510
# AACGTCAAGCTACTGT-1-A1-query        1.895965   0.074866      0.194458
# AACTTCTCAAGCGCTC-1-A1-query       29.668008   0.022233      0.000000
# ...                                     ...        ...           ...
# TTGGTTTGTAAGTAGT-1-B2-query       16.134831   0.031573      0.033708
# TTGTGGAGTATTGAGA-1-B2-query        2.914311   0.058286      0.130492
# TTGTTCAGTGGCAGAT-1-B2-query       29.395780   0.025575      0.015985
# TTTACTGAGTGTTCCA-1-B2-query        2.193167   0.035428      0.210881
# TTTCACAAGCTAAACA-1-B2-query       19.289069   0.030209      0.032024
#
#                              XIST-counts   S_score  G2M_score  _scvi_batch  \
# AAACCCAAGATACAGT-1-A1-query          0.0 -0.339369  -0.496060           15
# AACCCAATCAGCTGAT-1-A1-query          0.0  0.525671  -0.137838           14
# AACCTGAAGATAGCAT-1-A1-query          0.0 -0.268815  -0.516689           14
# AACGTCAAGCTACTGT-1-A1-query          0.0 -0.270605  -0.340320           15
# AACTTCTCAAGCGCTC-1-A1-query          0.0 -0.414867  -0.271517           15
# ...                                  ...       ...        ...          ...
# TTGGTTTGTAAGTAGT-1-B2-query          0.0 -0.518748  -0.153977           19
# TTGTGGAGTATTGAGA-1-B2-query          0.0 -0.117061  -0.443566           19
# TTGTTCAGTGGCAGAT-1-B2-query          0.0  0.373745  -0.350468           18
# TTTACTGAGTGTTCCA-1-B2-query          0.0  0.327349  -0.098295           18
# TTTCACAAGCTAAACA-1-B2-query          0.0 -0.658761  -0.670969           18
#
#                              _scvi_labels  C_scANVI  batch
# AAACCCAAGATACAGT-1-A1-query             5       CD4  query
# AACCCAATCAGCTGAT-1-A1-query             5       CD8  query
# AACCTGAAGATAGCAT-1-A1-query             5         B  query
# AACGTCAAGCTACTGT-1-A1-query             5       CD4  query
# AACTTCTCAAGCGCTC-1-A1-query             5       CD4  query
# ...                                   ...       ...    ...
# TTGGTTTGTAAGTAGT-1-B2-query             5       CD8  query
# TTGTGGAGTATTGAGA-1-B2-query             5       CD4  query
# TTGTTCAGTGGCAGAT-1-B2-query             5       CD8  query
# TTTACTGAGTGTTCCA-1-B2-query             5       CD8  query
# TTTCACAAGCTAAACA-1-B2-query             5       CD4  query
#
# [1128 rows x 28 columns]

# %%
query_export.write('/home/acirnu/data/ACM_cardiac_leuco/scANVI/Pkp2+Ttn_Ctrl_lymphoids_scANVI_cellstates_from_HCA_lymphoids_ac240320.raw.h5ad')

# %%
pd.crosstab(query_export.obs['C_scANVI'], query_export.obs['condition'])
# Out:
# condition  Pkp2_Ctr_noninf  Ttn_Ctr_noninf
# C_scANVI
# B                      183             132
# CD4                    343             207
# CD8                    139              66
# NK                      11               4
# NKT                     34               9
