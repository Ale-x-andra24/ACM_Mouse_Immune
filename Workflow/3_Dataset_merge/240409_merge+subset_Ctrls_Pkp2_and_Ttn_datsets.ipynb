# %% [markdown]
# ### Notebook for `merging` the Pkp2 and Ttn datasets of ACM murine cardiac leucocytes 6 month post MCMV infection
#
# #### Environment: Scanpy
#
# - **Developed by**: Alexandra Cirnu
# - **Modified by**: Alexandra Cirnu
# - **Würzburg Institute for Systems Immunology & Julius-Maximilian-Universität Würzburg**
# - **Date of creation**: 240220
# - **Date of modification**: 240409

# %% [markdown]
# ### Import required modules

# %%
import anndata
import numpy as np
import pandas as pd
import scanpy as sc
import muon as mu
from muon import atac as ac
from muon import prot as pt
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib import rcParams
from scipy.sparse import csr_matrix

# %%
# %matplotlib inline
sc.settings.verbosity = 3
sc.logging.print_versions()
sc.settings.set_figure_params(dpi = 160, color_map = 'RdPu', dpi_save = 180, vector_friendly = True, format = 'svg')
# Out:
# -----
# anndata     0.10.6
# scanpy      1.9.8
# -----
# PIL                 10.2.0
# appnope             0.1.4
# asttokens           NA
# colorama            0.4.6
# comm                0.2.1
# cycler              0.12.1
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.8.1
# decorator           5.1.1
# exceptiongroup      1.2.0
# executing           2.0.1
# h5py                3.10.0
# igraph              0.11.4
# ipykernel           6.29.2
# ipywidgets          8.1.2
# jedi                0.19.1
# joblib              1.3.2
# kiwisolver          1.4.5
# leidenalg           0.10.2
# llvmlite            0.42.0
# matplotlib          3.8.3
# matplotlib_inline   0.1.6
# mpl_toolkits        NA
# mudata              0.2.3
# muon                0.1.5
# natsort             8.4.0
# numba               0.59.0
# numpy               1.26.4
# packaging           23.2
# pandas              2.2.0
# parso               0.8.3
# patsy               0.5.6
# pickleshare         0.7.5
# platformdirs        4.2.0
# prompt_toolkit      3.0.42
# psutil              5.9.8
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.17.2
# pynndescent         0.5.11
# pyparsing           3.1.1
# pytz                2024.1
# scipy               1.12.0
# seaborn             0.13.2
# session_info        1.0.0
# six                 1.16.0
# sklearn             1.4.1.post1
# stack_data          0.6.2
# statsmodels         0.14.1
# texttable           1.7.0
# threadpoolctl       3.3.0
# tornado             6.4
# tqdm                4.66.2
# traitlets           5.14.1
# typing_extensions   NA
# umap                0.5.5
# vscode              NA
# wcwidth             0.2.13
# zmq                 25.1.2
# zoneinfo            NA
# -----
# IPython             8.21.0
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:35:25) [Clang 16.0.6 ]
# macOS-14.4.1-arm64-arm-64bit
# -----
# Session information updated at 2024-04-14 16:30

# %% [markdown]
# ## Read in all datasets

# %%
def X_is_raw(adata): return np.array_equal(adata.X.sum(axis=0).astype(int), adata.X.sum(axis=0))

# %%
mdata = mu.read_h5mu('/Users/alex/data/ACM_cardiac_leuco/processed_merged/Merge_demux_QCed_muon_ac240408.raw.h5mu')
mdata
# Out:
# /Users/alex/miniforge3/envs/Scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /Users/alex/miniforge3/envs/Scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# MuData object with n_obs × n_vars = 44594 × 32384
#   var:	'gene_ids', 'feature_types'
#   2 modalities
#     rna:	44594 x 32285
#       obs:	'sample', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'sample_colors'
#       layers:	'counts', 'sqrt_norm'
#     prot:	44594 x 99
#       obs:	'library'
#       var:	'gene_ids', 'feature_types'
#       uns:	'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap'
#       varm:	'PCs'
#       layers:	'counts', 'log_norm'
#       obsp:	'connectivities', 'distances'

# %%
adata = mdata.mod['rna']

# %%
adata.obs
# Out:
#                                     sample          condition    genotype  \
# AAACCCAAGAAGCGAA-1-A1  Pkp2_HetKO_noninf_1  Pkp2_HetKO_noninf  Pkp2_HetKO
# AAACCCAAGATACAGT-1-A1    Pkp2_Ctr_noninf_2    Pkp2_Ctr_noninf    Pkp2_Ctr
# AAACCCAAGTCTAACC-1-A1    Pkp2_HetKO_MCMV_2    Pkp2_HetKO_MCMV  Pkp2_HetKO
# AAACCCACAACCACGC-1-A1    Pkp2_HetKO_MCMV_3    Pkp2_HetKO_MCMV  Pkp2_HetKO
# AAACCCAGTGCTCTCT-1-A1    Pkp2_HetKO_MCMV_3    Pkp2_HetKO_MCMV  Pkp2_HetKO
# ...                                    ...                ...         ...
# TTTGTTGCAAGCTCTA-1-B2     Ttn_Ctr_noninf_1     Ttn_Ctr_noninf     Ttn_Ctr
# TTTGTTGGTACAGGTG-1-B2       Ttn_Ctr_MCMV_2       Ttn_Ctr_MCMV     Ttn_Ctr
# TTTGTTGGTAGTAAGT-1-B2     Ttn_HetKO_MCMV_2     Ttn_HetKO_MCMV   Ttn_HetKO
# TTTGTTGTCCCAGGAC-1-B2     Ttn_Ctr_noninf_2     Ttn_Ctr_noninf     Ttn_Ctr
# TTTGTTGTCCGGGACT-1-B2     Ttn_Ctr_noninf_2     Ttn_Ctr_noninf     Ttn_Ctr
#
#                       infection library model  n_genes_by_counts  \
# AAACCCAAGAAGCGAA-1-A1    noninf      A1  Pkp2               3786
# AAACCCAAGATACAGT-1-A1    noninf      A1  Pkp2               2769
# AAACCCAAGTCTAACC-1-A1      MCMV      A1  Pkp2               5514
# AAACCCACAACCACGC-1-A1      MCMV      A1  Pkp2               3097
# AAACCCAGTGCTCTCT-1-A1      MCMV      A1  Pkp2               2558
# ...                         ...     ...   ...                ...
# TTTGTTGCAAGCTCTA-1-B2    noninf      B2   Ttn               1849
# TTTGTTGGTACAGGTG-1-B2      MCMV      B2   Ttn               4744
# TTTGTTGGTAGTAAGT-1-B2      MCMV      B2   Ttn               2416
# TTTGTTGTCCCAGGAC-1-B2    noninf      B2   Ttn               2559
# TTTGTTGTCCGGGACT-1-B2    noninf      B2   Ttn               3333
#
#                        total_counts  doublet_scores  total_counts_mt  \
# AAACCCAAGAAGCGAA-1-A1       19322.0        0.158879            468.0
# AAACCCAAGATACAGT-1-A1        8562.0        0.037037            163.0
# AAACCCAAGTCTAACC-1-A1       30195.0        0.139442            569.0
# AAACCCACAACCACGC-1-A1       10116.0        0.066038            164.0
# AAACCCAGTGCTCTCT-1-A1        6153.0        0.027823            115.0
# ...                             ...             ...              ...
# TTTGTTGCAAGCTCTA-1-B2        3733.0        0.190000             65.0
# TTTGTTGGTACAGGTG-1-B2       24293.0        0.146919            905.0
# TTTGTTGGTAGTAAGT-1-B2        6564.0        0.040512             69.0
# TTTGTTGTCCCAGGAC-1-B2        6388.0        0.106383            148.0
# TTTGTTGTCCGGGACT-1-B2       10124.0        0.142857            186.0
#
#                        pct_counts_mt  total_counts_ribo  pct_counts_ribo  \
# AAACCCAAGAAGCGAA-1-A1       2.422109             3813.0        19.733982
# AAACCCAAGATACAGT-1-A1       1.903761             2026.0        23.662695
# AAACCCAAGTCTAACC-1-A1       1.884418             2666.0         8.829276
# AAACCCACAACCACGC-1-A1       1.621194              970.0         9.588771
# AAACCCAGTGCTCTCT-1-A1       1.869007              730.0        11.864132
# ...                              ...                ...              ...
# TTTGTTGCAAGCTCTA-1-B2       1.741227              189.0         5.062952
# TTTGTTGGTACAGGTG-1-B2       3.725353             3179.0        13.086075
# TTTGTTGGTAGTAAGT-1-B2       1.051188              983.0        14.975625
# TTTGTTGTCCCAGGAC-1-B2       2.316844              463.0         7.247965
# TTTGTTGTCCGGGACT-1-B2       1.837219              550.0         5.432635
#
#                        percent_mt  n_counts  percent_chrY  XIST-counts  \
# AAACCCAAGAAGCGAA-1-A1    0.024221   19322.0      0.056930          0.0
# AAACCCAAGATACAGT-1-A1    0.019038    8562.0      0.000000          0.0
# AAACCCAAGTCTAACC-1-A1    0.018844   30195.0      0.009935          0.0
# AAACCCACAACCACGC-1-A1    0.016212   10116.0      0.019771          0.0
# AAACCCAGTGCTCTCT-1-A1    0.018690    6153.0      0.065009          0.0
# ...                           ...       ...           ...          ...
# TTTGTTGCAAGCTCTA-1-B2    0.017412    3733.0      0.000000          0.0
# TTTGTTGGTACAGGTG-1-B2    0.037254   24293.0      0.000000         13.0
# TTTGTTGGTAGTAAGT-1-B2    0.010512    6564.0      0.030469          0.0
# TTTGTTGTCCCAGGAC-1-B2    0.023168    6388.0      0.140889          0.0
# TTTGTTGTCCGGGACT-1-B2    0.018372   10124.0      0.000000          0.0
#
#                         S_score  G2M_score
# AAACCCAAGAAGCGAA-1-A1 -0.583666  -0.626720
# AAACCCAAGATACAGT-1-A1 -0.339369  -0.496061
# AAACCCAAGTCTAACC-1-A1  2.894924   0.533799
# AAACCCACAACCACGC-1-A1 -0.006805  -0.399040
# AAACCCAGTGCTCTCT-1-A1 -0.340230  -0.079096
# ...                         ...        ...
# TTTGTTGCAAGCTCTA-1-B2 -0.179842  -0.495021
# TTTGTTGGTACAGGTG-1-B2 -0.435458  -0.744327
# TTTGTTGGTAGTAAGT-1-B2  0.363058  -0.589437
# TTTGTTGTCCCAGGAC-1-B2  0.080642  -0.877899
# TTTGTTGTCCGGGACT-1-B2 -0.865321  -0.612682
#
# [44594 rows x 19 columns]

# %% [markdown]
# ### Subset adata object and leave only Pkp2 Ctr noninf and Ttn Ctr noninf

# %%
adata = adata[adata.obs['condition'].isin(["Pkp2_Ctr_noninf", "Ttn_Ctr_noninf"]) , :]
adata.obs
# Out:
#                                   sample        condition  genotype infection  \
# AAACCCAAGATACAGT-1-A1  Pkp2_Ctr_noninf_2  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf
# AAACGCTGTTGTGTTG-1-A1  Pkp2_Ctr_noninf_1  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf
# AAACGCTTCTCGCTCA-1-A1  Pkp2_Ctr_noninf_1  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf
# AAAGGTACAGAACATA-1-A1  Pkp2_Ctr_noninf_2  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf
# AAAGTCCAGGGACACT-1-A1  Pkp2_Ctr_noninf_2  Pkp2_Ctr_noninf  Pkp2_Ctr    noninf
# ...                                  ...              ...       ...       ...
# TTTGGTTCACGCAGTC-1-B2   Ttn_Ctr_noninf_2   Ttn_Ctr_noninf   Ttn_Ctr    noninf
# TTTGGTTTCCTGTACC-1-B2   Ttn_Ctr_noninf_2   Ttn_Ctr_noninf   Ttn_Ctr    noninf
# TTTGTTGCAAGCTCTA-1-B2   Ttn_Ctr_noninf_1   Ttn_Ctr_noninf   Ttn_Ctr    noninf
# TTTGTTGTCCCAGGAC-1-B2   Ttn_Ctr_noninf_2   Ttn_Ctr_noninf   Ttn_Ctr    noninf
# TTTGTTGTCCGGGACT-1-B2   Ttn_Ctr_noninf_2   Ttn_Ctr_noninf   Ttn_Ctr    noninf
#
#                       library model  n_genes_by_counts  total_counts  \
# AAACCCAAGATACAGT-1-A1      A1  Pkp2               2769        8562.0
# AAACGCTGTTGTGTTG-1-A1      A1  Pkp2                365         750.0
# AAACGCTTCTCGCTCA-1-A1      A1  Pkp2               1599        3855.0
# AAAGGTACAGAACATA-1-A1      A1  Pkp2               3854       17536.0
# AAAGTCCAGGGACACT-1-A1      A1  Pkp2               3788       14174.0
# ...                       ...   ...                ...           ...
# TTTGGTTCACGCAGTC-1-B2      B2   Ttn               4219       18844.0
# TTTGGTTTCCTGTACC-1-B2      B2   Ttn               3321       11805.0
# TTTGTTGCAAGCTCTA-1-B2      B2   Ttn               1849        3733.0
# TTTGTTGTCCCAGGAC-1-B2      B2   Ttn               2559        6388.0
# TTTGTTGTCCGGGACT-1-B2      B2   Ttn               3333       10124.0
#
#                        doublet_scores  total_counts_mt  pct_counts_mt  \
# AAACCCAAGATACAGT-1-A1        0.037037            163.0       1.903761
# AAACGCTGTTGTGTTG-1-A1        0.056180            260.0      34.666668
# AAACGCTTCTCGCTCA-1-A1        0.083333            167.0       4.332036
# AAAGGTACAGAACATA-1-A1        0.088608            479.0       2.731524
# AAAGTCCAGGGACACT-1-A1        0.226994            330.0       2.328207
# ...                               ...              ...            ...
# TTTGGTTCACGCAGTC-1-B2        0.068120            683.0       3.624496
# TTTGGTTTCCTGTACC-1-B2        0.226994            263.0       2.227870
# TTTGTTGCAAGCTCTA-1-B2        0.190000             65.0       1.741227
# TTTGTTGTCCCAGGAC-1-B2        0.106383            148.0       2.316844
# TTTGTTGTCCGGGACT-1-B2        0.142857            186.0       1.837219
#
#                        total_counts_ribo  pct_counts_ribo  percent_mt  \
# AAACCCAAGATACAGT-1-A1             2026.0        23.662695    0.019038
# AAACGCTGTTGTGTTG-1-A1               34.0         4.533333    0.346667
# AAACGCTTCTCGCTCA-1-A1               70.0         1.815824    0.043320
# AAAGGTACAGAACATA-1-A1             1791.0        10.213275    0.027315
# AAAGTCCAGGGACACT-1-A1             2049.0        14.456045    0.023282
# ...                                  ...              ...         ...
# TTTGGTTCACGCAGTC-1-B2             2868.0        15.219699    0.036245
# TTTGGTTTCCTGTACC-1-B2             1469.0        12.443880    0.022279
# TTTGTTGCAAGCTCTA-1-B2              189.0         5.062952    0.017412
# TTTGTTGTCCCAGGAC-1-B2              463.0         7.247965    0.023168
# TTTGTTGTCCGGGACT-1-B2              550.0         5.432635    0.018372
#
#                        n_counts  percent_chrY  XIST-counts   S_score  \
# AAACCCAAGATACAGT-1-A1    8562.0      0.000000          0.0 -0.339369
# AAACGCTGTTGTGTTG-1-A1     750.0      0.000000          0.0 -0.019995
# AAACGCTTCTCGCTCA-1-A1    3855.0      0.025940          0.0 -0.169221
# AAAGGTACAGAACATA-1-A1   17536.0      0.051323          0.0 -0.317631
# AAAGTCCAGGGACACT-1-A1   14174.0      0.014110          0.0 -0.370103
# ...                         ...           ...          ...       ...
# TTTGGTTCACGCAGTC-1-B2   18844.0      0.000000          0.0 -0.901389
# TTTGGTTTCCTGTACC-1-B2   11805.0      0.025413          1.0 -0.277671
# TTTGTTGCAAGCTCTA-1-B2    3733.0      0.000000          0.0 -0.179842
# TTTGTTGTCCCAGGAC-1-B2    6388.0      0.140889          0.0  0.080642
# TTTGTTGTCCGGGACT-1-B2   10124.0      0.000000          0.0 -0.865321
#
#                        G2M_score
# AAACCCAAGATACAGT-1-A1  -0.496061
# AAACGCTGTTGTGTTG-1-A1  -0.083225
# AAACGCTTCTCGCTCA-1-A1  -0.390143
# AAAGGTACAGAACATA-1-A1  -0.578955
# AAAGTCCAGGGACACT-1-A1  -0.370084
# ...                          ...
# TTTGGTTCACGCAGTC-1-B2  -1.291862
# TTTGGTTTCCTGTACC-1-B2  -0.184796
# TTTGTTGCAAGCTCTA-1-B2  -0.495021
# TTTGTTGTCCCAGGAC-1-B2  -0.877899
# TTTGTTGTCCGGGACT-1-B2  -0.612682
#
# [7847 rows x 19 columns]

# %% [markdown]
# ### Check if raw data is stored in merged adata object

# %%
X_is_raw(adata)
# Out:
# True

# %% [markdown]
# #### Update the mdata object

# %%
mdata.mod['rna'] = adata
mdata
# Out:
# MuData object with n_obs × n_vars = 44594 × 32384
#   var:	'gene_ids', 'feature_types'
#   2 modalities
#     rna:	7847 x 32285
#       obs:	'sample', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       layers:	'counts', 'sqrt_norm'
#     prot:	44594 x 99
#       obs:	'library'
#       var:	'gene_ids', 'feature_types'
#       uns:	'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap'
#       varm:	'PCs'
#       layers:	'counts', 'log_norm'
#       obsp:	'connectivities', 'distances'

# %%
mdata.mod['prot'] = mdata.mod['prot'][mdata.mod['rna'].obs.index]
mdata.update()
mdata
# Out:
# MuData object with n_obs × n_vars = 7847 × 32384
#   var:	'gene_ids', 'feature_types'
#   2 modalities
#     rna:	7847 x 32285
#       obs:	'sample', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       layers:	'counts', 'sqrt_norm'
#     prot:	7847 x 99
#       obs:	'library'
#       var:	'gene_ids', 'feature_types'
#       uns:	'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap'
#       varm:	'PCs'
#       layers:	'counts', 'log_norm'
#       obsp:	'connectivities', 'distances'

# %% [markdown]
# ## Save merged object

# %%
mdata.write("/Users/alex/data/ACM_cardiac_leuco/processed_merged/Merge_demux_subset_Ctrls_QCed_muon_ac240409.raw.h5mu")
# Out:
# /Users/alex/miniforge3/envs/Scanpy/lib/python3.10/site-packages/anndata/_core/anndata.py:1209: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[key] = c
