# %% [markdown]
# # Compositional analysis of the ACM cardiac leucocytes 6mpi dataset (Pkp2+Ttn) - myeloids - using scCoda `pertpy`:
# - **Developed by**: Christian Eger
# - **Modified by**: Alexandra Cirnu
# - **Talavera-López Lab - Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg**
# - **Created on**: 231214
# - **Last modified**: 240503

# %% [markdown]
# #### Environment: scCoda
#
# To install `pertpy` on MacOS create a new mamba environment and activte it. Then go int 'github' folder and type 'git clone https://github.com/theislab/pertpy.git'. Change directory to 'pertpy' and type 'pip install .'
#
# Look at website to solve problem at the end: https://www.sc-best-practices.org/conditions/compositional.html

# %%
import warnings
import pandas as pd
warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")
import numpy as np
            #import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import altair as alt
import scanpy as sc
import pertpy as pt
from statannot import add_stat_annotation
from scipy import stats
import muon as mu
from muon import atac as ac
from muon import prot

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.5.post1
# scanpy      1.9.8
# -----
# PIL                         10.2.0
# absl                        NA
# adjustText                  1.0.4
# altair                      4.2.2
# arrow                       1.3.0
# arviz                       0.17.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# blitzgsea                   NA
# certifi                     2024.02.02
# cffi                        1.16.0
# chardet                     5.2.0
# charset_normalizer          3.3.2
# chex                        0.1.85
# colorama                    0.4.6
# comm                        0.2.1
# contextlib2                 NA
# custom_inherit              2.4.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.9.0
# debugpy                     1.8.1
# decorator                   5.1.1
# decoupler                   1.6.0
# docrep                      0.3.2
# entrypoints                 0.4
# etils                       1.7.0
# exceptiongroup              1.2.0
# executing                   2.0.1
# flax                        0.8.1
# fsspec                      2024.2.0
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# importlib_resources         NA
# ipykernel                   6.29.3
# ipywidgets                  8.1.2
# jax                         0.4.25
# jaxlib                      0.4.25
# jaxopt                      NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# lightning                   2.1.4
# lightning_fabric            2.2.0.post0
# lightning_utilities         0.10.1
# llvmlite                    0.42.0
# markupsafe                  2.1.5
# matplotlib                  3.8.3
# ml_collections              NA
# ml_dtypes                   0.3.2
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.8
# mudata                      0.2.3
# multipledispatch            0.6.0
# muon                        0.1.5
# natsort                     8.4.0
# numba                       0.59.0
# numpy                       1.26.4
# numpyro                     0.14.0
# opt_einsum                  v3.3.0
# optax                       0.1.9
# ott                         0.4.5
# packaging                   23.2
# pandas                      2.2.1
# parso                       0.8.3
# patsy                       0.5.6
# pertpy                      0.7.0
# pkg_resources               NA
# platformdirs                4.2.0
# ply                         3.11
# png                         0.20220715.0
# prompt_toolkit              3.0.43
# psutil                      5.9.8
# pubchempy                   1.0.4
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynndescent                 0.5.11
# pyomo                       6.7.1
# pyparsing                   3.1.1
# pyro                        1.9.0
# pytorch_lightning           2.2.0.post0
# pytz                        2024.1
# referencing                 NA
# reportlab                   4.1.0
# requests                    2.31.0
# rich                        NA
# rpds                        NA
# rpy2                        3.5.11
# scipy                       1.12.0
# scvi                        1.1.2
# seaborn                     0.13.2
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.4.1.post1
# skmisc                      0.3.1
# sparsecca                   0.3.1
# stack_data                  0.6.3
# statannot                   0.2.3
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# toolz                       0.12.1
# torch                       2.2.1+cu121
# torchgen                    NA
# torchmetrics                1.3.1
# tornado                     6.4
# toyplot                     1.0.3
# toytree                     2.0.1
# tqdm                        4.66.2
# traitlets                   5.14.1
# typing_extensions           NA
# tzlocal                     NA
# umap                        0.5.5
# urllib3                     2.2.1
# vscode                      NA
# wcwidth                     0.2.13
# xarray                      2024.2.0
# xarray_einstats             0.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-6.8.4-200.fc39.x86_64-x86_64-with-glibc2.38
# -----
# Session information updated at 2024-05-06 11:44

# %% [markdown]
# Manual git installation of pertpy necessary due to Apple silicon
# $ git clone https://github.com/theislab/pertpy.git
# $ cd pertpy
# $ pip install .

# %%
input = '/home/acirnu/data/ACM_cardiac_leuco/5_Leiden_clustering_and_annotation/ACM_myeloids_clustered_muon_ac240502.raw.h5mu'
mdata_data = mu.read_h5mu(input)
mdata_data
# Out:
# MuData object with n_obs × n_vars = 34482 × 29477
#   var:	'gene_ids', 'feature_types'
#   2 modalities
#     rna:	34482 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     prot:	34482 x 99
#       obs:	'library', 'batch'
#       var:	'gene_ids', 'feature_types'
#       uns:	'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap'
#       varm:	'PCs'
#       layers:	'counts', 'log_norm'

# %%
adata = mdata_data.mod["rna"]
adata
# Out:
# AnnData object with n_obs × n_vars = 34482 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo'
#     uns: 'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#                       cell_source              donor  n_counts  \
# AAACGCTGTTGTGTTG-1-A1   AG_Gerull  Pkp2_Ctr_noninf_1     478.0
# AAACGCTTCTCGCTCA-1-A1   AG_Gerull  Pkp2_Ctr_noninf_1    3581.0
# AAAGGTACAGAACATA-1-A1   AG_Gerull  Pkp2_Ctr_noninf_2   16539.0
# AAAGTCCAGGGACACT-1-A1   AG_Gerull  Pkp2_Ctr_noninf_2   13389.0
# AAAGTCCCAGTAGGAC-1-A1   AG_Gerull  Pkp2_Ctr_noninf_2   12092.0
# ...                           ...                ...       ...
# TTTGTTGAGGTTAGTA-1-B2   AG_Gerull   Ttn_HetKO_MCMV_1    4226.0
# TTTGTTGCAAGCTCTA-1-B2   AG_Gerull   Ttn_Ctr_noninf_1    3733.0
# TTTGTTGGTACAGGTG-1-B2   AG_Gerull     Ttn_Ctr_MCMV_2   24293.0
# TTTGTTGTCCCAGGAC-1-B2   AG_Gerull   Ttn_Ctr_noninf_2    6388.0
# TTTGTTGTCCGGGACT-1-B2   AG_Gerull   Ttn_Ctr_noninf_2   10124.0
#
#                                   sample seed_labels        condition  \
# AAACGCTGTTGTGTTG-1-A1  Pkp2_Ctr_noninf_1    DOCK4+MØ  Pkp2_Ctr_noninf
# AAACGCTTCTCGCTCA-1-A1  Pkp2_Ctr_noninf_1   Monocytes  Pkp2_Ctr_noninf
# AAAGGTACAGAACATA-1-A1  Pkp2_Ctr_noninf_2   Monocytes  Pkp2_Ctr_noninf
# AAAGTCCAGGGACACT-1-A1  Pkp2_Ctr_noninf_2    LYVE1+MØ  Pkp2_Ctr_noninf
# AAAGTCCCAGTAGGAC-1-A1  Pkp2_Ctr_noninf_2    LYVE1+MØ  Pkp2_Ctr_noninf
# ...                                  ...         ...              ...
# TTTGTTGAGGTTAGTA-1-B2   Ttn_HetKO_MCMV_1     Unknown   Ttn_HetKO_MCMV
# TTTGTTGCAAGCTCTA-1-B2   Ttn_Ctr_noninf_1     Unknown   Ttn_Ctr_noninf
# TTTGTTGGTACAGGTG-1-B2     Ttn_Ctr_MCMV_2     Unknown     Ttn_Ctr_MCMV
# TTTGTTGTCCCAGGAC-1-B2   Ttn_Ctr_noninf_2     Unknown   Ttn_Ctr_noninf
# TTTGTTGTCCGGGACT-1-B2   Ttn_Ctr_noninf_2     Unknown   Ttn_Ctr_noninf
#
#                         genotype infection library model  ...  percent_chrY  \
# AAACGCTGTTGTGTTG-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.000000
# AAACGCTTCTCGCTCA-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.025940
# AAAGGTACAGAACATA-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.051323
# AAAGTCCAGGGACACT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.014110
# AAAGTCCCAGTAGGAC-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.040006
# ...                          ...       ...     ...   ...  ...           ...
# TTTGTTGAGGTTAGTA-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...      0.141978
# TTTGTTGCAAGCTCTA-1-B2    Ttn_Ctr    noninf      B2   Ttn  ...      0.000000
# TTTGTTGGTACAGGTG-1-B2    Ttn_Ctr      MCMV      B2   Ttn  ...      0.000000
# TTTGTTGTCCCAGGAC-1-B2    Ttn_Ctr    noninf      B2   Ttn  ...      0.140889
# TTTGTTGTCCGGGACT-1-B2    Ttn_Ctr    noninf      B2   Ttn  ...      0.000000
#
#                        XIST-counts   S_score  G2M_score  _scvi_batch  \
# AAACGCTGTTGTGTTG-1-A1          0.0 -0.019995  -0.083225            6
# AAACGCTTCTCGCTCA-1-A1          0.0 -0.169221  -0.390143            6
# AAAGGTACAGAACATA-1-A1          0.0 -0.317631  -0.578955            7
# AAAGTCCAGGGACACT-1-A1          0.0 -0.370103  -0.370084            7
# AAAGTCCCAGTAGGAC-1-A1          0.0 -0.142503  -0.357287            7
# ...                            ...       ...        ...          ...
# TTTGTTGAGGTTAGTA-1-B2          0.0 -0.373712  -0.402608           25
# TTTGTTGCAAGCTCTA-1-B2          0.0 -0.179842  -0.495021           23
# TTTGTTGGTACAGGTG-1-B2         13.0 -0.435458  -0.744327           21
# TTTGTTGTCCCAGGAC-1-B2          0.0  0.080642  -0.877899           24
# TTTGTTGTCCGGGACT-1-B2          0.0 -0.865321  -0.612682           24
#
#                        _scvi_labels      batch     C_scANVI  leiden  \
# AAACGCTGTTGTGTTG-1-A1             1  reference     DOCK4+MØ       3
# AAACGCTTCTCGCTCA-1-A1             4  reference    Monocytes       3
# AAAGGTACAGAACATA-1-A1             4  reference    Monocytes       6
# AAAGTCCAGGGACACT-1-A1             2  reference     LYVE1+MØ       2
# AAAGTCCCAGTAGGAC-1-A1             2  reference     LYVE1+MØ       2
# ...                             ...        ...          ...     ...
# TTTGTTGAGGTTAGTA-1-B2             7      query  Neutrophils       5
# TTTGTTGCAAGCTCTA-1-B2             7      query     DOCK4+MØ       9
# TTTGTTGGTACAGGTG-1-B2             7      query   MØ_general      10
# TTTGTTGTCCCAGGAC-1-B2             7      query   MØ_general       0
# TTTGTTGTCCGGGACT-1-B2             7      query     LYVE1+MØ       2
#
#                        classification
# AAACGCTGTTGTGTTG-1-A1      DOCK4+MØ_3
# AAACGCTTCTCGCTCA-1-A1      DOCK4+MØ_3
# AAAGGTACAGAACATA-1-A1     Monocytes_6
# AAAGTCCAGGGACACT-1-A1      LYVE1+MØ_2
# AAAGTCCCAGTAGGAC-1-A1      LYVE1+MØ_2
# ...                               ...
# TTTGTTGAGGTTAGTA-1-B2   Neutrophils_5
# TTTGTTGCAAGCTCTA-1-B2      DOCK4+MØ_9
# TTTGTTGGTACAGGTG-1-B2   MØ_general_10
# TTTGTTGTCCCAGGAC-1-B2    MØ_general_0
# TTTGTTGTCCGGGACT-1-B2      LYVE1+MØ_2
#
# [34482 rows x 28 columns]

# %%
new_order_genotype = ['Pkp2_Ctr', 'Pkp2_HetKO', 'Ttn_Ctr', 'Ttn_HetKO']
adata.obs["genotype"] = adata.obs["genotype"].cat.reorder_categories(new_order_genotype, ordered=True)

adata.obs["genotype"].cat.categories
# Out:
# Index(['Pkp2_Ctr', 'Pkp2_HetKO', 'Ttn_Ctr', 'Ttn_HetKO'], dtype='object')

# %%
new_order_infection = ['noninf', 'MCMV']
adata.obs["infection"] = adata.obs["infection"].cat.reorder_categories(new_order_infection, ordered=True)

adata.obs["infection"].cat.categories
# Out:
# Index(['noninf', 'MCMV'], dtype='object')

# %%
new_order_condition = ['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV', 'Pkp2_HetKO_MCMV', 'Ttn_Ctr_noninf', 'Ttn_HetKO_noninf','Ttn_Ctr_MCMV', 'Ttn_HetKO_MCMV' ]
adata.obs["condition"] = adata.obs["condition"].cat.reorder_categories(new_order_condition, ordered=True)

adata.obs["condition"].cat.categories
# Out:
# Index(['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV',
#        'Pkp2_HetKO_MCMV', 'Ttn_Ctr_noninf', 'Ttn_HetKO_noninf', 'Ttn_Ctr_MCMV',
#        'Ttn_HetKO_MCMV'],
#       dtype='object')

# %% [markdown]
# create notebook for every compartment and compare across cell states
# visualization improvement
# reference to ctrl healthy

# %%
sccoda_model = pt.tl.Sccoda()
sccoda_data = sccoda_model.load(
    adata,
    type="cell_level",
    generate_sample_level=True,
    cell_type_identifier="classification",
    sample_identifier="sample",
    covariate_obs=["genotype", "infection", "condition"],
)
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 34512 × 29396
#   2 modalities
#     rna:	34482 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     coda:	30 x 18
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="genotype",
    y_scale="count",
    figsize=(30, 20),
    add_dots=False,
    args_swarmplot={"palette": ["red"]},
)
plt.show()

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="genotype",
    plot_facets=True,
    y_scale="log",
    add_dots=True,
    cmap="Reds",
)
plt.xticks(rotation=90)
plt.show()

# %%
pt.pl.coda.stacked_barplot(
    sccoda_data, modality_key="coda", feature_name="genotype", figsize=(15, 9) 
)
plt.legend(ncol=3, loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
sccoda_data = sccoda_model.prepare(
    sccoda_data,
    modality_key="coda",
    formula="genotype",
    reference_cell_type="automatic",
)
sccoda_data["coda"]
# Out:
# Automatic reference selection! Reference cell type set to DC_12
# Zero counts encountered in data! Added a pseudocount of 0.5.
# AnnData object with n_obs × n_vars = 30 × 18
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'

# %% [markdown]
# Run No-U-turn HMC sampling (nuts)

# %%
sccoda_model.run_nuts(sccoda_data, modality_key="coda", rng_key=1234)
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# sample: 100%|██████████| 11000/11000 [05:42<00:00, 32.10it/s, 511 steps of size 9.21e-03. acc. prob=0.87]

# %%
sccoda_data["coda"]
# Out:
# AnnData object with n_obs × n_vars = 30 × 18
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'
#     varm: 'intercept_df', 'effect_df_genotype[T.Pkp2_HetKO]', 'effect_df_genotype[T.Ttn_Ctr]', 'effect_df_genotype[T.Ttn_HetKO]'

# %% [markdown]
# #### Result interpreteation

# %% [markdown]
# **Intercepts**
#
# The first column of the intercept summary shows the parameters determined by the MCMC inference.
#
# The “Expected sample” column gives some context to the numerical values. If we had a new sample (with no active covariates) with a total number of cells equal to the mean sampling depth of the dataset, then this distribution over the cell types would be most likely.
#
# **Effects**
#
# For the effect summary, the first column again shows the inferred parameters for all combinations of covariates and cell types. Most important is the distinctions between zero and non-zero entries A value of zero means that no statistically credible effect was detected. For a value other than zero, a credible change was detected. A positive sign indicates an increase, a negative sign a decrease in abundance.
#
# Since the numerical values of the “Final Parameter” column are not straightforward to interpret, the “Expected sample” and “log2-fold change” columns give us an idea on the magnitude of the change. The expected sample is calculated for each covariate separately (covariate value = 1, all other covariates = 0), with the same method as for the intercepts. The log-fold change is then calculated between this expected sample and the expected sample with no active covariates from the intercept section. Since the data is compositional, cell types for which no credible change was detected, can still change in abundance as well, as soon as a credible effect is detected on another cell type due to the sum-to-one constraint. If there are no credible effects for a covariate, its expected sample will be identical to the intercept sample, therefore the log2-fold change is 0.

# %%
sccoda_model.summary(sccoda_data, modality_key= "coda")
# Out:
#                                           Compositional Analysis summary
# ┌────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────┐
# │ Name                                       │ Value                                                              │
# ├────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────┤
# │ Data                                       │ Data: 30 samples, 18 cell types                                    │
# │ Reference cell type                        │ DC_12                                                              │
# │ Formula                                    │ genotype                                                           │
# └────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Intercepts                                                                                                      │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                Final Parameter  Expected Sample                                                                 │
# │ Cell Type                                                                                                       │
# │ DC_12               1.271           25.257                                                                      │
# │ DC_14               0.225            8.874                                                                      │
# │ DC_16              -0.554            4.072                                                                      │
# │ DOCK4+MØ_3          3.003          142.754                                                                      │
# │ DOCK4+MØ_9          1.928           48.722                                                                      │
# │ LYVE1+MØ_1          3.329          197.773                                                                      │
# │ LYVE1+MØ_2          2.966          137.569                                                                      │
# │ LYVE1+MØ_4          2.485           85.040                                                                      │
# │ LYVE1+MØ_8          2.234           66.163                                                                      │
# │ Mast_15            -0.441            4.559                                                                      │
# │ Monocytes_6         1.783           42.145                                                                      │
# │ Monocytes_11        1.175           22.946                                                                      │
# │ Monocytes_13        0.217            8.803                                                                      │
# │ Monocytes_17       -0.687            3.565                                                                      │
# │ MØ_general_0        3.383          208.747                                                                      │
# │ MØ_general_7        2.025           53.684                                                                      │
# │ MØ_general_10       0.623           13.212                                                                      │
# │ Neutrophils_5       2.375           76.182                                                                      │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Effects                                                                                                         │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                                     Final Parameter  Expected Sample  log2-fold change                          │
# │ Covariate            Cell Type                                                                                  │
# │ genotypeT.Pkp2_HetKO DC_12              0.000            18.934            -0.416                               │
# │                      DC_14              0.000             6.652            -0.416                               │
# │                      DC_16              0.000             3.052            -0.416                               │
# │                      DOCK4+MØ_3         0.000           107.013            -0.416                               │
# │                      DOCK4+MØ_9         0.000            36.523            -0.416                               │
# │                      LYVE1+MØ_1         0.000           148.258            -0.416                               │
# │                      LYVE1+MØ_2         0.000           103.126            -0.416                               │
# │                      LYVE1+MØ_4         1.021           177.019             1.058                               │
# │                      LYVE1+MØ_8         0.000            49.598            -0.416                               │
# │                      Mast_15            0.000             3.418            -0.416                               │
# │                      Monocytes_6        1.187           103.488             1.296                               │
# │                      Monocytes_11       1.190            56.560             1.302                               │
# │                      Monocytes_13       0.000             6.599            -0.416                               │
# │                      Monocytes_17       0.000             2.672            -0.416                               │
# │                      MØ_general_0       0.000           156.484            -0.416                               │
# │                      MØ_general_7       0.000            40.244            -0.416                               │
# │                      MØ_general_10      2.002            73.315             2.472                               │
# │                      Neutrophils_5      0.000            57.109            -0.416                               │
# │ genotypeT.Ttn_Ctr    DC_12              0.000            24.631            -0.036                               │
# │                      DC_14              0.000             8.654            -0.036                               │
# │                      DC_16              0.000             3.971            -0.036                               │
# │                      DOCK4+MØ_3         0.000           139.215            -0.036                               │
# │                      DOCK4+MØ_9         0.000            47.514            -0.036                               │
# │                      LYVE1+MØ_1         0.000           192.870            -0.036                               │
# │                      LYVE1+MØ_2         0.000           134.158            -0.036                               │
# │                      LYVE1+MØ_4         0.000            82.932            -0.036                               │
# │                      LYVE1+MØ_8         0.000            64.523            -0.036                               │
# │                      Mast_15            0.000             4.446            -0.036                               │
# │                      Monocytes_6        0.000            41.100            -0.036                               │
# │                      Monocytes_11       0.000            22.377            -0.036                               │
# │                      Monocytes_13       0.000             8.585            -0.036                               │
# │                      Monocytes_17       0.000             3.476            -0.036                               │
# │                      MØ_general_0       0.000           203.571            -0.036                               │
# │                      MØ_general_7       0.435            80.866             0.591                               │
# │                      MØ_general_10      0.000            12.884            -0.036                               │
# │                      Neutrophils_5      0.000            74.293            -0.036                               │
# │ genotypeT.Ttn_HetKO  DC_12              0.000            23.886            -0.081                               │
# │                      DC_14              0.000             8.392            -0.081                               │
# │                      DC_16              0.000             3.851            -0.081                               │
# │                      DOCK4+MØ_3         0.000           135.003            -0.081                               │
# │                      DOCK4+MØ_9         0.000            46.076            -0.081                               │
# │                      LYVE1+MØ_1         0.000           187.035            -0.081                               │
# │                      LYVE1+MØ_2         0.000           130.099            -0.081                               │
# │                      LYVE1+MØ_4         0.000            80.423            -0.081                               │
# │                      LYVE1+MØ_8         0.000            62.571            -0.081                               │
# │                      Mast_15            0.000             4.312            -0.081                               │
# │                      Monocytes_6        0.000            39.857            -0.081                               │
# │                      Monocytes_11       0.000            21.700            -0.081                               │
# │                      Monocytes_13       0.000             8.325            -0.081                               │
# │                      Monocytes_17       0.000             3.371            -0.081                               │
# │                      MØ_general_0       0.000           197.413            -0.081                               │
# │                      MØ_general_7       0.447            79.345             0.564                               │
# │                      MØ_general_10      0.000            12.495            -0.081                               │
# │                      Neutrophils_5      0.385           105.912             0.475                               │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Filter out credible effects

# %%
sccoda_model.credible_effects(sccoda_data, modality_key="coda")
# Out:
# Covariate               Cell Type
# genotype[T.Pkp2_HetKO]  DC_12            False
#                         DC_14            False
#                         DC_16            False
#                         DOCK4+MØ_3       False
#                         DOCK4+MØ_9       False
#                         LYVE1+MØ_1       False
#                         LYVE1+MØ_2       False
#                         LYVE1+MØ_4        True
#                         LYVE1+MØ_8       False
#                         Mast_15          False
#                         Monocytes_6       True
#                         Monocytes_11      True
#                         Monocytes_13     False
#                         Monocytes_17     False
#                         MØ_general_0     False
#                         MØ_general_7     False
#                         MØ_general_10     True
#                         Neutrophils_5    False
# genotype[T.Ttn_Ctr]     DC_12            False
#                         DC_14            False
#                         DC_16            False
#                         DOCK4+MØ_3       False
#                         DOCK4+MØ_9       False
#                         LYVE1+MØ_1       False
#                         LYVE1+MØ_2       False
#                         LYVE1+MØ_4       False
#                         LYVE1+MØ_8       False
#                         Mast_15          False
#                         Monocytes_6      False
#                         Monocytes_11     False
#                         Monocytes_13     False
#                         Monocytes_17     False
#                         MØ_general_0     False
#                         MØ_general_7      True
#                         MØ_general_10    False
#                         Neutrophils_5    False
# genotype[T.Ttn_HetKO]   DC_12            False
#                         DC_14            False
#                         DC_16            False
#                         DOCK4+MØ_3       False
#                         DOCK4+MØ_9       False
#                         LYVE1+MØ_1       False
#                         LYVE1+MØ_2       False
#                         LYVE1+MØ_4       False
#                         LYVE1+MØ_8       False
#                         Mast_15          False
#                         Monocytes_6      False
#                         Monocytes_11     False
#                         Monocytes_13     False
#                         Monocytes_17     False
#                         MØ_general_0     False
#                         MØ_general_7      True
#                         MØ_general_10    False
#                         Neutrophils_5     True
# Name: Final Parameter, dtype: bool

# %%
pt.pl.coda.effects_barplot(sccoda_data, modality_key="coda", parameter="Final Parameter")

# %% [markdown]
# ##### Adjust the "false discovery rate"

# %% [raw]
# #If needed adjust the 'false discovery rate' - default is 0.05, however when no effects are detected it can be incresed to up to 0.2
# sccoda_model.set_fdr(sccoda_data, 0.2)
# sccoda_model.credible_effects(sccoda_data, modality_key="coda")

# %%
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 34512 × 29396
#   2 modalities
#     rna:	34482 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     coda:	30 x 18
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'
#       uns:	'scCODA_params'
#       obsm:	'covariate_matrix', 'sample_counts'
#       varm:	'intercept_df', 'effect_df_genotype[T.Pkp2_HetKO]', 'effect_df_genotype[T.Ttn_Ctr]', 'effect_df_genotype[T.Ttn_HetKO]'

# %%
sccoda_data["coda"].varm["effect_df_genotype[T.Pkp2_HetKO]"]
# Out:
#                Final Parameter  HDI 3%  HDI 97%     SD  Inclusion probability  \
# Cell Type
# DC_12                 0.000000   0.000    0.000  0.000                 0.0000
# DC_14                 0.000000  -0.347    0.783  0.201                 0.3475
# DC_16                 0.000000  -0.113    1.204  0.380                 0.5722
# DOCK4+MØ_3            0.000000  -0.004    0.385  0.127                 0.4845
# DOCK4+MØ_9            0.000000  -0.347    0.228  0.074                 0.2187
# LYVE1+MØ_1            0.000000  -0.419    0.001  0.147                 0.7088
# LYVE1+MØ_2            0.000000  -0.229    0.189  0.048                 0.1863
# LYVE1+MØ_4            1.021305   0.774    1.271  0.123                 1.0000
# LYVE1+MØ_8            0.000000  -0.138    0.372  0.076                 0.2353
# Mast_15               0.000000  -0.990    0.315  0.264                 0.3931
# Monocytes_6           1.186505   0.837    1.536  0.178                 1.0000
# Monocytes_11          1.190341   0.799    1.584  0.199                 1.0000
# Monocytes_13          0.000000  -0.507    0.580  0.150                 0.2976
# Monocytes_17          0.000000  -0.718    0.612  0.200                 0.3260
# MØ_general_0          0.000000  -0.260    0.122  0.052                 0.1930
# MØ_general_7          0.000000  -0.338    0.253  0.071                 0.2095
# MØ_general_10         2.001816   1.578    2.416  0.221                 1.0000
# Neutrophils_5         0.000000  -0.353    0.136  0.074                 0.2323
#
#                Expected Sample  log2-fold change
# Cell Type
# DC_12                18.933910         -0.415738
# DC_14                 6.652246         -0.415738
# DC_16                 3.052480         -0.415738
# DOCK4+MØ_3          107.013448         -0.415738
# DOCK4+MØ_9           36.523450         -0.415738
# LYVE1+MØ_1          148.258076         -0.415738
# LYVE1+MØ_2          103.126306         -0.415738
# LYVE1+MØ_4          177.019467          1.057694
# LYVE1+MØ_8           49.598198         -0.415738
# Mast_15               3.417655         -0.415738
# Monocytes_6         103.488443          1.296028
# Monocytes_11         56.559606          1.301561
# Monocytes_13          6.599240         -0.415738
# Monocytes_17          2.672340         -0.415738
# MØ_general_0        156.484116         -0.415738
# MØ_general_7         40.243742         -0.415738
# MØ_general_10        73.315355          2.472272
# Neutrophils_5        57.108588         -0.415738

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=sccoda_data["coda"].varm["effect_df_genotype[T.Pkp2_HetKO]"], x="Cell Type", y="log2-fold change", hue="Cell Type")
plt.xticks(rotation=90)
plt.show()

# %%
pt.pl.coda.effects_barplot(sccoda_data, "coda", "genotype")
plt.show()
