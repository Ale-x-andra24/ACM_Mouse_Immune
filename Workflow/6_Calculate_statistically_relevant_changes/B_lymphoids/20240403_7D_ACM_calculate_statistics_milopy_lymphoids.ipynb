# %% [markdown]
# # Compositional analysis of the ACM cardiac leucocytes 6mpi dataset (Pkp2+Ttn) - lymphoids - using `milopy`:
#
# and the single cell best practices tutorial https://www.sc-best-practices.org/conditions/compositional.html#without-labeled-clusters:
#
# - **Developed by**: Christian Eger
# - **Modified by**: Alexandra Cirnu
# - **Talavera-López Lab - Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg**
# - **Created on**: 231207
# - **Last modified**: 240403

# %% [markdown]
# #### Environment: milopy

# %%
import scanpy as sc
import pandas as pd
import pertpy as pt
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import numpy as np
import scvi
import rpy2
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri

# %%
rpy2.robjects.numpy2ri.activate()

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library(edgeR)
# Out:
# R[write to console]: Loading required package: limma

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.6
# scanpy      1.10.0
# -----
# PIL                         10.2.0
# absl                        NA
# adjustText                  1.1.1
# anyio                       NA
# arrow                       1.3.0
# arviz                       0.17.1
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# blitzgsea                   NA
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# chardet                     5.2.0
# charset_normalizer          3.3.2
# chex                        0.1.86
# colorama                    0.4.6
# comm                        0.2.2
# contextlib2                 NA
# custom_inherit              2.4.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.9.0
# debugpy                     1.8.1
# decorator                   5.1.1
# decoupler                   1.6.0
# defusedxml                  0.7.1
# docrep                      0.3.2
# etils                       1.7.0
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# flax                        0.8.2
# fqdn                        NA
# fsspec                      2024.3.1
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# importlib_resources         NA
# ipykernel                   6.29.3
# ipywidgets                  8.1.2
# isoduration                 NA
# jax                         0.4.25
# jaxlib                      0.4.25
# jaxopt                      NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       0.9.24
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.10.0
# jupyter_server              2.13.0
# jupyterlab_server           2.25.4
# kiwisolver                  1.4.5
# legacy_api_wrap             NA
# leidenalg                   0.10.2
# lightning                   2.1.4
# lightning_fabric            2.2.1
# lightning_utilities         0.11.2
# llvmlite                    0.42.0
# markupsafe                  2.1.5
# matplotlib                  3.8.3
# ml_collections              NA
# ml_dtypes                   0.4.0
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.8
# mudata                      0.2.3
# multipledispatch            0.6.0
# natsort                     8.4.0
# nbformat                    5.10.3
# numba                       0.59.1
# numpy                       1.26.4
# numpyro                     0.14.0
# opt_einsum                  v3.3.0
# optax                       0.2.2
# ott                         0.4.5
# overrides                   NA
# packaging                   24.0
# pandas                      2.2.1
# parso                       0.8.3
# patsy                       0.5.6
# pertpy                      0.7.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                4.2.0
# ply                         3.11
# png                         0.20220715.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pubchempy                   1.0.4
# pure_eval                   0.2.2
# pyarrow                     15.0.2
# pycparser                   2.22
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynndescent                 0.5.12
# pyomo                       6.7.1
# pyparsing                   3.1.2
# pyro                        1.9.0
# pythonjsonlogger            NA
# pytorch_lightning           2.2.1
# pytz                        2024.1
# referencing                 NA
# reportlab                   4.1.0
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rich                        NA
# rpds                        NA
# rpy2                        3.5.11
# scipy                       1.12.0
# scvi                        1.1.2
# seaborn                     0.13.2
# send2trash                  NA
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.4.1.post1
# skmisc                      0.3.1
# sniffio                     1.3.1
# socks                       1.7.1
# sparsecca                   0.3.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.4.0
# toolz                       0.12.1
# torch                       2.2.2+cu121
# torchgen                    NA
# torchmetrics                1.3.2
# tornado                     6.4
# toyplot                     1.0.3
# toytree                     2.0.5
# tqdm                        4.66.2
# traitlets                   5.14.2
# typing_extensions           NA
# tzlocal                     NA
# uri_template                NA
# urllib3                     2.2.1
# vscode                      NA
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# xarray                      2024.3.0
# xarray_einstats             0.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.1
# jupyter_core        5.7.2
# jupyterlab          4.1.5
# notebook            7.1.2
# -----
# Python 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# Linux-6.6.14-100.fc38.x86_64-x86_64-with-glibc2.37
# -----
# Session information updated at 2024-04-03 17:19

# %% [markdown]
# #### Load in data

# %%
adata = sc.read_h5ad("/home/acirnu/data/ACM_cardiac_leuco/scANVI/ACM_lymphoids_clustered_ac240403.raw.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 10104 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'n_genes', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'

# %%
adata.obs
# Out:
#                       cell_source               donor  n_counts  n_genes  \
# AAACCCAAGATACAGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    8265.0     2689
# AACCCAATCAGCTGAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13594.0     3640
# AACCTGAAGATAGCAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13182.0     3085
# AACGTCAAGCTACTGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    1860.0     1106
# AACTTCTCAAGCGCTC-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    9586.0     2703
# ...                           ...                 ...       ...      ...
# TTTGATCAGTATGACA-1-B2   AG_Gerull    Ttn_HetKO_MCMV_1   12119.0     2704
# TTTGGAGAGATTAGCA-1-B2   AG_Gerull      Ttn_Ctr_MCMV_2   20506.0     4156
# TTTGGTTAGCACCTGC-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    3174.0     1436
# TTTGTTGAGACCTCCG-1-B2   AG_Gerull  Ttn_HetKO_noninf_2    4549.0     1710
# TTTGTTGGTAGTAAGT-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    6564.0     2416
#
#                                    sample seed_labels         condition  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr_noninf_1         CD8   Pkp2_Ctr_noninf
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr_noninf_1           B   Pkp2_Ctr_noninf
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# ...                                   ...         ...               ...
# TTTGATCAGTATGACA-1-B2    Ttn_HetKO_MCMV_1     Unknown    Ttn_HetKO_MCMV
# TTTGGAGAGATTAGCA-1-B2      Ttn_Ctr_MCMV_2     Unknown      Ttn_Ctr_MCMV
# TTTGGTTAGCACCTGC-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO_noninf_2     Unknown  Ttn_HetKO_noninf
# TTTGTTGGTAGTAAGT-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
#
#                         genotype infection library  ... percent_chrY  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr    noninf      A1  ...     0.000000
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr    noninf      A1  ...     0.021233
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr    noninf      A1  ...     0.063510
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr    noninf      A1  ...     0.194458
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr    noninf      A1  ...     0.000000
# ...                          ...       ...     ...  ...          ...
# TTTGATCAGTATGACA-1-B2  Ttn_HetKO      MCMV      B2  ...     0.016503
# TTTGGAGAGATTAGCA-1-B2    Ttn_Ctr      MCMV      B2  ...     0.000000
# TTTGGTTAGCACCTGC-1-B2  Ttn_HetKO      MCMV      B2  ...     0.000000
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO    noninf      B2  ...     0.000000
# TTTGTTGGTAGTAAGT-1-B2  Ttn_HetKO      MCMV      B2  ...     0.030469
#
#                        XIST-counts   S_score  G2M_score  _scvi_batch  \
# AAACCCAAGATACAGT-1-A1          0.0 -0.339369  -0.496060            7
# AACCCAATCAGCTGAT-1-A1          0.0  0.525671  -0.137838            6
# AACCTGAAGATAGCAT-1-A1          0.0 -0.268815  -0.516689            6
# AACGTCAAGCTACTGT-1-A1          0.0 -0.270605  -0.340320            7
# AACTTCTCAAGCGCTC-1-A1          0.0 -0.414867  -0.271517            7
# ...                            ...       ...        ...          ...
# TTTGATCAGTATGACA-1-B2          0.0 -0.267751  -0.531946           25
# TTTGGAGAGATTAGCA-1-B2         23.0  2.905559   0.470866           21
# TTTGGTTAGCACCTGC-1-B2          0.0  0.000996  -0.736926           26
# TTTGTTGAGACCTCCG-1-B2          0.0 -0.428444  -0.362500           29
# TTTGTTGGTAGTAAGT-1-B2          0.0  0.363058  -0.589437           26
#
#                        _scvi_labels      batch  C_scANVI  leiden  \
# AAACCCAAGATACAGT-1-A1             1  reference       CD4       5
# AACCCAATCAGCTGAT-1-A1             2  reference       CD8       4
# AACCTGAAGATAGCAT-1-A1             0  reference         B      10
# AACGTCAAGCTACTGT-1-A1             1  reference       CD4      11
# AACTTCTCAAGCGCTC-1-A1             1  reference       CD4       5
# ...                             ...        ...       ...     ...
# TTTGATCAGTATGACA-1-B2             5      query         B      10
# TTTGGAGAGATTAGCA-1-B2             5      query         B       2
# TTTGGTTAGCACCTGC-1-B2             5      query       CD8       4
# TTTGTTGAGACCTCCG-1-B2             5      query         B      13
# TTTGTTGGTAGTAAGT-1-B2             5      query       CD8       0
#
#                        classification
# AAACCCAAGATACAGT-1-A1           CD4_5
# AACCCAATCAGCTGAT-1-A1           CD8_4
# AACCTGAAGATAGCAT-1-A1            B_10
# AACGTCAAGCTACTGT-1-A1          CD4_11
# AACTTCTCAAGCGCTC-1-A1           CD4_5
# ...                               ...
# TTTGATCAGTATGACA-1-B2            B_10
# TTTGGAGAGATTAGCA-1-B2             B_2
# TTTGGTTAGCACCTGC-1-B2           CD8_4
# TTTGTTGAGACCTCCG-1-B2            B_13
# TTTGTTGGTAGTAAGT-1-B2           CD8_0
#
# [10104 rows x 29 columns]

# %% [markdown]
# #### Dimensionality reduction to assess whether we see a batch effect in this dataset

# %%
milo = pt.tl.Milo()
mdata = milo.load(adata)
mdata
# Out:
# MuData object with n_obs × n_vars = 10104 × 29378
#   2 modalities
#     rna:	10104 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'n_genes', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#     milo:	0 x 0

# %%
# use logcounts to calculate PCA and neighbors
adata.layers["counts"] = adata.X.copy()
adata.layers["logcounts"] = sc.pp.log1p(adata.layers["counts"]).copy()
adata.X = adata.layers["logcounts"].copy()

sc.pp.highly_variable_genes(
    adata, n_top_genes=3000, subset=False
)  # 3k genes as used by authors for clustering

sc.pp.pca(adata)
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=30, use_rep="X_scANVI")
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=["condition", "genotype", "infection", "model", "C_scANVI", "classification", "library"], ncols=2, wspace=0.25)

# %% [markdown]
# #### Batch correction

# %% [markdown]
# In the single cell best practices tutorial there should be a batch correction step next. Skipped because batch correction already took place.

# %% [markdown]
# ### Defining neighborhoods

# %%
milo.make_nhoods(mdata, prop=0.1)
# Out:
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/pertpy/tools/_milo.py:183: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[1
#  0.875294   1.0424689  2.276747   1.0113413  1.5064033  0.9516401
#  0.80636024 0.9532492  0.6312216  1.3107938  1.1607728  1.1949737
#  0.64358944 0.71909034 1.2044182  0.7248155  1.4283998  0.66705084
#  2.3043218  0.7155945  1.38956    2.2201045  0.6163054  0.9241421
#  0.79988205 1.5761393  0.72218525 2.0446022  0.75959504 1.028804
#  1.0249048  2.79834    0.6699041  1.1920117  1.7761875  0.94661975
#  0.8712546  0.97386473 0.973036   1.0770127  0.8787665  1.4360216
#  1.118318   1.3287202  1.1783831  0.9081855  0.9170346  0.6168846
#  1.2658782  0.96881884 0.6287633  3.2214665  0.54350734 1.0880579
#  0.8146529  0.70643413 1.5662327  1.1866924  0.8040231  1.0022745
#  0.8847585  1.2605714  1.0134199  1.1279466  2.2011204  1.0135231
#  0.81428146 0.7642694  0.58293664 0.73237246 1.4663123  1.906429
#  0.7650183  0.82983226 0.81619334 1.4226791  0.8953293  1.1478406
#  1.0169303  0.97197366 1.3287845  1.0421618  0.8750452  0.9290543
#  0.90010744 0.9858505  1.1045754  2.1378887  1.7706431  1.3619189
#  0.7526994  0.8619374  0.87175226 0.8180541  0.7878735  2.1588082
#  0.8089577  0.75767624 1.9802117  1.1110907  1.6947292  1.8961592
#  0.7414507  1.7047111  0.9799831  1.1791543  1.7525234  0.7640317
#  1.283469   0.8240761  0.8531051  0.96103716 1.3949856  1.0276362
#  0.77204293 0.93915606 0.84527373 1.771156   0.696693   3.993439
#  0.8360159  1.5281143  1.4688711  2.40366    0.653088   0.8319843
#  0.8350732  0.71783334 0.7022852  1.1724967  0.7300664  0.822438
#  1.4554771  1.459749   1.3373171  0.6655953  0.75994277 0.95468885
#  1.096981   1.3122708  1.0169064  0.96916986 1.0549113  0.66104215
#  0.7712659  0.8822563  1.1345402  1.4609768  0.80114436 1.7687235
#  0.8769012  0.8409824  1.1441636  0.68757623 1.5706164  1.2636994
#  1.2105291  0.88552785 0.85989356 1.0382601  1.0847999  1.0703993
#  1.017607   1.106375   2.035957   0.9245527  1.0668678  0.81284434
#  1.0739051  0.6163597  1.2085649  1.0982898  1.3272756  0.9260318
#  0.9996448  0.8657698  1.4703861  0.6558322  1.5290282  0.97336876
#  1.160313   0.91863793 4.1478662  2.3773062  1.0367476  0.77022845
#  0.7424972  1.4483714  0.5639283  1.6528398  0.8835265  1.6904792
#  2.0400555  1.7761052  0.6708187  1.0140961  0.65624934 1.5743929
#  2.0558956  1.0423006  0.7783017  0.9582215  0.91522527 1.2023364 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   adata.obs.loc[adata.obs["nhood_ixs_refined"] == 1, "nhood_kth_distance"] = k_distances

# %%
adata.obsm["nhoods"]
# Out:
# <10104x912 sparse matrix of type '<class 'numpy.float32'>'
# 	with 12087 stored elements in Compressed Sparse Row format>

# %% [markdown]
# At this point we need to check the median number of cells in each neighbourhood, to make sure the neighbourhoods contain enough cells to detect differences between samples.

# %%
nhood_size = adata.obsm["nhoods"].toarray().sum(0)
plt.hist(nhood_size, bins=20)
plt.xlabel("# cells in neighbourhood")
plt.ylabel("# neighbouthoods")
# Out:
# Text(0, 0.5, '# neighbouthoods')

# %%
np.median(nhood_size)
# Out:
# 13.0

# %%
sc.pp.neighbors(adata, n_neighbors=50, use_rep="X_scANVI", key_added="milo")
milo.make_nhoods(mdata, neighbors_key="milo", prop=0.1)
# Out:
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/pertpy/tools/_milo.py:183: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 2
#   1.3375294  1.9323813  1.7222328  3.3733788  1.4405463  2.0216477
#   2.2236705  2.1335251  2.202337   1.6613551  2.6789267  4.6848187
#   1.925232   1.5383339  2.396033   1.3342975  2.834887   4.8188124
#   2.4043553  2.0498948  1.8912877  2.9516659  1.3961359  2.6851516
#   1.8410218  2.6489515  2.6568348  1.5856718  1.7868176  2.134513
#   2.1203701  1.7028229  2.3741167  2.0720778  3.3026922  2.6676974
#   1.4610233  1.2931918  4.1087923  1.6519935  1.7409716  1.734195
#   2.0600185  1.731873   2.225072   1.8766063  1.8990372  2.2848175
#   2.430329   1.526265   1.2932341  1.8037952  1.8114023  1.7842349
#   2.5155926  2.089028   2.1756287  4.762253   1.954379   1.8848495
#   1.5336848  1.6922835  1.5952353  2.0217485  2.0721908  1.4274417
#   1.8874166  1.5067929  1.9206681  1.2775317  1.9310424  1.4854659
#   1.7933807  2.3673258  1.6873093  4.3778367  3.0655866  2.226916
#   2.1742868  1.7165619  1.4607692  1.8791873  1.7426339  2.002328
#   2.155327   2.137567   2.1242645  1.8087087  2.1067688  1.4635749
#   1.4957877  2.5012825  1.5209706  1.613702   4.2911434  1.9437516
#   1.6726949  3.4735994  1.9524424  1.807291   1.5764055  1.8204256
#   2.5521283  2.007516   1.7179134  2.1972666  2.0445294  1.8774176
#   1.6600751  3.4509768  2.03252    3.263723   1.6284063  3.1249366
#   1.780716   2.1032863  2.2463367  2.7183285  1.6034834  2.7160819
#   2.3416607  2.440642   1.6042483  2.8115962  1.5029509  2.9717245
#   1.9962785  1.9856417  6.863705   1.4515064  2.4194024  1.8396101
#   3.0742269  1.4426565  4.1196885  1.3435419  1.8308479  2.114023
#   1.2447919  1.3660343  1.6206458  3.2958345  1.8765303  2.8870728
#   1.647839   1.9705793  2.5652602  1.7741823  1.8374339  2.2233758]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   adata.obs.loc[adata.obs["nhood_ixs_refined"] == 1, "nhood_kth_distance"] = k_distances

# %%
nhood_size = adata.obsm["nhoods"].toarray().sum(0)
plt.hist(nhood_size, bins=20)
plt.xlabel("# cells in neighbourhood")
plt.ylabel("# neighbouthoods")
# Out:
# Text(0, 0.5, '# neighbouthoods')

# %%
np.median(nhood_size)
# Out:
# 72.0

# %% [markdown]
# #### Count cells in neighborhood

# %%
adata.obs
# Out:
#                       cell_source               donor  n_counts  n_genes  \
# AAACCCAAGATACAGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    8265.0     2689
# AACCCAATCAGCTGAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13594.0     3640
# AACCTGAAGATAGCAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13182.0     3085
# AACGTCAAGCTACTGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    1860.0     1106
# AACTTCTCAAGCGCTC-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    9586.0     2703
# ...                           ...                 ...       ...      ...
# TTTGATCAGTATGACA-1-B2   AG_Gerull    Ttn_HetKO_MCMV_1   12119.0     2704
# TTTGGAGAGATTAGCA-1-B2   AG_Gerull      Ttn_Ctr_MCMV_2   20506.0     4156
# TTTGGTTAGCACCTGC-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    3174.0     1436
# TTTGTTGAGACCTCCG-1-B2   AG_Gerull  Ttn_HetKO_noninf_2    4549.0     1710
# TTTGTTGGTAGTAAGT-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    6564.0     2416
#
#                                    sample seed_labels         condition  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr_noninf_1         CD8   Pkp2_Ctr_noninf
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr_noninf_1           B   Pkp2_Ctr_noninf
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# ...                                   ...         ...               ...
# TTTGATCAGTATGACA-1-B2    Ttn_HetKO_MCMV_1     Unknown    Ttn_HetKO_MCMV
# TTTGGAGAGATTAGCA-1-B2      Ttn_Ctr_MCMV_2     Unknown      Ttn_Ctr_MCMV
# TTTGGTTAGCACCTGC-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO_noninf_2     Unknown  Ttn_HetKO_noninf
# TTTGTTGGTAGTAAGT-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
#
#                         genotype infection library  ... G2M_score  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr    noninf      A1  ... -0.496060
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr    noninf      A1  ... -0.137838
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr    noninf      A1  ... -0.516689
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr    noninf      A1  ... -0.340320
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr    noninf      A1  ... -0.271517
# ...                          ...       ...     ...  ...       ...
# TTTGATCAGTATGACA-1-B2  Ttn_HetKO      MCMV      B2  ... -0.531946
# TTTGGAGAGATTAGCA-1-B2    Ttn_Ctr      MCMV      B2  ...  0.470866
# TTTGGTTAGCACCTGC-1-B2  Ttn_HetKO      MCMV      B2  ... -0.736926
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO    noninf      B2  ... -0.362500
# TTTGTTGGTAGTAAGT-1-B2  Ttn_HetKO      MCMV      B2  ... -0.589437
#
#                        _scvi_batch  _scvi_labels      batch  C_scANVI  leiden  \
# AAACCCAAGATACAGT-1-A1            7             1  reference       CD4       5
# AACCCAATCAGCTGAT-1-A1            6             2  reference       CD8       4
# AACCTGAAGATAGCAT-1-A1            6             0  reference         B      10
# AACGTCAAGCTACTGT-1-A1            7             1  reference       CD4      11
# AACTTCTCAAGCGCTC-1-A1            7             1  reference       CD4       5
# ...                            ...           ...        ...       ...     ...
# TTTGATCAGTATGACA-1-B2           25             5      query         B      10
# TTTGGAGAGATTAGCA-1-B2           21             5      query         B       2
# TTTGGTTAGCACCTGC-1-B2           26             5      query       CD8       4
# TTTGTTGAGACCTCCG-1-B2           29             5      query         B      13
# TTTGTTGGTAGTAAGT-1-B2           26             5      query       CD8       0
#
#                        classification  nhood_ixs_random  nhood_ixs_refined  \
# AAACCCAAGATACAGT-1-A1           CD4_5                 0                  0
# AACCCAATCAGCTGAT-1-A1           CD8_4                 1                  0
# AACCTGAAGATAGCAT-1-A1            B_10                 0                  0
# AACGTCAAGCTACTGT-1-A1          CD4_11                 1                  1
# AACTTCTCAAGCGCTC-1-A1           CD4_5                 1                  0
# ...                               ...               ...                ...
# TTTGATCAGTATGACA-1-B2            B_10                 0                  0
# TTTGGAGAGATTAGCA-1-B2             B_2                 0                  0
# TTTGGTTAGCACCTGC-1-B2           CD8_4                 0                  0
# TTTGTTGAGACCTCCG-1-B2            B_13                 0                  0
# TTTGTTGGTAGTAAGT-1-B2           CD8_0                 0                  0
#
#                        nhood_kth_distance
# AAACCCAAGATACAGT-1-A1            0.000000
# AACCCAATCAGCTGAT-1-A1            0.000000
# AACCTGAAGATAGCAT-1-A1            0.000000
# AACGTCAAGCTACTGT-1-A1            2.897213
# AACTTCTCAAGCGCTC-1-A1            0.000000
# ...                                   ...
# TTTGATCAGTATGACA-1-B2            0.000000
# TTTGGAGAGATTAGCA-1-B2            0.000000
# TTTGGTTAGCACCTGC-1-B2            0.000000
# TTTGTTGAGACCTCCG-1-B2            0.000000
# TTTGTTGGTAGTAAGT-1-B2            0.000000
#
# [10104 rows x 32 columns]

# %%
milo.count_nhoods(mdata, sample_col="donor")
# Out:
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# MuData object with n_obs × n_vars = 10104 × 29378
#   2 modalities
#     rna:	10104 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'n_genes', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification', 'nhood_ixs_random', 'nhood_ixs_refined', 'nhood_kth_distance'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#       uns:	'hvg', 'pca', 'neighbors', 'umap', 'condition_colors', 'genotype_colors', 'infection_colors', 'model_colors', 'C_scANVI_colors', 'classification_colors', 'library_colors', 'nhood_neighbors_key', 'milo'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap', 'X_pca', 'nhoods'
#       varm:	'PCs'
#       layers:	'counts', 'logcounts'
#       obsp:	'distances', 'connectivities', 'milo_distances', 'milo_connectivities'
#     milo:	30 x 858
#       var:	'index_cell', 'kth_distance'
#       uns:	'sample_col'

# %%
mean_n_cells = mdata["milo"].X.toarray().mean(0)
plt.plot(nhood_size, mean_n_cells, ".")
plt.xlabel("# cells in nhood")
plt.ylabel("Mean # cells per sample in nhood")
# Out:
# Text(0, 0.5, 'Mean # cells per sample in nhood')

# %% [markdown]
# #### Run differential abundance test on neighborhoods

# %%
milo.da_nhoods(
    mdata, design="~infection", model_contrasts="infectionMCMV-infectionnoninf"
)
milo_results_Pkp2_hetko = mdata["milo"].obs.copy()
milo_results_Pkp2_hetko
# Out:
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/pertpy/tools/_milo.py:688: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pvalues = pvalues[keep_nhoods][o]
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/pertpy/tools/_milo.py:689: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   w = w[keep_nhoods][o]
#                     infection                donor
# Pkp2_Ctr_MCMV_1          MCMV      Pkp2_Ctr_MCMV_1
# Pkp2_Ctr_MCMV_2          MCMV      Pkp2_Ctr_MCMV_2
# Pkp2_Ctr_MCMV_3          MCMV      Pkp2_Ctr_MCMV_3
# Pkp2_Ctr_MCMV_4          MCMV      Pkp2_Ctr_MCMV_4
# Pkp2_Ctr_MCMV_5          MCMV      Pkp2_Ctr_MCMV_5
# Pkp2_Ctr_MCMV_6          MCMV      Pkp2_Ctr_MCMV_6
# Pkp2_Ctr_noninf_1      noninf    Pkp2_Ctr_noninf_1
# Pkp2_Ctr_noninf_2      noninf    Pkp2_Ctr_noninf_2
# Pkp2_Ctr_noninf_3      noninf    Pkp2_Ctr_noninf_3
# Pkp2_Ctr_noninf_4      noninf    Pkp2_Ctr_noninf_4
# Pkp2_HetKO_MCMV_1        MCMV    Pkp2_HetKO_MCMV_1
# Pkp2_HetKO_MCMV_2        MCMV    Pkp2_HetKO_MCMV_2
# Pkp2_HetKO_MCMV_3        MCMV    Pkp2_HetKO_MCMV_3
# Pkp2_HetKO_MCMV_4        MCMV    Pkp2_HetKO_MCMV_4
# Pkp2_HetKO_MCMV_5        MCMV    Pkp2_HetKO_MCMV_5
# Pkp2_HetKO_MCMV_6        MCMV    Pkp2_HetKO_MCMV_6
# Pkp2_HetKO_noninf_1    noninf  Pkp2_HetKO_noninf_1
# Pkp2_HetKO_noninf_2    noninf  Pkp2_HetKO_noninf_2
# Pkp2_HetKO_noninf_3    noninf  Pkp2_HetKO_noninf_3
# Pkp2_HetKO_noninf_4    noninf  Pkp2_HetKO_noninf_4
# Ttn_Ctr_MCMV_1           MCMV       Ttn_Ctr_MCMV_1
# Ttn_Ctr_MCMV_2           MCMV       Ttn_Ctr_MCMV_2
# Ttn_Ctr_MCMV_3           MCMV       Ttn_Ctr_MCMV_3
# Ttn_Ctr_noninf_1       noninf     Ttn_Ctr_noninf_1
# Ttn_Ctr_noninf_2       noninf     Ttn_Ctr_noninf_2
# Ttn_HetKO_MCMV_1         MCMV     Ttn_HetKO_MCMV_1
# Ttn_HetKO_MCMV_2         MCMV     Ttn_HetKO_MCMV_2
# Ttn_HetKO_MCMV_3         MCMV     Ttn_HetKO_MCMV_3
# Ttn_HetKO_noninf_1     noninf   Ttn_HetKO_noninf_1
# Ttn_HetKO_noninf_2     noninf   Ttn_HetKO_noninf_2

# %% [markdown]
# #### Data Diagnostics

# %%
def plot_milo_diagnostics(mdata):
    alpha = 0.1  ## significance threshold

    with matplotlib.rc_context({"figure.figsize": [12, 12]}):

        ## Check P-value histogram
        plt.subplot(2, 2, 1)
        plt.hist(mdata["milo"].var["PValue"], bins=20)
        plt.xlabel("Uncorrected P-value")

        ## Visualize extent of multiple-testing correction
        plt.subplot(2, 2, 2)
        plt.scatter(
            mdata["milo"].var["PValue"],
            mdata["milo"].var["SpatialFDR"],
            s=3,
        )
        plt.xlabel("Uncorrected P-value")
        plt.ylabel("SpatialFDR")

        ## Visualize volcano plot
        plt.subplot(2, 2, 3)
        plt.scatter(
            mdata["milo"].var["logFC"],
            -np.log10(mdata["milo"].var["SpatialFDR"]),
            s=3,
        )
        plt.axhline(
            y=-np.log10(alpha),
            color="red",
            linewidth=1,
            label=f"{int(alpha*100)} % SpatialFDR",
        )
        plt.legend()
        plt.xlabel("log-Fold Change")
        plt.ylabel("- log10(SpatialFDR)")
        plt.tight_layout()

        ## Visualize MA plot
        df = mdata["milo"].var
        emp_null = df[df["SpatialFDR"] >= alpha]["logFC"].mean()
        df["Sig"] = df["SpatialFDR"] < alpha

        plt.subplot(2, 2, 4)
        sns.scatterplot(data=df, x="logCPM", y="logFC", hue="Sig")
        plt.axhline(y=0, color="grey", linewidth=1)
        plt.axhline(y=emp_null, color="purple", linewidth=1)
        plt.legend(title=f"< {int(alpha*100)} % SpatialFDR")
        plt.xlabel("Mean log-counts")
        plt.ylabel("log-Fold Change")
        plt.show()


plot_milo_diagnostics(mdata)

# %% [markdown]
# #### Plotting logfoldchange on cells

# %%
milo.build_nhood_graph(mdata)
with matplotlib.rc_context({"figure.figsize": [10, 10]}):
    milo.plot_nhood_graph(mdata, alpha=0.1, min_size=5, plot_edges=False)
    sc.pl.umap(mdata["rna"], color=["C_scANVI", "classification"], ncols= 1, legend_loc="on data")

# %%
mdata["milo"]
# Out:
# AnnData object with n_obs × n_vars = 30 × 858
#     obs: 'infection', 'donor'
#     var: 'index_cell', 'kth_distance', 'SpatialFDR', 'Sig', 'logFC', 'logCPM', 'F', 'PValue', 'FDR', 'Nhood_size'
#     uns: 'sample_col', 'nhood'
#     varm: 'X_milo_graph'
#     varp: 'nhood_connectivities'

# %%
milo.annotate_nhoods(mdata, anno_col="classification")

# Define as mixed if fraction of cells in nhood with same label is lower than 0.75
#mdata["milo"].var["nhood_annotation"] = mdata["milo"].var["nhood_annotation"].cat.add_categories(['Mixed'])
#mdata["milo"].var.loc[mdata["milo"].var["nhood_annotation_frac"] < 0.75, "nhood_annotation"] = "Mixed"

# %%
mdata["milo"].var["nhood_annotation"].cat.categories
# Out:
# Index(['B_2', 'B_3', 'B_4', 'B_7', 'B_10', 'B_12', 'B_13', 'B_14', 'B_15',
#        'CD4_3', 'CD4_4', 'CD4_5', 'CD4_6', 'CD4_8', 'CD4_9', 'CD4_11',
#        'CD4_14', 'CD4_16', 'CD4_17', 'CD8_0', 'CD8_1', 'CD8_3', 'CD8_4',
#        'CD8_7', 'CD8_8', 'CD8_14', 'CD8_16', 'NKT_3', 'NKT_14', 'NKT_15',
#        'NKT_16', 'NK_1', 'NK_7', 'NK_14', 'NK_15', 'NK_16'],
#       dtype='object')

# %%
# Determine the number of categories
categories = mdata["milo"].var["nhood_annotation"].cat.categories
colors = ["steelblue", "darkorange", "forestgreen", "firebrick", "mediumpurple", "saddlebrown", "violet", "grey", "olive"]
while len(colors) < len(categories):
    colors += colors

# Calculate the grid size needed (assuming you want a 3x3 grid)
nrows = 9
ncols = 4
fig, axs = plt.subplots(nrows, ncols, sharey=False, sharex=False, tight_layout=False, figsize=(15,30))

# Loop through the categories and plot
for i, category in enumerate(categories):
    # Calculate the position of the current plot
    row = i // ncols
    col = i % ncols
    
    # Filter the data for the current category
    data = mdata["milo"].var[mdata["milo"].var["nhood_annotation"].isin([category])]["logFC"]
    
    # Plot the histogram
    axs[row, col].hist(data, bins=20, color=colors[i])
    axs[row, col].axvline(x=0, color='r', linewidth=1, linestyle='--')
    axs[row, col].set_xlabel("Log Fold Change")
    axs[row, col].set_ylabel("Number of Neighborhoods")
    axs[row, col].set_title(category)

# If there are fewer categories than subplots, you might want to hide the unused subplots
for j in range(i + 1, nrows * ncols):
    fig.delaxes(axs[j // ncols, j % ncols])

plt.show()

# %%
def significance_ratios(mdata_object):
    d = {"cell_compartments": [], "significance_ratio": []}
    for i in mdata_object["milo"].var["nhood_annotation"].unique():
        significant = 0
        insignificant = 0
        d["cell_compartments"].append(i)
        for j in mdata_object["milo"].var[mdata_object["milo"].var["nhood_annotation"].isin([i])]["Sig"]:
            if j == True:
                significant += 1
            else:
                insignificant += 1
        d["significance_ratio"].append(significant/(significant+insignificant))
    df = pd.DataFrame.from_dict(data=d)
    return df

# %%
significance = significance_ratios(mdata)
order = ['B_2', 'B_3', 'B_4', 'B_7', 'B_10', 'B_12', 'B_13', 'B_14', 'B_15',
       'CD4_3', 'CD4_4', 'CD4_5', 'CD4_6', 'CD4_8', 'CD4_9', 'CD4_11',
       'CD4_14', 'CD4_16', 'CD4_17', 'CD8_0', 'CD8_1', 'CD8_3', 'CD8_4',
       'CD8_7', 'CD8_8', 'CD8_14', 'CD8_16', 'NKT_3', 'NKT_14', 'NKT_15',
       'NKT_16', 'NK_1', 'NK_7', 'NK_14', 'NK_15', 'NK_16']

fig, axs = plt.subplots(2, figsize=(30,20), gridspec_kw={'height_ratios': [3, 1]})
sns.boxplot(data=mdata["milo"].var, x="nhood_annotation", y="logFC", order=order, ax=axs[0], palette= "tab20")
axs[0].axhline(y=0, color='r', linewidth=1, linestyle='--')
axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=90, ha="center")

sns.barplot(data=significance, x="cell_compartments", y="significance_ratio", order=order, ax=axs[1], palette= "tab20")
plt.ylim(0, 1.5)
axs[1].axhline(y=0.8, color='r', linewidth=1, linestyle='--')
axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation=90, ha="center")
# Out:
# /tmp/ipykernel_2019370/527532585.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=mdata["milo"].var, x="nhood_annotation", y="logFC", order=order, ax=axs[0], palette= "tab20")
# /tmp/ipykernel_2019370/527532585.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=90, ha="center")
# /tmp/ipykernel_2019370/527532585.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=significance, x="cell_compartments", y="significance_ratio", order=order, ax=axs[1], palette= "tab20")
# /tmp/ipykernel_2019370/527532585.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation=90, ha="center")
# [Text(0, 0, 'B_2'),
#  Text(1, 0, 'B_3'),
#  Text(2, 0, 'B_4'),
#  Text(3, 0, 'B_7'),
#  Text(4, 0, 'B_10'),
#  Text(5, 0, 'B_12'),
#  Text(6, 0, 'B_13'),
#  Text(7, 0, 'B_14'),
#  Text(8, 0, 'B_15'),
#  Text(9, 0, 'CD4_3'),
#  Text(10, 0, 'CD4_4'),
#  Text(11, 0, 'CD4_5'),
#  Text(12, 0, 'CD4_6'),
#  Text(13, 0, 'CD4_8'),
#  Text(14, 0, 'CD4_9'),
#  Text(15, 0, 'CD4_11'),
#  Text(16, 0, 'CD4_14'),
#  Text(17, 0, 'CD4_16'),
#  Text(18, 0, 'CD4_17'),
#  Text(19, 0, 'CD8_0'),
#  Text(20, 0, 'CD8_1'),
#  Text(21, 0, 'CD8_3'),
#  Text(22, 0, 'CD8_4'),
#  Text(23, 0, 'CD8_7'),
#  Text(24, 0, 'CD8_8'),
#  Text(25, 0, 'CD8_14'),
#  Text(26, 0, 'CD8_16'),
#  Text(27, 0, 'NKT_3'),
#  Text(28, 0, 'NKT_14'),
#  Text(29, 0, 'NKT_15'),
#  Text(30, 0, 'NKT_16'),
#  Text(31, 0, 'NK_1'),
#  Text(32, 0, 'NK_7'),
#  Text(33, 0, 'NK_14'),
#  Text(34, 0, 'NK_15'),
#  Text(35, 0, 'NK_16')]
