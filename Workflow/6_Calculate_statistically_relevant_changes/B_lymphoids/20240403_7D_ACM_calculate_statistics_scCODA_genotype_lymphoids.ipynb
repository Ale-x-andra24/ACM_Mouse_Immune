# %% [markdown]
# # Compositional analysis of the ACM cardiac leucocytes 6mpi dataset (Pkp2+Ttn) - myeloids - using scCoda `pertpy`:
# - **Developed by**: Christian Eger
# - **Modified by**: Alexandra Cirnu
# - **Talavera-López Lab - Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg**
# - **Created on**: 231214
# - **Last modified**: 240403

# %% [markdown]
# #### Environment: scCoda
#
# To install `pertpy` on MacOS create a new mamba environment and activte it. Then go int 'github' folder and type 'git clone https://github.com/theislab/pertpy.git'. Change directory to 'pertpy' and type 'pip install .'
#
# Look at website to solve problem at the end: https://www.sc-best-practices.org/conditions/compositional.html

# %%
import warnings

import pandas as pd

warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")

import numpy as np
            #import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import altair as alt

import scanpy as sc
import pertpy as pt
from statannot import add_stat_annotation
from scipy import stats

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.5.post1
# scanpy      1.9.8
# -----
# PIL                         10.2.0
# absl                        NA
# adjustText                  1.0.4
# altair                      4.2.2
# arrow                       1.3.0
# arviz                       0.17.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# blitzgsea                   NA
# certifi                     2024.02.02
# cffi                        1.16.0
# chardet                     5.2.0
# charset_normalizer          3.3.2
# chex                        0.1.85
# colorama                    0.4.6
# comm                        0.2.1
# contextlib2                 NA
# custom_inherit              2.4.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.9.0
# debugpy                     1.8.1
# decorator                   5.1.1
# decoupler                   1.6.0
# docrep                      0.3.2
# entrypoints                 0.4
# etils                       1.7.0
# exceptiongroup              1.2.0
# executing                   2.0.1
# flax                        0.8.1
# fsspec                      2024.2.0
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# importlib_resources         NA
# ipykernel                   6.29.3
# ipywidgets                  8.1.2
# jax                         0.4.25
# jaxlib                      0.4.25
# jaxopt                      NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# lightning                   2.1.4
# lightning_fabric            2.2.0.post0
# lightning_utilities         0.10.1
# llvmlite                    0.42.0
# markupsafe                  2.1.5
# matplotlib                  3.8.3
# matplotlib_inline           0.1.6
# ml_collections              NA
# ml_dtypes                   0.3.2
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.8
# mudata                      0.2.3
# multipledispatch            0.6.0
# natsort                     8.4.0
# numba                       0.59.0
# numpy                       1.26.4
# numpyro                     0.14.0
# opt_einsum                  v3.3.0
# optax                       0.1.9
# ott                         0.4.5
# packaging                   23.2
# pandas                      2.2.1
# parso                       0.8.3
# patsy                       0.5.6
# pertpy                      0.7.0
# pkg_resources               NA
# platformdirs                4.2.0
# ply                         3.11
# png                         0.20220715.0
# prompt_toolkit              3.0.43
# psutil                      5.9.8
# pubchempy                   1.0.4
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynndescent                 0.5.11
# pyomo                       6.7.1
# pyparsing                   3.1.1
# pyro                        1.9.0
# pytorch_lightning           2.2.0.post0
# pytz                        2024.1
# referencing                 NA
# reportlab                   4.1.0
# requests                    2.31.0
# rich                        NA
# rpds                        NA
# rpy2                        3.5.11
# scipy                       1.12.0
# scvi                        1.1.2
# seaborn                     0.13.2
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.4.1.post1
# skmisc                      0.3.1
# sparsecca                   0.3.1
# stack_data                  0.6.3
# statannot                   0.2.3
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# toolz                       0.12.1
# torch                       2.2.1+cu121
# torchgen                    NA
# torchmetrics                1.3.1
# tornado                     6.4
# toyplot                     1.0.3
# toytree                     2.0.1
# tqdm                        4.66.2
# traitlets                   5.14.1
# typing_extensions           NA
# tzlocal                     NA
# urllib3                     2.2.1
# vscode                      NA
# wcwidth                     0.2.13
# xarray                      2024.2.0
# xarray_einstats             0.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-6.6.14-100.fc38.x86_64-x86_64-with-glibc2.37
# -----
# Session information updated at 2024-04-03 18:25

# %% [markdown]
# Manual git installation of pertpy necessary due to Apple silicon
# $ git clone https://github.com/theislab/pertpy.git
# $ cd pertpy
# $ pip install .

# %%
adata = sc.read_h5ad("/home/acirnu/data/ACM_cardiac_leuco/scANVI/ACM_lymphoids_clustered_ac240403.raw.h5ad")
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 10104 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'n_genes', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'

# %%
adata.obs
# Out:
#                       cell_source               donor  n_counts  n_genes  \
# AAACCCAAGATACAGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    8265.0     2689
# AACCCAATCAGCTGAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13594.0     3640
# AACCTGAAGATAGCAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13182.0     3085
# AACGTCAAGCTACTGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    1860.0     1106
# AACTTCTCAAGCGCTC-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    9586.0     2703
# ...                           ...                 ...       ...      ...
# TTTGATCAGTATGACA-1-B2   AG_Gerull    Ttn_HetKO_MCMV_1   12119.0     2704
# TTTGGAGAGATTAGCA-1-B2   AG_Gerull      Ttn_Ctr_MCMV_2   20506.0     4156
# TTTGGTTAGCACCTGC-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    3174.0     1436
# TTTGTTGAGACCTCCG-1-B2   AG_Gerull  Ttn_HetKO_noninf_2    4549.0     1710
# TTTGTTGGTAGTAAGT-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    6564.0     2416
#
#                                    sample seed_labels         condition  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr_noninf_1         CD8   Pkp2_Ctr_noninf
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr_noninf_1           B   Pkp2_Ctr_noninf
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# ...                                   ...         ...               ...
# TTTGATCAGTATGACA-1-B2    Ttn_HetKO_MCMV_1     Unknown    Ttn_HetKO_MCMV
# TTTGGAGAGATTAGCA-1-B2      Ttn_Ctr_MCMV_2     Unknown      Ttn_Ctr_MCMV
# TTTGGTTAGCACCTGC-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO_noninf_2     Unknown  Ttn_HetKO_noninf
# TTTGTTGGTAGTAAGT-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
#
#                         genotype infection library  ... percent_chrY  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr    noninf      A1  ...     0.000000
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr    noninf      A1  ...     0.021233
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr    noninf      A1  ...     0.063510
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr    noninf      A1  ...     0.194458
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr    noninf      A1  ...     0.000000
# ...                          ...       ...     ...  ...          ...
# TTTGATCAGTATGACA-1-B2  Ttn_HetKO      MCMV      B2  ...     0.016503
# TTTGGAGAGATTAGCA-1-B2    Ttn_Ctr      MCMV      B2  ...     0.000000
# TTTGGTTAGCACCTGC-1-B2  Ttn_HetKO      MCMV      B2  ...     0.000000
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO    noninf      B2  ...     0.000000
# TTTGTTGGTAGTAAGT-1-B2  Ttn_HetKO      MCMV      B2  ...     0.030469
#
#                        XIST-counts   S_score  G2M_score  _scvi_batch  \
# AAACCCAAGATACAGT-1-A1          0.0 -0.339369  -0.496060            7
# AACCCAATCAGCTGAT-1-A1          0.0  0.525671  -0.137838            6
# AACCTGAAGATAGCAT-1-A1          0.0 -0.268815  -0.516689            6
# AACGTCAAGCTACTGT-1-A1          0.0 -0.270605  -0.340320            7
# AACTTCTCAAGCGCTC-1-A1          0.0 -0.414867  -0.271517            7
# ...                            ...       ...        ...          ...
# TTTGATCAGTATGACA-1-B2          0.0 -0.267751  -0.531946           25
# TTTGGAGAGATTAGCA-1-B2         23.0  2.905559   0.470866           21
# TTTGGTTAGCACCTGC-1-B2          0.0  0.000996  -0.736926           26
# TTTGTTGAGACCTCCG-1-B2          0.0 -0.428444  -0.362500           29
# TTTGTTGGTAGTAAGT-1-B2          0.0  0.363058  -0.589437           26
#
#                        _scvi_labels      batch  C_scANVI  leiden  \
# AAACCCAAGATACAGT-1-A1             1  reference       CD4       5
# AACCCAATCAGCTGAT-1-A1             2  reference       CD8       4
# AACCTGAAGATAGCAT-1-A1             0  reference         B      10
# AACGTCAAGCTACTGT-1-A1             1  reference       CD4      11
# AACTTCTCAAGCGCTC-1-A1             1  reference       CD4       5
# ...                             ...        ...       ...     ...
# TTTGATCAGTATGACA-1-B2             5      query         B      10
# TTTGGAGAGATTAGCA-1-B2             5      query         B       2
# TTTGGTTAGCACCTGC-1-B2             5      query       CD8       4
# TTTGTTGAGACCTCCG-1-B2             5      query         B      13
# TTTGTTGGTAGTAAGT-1-B2             5      query       CD8       0
#
#                        classification
# AAACCCAAGATACAGT-1-A1           CD4_5
# AACCCAATCAGCTGAT-1-A1           CD8_4
# AACCTGAAGATAGCAT-1-A1            B_10
# AACGTCAAGCTACTGT-1-A1          CD4_11
# AACTTCTCAAGCGCTC-1-A1           CD4_5
# ...                               ...
# TTTGATCAGTATGACA-1-B2            B_10
# TTTGGAGAGATTAGCA-1-B2             B_2
# TTTGGTTAGCACCTGC-1-B2           CD8_4
# TTTGTTGAGACCTCCG-1-B2            B_13
# TTTGTTGGTAGTAAGT-1-B2           CD8_0
#
# [10104 rows x 29 columns]

# %%
new_order_genotype = ['Pkp2_Ctr', 'Pkp2_HetKO', 'Ttn_Ctr', 'Ttn_HetKO']
adata.obs["genotype"] = adata.obs["genotype"].cat.reorder_categories(new_order_genotype, ordered=True)

adata.obs["genotype"].cat.categories
# Out:
# Index(['Pkp2_Ctr', 'Pkp2_HetKO', 'Ttn_Ctr', 'Ttn_HetKO'], dtype='object')

# %%
new_order_infection = ['noninf', 'MCMV']
adata.obs["infection"] = adata.obs["infection"].cat.reorder_categories(new_order_infection, ordered=True)

adata.obs["infection"].cat.categories
# Out:
# Index(['noninf', 'MCMV'], dtype='object')

# %%
new_order_condition = ['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV', 'Pkp2_HetKO_MCMV', 'Ttn_Ctr_noninf', 'Ttn_HetKO_noninf','Ttn_Ctr_MCMV', 'Ttn_HetKO_MCMV' ]
adata.obs["condition"] = adata.obs["condition"].cat.reorder_categories(new_order_condition, ordered=True)

adata.obs["condition"].cat.categories
# Out:
# Index(['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV',
#        'Pkp2_HetKO_MCMV', 'Ttn_Ctr_noninf', 'Ttn_HetKO_noninf', 'Ttn_Ctr_MCMV',
#        'Ttn_HetKO_MCMV'],
#       dtype='object')

# %% [markdown]
# create notebook for every compartment and compare across cell states
# visualization improvement
# reference to ctrl healthy

# %%
sccoda_model = pt.tl.Sccoda()
sccoda_data = sccoda_model.load(
    adata,
    type="cell_level",
    generate_sample_level=True,
    cell_type_identifier="classification",
    sample_identifier="sample",
    covariate_obs=["genotype", "infection", "condition"],
)
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 10134 × 29414
#   2 modalities
#     rna:	10104 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'n_genes', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#     coda:	30 x 36
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="genotype",
    y_scale="count",
    figsize=(30, 20),
    add_dots=False,
    args_swarmplot={"palette": ["red"]},
)
plt.show()

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="genotype",
    plot_facets=True,
    y_scale="log",
    add_dots=True,
    cmap="Reds",
)
plt.xticks(rotation=90)
plt.show()

# %%
pt.pl.coda.stacked_barplot(
    sccoda_data, modality_key="coda", feature_name="genotype", figsize=(15, 9) 
)
plt.legend(ncol=3, loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
sccoda_data = sccoda_model.prepare(
    sccoda_data,
    modality_key="coda",
    formula="genotype",
    reference_cell_type="automatic",
)
sccoda_data["coda"]
# Out:
# Automatic reference selection! Reference cell type set to NK_7
# Zero counts encountered in data! Added a pseudocount of 0.5.
# AnnData object with n_obs × n_vars = 30 × 36
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'

# %% [markdown]
# Run No-U-turn HMC sampling (nuts)

# %%
sccoda_model.run_nuts(sccoda_data, modality_key="coda", rng_key=1234)
# Out:
# sample: 100%|██████████| 11000/11000 [04:44<00:00, 38.63it/s, 255 steps of size 2.17e-02. acc. prob=0.83]

# %%
sccoda_data["coda"]
# Out:
# AnnData object with n_obs × n_vars = 30 × 36
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'
#     varm: 'intercept_df', 'effect_df_genotype[T.Pkp2_HetKO]', 'effect_df_genotype[T.Ttn_Ctr]', 'effect_df_genotype[T.Ttn_HetKO]'

# %% [markdown]
# #### Result interpreteation

# %% [markdown]
# **Intercepts**
#
# The first column of the intercept summary shows the parameters determined by the MCMC inference.
#
# The “Expected sample” column gives some context to the numerical values. If we had a new sample (with no active covariates) with a total number of cells equal to the mean sampling depth of the dataset, then this distribution over the cell types would be most likely.
#
# **Effects**
#
# For the effect summary, the first column again shows the inferred parameters for all combinations of covariates and cell types. Most important is the distinctions between zero and non-zero entries A value of zero means that no statistically credible effect was detected. For a value other than zero, a credible change was detected. A positive sign indicates an increase, a negative sign a decrease in abundance.
#
# Since the numerical values of the “Final Parameter” column are not straightforward to interpret, the “Expected sample” and “log2-fold change” columns give us an idea on the magnitude of the change. The expected sample is calculated for each covariate separately (covariate value = 1, all other covariates = 0), with the same method as for the intercepts. The log-fold change is then calculated between this expected sample and the expected sample with no active covariates from the intercept section. Since the data is compositional, cell types for which no credible change was detected, can still change in abundance as well, as soon as a credible effect is detected on another cell type due to the sum-to-one constraint. If there are no credible effects for a covariate, its expected sample will be identical to the intercept sample, therefore the log2-fold change is 0.

# %%
sccoda_model.summary(sccoda_data, modality_key= "coda")
# Out:
#                                           Compositional Analysis summary
# ┌────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────┐
# │ Name                                       │ Value                                                              │
# ├────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────┤
# │ Data                                       │ Data: 30 samples, 36 cell types                                    │
# │ Reference cell type                        │ NK_7                                                               │
# │ Formula                                    │ genotype                                                           │
# └────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Intercepts                                                                                                      │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │            Final Parameter  Expected Sample                                                                     │
# │ Cell Type                                                                                                       │
# │ B_2             1.594           25.517                                                                          │
# │ B_3            -0.862            2.189                                                                          │
# │ B_4            -0.872            2.167                                                                          │
# │ B_7            -0.868            2.176                                                                          │
# │ B_10            0.664           10.068                                                                          │
# │ B_12            0.914           12.927                                                                          │
# │ B_13            0.738           10.841                                                                          │
# │ B_14            0.429            7.959                                                                          │
# │ B_15           -0.870            2.171                                                                          │
# │ CD4_3           1.438           21.831                                                                          │
# │ CD4_4          -0.113            4.629                                                                          │
# │ CD4_5           1.735           29.380                                                                          │
# │ CD4_6           1.631           26.478                                                                          │
# │ CD4_8           0.871           12.383                                                                          │
# │ CD4_9           0.942           13.294                                                                          │
# │ CD4_11          0.872           12.395                                                                          │
# │ CD4_14         -0.862            2.189                                                                          │
# │ CD4_16         -0.628            2.766                                                                          │
# │ CD4_17          0.068            5.547                                                                          │
# │ CD8_0           1.289           18.809                                                                          │
# │ CD8_1           1.510           23.461                                                                          │

# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Filter out credible effects

# %%
sccoda_model.credible_effects(sccoda_data, modality_key="coda")
# Out:
# Covariate               Cell Type
# genotype[T.Pkp2_HetKO]  B_2           True
#                         B_3          False
#                         B_4          False
#                         B_7          False
#                         B_10          True
#                                      ...
# genotype[T.Ttn_HetKO]   NK_1         False
#                         NK_7         False
#                         NK_14        False
#                         NK_15        False
#                         NK_16        False
# Name: Final Parameter, Length: 108, dtype: bool

# %%
pt.pl.coda.effects_barplot(sccoda_data, modality_key="coda", parameter="Final Parameter")

# %% [markdown]
# ##### Adjust the "false discovery rate"

# %%
#If needed adjust the 'false discovery rate' - default is 0.05, however when no effects are detected it can be incresed to up to 0.2
sccoda_model.set_fdr(sccoda_data, 0.2)
sccoda_model.credible_effects(sccoda_data, modality_key="coda")
# Out:
# Covariate               Cell Type
# genotype[T.Pkp2_HetKO]  B_2           True
#                         B_3          False
#                         B_4          False
#                         B_7          False
#                         B_10          True
#                                      ...
# genotype[T.Ttn_HetKO]   NK_1         False
#                         NK_7         False
#                         NK_14        False
#                         NK_15        False
#                         NK_16        False
# Name: Final Parameter, Length: 108, dtype: bool

# %%
pt.pl.coda.effects_barplot(sccoda_data, modality_key="coda", parameter="Final Parameter")

# %%
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 10134 × 29414
#   2 modalities
#     rna:	10104 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'n_genes', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'doublet_scores', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo', 'n_cells_by_counts-A1', 'mean_counts-A1', 'pct_dropout_by_counts-A1', 'total_counts-A1', 'n_cells_by_counts-A2', 'mean_counts-A2', 'pct_dropout_by_counts-A2', 'total_counts-A2', 'n_cells_by_counts-A3', 'mean_counts-A3', 'pct_dropout_by_counts-A3', 'total_counts-A3', 'n_cells_by_counts-A4', 'mean_counts-A4', 'pct_dropout_by_counts-A4', 'total_counts-A4', 'n_cells_by_counts-B1', 'mean_counts-B1', 'pct_dropout_by_counts-B1', 'total_counts-B1', 'n_cells_by_counts-B2', 'mean_counts-B2', 'pct_dropout_by_counts-B2', 'total_counts-B2'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#     coda:	30 x 36
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'
#       uns:	'scCODA_params'
#       obsm:	'covariate_matrix', 'sample_counts'
#       varm:	'intercept_df', 'effect_df_genotype[T.Pkp2_HetKO]', 'effect_df_genotype[T.Ttn_Ctr]', 'effect_df_genotype[T.Ttn_HetKO]'

# %%
sccoda_data["coda"].varm["effect_df_genotype[T.Pkp2_HetKO]"]
# Out:
#            Final Parameter  HDI 3%  HDI 97%     SD  Inclusion probability  \
# Cell Type
# B_2               0.597013   0.282    0.947  0.178                 0.9961
# B_3               0.000000  -0.633    0.448  0.198                 0.4628
# B_4               0.000000  -0.655    0.443  0.205                 0.4693
# B_7               0.000000  -0.694    0.427  0.211                 0.4757
# B_10              0.666456   0.194    1.103  0.255                 0.9803
# B_12             -0.642772  -1.128   -0.124  0.291                 0.9521
# B_13             -0.545456  -1.018    0.006  0.315                 0.8664
# B_14              0.386342  -0.062    0.878  0.282                 0.7184
# B_15              0.000000  -0.689    0.425  0.211                 0.4636
# CD4_3             0.000000  -0.175    0.540  0.151                 0.4472
# CD4_4             0.000000  -0.635    0.340  0.197                 0.4734
# CD4_5            -0.319006  -0.663    0.029  0.218                 0.7131
# CD4_6             0.000000  -0.187    0.457  0.131                 0.4223
# CD4_8             0.000000  -0.265    0.529  0.146                 0.4175
# CD4_9             0.000000  -0.726    0.129  0.219                 0.5548
# CD4_11            0.000000  -0.301    0.481  0.138                 0.4067
# CD4_14            0.000000  -0.633    0.452  0.197                 0.4609
# CD4_16            0.000000  -0.673    0.375  0.201                 0.4677
# CD4_17            0.000000  -0.680    0.319  0.194                 0.4677
# CD8_0             0.000000  -0.350    0.468  0.144                 0.4186
# CD8_1             0.000000  -0.295    0.487  0.138                 0.4091
# CD8_3             0.000000  -0.660    0.365  0.193                 0.4672
# CD8_4             0.000000  -0.406    0.275  0.115                 0.3846
# CD8_7            -0.411765  -0.777    0.004  0.248                 0.8263
# CD8_8             0.000000  -0.543    0.431  0.173                 0.4334
# CD8_14            0.000000  -0.670    0.438  0.214                 0.4842
# CD8_16            0.000000  -0.660    0.388  0.205                 0.4754
# NKT_3             0.000000  -0.575    0.516  0.195                 0.4594
# NKT_14            0.000000  -0.642    0.418  0.200                 0.4691
# NKT_15            0.000000  -0.573    0.366  0.174                 0.4408
# NKT_16            0.000000  -0.642    0.364  0.191                 0.4591
# NK_1              0.000000  -0.636    0.441  0.203                 0.4727
# NK_7              0.000000   0.000    0.000  0.000                 0.0000
# NK_14             0.000000  -0.668    0.389  0.204                 0.4753
# NK_15             0.000000  -0.670    0.397  0.207                 0.4693
# NK_16             0.000000  -0.578    0.479  0.188                 0.4581
#
#            Expected Sample  log2-fold change
# Cell Type
# B_2              45.323612          0.828825
# B_3               2.140021         -0.032482
# B_4               2.118727         -0.032482
# B_7               2.127219         -0.032482
# B_10             19.168567          0.929011
# B_12              6.646186         -0.959806
# B_13              6.143281         -0.819409
# B_14             11.451923          0.524892
# B_15              2.122969         -0.032482
# CD4_3            21.344956         -0.032482
# CD4_4             4.525895         -0.032482
# CD4_5            20.880376         -0.492710
# CD4_6            25.888929         -0.032482
# CD4_8            12.107383         -0.032482
# CD4_9            12.998259         -0.032482
# CD4_11           12.119497         -0.032482
# CD4_14            2.140021         -0.032482
# CD4_16            2.704225         -0.032482
# CD4_17            5.423902         -0.032482
# CD8_0            18.390155         -0.032482
# CD8_1            22.938471         -0.032482
# CD8_3             4.937284         -0.032482
# CD8_4            22.984393         -0.032482
# CD8_7            14.571255         -0.626533
# CD8_8             5.380684         -0.032482
# CD8_14            2.159368         -0.032482
# CD8_16            3.413764         -0.032482
# NKT_3             2.209609         -0.032482
# NKT_14            2.120847         -0.032482
# NKT_15            6.441848         -0.032482
# NKT_16            4.091106         -0.032482
# NK_1              2.140021         -0.032482
# NK_7              7.939223         -0.032482
# NK_14             2.125093         -0.032482
# NK_15             2.135745         -0.032482
# NK_16             2.295190         -0.032482

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=sccoda_data["coda"].varm["effect_df_genotype[T.Pkp2_HetKO]"], x="Cell Type", y="log2-fold change", hue="Cell Type")
plt.xticks(rotation=90)
plt.show()

# %%
pt.pl.coda.effects_barplot(sccoda_data, "coda", "genotype")
plt.show()
