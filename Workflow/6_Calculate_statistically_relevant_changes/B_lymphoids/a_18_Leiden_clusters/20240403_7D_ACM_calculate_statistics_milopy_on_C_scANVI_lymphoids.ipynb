# %% [markdown]
# # Compositional analysis of the ACM cardiac leucocytes 6mpi dataset (Pkp2+Ttn) - lymphoids - using `milopy`:
#
# and the single cell best practices tutorial https://www.sc-best-practices.org/conditions/compositional.html#without-labeled-clusters:
#
# - **Developed by**: Christian Eger
# - **Modified by**: Alexandra Cirnu
# - **Talavera-López Lab - Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg**
# - **Created on**: 231207
# - **Last modified**: 240403

# %% [markdown]
# #### Environment: milopy

# %%
import scanpy as sc
import pandas as pd
import pertpy as pt
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import numpy as np
import scvi
import rpy2
import rpy2.robjects as robjects
from rpy2.robjects import pandas2ri
from scipy.sparse import csr_matrix
import muon as mu
from muon import atac as ac
from muon import prot

# %%
rpy2.robjects.numpy2ri.activate()

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library(edgeR)
# Out:
# R[write to console]: Loading required package: limma

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.6
# scanpy      1.9.8
# -----
# PIL                         10.2.0
# absl                        NA
# adjustText                  1.1.1
# anyio                       NA
# arrow                       1.3.0
# arviz                       0.17.1
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# babel                       2.14.0
# blitzgsea                   NA
# brotli                      1.1.0
# certifi                     2024.02.02
# cffi                        1.16.0
# chardet                     5.2.0
# charset_normalizer          3.3.2
# chex                        0.1.86
# colorama                    0.4.6
# comm                        0.2.2
# contextlib2                 NA
# custom_inherit              2.4.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.9.0
# debugpy                     1.8.1
# decorator                   5.1.1
# decoupler                   1.6.0
# defusedxml                  0.7.1
# docrep                      0.3.2
# etils                       1.7.0
# exceptiongroup              1.2.0
# executing                   2.0.1
# fastjsonschema              NA
# flax                        0.8.2
# fqdn                        NA
# fsspec                      2024.3.1
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# importlib_resources         NA
# ipykernel                   6.29.3
# ipywidgets                  8.1.2
# isoduration                 NA
# jax                         0.4.25
# jaxlib                      0.4.25
# jaxopt                      NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# json5                       0.9.24
# jsonpointer                 2.4
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# jupyter_events              0.10.0
# jupyter_server              2.13.0
# jupyterlab_server           2.25.4
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# lightning                   2.1.4
# lightning_fabric            2.2.1
# lightning_utilities         0.11.2
# llvmlite                    0.42.0
# markupsafe                  2.1.5
# matplotlib                  3.8.3
# ml_collections              NA
# ml_dtypes                   0.4.0
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.8
# mudata                      0.2.3
# multipledispatch            0.6.0
# muon                        0.1.5
# natsort                     8.4.0
# nbformat                    5.10.3
# numba                       0.59.1
# numpy                       1.26.4
# numpyro                     0.14.0
# opt_einsum                  v3.3.0
# optax                       0.2.2
# ott                         0.4.5
# overrides                   NA
# packaging                   24.0
# pandas                      2.2.1
# parso                       0.8.3
# patsy                       0.5.6
# pertpy                      0.7.0
# pickleshare                 0.7.5
# pkg_resources               NA
# platformdirs                4.2.0
# ply                         3.11
# png                         0.20220715.0
# prometheus_client           NA
# prompt_toolkit              3.0.42
# psutil                      5.9.8
# pubchempy                   1.0.4
# pure_eval                   0.2.2
# pyarrow                     15.0.2
# pycparser                   2.22
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynndescent                 0.5.12
# pyomo                       6.7.1
# pyparsing                   3.1.2
# pyro                        1.9.0
# pythonjsonlogger            NA
# pytorch_lightning           2.2.1
# pytz                        2024.1
# referencing                 NA
# reportlab                   4.1.0
# requests                    2.31.0
# rfc3339_validator           0.1.4
# rfc3986_validator           0.1.1
# rich                        NA
# rpds                        NA
# rpy2                        3.5.11
# scipy                       1.12.0
# scvi                        1.1.2
# seaborn                     0.13.2
# send2trash                  NA
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.4.1.post1
# skmisc                      0.3.1
# sniffio                     1.3.1
# socks                       1.7.1
# sparsecca                   0.3.1
# stack_data                  0.6.2
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.4.0
# toolz                       0.12.1
# torch                       2.2.2+cu121
# torchgen                    NA
# torchmetrics                1.3.2
# tornado                     6.4
# toyplot                     1.0.3
# toytree                     2.0.5
# tqdm                        4.66.2
# traitlets                   5.14.2
# typing_extensions           NA
# tzlocal                     NA
# umap                        0.5.5
# uri_template                NA
# urllib3                     2.2.1
# vscode                      NA
# wcwidth                     0.2.13
# webcolors                   1.13
# websocket                   1.7.0
# xarray                      2024.3.0
# xarray_einstats             0.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.1
# jupyter_core        5.7.2
# jupyterlab          4.1.5
# notebook            7.1.2
# -----
# Python 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# Linux-6.8.4-200.fc39.x86_64-x86_64-with-glibc2.38
# -----
# Session information updated at 2024-04-15 14:10

# %% [markdown]
# #### Load in data

# %%
input = '/home/acirnu/data/ACM_cardiac_leuco/5_Leiden_clustering_and_annotation/ACM_lymphoids_clustered_muon_ac240415.raw.h5mu'
mdata_data = mu.read_h5mu(input)
mdata_data
# Out:
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# MuData object with n_obs × n_vars = 10104 × 29477
#   var:	'gene_ids', 'feature_types'
#   2 modalities
#     rna:	10104 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     prot:	10104 x 99
#       obs:	'library', 'batch'
#       var:	'gene_ids', 'feature_types'
#       uns:	'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap'
#       varm:	'PCs'
#       layers:	'counts', 'log_norm'

# %%
adata = mdata_data.mod["rna"]
adata
# Out:
# AnnData object with n_obs × n_vars = 10104 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo'
#     uns: 'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#                       cell_source               donor  n_counts  \
# AAACCCAAGATACAGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    8265.0
# AACCCAATCAGCTGAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13594.0
# AACCTGAAGATAGCAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13182.0
# AACGTCAAGCTACTGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    1860.0
# AACTTCTCAAGCGCTC-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    9586.0
# ...                           ...                 ...       ...
# TTTGATCAGTATGACA-1-B2   AG_Gerull    Ttn_HetKO_MCMV_1   12119.0
# TTTGGAGAGATTAGCA-1-B2   AG_Gerull      Ttn_Ctr_MCMV_2   20506.0
# TTTGGTTAGCACCTGC-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    3174.0
# TTTGTTGAGACCTCCG-1-B2   AG_Gerull  Ttn_HetKO_noninf_2    4549.0
# TTTGTTGGTAGTAAGT-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    6564.0
#
#                                    sample seed_labels         condition  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr_noninf_1         CD8   Pkp2_Ctr_noninf
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr_noninf_1           B   Pkp2_Ctr_noninf
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# ...                                   ...         ...               ...
# TTTGATCAGTATGACA-1-B2    Ttn_HetKO_MCMV_1     Unknown    Ttn_HetKO_MCMV
# TTTGGAGAGATTAGCA-1-B2      Ttn_Ctr_MCMV_2     Unknown      Ttn_Ctr_MCMV
# TTTGGTTAGCACCTGC-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO_noninf_2     Unknown  Ttn_HetKO_noninf
# TTTGTTGGTAGTAAGT-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
#
#                         genotype infection library model  ...  percent_chrY  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.000000
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.021233
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.063510
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.194458
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.000000
# ...                          ...       ...     ...   ...  ...           ...
# TTTGATCAGTATGACA-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...      0.016503
# TTTGGAGAGATTAGCA-1-B2    Ttn_Ctr      MCMV      B2   Ttn  ...      0.000000
# TTTGGTTAGCACCTGC-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...      0.000000
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO    noninf      B2   Ttn  ...      0.000000
# TTTGTTGGTAGTAAGT-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...      0.030469
#
#                        XIST-counts   S_score  G2M_score  _scvi_batch  \
# AAACCCAAGATACAGT-1-A1          0.0 -0.339369  -0.496061            7
# AACCCAATCAGCTGAT-1-A1          0.0  0.525671  -0.137837            6
# AACCTGAAGATAGCAT-1-A1          0.0 -0.268814  -0.516689            6
# AACGTCAAGCTACTGT-1-A1          0.0 -0.270605  -0.340320            7
# AACTTCTCAAGCGCTC-1-A1          0.0 -0.414867  -0.271517            7
# ...                            ...       ...        ...          ...
# TTTGATCAGTATGACA-1-B2          0.0 -0.267751  -0.531946           25
# TTTGGAGAGATTAGCA-1-B2         23.0  2.905558   0.470866           21
# TTTGGTTAGCACCTGC-1-B2          0.0  0.000996  -0.736926           26
# TTTGTTGAGACCTCCG-1-B2          0.0 -0.428444  -0.362500           29
# TTTGTTGGTAGTAAGT-1-B2          0.0  0.363058  -0.589437           26
#
#                        _scvi_labels      batch  C_scANVI  leiden  \
# AAACCCAAGATACAGT-1-A1             1  reference       CD4       5
# AACCCAATCAGCTGAT-1-A1             2  reference       CD8       4
# AACCTGAAGATAGCAT-1-A1             0  reference         B      10
# AACGTCAAGCTACTGT-1-A1             1  reference       CD4      11
# AACTTCTCAAGCGCTC-1-A1             1  reference       CD4       5
# ...                             ...        ...       ...     ...
# TTTGATCAGTATGACA-1-B2             5      query         B      10
# TTTGGAGAGATTAGCA-1-B2             5      query         B       2
# TTTGGTTAGCACCTGC-1-B2             5      query       CD8       4
# TTTGTTGAGACCTCCG-1-B2             5      query         B      13
# TTTGTTGGTAGTAAGT-1-B2             5      query       CD8       0
#
#                        classification
# AAACCCAAGATACAGT-1-A1           CD4_5
# AACCCAATCAGCTGAT-1-A1           CD8_4
# AACCTGAAGATAGCAT-1-A1            B_10
# AACGTCAAGCTACTGT-1-A1          CD4_11
# AACTTCTCAAGCGCTC-1-A1           CD4_5
# ...                               ...
# TTTGATCAGTATGACA-1-B2            B_10
# TTTGGAGAGATTAGCA-1-B2             B_2
# TTTGGTTAGCACCTGC-1-B2           CD8_4
# TTTGTTGAGACCTCCG-1-B2            B_13
# TTTGTTGGTAGTAAGT-1-B2           CD8_0
#
# [10104 rows x 28 columns]

# %% [markdown]
# #### Dimensionality reduction to assess whether we see a batch effect in this dataset

# %%
milo = pt.tl.Milo()
mdata = milo.load(adata)
mdata
# Out:
# MuData object with n_obs × n_vars = 10104 × 29378
#   2 modalities
#     rna:	10104 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     milo:	0 x 0

# %%
# use logcounts to calculate PCA and neighbors
adata.layers["counts"] = adata.X.copy()
adata.layers["logcounts"] = sc.pp.log1p(adata.layers["counts"]).copy()
adata.X = adata.layers["logcounts"].copy()

sc.pp.highly_variable_genes(
    adata, n_top_genes=3000, subset=False
)  # 3k genes as used by authors for clustering

sc.pp.pca(adata)
sc.pp.neighbors(adata, n_neighbors=10, n_pcs=30, use_rep="X_scANVI")
sc.tl.umap(adata)
# Out:
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/preprocessing/_highly_variable_genes.py:226: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby("mean_bin")["dispersions"]

# %%
sc.pl.umap(adata, color=["condition", "genotype", "infection", "model", "C_scANVI", "classification", "library"], ncols=2, wspace=0.25)
# Out:
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
#  2.18414783 0.99933952 1.44038832 0.94451314 0.80627745 0.92663187
#  0.61000258 1.25346613 1.11900699 1.15678596 0.59787095 0.69276941
#  1.15642095 0.71204275 1.38832402 0.66069305 2.23494959 0.70547295
#  1.29523778 2.20860338 0.60301906 0.91021585 0.79622597 1.50415909
#  0.66885316 2.02044582 0.71762848 1.01368916 0.99075675 2.51524258
#  0.63895029 1.17187083 1.59559953 0.89958072 0.8456775  0.96019453
#  0.96824908 1.06829488 0.8668521  1.41903305 1.11245227 1.27347124
#  1.16212106 0.85635942 0.86936933 0.57303149 1.26473546 0.94667107
#  0.61593378 3.20397949 0.54045719 1.03429461 0.79270989 0.69353276
#  1.45202506 1.16157496 0.7941007  0.98691612 0.81520289 1.19145048
#  0.9903779  1.10310078 2.19939804 1.00045586 0.79783309 0.73778236
#  0.56947732 0.70552951 1.43374157 1.83493435 0.75390249 0.79921877
#  0.78816837 1.39441526 0.89298195 1.12249947 1.00033605 0.96283484
#  1.31460202 1.01009357 0.86718535 0.91692048 0.88772237 0.92080295
#  1.00207865 2.13615704 1.76807332 1.32985651 0.7339254  0.8382054
#  0.80287951 0.79393172 0.76932591 2.12341809 0.78981954 0.755889
#  1.74413764 1.10121751 1.6489048  1.894835   0.72956389 1.56078279
#  0.94879997 1.17124069 1.71668541 0.75467831 1.17449009 0.7901904
#  0.87391359 1.24336302 1.00987089 0.76515812 0.927589   0.76607567
#  1.7458266  0.68788099 3.90194225 0.8324489  1.42805123 1.40820158
#  2.06930971 0.64761531 0.8270039  0.83179301 0.70251918 0.67700684
#  1.15363848 0.6697098  0.82168096 1.34406054 1.42774487 1.17345667
#  0.65980119 0.75640655 0.86040008 1.07769883 1.29893541 0.97258848
#  0.9369024  1.04824495 0.64233166 0.73959672 0.87996978 1.08572829
#  1.45226407 0.7990284  1.70272732 0.85204804 0.83104551 1.08713019
#  0.66829461 1.51417494 1.25669777 1.18721735 0.88308936 0.85681933
#  0.99738806 1.01180124 1.06462777 1.01591241 1.07919109 2.02831578
#  0.87897825 1.00775278 0.81274641 1.0303278  0.59018016 1.19566631
#  1.26410079 0.91061997 0.98780656 0.85930771 1.34181941 0.64971513
#  1.49954474 0.94335681 1.15821779 0.85287613 4.14781284 2.3679173
#  1.00710392 0.71721059 0.72808009 1.39964116 0.55138159 1.64519215
#  0.87142396 1.67965221 1.96962833 1.69856179 0.65952194 1.01156366
#  0.63591129 1.52481389 1.96953309 1.00913429 0.76986319 0.93235785
#  0.90633219 1.19757712]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   adata.obs.loc[adata.obs["nhood_ixs_refined"] == 1, "nhood_kth_distance"] = k_distances

# %%
adata.obsm["nhoods"]
# Out:
# <10104x914 sparse matrix of type '<class 'numpy.float32'>'
# 	with 12115 stored elements in Compressed Sparse Row format>

# %% [markdown]
# At this point we need to check the median number of cells in each neighbourhood, to make sure the neighbourhoods contain enough cells to detect differences between samples.

# %%
nhood_size = adata.obsm["nhoods"].toarray().sum(0)
plt.hist(nhood_size, bins=20)
plt.xlabel("# cells in neighbourhood")
plt.ylabel("# neighbouthoods")
# Out:
# Text(0, 0.5, '# neighbouthoods')

# %%
np.median(nhood_size)
# Out:
# 13.0

# %%
sc.pp.neighbors(adata, n_neighbors=50, use_rep="X_scANVI", key_added="milo")
milo.make_nhoods(mdata, neighbors_key="milo", prop=0.1)
# Out:
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/pertpy/tools/_milo.py:183: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 2
#   2.21756315  2.13346696  2.17106867  1.62685513  2.64394665  4.66257095
#   1.91907167  1.5344758   2.38882947  1.32282734  2.81594467  4.7792716
#   2.37140465  2.02105331  1.87861192  2.9436605   1.39113033  2.65527487
#   1.83907127  2.63942885  2.65181112  1.58430195  1.76643872  2.13143086
#   2.11845374  1.69559932  2.37366891  2.02897263  3.29600477  2.59303713
#   1.4342829   1.28793406  4.07133961  1.65017664  1.69010115  1.73217559
#   2.05611539  1.72129476  2.16250849  1.8721621   1.87808478  2.27242613
#   2.42188859  1.52272725  1.2883327   1.76430058  1.76797175  1.78012896
#   2.43663073  2.08044052  2.17502093  4.75869799  1.94536436  1.8778137
#   1.53117371  1.676332    1.58138311  2.01394892  2.06591034  1.4151336
#   1.88119578  1.50313199  1.88818479  1.27317405  1.89127088  1.47987461
#   1.78137541  2.36325097  1.63348472  4.29642344  3.02965856  2.20276594
#   2.16009784  1.7098316   1.43965518  1.859761    1.7170459   2.00193048
#   2.14719605  2.13098288  2.11657929  1.79145122  2.09553957  1.45602369
#   1.4923737   2.49168515  1.51708221  1.61295998  4.28748655  1.91757965
#   1.66267502  3.47222257  1.94995654  1.79490638  1.57326162  1.81619871
#   2.54878211  1.99488497  1.71578336  2.19136691  2.0253737   1.81879079
#   1.64616477  3.28996229  2.02320528  3.24617529  1.62016797  3.1127038
#   1.76265407  2.09429765  2.235286    2.71038532  1.58843565  2.69486737
#   2.32906818  2.34211111  1.59465003  2.80736566  1.49170136  2.94540977
#   1.99541092  1.9837935   6.86353827  1.43789184  2.41633296  1.82672024
#   3.06126189  1.44126129  4.07879019  1.33886039  1.81970382  2.09838271
#   1.24456668  1.35861588  1.61539638  3.29414248  1.86324942  2.87951994
#   1.64211297  1.96813631  2.55833483  1.75502145  1.82228267  2.22096419]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   adata.obs.loc[adata.obs["nhood_ixs_refined"] == 1, "nhood_kth_distance"] = k_distances

# %%
nhood_size = adata.obsm["nhoods"].toarray().sum(0)
plt.hist(nhood_size, bins=20)
plt.xlabel("# cells in neighbourhood")
plt.ylabel("# neighbouthoods")
# Out:
# Text(0, 0.5, '# neighbouthoods')

# %%
np.median(nhood_size)
# Out:
# 72.0

# %% [markdown]
# #### Count cells in neighborhood

# %%
adata.obs
# Out:
#                       cell_source               donor  n_counts  \
# AAACCCAAGATACAGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    8265.0
# AACCCAATCAGCTGAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13594.0
# AACCTGAAGATAGCAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13182.0
# AACGTCAAGCTACTGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    1860.0
# AACTTCTCAAGCGCTC-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    9586.0
# ...                           ...                 ...       ...
# TTTGATCAGTATGACA-1-B2   AG_Gerull    Ttn_HetKO_MCMV_1   12119.0
# TTTGGAGAGATTAGCA-1-B2   AG_Gerull      Ttn_Ctr_MCMV_2   20506.0
# TTTGGTTAGCACCTGC-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    3174.0
# TTTGTTGAGACCTCCG-1-B2   AG_Gerull  Ttn_HetKO_noninf_2    4549.0
# TTTGTTGGTAGTAAGT-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    6564.0
#
#                                    sample seed_labels         condition  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr_noninf_1         CD8   Pkp2_Ctr_noninf
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr_noninf_1           B   Pkp2_Ctr_noninf
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# ...                                   ...         ...               ...
# TTTGATCAGTATGACA-1-B2    Ttn_HetKO_MCMV_1     Unknown    Ttn_HetKO_MCMV
# TTTGGAGAGATTAGCA-1-B2      Ttn_Ctr_MCMV_2     Unknown      Ttn_Ctr_MCMV
# TTTGGTTAGCACCTGC-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO_noninf_2     Unknown  Ttn_HetKO_noninf
# TTTGTTGGTAGTAAGT-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
#
#                         genotype infection library model  ...  G2M_score  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...  -0.496061
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...  -0.137837
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...  -0.516689
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...  -0.340320
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...  -0.271517
# ...                          ...       ...     ...   ...  ...        ...
# TTTGATCAGTATGACA-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...  -0.531946
# TTTGGAGAGATTAGCA-1-B2    Ttn_Ctr      MCMV      B2   Ttn  ...   0.470866
# TTTGGTTAGCACCTGC-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...  -0.736926
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO    noninf      B2   Ttn  ...  -0.362500
# TTTGTTGGTAGTAAGT-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...  -0.589437
#
#                        _scvi_batch  _scvi_labels      batch  C_scANVI  leiden  \
# AAACCCAAGATACAGT-1-A1            7             1  reference       CD4       5
# AACCCAATCAGCTGAT-1-A1            6             2  reference       CD8       4
# AACCTGAAGATAGCAT-1-A1            6             0  reference         B      10
# AACGTCAAGCTACTGT-1-A1            7             1  reference       CD4      11
# AACTTCTCAAGCGCTC-1-A1            7             1  reference       CD4       5
# ...                            ...           ...        ...       ...     ...
# TTTGATCAGTATGACA-1-B2           25             5      query         B      10
# TTTGGAGAGATTAGCA-1-B2           21             5      query         B       2
# TTTGGTTAGCACCTGC-1-B2           26             5      query       CD8       4
# TTTGTTGAGACCTCCG-1-B2           29             5      query         B      13
# TTTGTTGGTAGTAAGT-1-B2           26             5      query       CD8       0
#
#                        classification  nhood_ixs_random  nhood_ixs_refined  \
# AAACCCAAGATACAGT-1-A1           CD4_5                 0                  0
# AACCCAATCAGCTGAT-1-A1           CD8_4                 1                  0
# AACCTGAAGATAGCAT-1-A1            B_10                 0                  0
# AACGTCAAGCTACTGT-1-A1          CD4_11                 1                  1
# AACTTCTCAAGCGCTC-1-A1           CD4_5                 1                  0
# ...                               ...               ...                ...
# TTTGATCAGTATGACA-1-B2            B_10                 0                  0
# TTTGGAGAGATTAGCA-1-B2             B_2                 0                  0
# TTTGGTTAGCACCTGC-1-B2           CD8_4                 0                  0
# TTTGTTGAGACCTCCG-1-B2            B_13                 0                  0
# TTTGTTGGTAGTAAGT-1-B2           CD8_0                 0                  0
#
#                        nhood_kth_distance
# AAACCCAAGATACAGT-1-A1            0.000000
# AACCCAATCAGCTGAT-1-A1            0.000000
# AACCTGAAGATAGCAT-1-A1            0.000000
# AACGTCAAGCTACTGT-1-A1            2.890265
# AACTTCTCAAGCGCTC-1-A1            0.000000
# ...                                   ...
# TTTGATCAGTATGACA-1-B2            0.000000
# TTTGGAGAGATTAGCA-1-B2            0.000000
# TTTGGTTAGCACCTGC-1-B2            0.000000
# TTTGTTGAGACCTCCG-1-B2            0.000000
# TTTGTTGGTAGTAAGT-1-B2            0.000000
#
# [10104 rows x 31 columns]

# %%
milo.count_nhoods(mdata, sample_col="donor")
# Out:
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# MuData object with n_obs × n_vars = 10104 × 29378
#   2 modalities
#     rna:	10104 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification', 'nhood_ixs_random', 'nhood_ixs_refined', 'nhood_kth_distance'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups', 'hvg', 'pca', 'umap', 'condition_colors', 'genotype_colors', 'infection_colors', 'model_colors', 'library_colors', 'nhood_neighbors_key', 'milo'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap', 'X_pca', 'nhoods'
#       varm:	'PCs'
#       layers:	'counts', 'logcounts'
#       obsp:	'connectivities', 'distances', 'milo_distances', 'milo_connectivities'
#     milo:	30 x 858
#       var:	'index_cell', 'kth_distance'
#       uns:	'sample_col'

# %%
mean_n_cells = mdata["milo"].X.toarray().mean(0)
plt.plot(nhood_size, mean_n_cells, ".")
plt.xlabel("# cells in nhood")
plt.ylabel("Mean # cells per sample in nhood")
# Out:
# Text(0, 0.5, 'Mean # cells per sample in nhood')

# %% [markdown]
# #### Run differential abundance test on neighborhoods

# %%
milo.da_nhoods(
    mdata, design="~infection", model_contrasts="infectionMCMV-infectionnoninf"
)
milo_results_Pkp2_hetko = mdata["milo"].obs.copy()
milo_results_Pkp2_hetko
# Out:
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/pertpy/tools/_milo.py:688: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pvalues = pvalues[keep_nhoods][o]
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/pertpy/tools/_milo.py:689: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   w = w[keep_nhoods][o]
#                     infection                donor
# Pkp2_Ctr_MCMV_1          MCMV      Pkp2_Ctr_MCMV_1
# Pkp2_Ctr_MCMV_2          MCMV      Pkp2_Ctr_MCMV_2
# Pkp2_Ctr_MCMV_3          MCMV      Pkp2_Ctr_MCMV_3
# Pkp2_Ctr_MCMV_4          MCMV      Pkp2_Ctr_MCMV_4
# Pkp2_Ctr_MCMV_5          MCMV      Pkp2_Ctr_MCMV_5
# Pkp2_Ctr_MCMV_6          MCMV      Pkp2_Ctr_MCMV_6
# Pkp2_Ctr_noninf_1      noninf    Pkp2_Ctr_noninf_1
# Pkp2_Ctr_noninf_2      noninf    Pkp2_Ctr_noninf_2
# Pkp2_Ctr_noninf_3      noninf    Pkp2_Ctr_noninf_3
# Pkp2_Ctr_noninf_4      noninf    Pkp2_Ctr_noninf_4
# Pkp2_HetKO_MCMV_1        MCMV    Pkp2_HetKO_MCMV_1
# Pkp2_HetKO_MCMV_2        MCMV    Pkp2_HetKO_MCMV_2
# Pkp2_HetKO_MCMV_3        MCMV    Pkp2_HetKO_MCMV_3
# Pkp2_HetKO_MCMV_4        MCMV    Pkp2_HetKO_MCMV_4
# Pkp2_HetKO_MCMV_5        MCMV    Pkp2_HetKO_MCMV_5
# Pkp2_HetKO_MCMV_6        MCMV    Pkp2_HetKO_MCMV_6
# Pkp2_HetKO_noninf_1    noninf  Pkp2_HetKO_noninf_1
# Pkp2_HetKO_noninf_2    noninf  Pkp2_HetKO_noninf_2
# Pkp2_HetKO_noninf_3    noninf  Pkp2_HetKO_noninf_3
# Pkp2_HetKO_noninf_4    noninf  Pkp2_HetKO_noninf_4
# Ttn_Ctr_MCMV_1           MCMV       Ttn_Ctr_MCMV_1
# Ttn_Ctr_MCMV_2           MCMV       Ttn_Ctr_MCMV_2
# Ttn_Ctr_MCMV_3           MCMV       Ttn_Ctr_MCMV_3
# Ttn_Ctr_noninf_1       noninf     Ttn_Ctr_noninf_1
# Ttn_Ctr_noninf_2       noninf     Ttn_Ctr_noninf_2
# Ttn_HetKO_MCMV_1         MCMV     Ttn_HetKO_MCMV_1
# Ttn_HetKO_MCMV_2         MCMV     Ttn_HetKO_MCMV_2
# Ttn_HetKO_MCMV_3         MCMV     Ttn_HetKO_MCMV_3
# Ttn_HetKO_noninf_1     noninf   Ttn_HetKO_noninf_1
# Ttn_HetKO_noninf_2     noninf   Ttn_HetKO_noninf_2

# %% [markdown]
# #### Data Diagnostics

# %%
def plot_milo_diagnostics(mdata):
    alpha = 0.1  ## significance threshold

    with matplotlib.rc_context({"figure.figsize": [12, 12]}):

        ## Check P-value histogram
        plt.subplot(2, 2, 1)
        plt.hist(mdata["milo"].var["PValue"], bins=20)
        plt.xlabel("Uncorrected P-value")

        ## Visualize extent of multiple-testing correction
        plt.subplot(2, 2, 2)
        plt.scatter(
            mdata["milo"].var["PValue"],
            mdata["milo"].var["SpatialFDR"],
            s=3,
        )
        plt.xlabel("Uncorrected P-value")
        plt.ylabel("SpatialFDR")

        ## Visualize volcano plot
        plt.subplot(2, 2, 3)
        plt.scatter(
            mdata["milo"].var["logFC"],
            -np.log10(mdata["milo"].var["SpatialFDR"]),
            s=3,
        )
        plt.axhline(
            y=-np.log10(alpha),
            color="red",
            linewidth=1,
            label=f"{int(alpha*100)} % SpatialFDR",
        )
        plt.legend()
        plt.xlabel("log-Fold Change")
        plt.ylabel("- log10(SpatialFDR)")
        plt.tight_layout()

        ## Visualize MA plot
        df = mdata["milo"].var
        emp_null = df[df["SpatialFDR"] >= alpha]["logFC"].mean()
        df["Sig"] = df["SpatialFDR"] < alpha

        plt.subplot(2, 2, 4)
        sns.scatterplot(data=df, x="logCPM", y="logFC", hue="Sig")
        plt.axhline(y=0, color="grey", linewidth=1)
        plt.axhline(y=emp_null, color="purple", linewidth=1)
        plt.legend(title=f"< {int(alpha*100)} % SpatialFDR")
        plt.xlabel("Mean log-counts")
        plt.ylabel("log-Fold Change")
        plt.show()


plot_milo_diagnostics(mdata)

# %% [markdown]
# #### Plotting logfoldchange on cells

# %%
milo.build_nhood_graph(mdata)
with matplotlib.rc_context({"figure.figsize": [10, 10]}):
    milo.plot_nhood_graph(mdata, alpha=0.1, min_size=5, plot_edges=False)
    sc.pl.umap(mdata["rna"], color=["C_scANVI", "C_scANVI"], ncols= 1, legend_loc="on data")
# Out:
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /home/acirnu/miniforge3/envs/milopy/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
mdata["milo"]
# Out:
# AnnData object with n_obs × n_vars = 30 × 858
#     obs: 'infection', 'donor'
#     var: 'index_cell', 'kth_distance', 'logFC', 'logCPM', 'F', 'PValue', 'FDR', 'SpatialFDR', 'Sig', 'Nhood_size'
#     uns: 'sample_col', 'nhood'
#     varm: 'X_milo_graph'
#     varp: 'nhood_connectivities'

# %%
milo.annotate_nhoods(mdata, anno_col="C_scANVI")

# Define as mixed if fraction of cells in nhood with same label is lower than 0.75
#mdata["milo"].var["nhood_annotation"] = mdata["milo"].var["nhood_annotation"].cat.add_categories(['Mixed'])
#mdata["milo"].var.loc[mdata["milo"].var["nhood_annotation_frac"] < 0.75, "nhood_annotation"] = "Mixed"

# %%
mdata["milo"].var["nhood_annotation"].cat.categories
# Out:
# Index(['B', 'CD4', 'CD8', 'NK', 'NKT'], dtype='object')

# %%
# Determine the number of categories
categories = mdata["milo"].var["nhood_annotation"].cat.categories
colors = ["steelblue", "darkorange", "forestgreen", "firebrick", "mediumpurple", "saddlebrown", "violet", "grey", "olive"]
while len(colors) < len(categories):
    colors += colors

# Calculate the grid size needed (assuming you want a 3x3 grid)
nrows = 9
ncols = 4
fig, axs = plt.subplots(nrows, ncols, sharey=False, sharex=False, tight_layout=False, figsize=(15,30))

# Loop through the categories and plot
for i, category in enumerate(categories):
    # Calculate the position of the current plot
    row = i // ncols
    col = i % ncols
    
    # Filter the data for the current category
    data = mdata["milo"].var[mdata["milo"].var["nhood_annotation"].isin([category])]["logFC"]
    
    # Plot the histogram
    axs[row, col].hist(data, bins=20, color=colors[i])
    axs[row, col].axvline(x=0, color='r', linewidth=1, linestyle='--')
    axs[row, col].set_xlabel("Log Fold Change")
    axs[row, col].set_ylabel("Number of Neighborhoods")
    axs[row, col].set_title(category)

# If there are fewer categories than subplots, you might want to hide the unused subplots
for j in range(i + 1, nrows * ncols):
    fig.delaxes(axs[j // ncols, j % ncols])

plt.show()

# %%
def significance_ratios(mdata_object):
    d = {"cell_compartments": [], "significance_ratio": []}
    for i in mdata_object["milo"].var["nhood_annotation"].unique():
        significant = 0
        insignificant = 0
        d["cell_compartments"].append(i)
        for j in mdata_object["milo"].var[mdata_object["milo"].var["nhood_annotation"].isin([i])]["Sig"]:
            if j == True:
                significant += 1
            else:
                insignificant += 1
        d["significance_ratio"].append(significant/(significant+insignificant))
    df = pd.DataFrame.from_dict(data=d)
    return df

# %%
significance = significance_ratios(mdata)
order = ['B', 'CD4', 'CD8', 'NK', 'NKT']

fig, axs = plt.subplots(2, figsize=(10,10), gridspec_kw={'height_ratios': [3, 1]})
sns.boxplot(data=mdata["milo"].var, x="nhood_annotation", y="logFC", order=order, ax=axs[0], palette= "tab20")
axs[0].axhline(y=0, color='r', linewidth=1, linestyle='--')
axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=90, ha="center")

sns.barplot(data=significance, x="cell_compartments", y="significance_ratio", order=order, ax=axs[1], palette= "tab20")
plt.ylim(0, 1.5)
axs[1].axhline(y=0.8, color='r', linewidth=1, linestyle='--')
axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation=90, ha="center")
# Out:
# /tmp/ipykernel_448719/3820109023.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=mdata["milo"].var, x="nhood_annotation", y="logFC", order=order, ax=axs[0], palette= "tab20")
# /tmp/ipykernel_448719/3820109023.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation=90, ha="center")
# /tmp/ipykernel_448719/3820109023.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=significance, x="cell_compartments", y="significance_ratio", order=order, ax=axs[1], palette= "tab20")
# /tmp/ipykernel_448719/3820109023.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation=90, ha="center")
# [Text(0, 0, 'B'),
#  Text(1, 0, 'CD4'),
#  Text(2, 0, 'CD8'),
#  Text(3, 0, 'NK'),
#  Text(4, 0, 'NKT')]
