# %% [markdown]
# # Compositional analysis of the ACM cardiac leucocytes 6mpi dataset (Pkp2+Ttn) - lymphoids - using scCoda `pertpy`:
# - **Developed by**: Christian Eger
# - **Modified by**: Alexandra Cirnu
# - **Talavera-López Lab - Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg**
# - **Created on**: 231214
# - **Last modified**: 240403

# %% [markdown]
# #### Environment: scCoda
#
# To install `pertpy` on MacOS create a new mamba environment and activte it. Then go int 'github' folder and type 'git clone https://github.com/theislab/pertpy.git'. Change directory to 'pertpy' and type 'pip install .'
#
# Look at website to solve problem at the end: https://www.sc-best-practices.org/conditions/compositional.html

# %%
import warnings
import pandas as pd
warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")
import numpy as np
            #import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import altair as alt
import scanpy as sc
import pertpy as pt
from statannot import add_stat_annotation
from scipy import stats
import muon as mu
from muon import atac as ac
from muon import prot

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.5.post1
# scanpy      1.9.8
# -----
# PIL                         10.2.0
# absl                        NA
# adjustText                  1.0.4
# altair                      4.2.2
# arrow                       1.3.0
# arviz                       0.17.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# blitzgsea                   NA
# certifi                     2024.02.02
# cffi                        1.16.0
# chardet                     5.2.0
# charset_normalizer          3.3.2
# chex                        0.1.85
# colorama                    0.4.6
# comm                        0.2.1
# contextlib2                 NA
# custom_inherit              2.4.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.9.0
# debugpy                     1.8.1
# decorator                   5.1.1
# decoupler                   1.6.0
# docrep                      0.3.2
# entrypoints                 0.4
# etils                       1.7.0
# exceptiongroup              1.2.0
# executing                   2.0.1
# flax                        0.8.1
# fsspec                      2024.2.0
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# importlib_resources         NA
# ipykernel                   6.29.3
# ipywidgets                  8.1.2
# jax                         0.4.25
# jaxlib                      0.4.25
# jaxopt                      NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# lightning                   2.1.4
# lightning_fabric            2.2.0.post0
# lightning_utilities         0.10.1
# llvmlite                    0.42.0
# markupsafe                  2.1.5
# matplotlib                  3.8.3
# ml_collections              NA
# ml_dtypes                   0.3.2
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.8
# mudata                      0.2.3
# multipledispatch            0.6.0
# muon                        0.1.5
# natsort                     8.4.0
# numba                       0.59.0
# numpy                       1.26.4
# numpyro                     0.14.0
# opt_einsum                  v3.3.0
# optax                       0.1.9
# ott                         0.4.5
# packaging                   23.2
# pandas                      2.2.1
# parso                       0.8.3
# patsy                       0.5.6
# pertpy                      0.7.0
# pkg_resources               NA
# platformdirs                4.2.0
# ply                         3.11
# png                         0.20220715.0
# prompt_toolkit              3.0.43
# psutil                      5.9.8
# pubchempy                   1.0.4
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynndescent                 0.5.11
# pyomo                       6.7.1
# pyparsing                   3.1.1
# pyro                        1.9.0
# pytorch_lightning           2.2.0.post0
# pytz                        2024.1
# referencing                 NA
# reportlab                   4.1.0
# requests                    2.31.0
# rich                        NA
# rpds                        NA
# rpy2                        3.5.11
# scipy                       1.12.0
# scvi                        1.1.2
# seaborn                     0.13.2
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.4.1.post1
# skmisc                      0.3.1
# sparsecca                   0.3.1
# stack_data                  0.6.3
# statannot                   0.2.3
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# toolz                       0.12.1
# torch                       2.2.1+cu121
# torchgen                    NA
# torchmetrics                1.3.1
# tornado                     6.4
# toyplot                     1.0.3
# toytree                     2.0.1
# tqdm                        4.66.2
# traitlets                   5.14.1
# typing_extensions           NA
# tzlocal                     NA
# umap                        0.5.5
# urllib3                     2.2.1
# vscode                      NA
# wcwidth                     0.2.13
# xarray                      2024.2.0
# xarray_einstats             0.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-6.8.4-200.fc39.x86_64-x86_64-with-glibc2.38
# -----
# Session information updated at 2024-05-06 11:56

# %% [markdown]
# Manual git installation of pertpy necessary due to Apple silicon
# $ git clone https://github.com/theislab/pertpy.git
# $ cd pertpy
# $ pip install .

# %%
input = '/home/acirnu/data/ACM_cardiac_leuco/5_Leiden_clustering_and_annotation/ACM_lymphoids_clustered_muon_ac240506.raw.h5mu'
mdata_data = mu.read_h5mu(input)
mdata_data
# Out:
# MuData object with n_obs × n_vars = 10104 × 29477
#   var:	'gene_ids', 'feature_types'
#   2 modalities
#     rna:	10104 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     prot:	10104 x 99
#       obs:	'library', 'batch'
#       var:	'gene_ids', 'feature_types'
#       uns:	'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap'
#       varm:	'PCs'
#       layers:	'counts', 'log_norm'

# %%
adata = mdata_data.mod["rna"]
adata
# Out:
# AnnData object with n_obs × n_vars = 10104 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo'
#     uns: 'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#                       cell_source               donor  n_counts  \
# AAACCCAAGATACAGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    8265.0
# AACCCAATCAGCTGAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13594.0
# AACCTGAAGATAGCAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13182.0
# AACGTCAAGCTACTGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    1860.0
# AACTTCTCAAGCGCTC-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    9586.0
# ...                           ...                 ...       ...
# TTTGATCAGTATGACA-1-B2   AG_Gerull    Ttn_HetKO_MCMV_1   12119.0
# TTTGGAGAGATTAGCA-1-B2   AG_Gerull      Ttn_Ctr_MCMV_2   20506.0
# TTTGGTTAGCACCTGC-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    3174.0
# TTTGTTGAGACCTCCG-1-B2   AG_Gerull  Ttn_HetKO_noninf_2    4549.0
# TTTGTTGGTAGTAAGT-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    6564.0
#
#                                    sample seed_labels         condition  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr_noninf_1         CD8   Pkp2_Ctr_noninf
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr_noninf_1           B   Pkp2_Ctr_noninf
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# ...                                   ...         ...               ...
# TTTGATCAGTATGACA-1-B2    Ttn_HetKO_MCMV_1     Unknown    Ttn_HetKO_MCMV
# TTTGGAGAGATTAGCA-1-B2      Ttn_Ctr_MCMV_2     Unknown      Ttn_Ctr_MCMV
# TTTGGTTAGCACCTGC-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO_noninf_2     Unknown  Ttn_HetKO_noninf
# TTTGTTGGTAGTAAGT-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
#
#                         genotype infection library model  ...  percent_chrY  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.000000
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.021233
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.063510
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.194458
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.000000
# ...                          ...       ...     ...   ...  ...           ...
# TTTGATCAGTATGACA-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...      0.016503
# TTTGGAGAGATTAGCA-1-B2    Ttn_Ctr      MCMV      B2   Ttn  ...      0.000000
# TTTGGTTAGCACCTGC-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...      0.000000
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO    noninf      B2   Ttn  ...      0.000000
# TTTGTTGGTAGTAAGT-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...      0.030469
#
#                        XIST-counts   S_score  G2M_score  _scvi_batch  \
# AAACCCAAGATACAGT-1-A1          0.0 -0.339369  -0.496061            7
# AACCCAATCAGCTGAT-1-A1          0.0  0.525671  -0.137837            6
# AACCTGAAGATAGCAT-1-A1          0.0 -0.268814  -0.516689            6
# AACGTCAAGCTACTGT-1-A1          0.0 -0.270605  -0.340320            7
# AACTTCTCAAGCGCTC-1-A1          0.0 -0.414867  -0.271517            7
# ...                            ...       ...        ...          ...
# TTTGATCAGTATGACA-1-B2          0.0 -0.267751  -0.531946           25
# TTTGGAGAGATTAGCA-1-B2         23.0  2.905558   0.470866           21
# TTTGGTTAGCACCTGC-1-B2          0.0  0.000996  -0.736926           26
# TTTGTTGAGACCTCCG-1-B2          0.0 -0.428444  -0.362500           29
# TTTGTTGGTAGTAAGT-1-B2          0.0  0.363058  -0.589437           26
#
#                        _scvi_labels      batch  C_scANVI  leiden  \
# AAACCCAAGATACAGT-1-A1             1  reference       CD4       4
# AACCCAATCAGCTGAT-1-A1             2  reference       CD8       7
# AACCTGAAGATAGCAT-1-A1             0  reference         B       9
# AACGTCAAGCTACTGT-1-A1             1  reference       CD4      11
# AACTTCTCAAGCGCTC-1-A1             1  reference       CD4       4
# ...                             ...        ...       ...     ...
# TTTGATCAGTATGACA-1-B2             5      query         B       9
# TTTGGAGAGATTAGCA-1-B2             5      query         B       2
# TTTGGTTAGCACCTGC-1-B2             5      query       CD8       7
# TTTGTTGAGACCTCCG-1-B2             5      query         B      13
# TTTGTTGGTAGTAAGT-1-B2             5      query       CD8       0
#
#                        classification
# AAACCCAAGATACAGT-1-A1           CD4_4
# AACCCAATCAGCTGAT-1-A1           CD8_7
# AACCTGAAGATAGCAT-1-A1             B_9
# AACGTCAAGCTACTGT-1-A1          CD4_11
# AACTTCTCAAGCGCTC-1-A1           CD4_4
# ...                               ...
# TTTGATCAGTATGACA-1-B2             B_9
# TTTGGAGAGATTAGCA-1-B2             B_2
# TTTGGTTAGCACCTGC-1-B2           CD8_7
# TTTGTTGAGACCTCCG-1-B2            B_13
# TTTGTTGGTAGTAAGT-1-B2           CD8_0
#
# [10104 rows x 28 columns]

# %%
new_order_genotype = ['Pkp2_Ctr', 'Pkp2_HetKO', 'Ttn_Ctr', 'Ttn_HetKO']
adata.obs["genotype"] = adata.obs["genotype"].cat.reorder_categories(new_order_genotype, ordered=True)

adata.obs["genotype"].cat.categories
# Out:
# Index(['Pkp2_Ctr', 'Pkp2_HetKO', 'Ttn_Ctr', 'Ttn_HetKO'], dtype='object')

# %%
new_order_infection = ['noninf', 'MCMV']
adata.obs["infection"] = adata.obs["infection"].cat.reorder_categories(new_order_infection, ordered=True)

adata.obs["infection"].cat.categories
# Out:
# Index(['noninf', 'MCMV'], dtype='object')

# %%
new_order_condition = ['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV', 'Pkp2_HetKO_MCMV', 'Ttn_Ctr_noninf', 'Ttn_HetKO_noninf','Ttn_Ctr_MCMV', 'Ttn_HetKO_MCMV' ]
adata.obs["condition"] = adata.obs["condition"].cat.reorder_categories(new_order_condition, ordered=True)

adata.obs["condition"].cat.categories
# Out:
# Index(['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV',
#        'Pkp2_HetKO_MCMV', 'Ttn_Ctr_noninf', 'Ttn_HetKO_noninf', 'Ttn_Ctr_MCMV',
#        'Ttn_HetKO_MCMV'],
#       dtype='object')

# %% [markdown]
# create notebook for every compartment and compare across cell states
# visualization improvement
# reference to ctrl healthy

# %%
sccoda_model = pt.tl.Sccoda()
sccoda_data = sccoda_model.load(
    adata,
    type="cell_level",
    generate_sample_level=True,
    cell_type_identifier="classification",
    sample_identifier="sample",
    covariate_obs=["condition"],
)
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 10134 × 29396
#   2 modalities
#     rna:	10104 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     coda:	30 x 18
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="condition",
    y_scale="count",
    figsize=(30, 20),
    add_dots=False,
    args_swarmplot={"palette": ["red"]},
)
plt.show()

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="condition",
    plot_facets=True,
    y_scale="log",
    add_dots=True,
    cmap="Reds",
)
plt.xticks(rotation=90)
plt.show()

# %%
pt.pl.coda.stacked_barplot(
    sccoda_data, modality_key="coda", feature_name="condition", figsize=(15, 9) 
)
plt.legend(ncol=3, loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
sccoda_data = sccoda_model.prepare(
    sccoda_data,
    modality_key="coda",
    formula="condition",
    reference_cell_type="automatic",
)
sccoda_data["coda"]
# Out:
# Automatic reference selection! Reference cell type set to CD4_15
# Zero counts encountered in data! Added a pseudocount of 0.5.
# AnnData object with n_obs × n_vars = 30 × 18
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'

# %% [markdown]
# Run No-U-turn HMC sampling (nuts)

# %%
sccoda_model.run_nuts(sccoda_data, modality_key="coda", rng_key=1234)
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# sample: 100%|██████████| 11000/11000 [05:20<00:00, 34.29it/s, 511 steps of size 1.16e-02. acc. prob=0.70]

# %%
sccoda_data["coda"]
# Out:
# AnnData object with n_obs × n_vars = 30 × 18
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'
#     varm: 'intercept_df', 'effect_df_condition[T.Pkp2_HetKO_noninf]', 'effect_df_condition[T.Pkp2_Ctr_MCMV]', 'effect_df_condition[T.Pkp2_HetKO_MCMV]', 'effect_df_condition[T.Ttn_Ctr_noninf]', 'effect_df_condition[T.Ttn_HetKO_noninf]', 'effect_df_condition[T.Ttn_Ctr_MCMV]', 'effect_df_condition[T.Ttn_HetKO_MCMV]'

# %% [markdown]
# #### Result interpreteation

# %% [markdown]
# **Intercepts**
#
# The first column of the intercept summary shows the parameters determined by the MCMC inference.
#
# The “Expected sample” column gives some context to the numerical values. If we had a new sample (with no active covariates) with a total number of cells equal to the mean sampling depth of the dataset, then this distribution over the cell types would be most likely.
#
# **Effects**
#
# For the effect summary, the first column again shows the inferred parameters for all combinations of covariates and cell types. Most important is the distinctions between zero and non-zero entries A value of zero means that no statistically credible effect was detected. For a value other than zero, a credible change was detected. A positive sign indicates an increase, a negative sign a decrease in abundance.
#
# Since the numerical values of the “Final Parameter” column are not straightforward to interpret, the “Expected sample” and “log2-fold change” columns give us an idea on the magnitude of the change. The expected sample is calculated for each covariate separately (covariate value = 1, all other covariates = 0), with the same method as for the intercepts. The log-fold change is then calculated between this expected sample and the expected sample with no active covariates from the intercept section. Since the data is compositional, cell types for which no credible change was detected, can still change in abundance as well, as soon as a credible effect is detected on another cell type due to the sum-to-one constraint. If there are no credible effects for a covariate, its expected sample will be identical to the intercept sample, therefore the log2-fold change is 0.

# %%
sccoda_model.summary(sccoda_data, modality_key= "coda")
# Out:
#                                           Compositional Analysis summary
# ┌────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────┐
# │ Name                                       │ Value                                                              │
# ├────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────┤
# │ Data                                       │ Data: 30 samples, 18 cell types                                    │
# │ Reference cell type                        │ CD4_15                                                             │
# │ Formula                                    │ condition                                                          │
# └────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Intercepts                                                                                                      │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │            Final Parameter  Expected Sample                                                                     │
# │ Cell Type                                                                                                       │
# │ B_2             2.070           44.957                                                                          │
# │ B_9             0.889           13.801                                                                          │
# │ B_12            0.995           15.344                                                                          │
# │ B_13            0.877           13.636                                                                          │
# │ B_17           -0.213            4.585                                                                          │
# │ CD4_3           1.161           18.115                                                                          │
# │ CD4_4           2.185           50.436                                                                          │
# │ CD4_6           1.885           37.364                                                                          │
# │ CD4_8           1.015           15.654                                                                          │
# │ CD4_10          1.184           18.536                                                                          │
# │ CD4_11          1.041           16.066                                                                          │
# │ CD4_15          0.421            8.643                                                                          │
# │ CD4_16          0.161            6.664                                                                          │
# │ CD8_0           0.224            7.097                                                                          │
# │ CD8_1           0.494            9.297                                                                          │
# │ CD8_7           1.103           17.094                                                                          │
# │ NKT_14          0.335            7.930                                                                          │
# │ NK_5            1.731           32.031                                                                          │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Effects                                                                                                         │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                                         Final Parameter  Expected Sample  log2-fold change                      │
# │ Covariate                    Cell Type                                                                          │
# │ conditionT.Pkp2_HetKO_noninf B_2             0.529           69.800             0.635                           │
# │                              B_9             0.000           12.628            -0.128                           │
# │                              B_12            0.000           14.040            -0.128                           │
# │                              B_13            0.000           12.477            -0.128                           │
# │                              B_17            0.000            4.195            -0.128                           │
# │                              CD4_3           0.000           16.575            -0.128                           │
# │                              CD4_4           0.000           46.150            -0.128                           │
# │                              CD4_6           0.000           34.188            -0.128                           │
# │                              CD4_8           0.000           14.323            -0.128                           │
# │                              CD4_10          0.000           16.961            -0.128                           │
# │                              CD4_11          0.000           14.701            -0.128                           │
# │                              CD4_15          0.000            7.908            -0.128                           │
# │                              CD4_16          0.000            6.098            -0.128                           │
# │                              CD8_0           0.000            6.494            -0.128                           │
# │                              CD8_1           0.000            8.507            -0.128                           │
# │                              CD8_7           0.000           15.641            -0.128                           │
# │                              NKT_14          0.000            7.256            -0.128                           │
# │                              NK_5            0.000           29.309            -0.128                           │
# │ conditionT.Pkp2_Ctr_MCMV     B_2             0.000           21.717            -1.050                           │
# │                              B_9             0.000            6.667            -1.050                           │
# │                              B_12            0.000            7.412            -1.050                           │
# │                              B_13            0.000            6.587            -1.050                           │
# │                              B_17            0.000            2.215            -1.050                           │
# │                              CD4_3           1.687           47.259             1.383                           │
# │                              CD4_4           0.000           24.364            -1.050                           │
# │                              CD4_6           0.000           18.049            -1.050                           │
# │                              CD4_8           1.112           22.997             0.555                           │
# │                              CD4_10          0.000            8.954            -1.050                           │
# │                              CD4_11          0.000            7.761            -1.050                           │
# │                              CD4_15          0.000            4.175            -1.050                           │
# │                              CD4_16          0.000            3.219            -1.050                           │
# │                              CD8_0           2.593           45.834             2.691                           │
# │                              CD8_1           2.576           59.047             2.667                           │
# │                              CD8_7           1.345           31.688             0.890                           │
# │                              NKT_14          0.000            3.831            -1.050                           │
# │                              NK_5            0.000           15.473            -1.050                           │
# │ conditionT.Pkp2_HetKO_MCMV   B_2             0.622           41.041            -0.131                           │
# │                              B_9             0.951           17.516             0.344                           │
# │                              B_12            0.000            7.523            -1.028                           │
# │                              B_13            0.000            6.685            -1.028                           │
# │                              B_17            0.000            2.248            -1.028                           │
# │                              CD4_3           1.376           35.154             0.957                           │
# │                              CD4_4           0.000           24.727            -1.028                           │
# │                              CD4_6           0.000           18.318            -1.028                           │
# │                              CD4_8           0.865           18.234             0.220                           │
# │                              CD4_10          0.000            9.088            -1.028                           │
# │                              CD4_11          0.000            7.877            -1.028                           │
# │                              CD4_15          0.000            4.237            -1.028                           │
# │                              CD4_16          0.000            3.267            -1.028                           │
# │                              CD8_0           2.702           51.895             2.870                           │
# │                              CD8_1           2.400           50.247             2.434                           │
# │                              CD8_7           0.850           19.603             0.198                           │
# │                              NKT_14          0.000            3.888            -1.028                           │
# │                              NK_5            0.000           15.704            -1.028                           │
# │ conditionT.Ttn_Ctr_noninf    B_2             0.000           44.957             0.000                           │
# │                              B_9             0.000           13.801             0.000                           │
# │                              B_12            0.000           15.344             0.000                           │
# │                              B_13            0.000           13.636             0.000                           │
# │                              B_17            0.000            4.585             0.000                           │
# │                              CD4_3           0.000           18.115             0.000                           │
# │                              CD4_4           0.000           50.436             0.000                           │
# │                              CD4_6           0.000           37.364             0.000                           │
# │                              CD4_8           0.000           15.654             0.000                           │
# │                              CD4_10          0.000           18.536             0.000                           │
# │                              CD4_11          0.000           16.066             0.000                           │
# │                              CD4_15          0.000            8.643             0.000                           │
# │                              CD4_16          0.000            6.664             0.000                           │
# │                              CD8_0           0.000            7.097             0.000                           │
# │                              CD8_1           0.000            9.297             0.000                           │
# │                              CD8_7           0.000           17.094             0.000                           │
# │                              NKT_14          0.000            7.930             0.000                           │
# │                              NK_5            0.000           32.031             0.000                           │
# │ conditionT.Ttn_HetKO_noninf  B_2             0.000           41.049            -0.131                           │
# │                              B_9             0.000           12.601            -0.131                           │
# │                              B_12            0.000           14.010            -0.131                           │
# │                              B_13            0.000           12.451            -0.131                           │
# │                              B_17            0.000            4.186            -0.131                           │
# │                              CD4_3           0.000           16.540            -0.131                           │
# │                              CD4_4           0.000           46.052            -0.131                           │
# │                              CD4_6           0.000           34.116            -0.131                           │
# │                              CD4_8           0.000           14.293            -0.131                           │
# │                              CD4_10          1.005           46.240             1.319                           │
# │                              CD4_11          0.000           14.670            -0.131                           │
# │                              CD4_15          0.000            7.891            -0.131                           │
# │                              CD4_16          0.000            6.085            -0.131                           │
# │                              CD8_0           0.000            6.480            -0.131                           │
# │                              CD8_1           0.000            8.489            -0.131                           │
# │                              CD8_7           0.000           15.608            -0.131                           │
# │                              NKT_14          0.000            7.241            -0.131                           │
# │                              NK_5            0.000           29.247            -0.131                           │
# │ conditionT.Ttn_Ctr_MCMV      B_2            -0.790           22.000            -1.031                           │
# │                              B_9             0.000           14.885             0.109                           │
# │                              B_12            0.000           16.549             0.109                           │
# │                              B_13            0.000           14.707             0.109                           │
# │                              B_17            0.000            4.945             0.109                           │
# │                              CD4_3           0.000           19.537             0.109                           │
# │                              CD4_4           0.000           54.398             0.109                           │
# │                              CD4_6           0.000           40.299             0.109                           │
# │                              CD4_8           0.000           16.883             0.109                           │
# │                              CD4_10          0.000           19.992             0.109                           │
# │                              CD4_11          0.000           17.328             0.109                           │
# │                              CD4_15          0.000            9.321             0.109                           │
# │                              CD4_16          0.000            7.187             0.109                           │
# │                              CD8_0           0.000            7.655             0.109                           │
# │                              CD8_1           0.000           10.027             0.109                           │
# │                              CD8_7           0.000           18.436             0.109                           │
# │                              NKT_14          0.000            8.553             0.109                           │
# │                              NK_5            0.000           34.547             0.109                           │
# │ conditionT.Ttn_HetKO_MCMV    B_2            -0.854           23.943            -0.909                           │
# │                              B_9             0.000           17.263             0.323                           │
# │                              B_12            0.000           19.193             0.323                           │
# │                              B_13            0.000           17.057             0.323                           │
# │                              B_17            0.000            5.735             0.323                           │
# │                              CD4_3           0.000           22.659             0.323                           │
# │                              CD4_4          -0.902           25.594            -0.979                           │
# │                              CD4_6          -1.177           14.410            -1.375                           │
# │                              CD4_8           0.000           19.581             0.323                           │
# │                              CD4_10          0.000           23.186             0.323                           │
# │                              CD4_11          0.000           20.096             0.323                           │
# │                              CD4_15          0.000           10.811             0.323                           │
# │                              CD4_16          0.000            8.336             0.323                           │
# │                              CD8_0           0.000            8.878             0.323                           │
# │                              CD8_1           0.919           29.141             1.648                           │
# │                              CD8_7           0.000           21.382             0.323                           │
# │                              NKT_14          0.000            9.920             0.323                           │
# │                              NK_5            0.000           40.067             0.323                           │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Filter out credible effects

# %%
sccoda_model.credible_effects(sccoda_data, modality_key="coda")
# Out:
# Covariate                       Cell Type
# condition[T.Pkp2_HetKO_noninf]  B_2           True
#                                 B_9          False
#                                 B_12         False
#                                 B_13         False
#                                 B_17         False
#                                              ...
# condition[T.Ttn_HetKO_MCMV]     CD8_0        False
#                                 CD8_1         True
#                                 CD8_7        False
#                                 NKT_14       False
#                                 NK_5         False
# Name: Final Parameter, Length: 126, dtype: bool

# %%
pt.pl.coda.effects_barplot(sccoda_data, modality_key="coda", parameter="Final Parameter")

# %% [markdown]
# ##### Adjust the "false discovery rate"

# %% [raw]
# #If needed adjust the 'false discovery rate' - default is 0.05, however when no effects are detected it can be incresed to up to 0.2
# sccoda_model.set_fdr(sccoda_data, 0.2)
# sccoda_model.credible_effects(sccoda_data, modality_key="coda")

# %%
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 10134 × 29396
#   2 modalities
#     rna:	10104 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     coda:	30 x 18
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'
#       uns:	'scCODA_params'
#       obsm:	'covariate_matrix', 'sample_counts'
#       varm:	'intercept_df', 'effect_df_condition[T.Pkp2_HetKO_noninf]', 'effect_df_condition[T.Pkp2_Ctr_MCMV]', 'effect_df_condition[T.Pkp2_HetKO_MCMV]', 'effect_df_condition[T.Ttn_Ctr_noninf]', 'effect_df_condition[T.Ttn_HetKO_noninf]', 'effect_df_condition[T.Ttn_Ctr_MCMV]', 'effect_df_condition[T.Ttn_HetKO_MCMV]'

# %%
sccoda_data["coda"].varm["effect_df_condition[T.Pkp2_HetKO_noninf]"]
# Out:
#            Final Parameter  HDI 3%  HDI 97%     SD  Inclusion probability  \
# Cell Type
# B_2               0.528752  -0.008    0.966  0.301                 0.8728
# B_9               0.000000  -0.011    1.285  0.399                 0.8412
# B_12              0.000000  -1.256    0.058  0.384                 0.7254
# B_13              0.000000  -0.956    0.286  0.292                 0.5161
# B_17              0.000000  -0.309    1.122  0.356                 0.6012
# CD4_3             0.000000  -0.548    0.453  0.166                 0.4209
# CD4_4             0.000000  -0.608    0.347  0.164                 0.4068
# CD4_6             0.000000  -0.130    0.752  0.251                 0.6443
# CD4_8             0.000000  -0.275    0.789  0.240                 0.5059
# CD4_10            0.000000  -0.489    0.539  0.170                 0.4021
# CD4_11            0.000000  -0.181    0.894  0.282                 0.6106
# CD4_15            0.000000   0.000    0.000  0.000                 0.0000
# CD4_16            0.000000  -0.541    0.707  0.228                 0.4749
# CD8_0             0.000000  -1.321    0.211  0.431                 0.6686
# CD8_1             0.000000  -1.130    0.308  0.370                 0.6180
# CD8_7             0.000000  -0.562    0.503  0.177                 0.4022
# NKT_14            0.000000  -0.774    0.584  0.235                 0.4389
# NK_5              0.000000  -0.447    0.445  0.142                 0.3790
#
#            Expected Sample  log2-fold change
# Cell Type
# B_2              69.800420          0.634680
# B_9              12.627644         -0.128147
# B_12             14.039691         -0.128147
# B_13             12.477018         -0.128147
# B_17              4.194979         -0.128147
# CD4_3            16.574882         -0.128147
# CD4_4            46.149605         -0.128147
# CD4_6            34.188468         -0.128147
# CD4_8            14.323312         -0.128147
# CD4_10           16.960522         -0.128147
# CD4_11           14.700601         -0.128147
# CD4_15            7.908107         -0.128147
# CD4_16            6.097558         -0.128147
# CD8_0             6.494063         -0.128147
# CD8_1             8.506992         -0.128147
# CD8_7            15.640886         -0.128147
# NKT_14            7.256433         -0.128147
# NK_5             29.308817         -0.128147

# %%
sccoda_data["coda"].varm["effect_df_condition[T.Pkp2_HetKO_MCMV]"]
# Out:
#            Final Parameter  HDI 3%  HDI 97%     SD  Inclusion probability  \
# Cell Type
# B_2               0.621664  -0.003    1.063  0.342                 0.8501
# B_9               0.951195   0.272    1.586  0.390                 0.9514
# B_12              0.000000  -1.331    0.011  0.439                 0.6787
# B_13              0.000000  -1.471    0.004  0.483                 0.7478
# B_17              0.000000  -0.187    1.471  0.456                 0.5405
# CD4_3             1.375831   0.851    1.947  0.281                 1.0000
# CD4_4             0.000000  -1.283    0.006  0.402                 0.8351
# CD4_6             0.000000  -0.760    0.369  0.183                 0.2924
# CD4_8             0.865386   0.248    1.427  0.366                 0.9285
# CD4_10            0.000000  -1.210    0.078  0.369                 0.5375
# CD4_11            0.000000  -0.903    0.401  0.192                 0.2832
# CD4_15            0.000000   0.000    0.000  0.000                 0.0000
# CD4_16            0.000000  -1.080    0.430  0.275                 0.3434
# CD8_0             2.702318   2.050    3.403  0.357                 1.0000
# CD8_1             2.400043   1.754    3.090  0.348                 1.0000
# CD8_7             0.849785   0.265    1.405  0.350                 0.9362
# NKT_14            0.000000  -0.678    0.823  0.222                 0.3236
# NK_5              0.000000  -0.335    0.770  0.165                 0.2908
#
#            Expected Sample  log2-fold change
# Cell Type
# B_2              41.040766         -0.131498
# B_9              17.515684          0.343915
# B_12              7.522522         -1.028370
# B_13              6.685235         -1.028370
# B_17              2.247686         -1.028370
# CD4_3            35.153785          0.956535
# CD4_4            24.727139         -1.028370
# CD4_6            18.318315         -1.028370
# CD4_8            18.233990          0.220118
# CD4_10            9.087514         -1.028370
# CD4_11            7.876640         -1.028370
# CD4_15            4.237195         -1.028370
# CD4_16            3.267096         -1.028370
# CD8_0            51.894855          2.870251
# CD8_1            50.246693          2.434161
# CD8_7            19.603081          0.197611
# NKT_14            3.888025         -1.028370
# NK_5             15.703779         -1.028370

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=sccoda_data["coda"].varm["effect_df_condition[T.Pkp2_HetKO_MCMV]"], x="Cell Type", y="log2-fold change", hue="Cell Type")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=sccoda_data["coda"].varm["effect_df_condition[T.Pkp2_HetKO_noninf]"], x="Cell Type", y="log2-fold change", hue="Cell Type")
plt.xticks(rotation=90)
plt.show()

# %%
pt.pl.coda.effects_barplot(sccoda_data, "coda", "condition")
plt.show()
