# %% [markdown]
# # Compositional analysis of the ACM cardiac leucocytes 6mpi dataset (Pkp2+Ttn) - myeloids - using scCoda `pertpy`:
# - **Developed by**: Christian Eger
# - **Modified by**: Alexandra Cirnu
# - **Talavera-López Lab - Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg**
# - **Created on**: 231214
# - **Last modified**: 240403

# %% [markdown]
# #### Environment: scCoda
#
# To install `pertpy` on MacOS create a new mamba environment and activte it. Then go int 'github' folder and type 'git clone https://github.com/theislab/pertpy.git'. Change directory to 'pertpy' and type 'pip install .'
#
# Look at website to solve problem at the end: https://www.sc-best-practices.org/conditions/compositional.html

# %%
import warnings
import pandas as pd
warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")
import numpy as np
            #import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import altair as alt
import scanpy as sc
import pertpy as pt
from statannot import add_stat_annotation
from scipy import stats
import muon as mu
from muon import atac as ac
from muon import prot

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.5.post1
# scanpy      1.9.8
# -----
# PIL                         10.2.0
# absl                        NA
# adjustText                  1.0.4
# altair                      4.2.2
# arrow                       1.3.0
# arviz                       0.17.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# blitzgsea                   NA
# certifi                     2024.02.02
# cffi                        1.16.0
# chardet                     5.2.0
# charset_normalizer          3.3.2
# chex                        0.1.85
# colorama                    0.4.6
# comm                        0.2.1
# contextlib2                 NA
# custom_inherit              2.4.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.9.0
# debugpy                     1.8.1
# decorator                   5.1.1
# decoupler                   1.6.0
# docrep                      0.3.2
# entrypoints                 0.4
# etils                       1.7.0
# exceptiongroup              1.2.0
# executing                   2.0.1
# flax                        0.8.1
# fsspec                      2024.2.0
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# importlib_resources         NA
# ipykernel                   6.29.3
# ipywidgets                  8.1.2
# jax                         0.4.25
# jaxlib                      0.4.25
# jaxopt                      NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# lightning                   2.1.4
# lightning_fabric            2.2.0.post0
# lightning_utilities         0.10.1
# llvmlite                    0.42.0
# markupsafe                  2.1.5
# matplotlib                  3.8.3
# ml_collections              NA
# ml_dtypes                   0.3.2
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.8
# mudata                      0.2.3
# multipledispatch            0.6.0
# muon                        0.1.5
# natsort                     8.4.0
# numba                       0.59.0
# numpy                       1.26.4
# numpyro                     0.14.0
# opt_einsum                  v3.3.0
# optax                       0.1.9
# ott                         0.4.5
# packaging                   23.2
# pandas                      2.2.1
# parso                       0.8.3
# patsy                       0.5.6
# pertpy                      0.7.0
# pkg_resources               NA
# platformdirs                4.2.0
# ply                         3.11
# png                         0.20220715.0
# prompt_toolkit              3.0.43
# psutil                      5.9.8
# pubchempy                   1.0.4
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynndescent                 0.5.11
# pyomo                       6.7.1
# pyparsing                   3.1.1
# pyro                        1.9.0
# pytorch_lightning           2.2.0.post0
# pytz                        2024.1
# referencing                 NA
# reportlab                   4.1.0
# requests                    2.31.0
# rich                        NA
# rpds                        NA
# rpy2                        3.5.11
# scipy                       1.12.0
# scvi                        1.1.2
# seaborn                     0.13.2
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.4.1.post1
# skmisc                      0.3.1
# sparsecca                   0.3.1
# stack_data                  0.6.3
# statannot                   0.2.3
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# toolz                       0.12.1
# torch                       2.2.1+cu121
# torchgen                    NA
# torchmetrics                1.3.1
# tornado                     6.4
# toyplot                     1.0.3
# toytree                     2.0.1
# tqdm                        4.66.2
# traitlets                   5.14.1
# typing_extensions           NA
# tzlocal                     NA
# umap                        0.5.5
# urllib3                     2.2.1
# vscode                      NA
# wcwidth                     0.2.13
# xarray                      2024.2.0
# xarray_einstats             0.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-6.8.4-200.fc39.x86_64-x86_64-with-glibc2.38
# -----
# Session information updated at 2024-05-06 11:56

# %% [markdown]
# Manual git installation of pertpy necessary due to Apple silicon
# $ git clone https://github.com/theislab/pertpy.git
# $ cd pertpy
# $ pip install .

# %%
input = '/home/acirnu/data/ACM_cardiac_leuco/5_Leiden_clustering_and_annotation/ACM_lymphoids_clustered_muon_ac240506.raw.h5mu'
mdata_data = mu.read_h5mu(input)
mdata_data
# Out:
# MuData object with n_obs × n_vars = 10104 × 29477
#   var:	'gene_ids', 'feature_types'
#   2 modalities
#     rna:	10104 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     prot:	10104 x 99
#       obs:	'library', 'batch'
#       var:	'gene_ids', 'feature_types'
#       uns:	'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap'
#       varm:	'PCs'
#       layers:	'counts', 'log_norm'

# %%
adata = mdata_data.mod["rna"]
adata
# Out:
# AnnData object with n_obs × n_vars = 10104 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo'
#     uns: 'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#                       cell_source               donor  n_counts  \
# AAACCCAAGATACAGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    8265.0
# AACCCAATCAGCTGAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13594.0
# AACCTGAAGATAGCAT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1   13182.0
# AACGTCAAGCTACTGT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    1860.0
# AACTTCTCAAGCGCTC-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2    9586.0
# ...                           ...                 ...       ...
# TTTGATCAGTATGACA-1-B2   AG_Gerull    Ttn_HetKO_MCMV_1   12119.0
# TTTGGAGAGATTAGCA-1-B2   AG_Gerull      Ttn_Ctr_MCMV_2   20506.0
# TTTGGTTAGCACCTGC-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    3174.0
# TTTGTTGAGACCTCCG-1-B2   AG_Gerull  Ttn_HetKO_noninf_2    4549.0
# TTTGTTGGTAGTAAGT-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    6564.0
#
#                                    sample seed_labels         condition  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr_noninf_1         CD8   Pkp2_Ctr_noninf
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr_noninf_1           B   Pkp2_Ctr_noninf
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr_noninf_2         CD4   Pkp2_Ctr_noninf
# ...                                   ...         ...               ...
# TTTGATCAGTATGACA-1-B2    Ttn_HetKO_MCMV_1     Unknown    Ttn_HetKO_MCMV
# TTTGGAGAGATTAGCA-1-B2      Ttn_Ctr_MCMV_2     Unknown      Ttn_Ctr_MCMV
# TTTGGTTAGCACCTGC-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO_noninf_2     Unknown  Ttn_HetKO_noninf
# TTTGTTGGTAGTAAGT-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
#
#                         genotype infection library model  ...  percent_chrY  \
# AAACCCAAGATACAGT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.000000
# AACCCAATCAGCTGAT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.021233
# AACCTGAAGATAGCAT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.063510
# AACGTCAAGCTACTGT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.194458
# AACTTCTCAAGCGCTC-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...      0.000000
# ...                          ...       ...     ...   ...  ...           ...
# TTTGATCAGTATGACA-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...      0.016503
# TTTGGAGAGATTAGCA-1-B2    Ttn_Ctr      MCMV      B2   Ttn  ...      0.000000
# TTTGGTTAGCACCTGC-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...      0.000000
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO    noninf      B2   Ttn  ...      0.000000
# TTTGTTGGTAGTAAGT-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...      0.030469
#
#                        XIST-counts   S_score  G2M_score  _scvi_batch  \
# AAACCCAAGATACAGT-1-A1          0.0 -0.339369  -0.496061            7
# AACCCAATCAGCTGAT-1-A1          0.0  0.525671  -0.137837            6
# AACCTGAAGATAGCAT-1-A1          0.0 -0.268814  -0.516689            6
# AACGTCAAGCTACTGT-1-A1          0.0 -0.270605  -0.340320            7
# AACTTCTCAAGCGCTC-1-A1          0.0 -0.414867  -0.271517            7
# ...                            ...       ...        ...          ...
# TTTGATCAGTATGACA-1-B2          0.0 -0.267751  -0.531946           25
# TTTGGAGAGATTAGCA-1-B2         23.0  2.905558   0.470866           21
# TTTGGTTAGCACCTGC-1-B2          0.0  0.000996  -0.736926           26
# TTTGTTGAGACCTCCG-1-B2          0.0 -0.428444  -0.362500           29
# TTTGTTGGTAGTAAGT-1-B2          0.0  0.363058  -0.589437           26
#
#                        _scvi_labels      batch  C_scANVI  leiden  \
# AAACCCAAGATACAGT-1-A1             1  reference       CD4       4
# AACCCAATCAGCTGAT-1-A1             2  reference       CD8       7
# AACCTGAAGATAGCAT-1-A1             0  reference         B       9
# AACGTCAAGCTACTGT-1-A1             1  reference       CD4      11
# AACTTCTCAAGCGCTC-1-A1             1  reference       CD4       4
# ...                             ...        ...       ...     ...
# TTTGATCAGTATGACA-1-B2             5      query         B       9
# TTTGGAGAGATTAGCA-1-B2             5      query         B       2
# TTTGGTTAGCACCTGC-1-B2             5      query       CD8       7
# TTTGTTGAGACCTCCG-1-B2             5      query         B      13
# TTTGTTGGTAGTAAGT-1-B2             5      query       CD8       0
#
#                        classification
# AAACCCAAGATACAGT-1-A1           CD4_4
# AACCCAATCAGCTGAT-1-A1           CD8_7
# AACCTGAAGATAGCAT-1-A1             B_9
# AACGTCAAGCTACTGT-1-A1          CD4_11
# AACTTCTCAAGCGCTC-1-A1           CD4_4
# ...                               ...
# TTTGATCAGTATGACA-1-B2             B_9
# TTTGGAGAGATTAGCA-1-B2             B_2
# TTTGGTTAGCACCTGC-1-B2           CD8_7
# TTTGTTGAGACCTCCG-1-B2            B_13
# TTTGTTGGTAGTAAGT-1-B2           CD8_0
#
# [10104 rows x 28 columns]

# %%
new_order_genotype = ['Pkp2_Ctr', 'Pkp2_HetKO', 'Ttn_Ctr', 'Ttn_HetKO']
adata.obs["genotype"] = adata.obs["genotype"].cat.reorder_categories(new_order_genotype, ordered=True)

adata.obs["genotype"].cat.categories
# Out:
# Index(['Pkp2_Ctr', 'Pkp2_HetKO', 'Ttn_Ctr', 'Ttn_HetKO'], dtype='object')

# %%
new_order_infection = ['noninf', 'MCMV']
adata.obs["infection"] = adata.obs["infection"].cat.reorder_categories(new_order_infection, ordered=True)

adata.obs["infection"].cat.categories
# Out:
# Index(['noninf', 'MCMV'], dtype='object')

# %%
new_order_condition = ['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV', 'Pkp2_HetKO_MCMV', 'Ttn_Ctr_noninf', 'Ttn_HetKO_noninf','Ttn_Ctr_MCMV', 'Ttn_HetKO_MCMV' ]
adata.obs["condition"] = adata.obs["condition"].cat.reorder_categories(new_order_condition, ordered=True)

adata.obs["condition"].cat.categories
# Out:
# Index(['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV',
#        'Pkp2_HetKO_MCMV', 'Ttn_Ctr_noninf', 'Ttn_HetKO_noninf', 'Ttn_Ctr_MCMV',
#        'Ttn_HetKO_MCMV'],
#       dtype='object')

# %% [markdown]
# create notebook for every compartment and compare across cell states
# visualization improvement
# reference to ctrl healthy

# %%
sccoda_model = pt.tl.Sccoda()
sccoda_data = sccoda_model.load(
    adata,
    type="cell_level",
    generate_sample_level=True,
    cell_type_identifier="classification",
    sample_identifier="sample",
    covariate_obs=["genotype", "infection", "condition"],
)
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 10134 × 29396
#   2 modalities
#     rna:	10104 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     coda:	30 x 18
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="genotype",
    y_scale="count",
    figsize=(30, 20),
    add_dots=False,
    args_swarmplot={"palette": ["red"]},
)
plt.show()

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="genotype",
    plot_facets=True,
    y_scale="log",
    add_dots=True,
    cmap="Reds",
)
plt.xticks(rotation=90)
plt.show()

# %%
pt.pl.coda.stacked_barplot(
    sccoda_data, modality_key="coda", feature_name="genotype", figsize=(15, 9) 
)
plt.legend(ncol=3, loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
sccoda_data = sccoda_model.prepare(
    sccoda_data,
    modality_key="coda",
    formula="genotype",
    reference_cell_type="automatic",
)
sccoda_data["coda"]
# Out:
# Automatic reference selection! Reference cell type set to CD4_15
# Zero counts encountered in data! Added a pseudocount of 0.5.
# AnnData object with n_obs × n_vars = 30 × 18
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'

# %% [markdown]
# Run No-U-turn HMC sampling (nuts)

# %%
sccoda_model.run_nuts(sccoda_data, modality_key="coda", rng_key=1234)
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# sample: 100%|██████████| 11000/11000 [02:14<00:00, 81.89it/s, 255 steps of size 2.28e-02. acc. prob=0.85]

# %%
sccoda_data["coda"]
# Out:
# AnnData object with n_obs × n_vars = 30 × 18
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'
#     varm: 'intercept_df', 'effect_df_genotype[T.Pkp2_HetKO]', 'effect_df_genotype[T.Ttn_Ctr]', 'effect_df_genotype[T.Ttn_HetKO]'

# %% [markdown]
# #### Result interpreteation

# %% [markdown]
# **Intercepts**
#
# The first column of the intercept summary shows the parameters determined by the MCMC inference.
#
# The “Expected sample” column gives some context to the numerical values. If we had a new sample (with no active covariates) with a total number of cells equal to the mean sampling depth of the dataset, then this distribution over the cell types would be most likely.
#
# **Effects**
#
# For the effect summary, the first column again shows the inferred parameters for all combinations of covariates and cell types. Most important is the distinctions between zero and non-zero entries A value of zero means that no statistically credible effect was detected. For a value other than zero, a credible change was detected. A positive sign indicates an increase, a negative sign a decrease in abundance.
#
# Since the numerical values of the “Final Parameter” column are not straightforward to interpret, the “Expected sample” and “log2-fold change” columns give us an idea on the magnitude of the change. The expected sample is calculated for each covariate separately (covariate value = 1, all other covariates = 0), with the same method as for the intercepts. The log-fold change is then calculated between this expected sample and the expected sample with no active covariates from the intercept section. Since the data is compositional, cell types for which no credible change was detected, can still change in abundance as well, as soon as a credible effect is detected on another cell type due to the sum-to-one constraint. If there are no credible effects for a covariate, its expected sample will be identical to the intercept sample, therefore the log2-fold change is 0.

# %%
sccoda_model.summary(sccoda_data, modality_key= "coda")
# Out:
#                                           Compositional Analysis summary
# ┌────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────┐
# │ Name                                       │ Value                                                              │
# ├────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────┤
# │ Data                                       │ Data: 30 samples, 18 cell types                                    │
# │ Reference cell type                        │ CD4_15                                                             │
# │ Formula                                    │ genotype                                                           │
# └────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Intercepts                                                                                                      │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │            Final Parameter  Expected Sample                                                                     │
# │ Cell Type                                                                                                       │
# │ B_2             1.132           32.397                                                                          │
# │ B_9             0.205           12.821                                                                          │
# │ B_12            0.349           14.807                                                                          │
# │ B_13            0.189           12.617                                                                          │
# │ B_17           -0.668            5.355                                                                          │
# │ CD4_3           1.020           28.965                                                                          │
# │ CD4_4           1.175           33.821                                                                          │
# │ CD4_6           0.941           26.765                                                                          │
# │ CD4_8           0.667           20.350                                                                          │
# │ CD4_10          0.439           16.201                                                                          │
# │ CD4_11          0.249           13.398                                                                          │
# │ CD4_15         -0.161            8.891                                                                          │
# │ CD4_16         -0.371            7.207                                                                          │
# │ CD8_0           0.588           18.804                                                                          │
# │ CD8_1           0.819           23.691                                                                          │
# │ CD8_7           0.786           22.922                                                                          │
# │ NKT_14         -0.226            8.332                                                                          │
# │ NK_5            1.052           29.907                                                                          │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Effects                                                                                                         │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                                 Final Parameter  Expected Sample  log2-fold change                              │
# │ Covariate            Cell Type                                                                                  │
# │ genotypeT.Pkp2_HetKO B_2            0.000            32.397            0.000                                    │
# │                      B_9            0.000            12.821            0.000                                    │
# │                      B_12           0.000            14.807            0.000                                    │
# │                      B_13           0.000            12.617            0.000                                    │
# │                      B_17           0.000             5.355            0.000                                    │
# │                      CD4_3          0.000            28.965            0.000                                    │
# │                      CD4_4          0.000            33.821            0.000                                    │
# │                      CD4_6          0.000            26.765            0.000                                    │
# │                      CD4_8          0.000            20.350            0.000                                    │
# │                      CD4_10         0.000            16.201            0.000                                    │
# │                      CD4_11         0.000            13.398            0.000                                    │
# │                      CD4_15         0.000             8.891            0.000                                    │
# │                      CD4_16         0.000             7.207            0.000                                    │
# │                      CD8_0          0.000            18.804            0.000                                    │
# │                      CD8_1          0.000            23.691            0.000                                    │
# │                      CD8_7          0.000            22.922            0.000                                    │
# │                      NKT_14         0.000             8.332            0.000                                    │
# │                      NK_5           0.000            29.907            0.000                                    │
# │ genotypeT.Ttn_Ctr    B_2            0.000            32.397            0.000                                    │
# │                      B_9            0.000            12.821            0.000                                    │
# │                      B_12           0.000            14.807            0.000                                    │
# │                      B_13           0.000            12.617            0.000                                    │
# │                      B_17           0.000             5.355            0.000                                    │
# │                      CD4_3          0.000            28.965            0.000                                    │
# │                      CD4_4          0.000            33.821            0.000                                    │
# │                      CD4_6          0.000            26.765            0.000                                    │
# │                      CD4_8          0.000            20.350            0.000                                    │
# │                      CD4_10         0.000            16.201            0.000                                    │
# │                      CD4_11         0.000            13.398            0.000                                    │
# │                      CD4_15         0.000             8.891            0.000                                    │
# │                      CD4_16         0.000             7.207            0.000                                    │
# │                      CD8_0          0.000            18.804            0.000                                    │
# │                      CD8_1          0.000            23.691            0.000                                    │
# │                      CD8_7          0.000            22.922            0.000                                    │
# │                      NKT_14         0.000             8.332            0.000                                    │
# │                      NK_5           0.000            29.907            0.000                                    │
# │ genotypeT.Ttn_HetKO  B_2            0.000            32.397            0.000                                    │
# │                      B_9            0.000            12.821            0.000                                    │
# │                      B_12           0.000            14.807            0.000                                    │
# │                      B_13           0.000            12.617            0.000                                    │
# │                      B_17           0.000             5.355            0.000                                    │
# │                      CD4_3          0.000            28.965            0.000                                    │
# │                      CD4_4          0.000            33.821            0.000                                    │
# │                      CD4_6          0.000            26.765            0.000                                    │
# │                      CD4_8          0.000            20.350            0.000                                    │
# │                      CD4_10         0.000            16.201            0.000                                    │
# │                      CD4_11         0.000            13.398            0.000                                    │
# │                      CD4_15         0.000             8.891            0.000                                    │
# │                      CD4_16         0.000             7.207            0.000                                    │
# │                      CD8_0          0.000            18.804            0.000                                    │
# │                      CD8_1          0.000            23.691            0.000                                    │
# │                      CD8_7          0.000            22.922            0.000                                    │
# │                      NKT_14         0.000             8.332            0.000                                    │
# │                      NK_5           0.000            29.907            0.000                                    │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Filter out credible effects

# %%
sccoda_model.credible_effects(sccoda_data, modality_key="coda")
# Out:
# Covariate               Cell Type
# genotype[T.Pkp2_HetKO]  B_2          False
#                         B_9          False
#                         B_12         False
#                         B_13         False
#                         B_17         False
#                         CD4_3        False
#                         CD4_4        False
#                         CD4_6        False
#                         CD4_8        False
#                         CD4_10       False
#                         CD4_11       False
#                         CD4_15       False
#                         CD4_16       False
#                         CD8_0        False
#                         CD8_1        False
#                         CD8_7        False
#                         NKT_14       False
#                         NK_5         False
# genotype[T.Ttn_Ctr]     B_2          False
#                         B_9          False
#                         B_12         False
#                         B_13         False
#                         B_17         False
#                         CD4_3        False
#                         CD4_4        False
#                         CD4_6        False
#                         CD4_8        False
#                         CD4_10       False
#                         CD4_11       False
#                         CD4_15       False
#                         CD4_16       False
#                         CD8_0        False
#                         CD8_1        False
#                         CD8_7        False
#                         NKT_14       False
#                         NK_5         False
# genotype[T.Ttn_HetKO]   B_2          False
#                         B_9          False
#                         B_12         False
#                         B_13         False
#                         B_17         False
#                         CD4_3        False
#                         CD4_4        False
#                         CD4_6        False
#                         CD4_8        False
#                         CD4_10       False
#                         CD4_11       False
#                         CD4_15       False
#                         CD4_16       False
#                         CD8_0        False
#                         CD8_1        False
#                         CD8_7        False
#                         NKT_14       False
#                         NK_5         False
# Name: Final Parameter, dtype: bool

# %%
pt.pl.coda.effects_barplot(sccoda_data, modality_key="coda", parameter="Final Parameter")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 pt.pl.coda.effects_barplot(sccoda_data, modality_key="coda", parameter="Final Parameter")
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/pertpy/plot/_coda.py:197, in CodaPlot.effects_barplot(data, modality_key, covariates, parameter, plot_facets, plot_zero_covariate, plot_zero_cell_type, figsize, dpi, cmap, level_order, args_barplot)
#     194 from pertpy.tools import Sccoda
#     196 coda = Sccoda()
# --> 197 return coda.plot_effects_barplot(
#     198     data=data,
#     199     modality_key=modality_key,
#     200     covariates=covariates,
#     201     parameter=parameter,
#     202     plot_facets=plot_facets,
#     203     plot_zero_covariate=plot_zero_covariate,
#     204     plot_zero_cell_type=plot_zero_cell_type,
#     205     figsize=figsize,
#     206     dpi=dpi,
#     207     cmap=cmap,
#     208     level_order=level_order,
#     209     args_barplot=args_barplot,
#     210 )
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/pertpy/tools/_coda/_base_coda.py:1392, in CompositionalModel2.plot_effects_barplot(self, data, modality_key, covariates, parameter, plot_facets, plot_zero_covariate, plot_zero_cell_type, figsize, dpi, cmap, level_order, args_barplot)
#    1389     height = 3
#    1390     aspect = 2
# -> 1392 g = sns.FacetGrid(
#    1393     plot_df,
#    1394     col="Covariate",
#    1395     sharey=True,
#    1396     sharex=False,
#    1397     height=height,
#    1398     aspect=aspect,
#    1399 )
#    1401 g.map(
#    1402     sns.barplot,
#    1403     "Cell Type",
#    (...)
#    1407     **args_barplot,
#    1408 )
#    1409 g.set_xticklabels(rotation=90)
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/seaborn/axisgrid.py:462, in FacetGrid.__init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws)
#     455 if col_wrap is None:
#     457     kwargs = dict(squeeze=False,
#     458                   sharex=sharex, sharey=sharey,
#     459                   subplot_kw=subplot_kws,
#     460                   gridspec_kw=gridspec_kws)
# --> 462     axes = fig.subplots(nrow, ncol, **kwargs)
#     464     if col is None and row is None:
#     465         axes_dict = {}
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/matplotlib/figure.py:930, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     926         raise ValueError("'width_ratios' must not be defined both as "
#     927                          "parameter and as key in 'gridspec_kw'")
#     928     gridspec_kw['width_ratios'] = width_ratios
# --> 930 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#     931 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     932                   subplot_kw=subplot_kw)
#     933 return axs
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/matplotlib/figure.py:1542, in FigureBase.add_gridspec(self, nrows, ncols, **kwargs)
#    1503 """
#    1504 Return a `.GridSpec` that has this figure as a parent.  This allows
#    1505 complex layout of Axes in the figure.
#    (...)
#    1538
#    1539 """
#    1541 _ = kwargs.pop('figure', None)  # pop in case user has added this...
# -> 1542 gs = GridSpec(nrows=nrows, ncols=ncols, figure=self, **kwargs)
#    1543 return gs
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/matplotlib/gridspec.py:378, in GridSpec.__init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     375 self.hspace = hspace
#     376 self.figure = figure
# --> 378 super().__init__(nrows, ncols,
#     379                  width_ratios=width_ratios,
#     380                  height_ratios=height_ratios)
#
# File ~/miniforge3/envs/scCoda/lib/python3.10/site-packages/matplotlib/gridspec.py:51, in GridSpecBase.__init__(self, nrows, ncols, height_ratios, width_ratios)
#      48     raise ValueError(
#      49         f"Number of rows must be a positive integer, not {nrows!r}")
#      50 if not isinstance(ncols, Integral) or ncols <= 0:
# ---> 51     raise ValueError(
#      52         f"Number of columns must be a positive integer, not {ncols!r}")
#      53 self._nrows, self._ncols = nrows, ncols
#      54 self.set_height_ratios(height_ratios)
#
# ValueError: Number of columns must be a positive integer, not 0

# %% [markdown]
# ##### Adjust the "false discovery rate"

# %%
#If needed adjust the 'false discovery rate' - default is 0.05, however when no effects are detected it can be incresed to up to 0.2
sccoda_model.set_fdr(sccoda_data, 0.2)
sccoda_model.credible_effects(sccoda_data, modality_key="coda")
# Out:
# Covariate               Cell Type
# genotype[T.Pkp2_HetKO]  B_2           True
#                         B_9           True
#                         B_12          True
#                         B_13          True
#                         B_17         False
#                         CD4_3        False
#                         CD4_4        False
#                         CD4_6        False
#                         CD4_8        False
#                         CD4_10       False
#                         CD4_11       False
#                         CD4_15       False
#                         CD4_16       False
#                         CD8_0        False
#                         CD8_1        False
#                         CD8_7        False
#                         NKT_14       False
#                         NK_5         False
# genotype[T.Ttn_Ctr]     B_2          False
#                         B_9          False
#                         B_12         False
#                         B_13         False
#                         B_17         False
#                         CD4_3        False
#                         CD4_4        False
#                         CD4_6        False
#                         CD4_8        False
#                         CD4_10        True
#                         CD4_11       False
#                         CD4_15       False
#                         CD4_16       False
#                         CD8_0        False
#                         CD8_1        False
#                         CD8_7        False
#                         NKT_14       False
#                         NK_5         False
# genotype[T.Ttn_HetKO]   B_2          False
#                         B_9          False
#                         B_12         False
#                         B_13         False
#                         B_17         False
#                         CD4_3        False
#                         CD4_4        False
#                         CD4_6        False
#                         CD4_8        False
#                         CD4_10       False
#                         CD4_11       False
#                         CD4_15       False
#                         CD4_16       False
#                         CD8_0        False
#                         CD8_1        False
#                         CD8_7        False
#                         NKT_14       False
#                         NK_5         False
# Name: Final Parameter, dtype: bool

# %%
pt.pl.coda.effects_barplot(sccoda_data, modality_key="coda", parameter="Final Parameter")

# %%
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 10134 × 29396
#   2 modalities
#     rna:	10104 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     coda:	30 x 18
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'
#       uns:	'scCODA_params'
#       obsm:	'covariate_matrix', 'sample_counts'
#       varm:	'intercept_df', 'effect_df_genotype[T.Pkp2_HetKO]', 'effect_df_genotype[T.Ttn_Ctr]', 'effect_df_genotype[T.Ttn_HetKO]'

# %%
sccoda_data["coda"].varm["effect_df_genotype[T.Pkp2_HetKO]"]
# Out:
#            Final Parameter  HDI 3%  HDI 97%     SD  Inclusion probability  \
# Cell Type
# B_2               0.493284   0.072    0.898  0.243                 0.9284
# B_9               0.553407  -0.005    1.042  0.325                 0.8654
# B_12             -0.490046  -0.997    0.048  0.327                 0.7994
# B_13             -0.435707  -0.974    0.077  0.318                 0.7288
# B_17              0.000000  -0.257    0.849  0.266                 0.5683
# CD4_3             0.000000  -0.299    0.451  0.131                 0.4066
# CD4_4             0.000000  -0.718    0.067  0.220                 0.6226
# CD4_6             0.000000  -0.243    0.504  0.143                 0.4212
# CD4_8             0.000000  -0.325    0.505  0.148                 0.4109
# CD4_10            0.000000  -0.712    0.241  0.223                 0.5341
# CD4_11            0.000000  -0.293    0.590  0.158                 0.4323
# CD4_15            0.000000   0.000    0.000  0.000                 0.0000
# CD4_16            0.000000  -0.630    0.371  0.184                 0.4429
# CD8_0             0.000000  -0.358    0.543  0.163                 0.4337
# CD8_1             0.000000  -0.387    0.456  0.143                 0.4163
# CD8_7             0.000000  -0.465    0.317  0.132                 0.3940
# NKT_14            0.000000  -0.545    0.425  0.174                 0.4457
# NK_5              0.000000  -0.555    0.228  0.167                 0.4758
#
#            Expected Sample  log2-fold change
# Cell Type
# B_2              50.094413          0.628770
# B_9              21.052785          0.715510
# B_12              8.564100         -0.789876
# B_13              7.705378         -0.711480
# B_17              5.056252         -0.082888
# CD4_3            27.347510         -0.082888
# CD4_4            31.932538         -0.082888
# CD4_6            25.270191         -0.082888
# CD4_8            19.213737         -0.082888
# CD4_10           15.296522         -0.082888
# CD4_11           12.649599         -0.082888
# CD4_15            8.394909         -0.082888
# CD4_16            6.804781         -0.082888
# CD8_0            17.754260         -0.082888
# CD8_1            22.367869         -0.082888
# CD8_7            21.641776         -0.082888
# NKT_14            7.866596         -0.082888
# NK_5             28.236783         -0.082888

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=sccoda_data["coda"].varm["effect_df_genotype[T.Pkp2_HetKO]"], x="Cell Type", y="log2-fold change", hue="Cell Type")
plt.xticks(rotation=90)
plt.show()

# %%
pt.pl.coda.effects_barplot(sccoda_data, "coda", "genotype")
plt.show()
