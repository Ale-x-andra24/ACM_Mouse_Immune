# %% [markdown]
# # Compositional analysis of the ACM cardiac leucocytes 6mpi dataset (Pkp2+Ttn) - myeloids - using scCoda `pertpy`:
# - **Developed by**: Christian Eger
# - **Modified by**: Alexandra Cirnu
# - **Talavera-López Lab - Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg**
# - **Created on**: 231214
# - **Last modified**: 240509

# %% [markdown]
# #### Environment: scCoda
#
# To install `pertpy` on MacOS create a new mamba environment and activte it. Then go int 'github' folder and type 'git clone https://github.com/theislab/pertpy.git'. Change directory to 'pertpy' and type 'pip install .'
#
# Look at website to solve problem at the end: https://www.sc-best-practices.org/conditions/compositional.html

# %%
import warnings
import pandas as pd
warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")
import numpy as np
            #import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import altair as alt
import scanpy as sc
import pertpy as pt
from statannot import add_stat_annotation
from scipy import stats
import muon as mu
from muon import atac as ac
from muon import prot

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.5.post1
# scanpy      1.9.8
# -----
# PIL                         10.2.0
# absl                        NA
# adjustText                  1.0.4
# altair                      4.2.2
# arrow                       1.3.0
# arviz                       0.17.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# blitzgsea                   NA
# certifi                     2024.02.02
# cffi                        1.16.0
# chardet                     5.2.0
# charset_normalizer          3.3.2
# chex                        0.1.85
# colorama                    0.4.6
# comm                        0.2.1
# contextlib2                 NA
# custom_inherit              2.4.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.9.0
# debugpy                     1.8.1
# decorator                   5.1.1
# decoupler                   1.6.0
# docrep                      0.3.2
# entrypoints                 0.4
# etils                       1.7.0
# exceptiongroup              1.2.0
# executing                   2.0.1
# flax                        0.8.1
# fsspec                      2024.2.0
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# importlib_resources         NA
# ipykernel                   6.29.3
# ipywidgets                  8.1.2
# jax                         0.4.25
# jaxlib                      0.4.25
# jaxopt                      NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# lightning                   2.1.4
# lightning_fabric            2.2.0.post0
# lightning_utilities         0.10.1
# llvmlite                    0.42.0
# markupsafe                  2.1.5
# matplotlib                  3.8.3
# ml_collections              NA
# ml_dtypes                   0.3.2
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.8
# mudata                      0.2.3
# multipledispatch            0.6.0
# muon                        0.1.5
# natsort                     8.4.0
# numba                       0.59.0
# numpy                       1.26.4
# numpyro                     0.14.0
# opt_einsum                  v3.3.0
# optax                       0.1.9
# ott                         0.4.5
# packaging                   23.2
# pandas                      2.2.1
# parso                       0.8.3
# patsy                       0.5.6
# pertpy                      0.7.0
# pkg_resources               NA
# platformdirs                4.2.0
# ply                         3.11
# png                         0.20220715.0
# prompt_toolkit              3.0.43
# psutil                      5.9.8
# pubchempy                   1.0.4
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynndescent                 0.5.11
# pyomo                       6.7.1
# pyparsing                   3.1.1
# pyro                        1.9.0
# pytorch_lightning           2.2.0.post0
# pytz                        2024.1
# referencing                 NA
# reportlab                   4.1.0
# requests                    2.31.0
# rich                        NA
# rpds                        NA
# rpy2                        3.5.11
# scipy                       1.12.0
# scvi                        1.1.2
# seaborn                     0.13.2
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.4.1.post1
# skmisc                      0.3.1
# sparsecca                   0.3.1
# stack_data                  0.6.3
# statannot                   0.2.3
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# toolz                       0.12.1
# torch                       2.2.1+cu121
# torchgen                    NA
# torchmetrics                1.3.1
# tornado                     6.4
# toyplot                     1.0.3
# toytree                     2.0.1
# tqdm                        4.66.2
# traitlets                   5.14.1
# typing_extensions           NA
# tzlocal                     NA
# umap                        0.5.5
# urllib3                     2.2.1
# vscode                      NA
# wcwidth                     0.2.13
# xarray                      2024.2.0
# xarray_einstats             0.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-6.8.4-200.fc39.x86_64-x86_64-with-glibc2.38
# -----
# Session information updated at 2024-05-09 11:10

# %% [markdown]
# Manual git installation of pertpy necessary due to Apple silicon
# $ git clone https://github.com/theislab/pertpy.git
# $ cd pertpy
# $ pip install .

# %%
input = '/home/acirnu/github/ACM_Mouse_Immune/Workflow/5_Leiden_clustering+annotation_on_all_conditions/C_merge_lymphoids+myeloids/ACM_myeloids+lymphoids_leiden_clustered_muon_ac240507.raw.h5mu'
mdata_data = mu.read_h5mu(input) 
mdata_data
# Out:
# MuData object with n_obs × n_vars = 44586 × 29477
#   var:	'gene_ids', 'feature_types'
#   2 modalities
#     rna:	44586 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification', 'lineage'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'neighbors', 'umap'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     prot:	44586 x 99
#       obs:	'library', 'batch', 'lineage'
#       var:	'gene_ids', 'feature_types'
#       uns:	'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap'
#       varm:	'PCs'
#       layers:	'counts', 'log_norm'

# %%
adata = mdata_data.mod["rna"]
adata
# Out:
# AnnData object with n_obs × n_vars = 44586 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification', 'lineage'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo'
#     uns: 'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'neighbors', 'umap'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#                       cell_source               donor  n_counts  \
# AAACGCTGTTGTGTTG-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1     478.0
# AAACGCTTCTCGCTCA-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1    3581.0
# AAAGGTACAGAACATA-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2   16539.0
# AAAGTCCAGGGACACT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2   13389.0
# AAAGTCCCAGTAGGAC-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2   12092.0
# ...                           ...                 ...       ...
# TTTGATCAGTATGACA-1-B2   AG_Gerull    Ttn_HetKO_MCMV_1   12119.0
# TTTGGAGAGATTAGCA-1-B2   AG_Gerull      Ttn_Ctr_MCMV_2   20506.0
# TTTGGTTAGCACCTGC-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    3174.0
# TTTGTTGAGACCTCCG-1-B2   AG_Gerull  Ttn_HetKO_noninf_2    4549.0
# TTTGTTGGTAGTAAGT-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    6564.0
#
#                                    sample seed_labels         condition  \
# AAACGCTGTTGTGTTG-1-A1   Pkp2_Ctr_noninf_1    DOCK4+MØ   Pkp2_Ctr_noninf
# AAACGCTTCTCGCTCA-1-A1   Pkp2_Ctr_noninf_1   Monocytes   Pkp2_Ctr_noninf
# AAAGGTACAGAACATA-1-A1   Pkp2_Ctr_noninf_2   Monocytes   Pkp2_Ctr_noninf
# AAAGTCCAGGGACACT-1-A1   Pkp2_Ctr_noninf_2    LYVE1+MØ   Pkp2_Ctr_noninf
# AAAGTCCCAGTAGGAC-1-A1   Pkp2_Ctr_noninf_2    LYVE1+MØ   Pkp2_Ctr_noninf
# ...                                   ...         ...               ...
# TTTGATCAGTATGACA-1-B2    Ttn_HetKO_MCMV_1     Unknown    Ttn_HetKO_MCMV
# TTTGGAGAGATTAGCA-1-B2      Ttn_Ctr_MCMV_2     Unknown      Ttn_Ctr_MCMV
# TTTGGTTAGCACCTGC-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO_noninf_2     Unknown  Ttn_HetKO_noninf
# TTTGTTGGTAGTAAGT-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
#
#                         genotype infection library model  ...  XIST-counts  \
# AAACGCTGTTGTGTTG-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...          0.0
# AAACGCTTCTCGCTCA-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...          0.0
# AAAGGTACAGAACATA-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...          0.0
# AAAGTCCAGGGACACT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...          0.0
# AAAGTCCCAGTAGGAC-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...          0.0
# ...                          ...       ...     ...   ...  ...          ...
# TTTGATCAGTATGACA-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...          0.0
# TTTGGAGAGATTAGCA-1-B2    Ttn_Ctr      MCMV      B2   Ttn  ...         23.0
# TTTGGTTAGCACCTGC-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...          0.0
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO    noninf      B2   Ttn  ...          0.0
# TTTGTTGGTAGTAAGT-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...          0.0
#
#                         S_score  G2M_score  _scvi_batch  _scvi_labels  \
# AAACGCTGTTGTGTTG-1-A1 -0.019995  -0.083225            6             1
# AAACGCTTCTCGCTCA-1-A1 -0.169221  -0.390143            6             4
# AAAGGTACAGAACATA-1-A1 -0.317631  -0.578955            7             4
# AAAGTCCAGGGACACT-1-A1 -0.370103  -0.370084            7             2
# AAAGTCCCAGTAGGAC-1-A1 -0.142503  -0.357287            7             2
# ...                         ...        ...          ...           ...
# TTTGATCAGTATGACA-1-B2 -0.267751  -0.531946           25             5
# TTTGGAGAGATTAGCA-1-B2  2.905558   0.470866           21             5
# TTTGGTTAGCACCTGC-1-B2  0.000996  -0.736926           26             5
# TTTGTTGAGACCTCCG-1-B2 -0.428444  -0.362500           29             5
# TTTGTTGGTAGTAAGT-1-B2  0.363058  -0.589437           26             5
#
#                            batch   C_scANVI  leiden  classification   lineage
# AAACGCTGTTGTGTTG-1-A1  reference   DOCK4+MØ       3      DOCK4+MØ_3   myeloid
# AAACGCTTCTCGCTCA-1-A1  reference  Monocytes       3      DOCK4+MØ_3   myeloid
# AAAGGTACAGAACATA-1-A1  reference  Monocytes       6     Monocytes_6   myeloid
# AAAGTCCAGGGACACT-1-A1  reference   LYVE1+MØ       2      LYVE1+MØ_2   myeloid
# AAAGTCCCAGTAGGAC-1-A1  reference   LYVE1+MØ       2      LYVE1+MØ_2   myeloid
# ...                          ...        ...     ...             ...       ...
# TTTGATCAGTATGACA-1-B2      query          B       9             B_9  lymphoid
# TTTGGAGAGATTAGCA-1-B2      query          B       2             B_2  lymphoid
# TTTGGTTAGCACCTGC-1-B2      query        CD8       7           CD8_7  lymphoid
# TTTGTTGAGACCTCCG-1-B2      query          B      13            B_13  lymphoid
# TTTGTTGGTAGTAAGT-1-B2      query        CD8       0           CD8_0  lymphoid
#
# [44586 rows x 29 columns]

# %%
new_order_genotype = ['Pkp2_Ctr', 'Pkp2_HetKO', 'Ttn_Ctr', 'Ttn_HetKO']
adata.obs["genotype"] = adata.obs["genotype"].cat.reorder_categories(new_order_genotype, ordered=True)

adata.obs["genotype"].cat.categories
# Out:
# Index(['Pkp2_Ctr', 'Pkp2_HetKO', 'Ttn_Ctr', 'Ttn_HetKO'], dtype='object')

# %%
new_order_infection = ['noninf', 'MCMV']
adata.obs["infection"] = adata.obs["infection"].cat.reorder_categories(new_order_infection, ordered=True)

adata.obs["infection"].cat.categories
# Out:
# Index(['noninf', 'MCMV'], dtype='object')

# %%
new_order_condition = ['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV', 'Pkp2_HetKO_MCMV', 'Ttn_Ctr_noninf', 'Ttn_HetKO_noninf','Ttn_Ctr_MCMV', 'Ttn_HetKO_MCMV' ]
adata.obs["condition"] = adata.obs["condition"].cat.reorder_categories(new_order_condition, ordered=True)

adata.obs["condition"].cat.categories
# Out:
# Index(['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV',
#        'Pkp2_HetKO_MCMV', 'Ttn_Ctr_noninf', 'Ttn_HetKO_noninf', 'Ttn_Ctr_MCMV',
#        'Ttn_HetKO_MCMV'],
#       dtype='object')

# %% [markdown]
# create notebook for every compartment and compare across cell states
# visualization improvement
# reference to ctrl healthy

# %%
sccoda_model = pt.tl.Sccoda()
sccoda_data = sccoda_model.load(
    adata,
    type="cell_level",
    generate_sample_level=True,
    cell_type_identifier="classification",
    sample_identifier="sample",
    covariate_obs=["condition"],
)
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 44616 × 29414
#   2 modalities
#     rna:	44586 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification', 'lineage'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'neighbors', 'umap'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     coda:	30 x 36
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="condition",
    y_scale="count",
    figsize=(30, 20),
    add_dots=False,
    args_swarmplot={"palette": ["red"]},
)
plt.show()

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="condition",
    plot_facets=True,
    y_scale="log",
    add_dots=True,
    cmap="Reds",
)
plt.xticks(rotation=90)
plt.show()

# %%
pt.pl.coda.stacked_barplot(
    sccoda_data, modality_key="coda", feature_name="condition", figsize=(15, 9) 
)
plt.legend(ncol=3, loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
sccoda_data = sccoda_model.prepare(
    sccoda_data,
    modality_key="coda",
    formula="condition",
    reference_cell_type="automatic",
)
sccoda_data["coda"]
# Out:
# Automatic reference selection! Reference cell type set to CD4_15
# Zero counts encountered in data! Added a pseudocount of 0.5.
# AnnData object with n_obs × n_vars = 30 × 36
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'

# %% [markdown]
# Run No-U-turn HMC sampling (nuts)

# %%
sccoda_model.run_nuts(sccoda_data, modality_key="coda", rng_key=1234)
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# sample: 100%|██████████| 11000/11000 [13:29<00:00, 13.59it/s, 511 steps of size 8.66e-03. acc. prob=0.88]

# %%
sccoda_data["coda"]
# Out:
# AnnData object with n_obs × n_vars = 30 × 36
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'
#     varm: 'intercept_df', 'effect_df_condition[T.Pkp2_HetKO_noninf]', 'effect_df_condition[T.Pkp2_Ctr_MCMV]', 'effect_df_condition[T.Pkp2_HetKO_MCMV]', 'effect_df_condition[T.Ttn_Ctr_noninf]', 'effect_df_condition[T.Ttn_HetKO_noninf]', 'effect_df_condition[T.Ttn_Ctr_MCMV]', 'effect_df_condition[T.Ttn_HetKO_MCMV]'

# %% [markdown]
# #### Result interpreteation

# %% [markdown]
# **Intercepts**
#
# The first column of the intercept summary shows the parameters determined by the MCMC inference.
#
# The “Expected sample” column gives some context to the numerical values. If we had a new sample (with no active covariates) with a total number of cells equal to the mean sampling depth of the dataset, then this distribution over the cell types would be most likely.
#
# **Effects**
#
# For the effect summary, the first column again shows the inferred parameters for all combinations of covariates and cell types. Most important is the distinctions between zero and non-zero entries A value of zero means that no statistically credible effect was detected. For a value other than zero, a credible change was detected. A positive sign indicates an increase, a negative sign a decrease in abundance.
#
# Since the numerical values of the “Final Parameter” column are not straightforward to interpret, the “Expected sample” and “log2-fold change” columns give us an idea on the magnitude of the change. The expected sample is calculated for each covariate separately (covariate value = 1, all other covariates = 0), with the same method as for the intercepts. The log-fold change is then calculated between this expected sample and the expected sample with no active covariates from the intercept section. Since the data is compositional, cell types for which no credible change was detected, can still change in abundance as well, as soon as a credible effect is detected on another cell type due to the sum-to-one constraint. If there are no credible effects for a covariate, its expected sample will be identical to the intercept sample, therefore the log2-fold change is 0.

# %%
sccoda_model.summary(sccoda_data, modality_key= "coda")
# Out:
#                                           Compositional Analysis summary
# ┌────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────┐
# │ Name                                       │ Value                                                              │
# ├────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────┤
# │ Data                                       │ Data: 30 samples, 36 cell types                                    │
# │ Reference cell type                        │ CD4_15                                                             │
# │ Formula                                    │ condition                                                          │
# └────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Intercepts                                                                                                      │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                Final Parameter  Expected Sample                                                                 │
# │ Cell Type                                                                                                       │
# │ B_2                 1.406           27.956                                                                      │
# │ B_9                 0.372            9.941                                                                      │
# │ B_12                0.658           13.232                                                                      │
# │ B_13                0.586           12.313                                                                      │
# │ B_17               -0.479            4.245                                                                      │
# │ CD4_3               0.899           16.838                                                                      │
# │ CD4_4               1.599           33.908                                                                      │
# │ CD4_6               1.323           25.730                                                                      │
# │ CD4_8               0.742           14.392                                                                      │
# │ CD4_10              0.927           17.316                                                                      │
# │ CD4_11              0.602           12.511                                                                      │
# │ CD4_15              0.166            8.090                                                                      │
# │ CD4_16             -0.057            6.473                                                                      │
# │ CD8_0               0.206            8.420                                                                      │
# │ CD8_1               0.439           10.630                                                                      │
# │ CD8_7               0.808           15.373                                                                      │
# │ DC_12               1.365           26.833                                                                      │
# │ DC_14              -0.006            6.812                                                                      │
# │ DC_16              -0.500            4.156                                                                      │
# │ DOCK4+MØ_3          3.080          149.103                                                                      │
# │ DOCK4+MØ_9          2.057           53.605                                                                      │
# │ LYVE1+MØ_1          3.372          199.665                                                                      │
# │ LYVE1+MØ_2          3.072          147.915                                                                      │
# │ LYVE1+MØ_4          2.500           83.483                                                                      │
# │ LYVE1+MØ_8          2.296           68.077                                                                      │
# │ Mast_15            -0.388            4.649                                                                      │
# │ Monocytes_6         1.639           35.291                                                                      │
# │ Monocytes_11        1.139           21.405                                                                      │
# │ Monocytes_13        0.288            9.140                                                                      │
# │ Monocytes_17       -0.660            3.542                                                                      │
# │ MØ_general_0        3.495          225.798                                                                      │
# │ MØ_general_7        2.447           79.173                                                                      │
# │ MØ_general_10       0.679           13.513                                                                      │
# │ NKT_14             -0.033            6.630                                                                      │
# │ NK_5                1.454           29.331                                                                      │
# │ Neutrophils_5       2.480           81.830                                                                      │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Effects                                                                                                         │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                                             Final Parameter  Expected Sample  log2-fold change                  │
# │ Covariate                    Cell Type                                                                          │
# │ conditionT.Pkp2_HetKO_noninf B_2                 0.978           57.222             1.033                       │
# │                              B_9                 0.996           20.727             1.060                       │
# │                              B_12                0.000           10.187            -0.377                       │
# │                              B_13                0.000            9.479            -0.377                       │
# │                              B_17                0.000            3.268            -0.377                       │
# │                              CD4_3               0.000           12.963            -0.377                       │
# │                              CD4_4               0.000           26.104            -0.377                       │
# │                              CD4_6               0.665           38.513             0.582                       │
# │                              CD4_8               0.000           11.079            -0.377                       │
# │                              CD4_10              0.000           13.331            -0.377                       │
# │                              CD4_11              0.000            9.632            -0.377                       │
# │                              CD4_15              0.000            6.228            -0.377                       │
# │                              CD4_16              0.000            4.983            -0.377                       │
# │                              CD8_0              -0.764            3.021            -1.479                       │
# │                              CD8_1               0.000            8.183            -0.377                       │
# │                              CD8_7               0.000           11.835            -0.377                       │
# │                              DC_12               0.000           20.657            -0.377                       │
# │                              DC_14               0.000            5.244            -0.377                       │
# │                              DC_16               0.000            3.200            -0.377                       │
# │                              DOCK4+MØ_3          0.000          114.786            -0.377                       │
# │                              DOCK4+MØ_9          0.000           41.267            -0.377                       │
# │                              LYVE1+MØ_1          0.000          153.710            -0.377                       │
# │                              LYVE1+MØ_2          0.000          113.871            -0.377                       │
# │                              LYVE1+MØ_4          1.069          187.247             1.165                       │
# │                              LYVE1+MØ_8          0.000           52.409            -0.377                       │
# │                              Mast_15             0.000            3.579            -0.377                       │
# │                              Monocytes_6         1.362          106.115             1.588                       │
# │                              Monocytes_11        1.289           59.802             1.482                       │
# │                              Monocytes_13        0.000            7.036            -0.377                       │
# │                              Monocytes_17        0.000            2.727            -0.377                       │
# │                              MØ_general_0        0.000          173.829            -0.377                       │
# │                              MØ_general_7       -0.480           37.731            -1.069                       │
# │                              MØ_general_10       1.858           66.674             2.303                       │
# │                              NKT_14              0.000            5.104            -0.377                       │
# │                              NK_5                0.000           22.580            -0.377                       │
# │                              Neutrophils_5       0.000           62.996            -0.377                       │
# │ conditionT.Pkp2_Ctr_MCMV     B_2                 0.000           24.324            -0.201                       │
# │                              B_9                 0.000            8.649            -0.201                       │
# │                              B_12                0.000           11.513            -0.201                       │
# │                              B_13                0.000           10.713            -0.201                       │
# │                              B_17                0.000            3.693            -0.201                       │
# │                              CD4_3               1.426           60.954             1.856                       │
# │                              CD4_4               0.000           29.503            -0.201                       │
# │                              CD4_6               0.000           22.387            -0.201                       │
# │                              CD4_8               0.876           30.074             1.063                       │
# │                              CD4_10              0.000           15.067            -0.201                       │
# │                              CD4_11              0.000           10.886            -0.201                       │
# │                              CD4_15              0.000            7.039            -0.201                       │
# │                              CD4_16              0.000            5.632            -0.201                       │
# │                              CD8_0               2.063           57.651             2.775                       │
# │                              CD8_1               2.083           74.240             2.804                       │
# │                              CD8_7               1.113           40.710             1.405                       │
# │                              DC_12               0.000           23.347            -0.201                       │
# │                              DC_14               0.730           12.301             0.853                       │
# │                              DC_16               0.000            3.616            -0.201                       │
# │                              DOCK4+MØ_3          0.000          129.733            -0.201                       │
# │                              DOCK4+MØ_9          0.000           46.641            -0.201                       │
# │                              LYVE1+MØ_1          0.000          173.726            -0.201                       │
# │                              LYVE1+MØ_2          0.000          128.700            -0.201                       │
# │                              LYVE1+MØ_4          0.000           72.638            -0.201                       │
# │                              LYVE1+MØ_8          0.000           59.233            -0.201                       │
# │                              Mast_15             0.000            4.045            -0.201                       │
# │                              Monocytes_6         0.492           50.199             0.508                       │
# │                              Monocytes_11        0.000           18.625            -0.201                       │
# │                              Monocytes_13        0.000            7.952            -0.201                       │
# │                              Monocytes_17        0.000            3.082            -0.201                       │
# │                              MØ_general_0        0.000          196.464            -0.201                       │
# │                              MØ_general_7       -0.840           29.732            -1.413                       │
# │                              MØ_general_10       0.000           11.757            -0.201                       │
# │                              NKT_14              0.000            5.769            -0.201                       │
# │                              NK_5                0.000           25.520            -0.201                       │
# │                              Neutrophils_5       0.000           71.199            -0.201                       │
# │ conditionT.Pkp2_HetKO_MCMV   B_2                 0.974           48.727             0.802                       │
# │                              B_9                 1.190           21.509             1.114                       │
# │                              B_12                0.000            8.707            -0.604                       │
# │                              B_13                0.000            8.102            -0.604                       │
# │                              B_17                0.000            2.793            -0.604                       │
# │                              CD4_3               1.393           44.602             1.405                       │
# │                              CD4_4               0.000           22.312            -0.604                       │
# │                              CD4_6               0.000           16.930            -0.604                       │
# │                              CD4_8               0.876           22.743             0.660                       │
# │                              CD4_10              0.000           11.394            -0.604                       │
# │                              CD4_11              0.000            8.233            -0.604                       │
# │                              CD4_15              0.000            5.323            -0.604                       │
# │                              CD4_16              0.000            4.259            -0.604                       │
# │                              CD8_0               2.469           65.445             2.958                       │
# │                              CD8_1               2.211           63.822             2.586                       │
# │                              CD8_7               0.887           24.564             0.676                       │
# │                              DC_12               0.000           17.657            -0.604                       │
# │                              DC_14               0.988           12.042             0.822                       │
# │                              DC_16               0.000            2.735            -0.604                       │
# │                              DOCK4+MØ_3          0.000           98.112            -0.604                       │
# │                              DOCK4+MØ_9          0.000           35.273            -0.604                       │
# │                              LYVE1+MØ_1          0.000          131.382            -0.604                       │
# │                              LYVE1+MØ_2          0.000           97.330            -0.604                       │
# │                              LYVE1+MØ_4          1.080          161.686             0.954                       │
# │                              LYVE1+MØ_8          0.000           44.795            -0.604                       │
# │                              Mast_15             0.000            3.059            -0.604                       │
# │                              Monocytes_6         1.413           95.376             1.434                       │
# │                              Monocytes_11        1.272           50.266             1.232                       │
# │                              Monocytes_13        0.000            6.014            -0.604                       │
# │                              Monocytes_17        0.000            2.331            -0.604                       │
# │                              MØ_general_0        0.000          148.577            -0.604                       │
# │                              MØ_general_7        0.000           52.097            -0.604                       │
# │                              MØ_general_10       2.086           71.614             2.406                       │
# │                              NKT_14              0.000            4.363            -0.604                       │
# │                              NK_5                0.000           19.300            -0.604                       │
# │                              Neutrophils_5       0.000           53.845            -0.604                       │
# │ conditionT.Ttn_Ctr_noninf    B_2                 0.000           27.956             0.000                       │
# │                              B_9                 0.000            9.941             0.000                       │
# │                              B_12                0.000           13.232             0.000                       │
# │                              B_13                0.000           12.313             0.000                       │
# │                              B_17                0.000            4.245             0.000                       │
# │                              CD4_3               0.000           16.838             0.000                       │
# │                              CD4_4               0.000           33.908             0.000                       │
# │                              CD4_6               0.000           25.730             0.000                       │
# │                              CD4_8               0.000           14.392             0.000                       │
# │                              CD4_10              0.000           17.316             0.000                       │
# │                              CD4_11              0.000           12.511             0.000                       │
# │                              CD4_15              0.000            8.090             0.000                       │
# │                              CD4_16              0.000            6.473             0.000                       │
# │                              CD8_0               0.000            8.420             0.000                       │
# │                              CD8_1               0.000           10.630             0.000                       │
# │                              CD8_7               0.000           15.373             0.000                       │
# │                              DC_12               0.000           26.833             0.000                       │
# │                              DC_14               0.000            6.812             0.000                       │
# │                              DC_16               0.000            4.156             0.000                       │
# │                              DOCK4+MØ_3          0.000          149.103             0.000                       │
# │                              DOCK4+MØ_9          0.000           53.605             0.000                       │
# │                              LYVE1+MØ_1          0.000          199.665             0.000                       │
# │                              LYVE1+MØ_2          0.000          147.915             0.000                       │
# │                              LYVE1+MØ_4          0.000           83.483             0.000                       │
# │                              LYVE1+MØ_8          0.000           68.077             0.000                       │
# │                              Mast_15             0.000            4.649             0.000                       │
# │                              Monocytes_6         0.000           35.291             0.000                       │
# │                              Monocytes_11        0.000           21.405             0.000                       │
# │                              Monocytes_13        0.000            9.140             0.000                       │
# │                              Monocytes_17        0.000            3.542             0.000                       │
# │                              MØ_general_0        0.000          225.798             0.000                       │
# │                              MØ_general_7        0.000           79.173             0.000                       │
# │                              MØ_general_10       0.000           13.513             0.000                       │
# │                              NKT_14              0.000            6.630             0.000                       │
# │                              NK_5                0.000           29.331             0.000                       │
# │                              Neutrophils_5       0.000           81.830             0.000                       │
# │ conditionT.Ttn_HetKO_noninf  B_2                 0.000           27.216            -0.039                       │
# │                              B_9                 0.000            9.678            -0.039                       │
# │                              B_12                0.000           12.882            -0.039                       │
# │                              B_13                0.000           11.987            -0.039                       │
# │                              B_17                0.000            4.132            -0.039                       │
# │                              CD4_3               0.000           16.392            -0.039                       │
# │                              CD4_4               0.000           33.010            -0.039                       │
# │                              CD4_6               0.000           25.049            -0.039                       │
# │                              CD4_8               0.000           14.011            -0.039                       │
# │                              CD4_10              0.000           16.858            -0.039                       │
# │                              CD4_11              0.000           12.180            -0.039                       │
# │                              CD4_15              0.000            7.876            -0.039                       │
# │                              CD4_16              0.000            6.302            -0.039                       │
# │                              CD8_0               0.000            8.197            -0.039                       │
# │                              CD8_1               0.000           10.348            -0.039                       │
# │                              CD8_7               0.000           14.967            -0.039                       │
# │                              DC_12               0.000           26.123            -0.039                       │
# │                              DC_14               0.000            6.631            -0.039                       │
# │                              DC_16               0.000            4.046            -0.039                       │
# │                              DOCK4+MØ_3          0.000          145.157            -0.039                       │
# │                              DOCK4+MØ_9          0.000           52.186            -0.039                       │
# │                              LYVE1+MØ_1          0.000          194.380            -0.039                       │
# │                              LYVE1+MØ_2          0.000          144.000            -0.039                       │
# │                              LYVE1+MØ_4          0.000           81.273            -0.039                       │
# │                              LYVE1+MØ_8          0.000           66.275            -0.039                       │
# │                              Mast_15             0.000            4.526            -0.039                       │
# │                              Monocytes_6         0.000           34.357            -0.039                       │
# │                              Monocytes_11        0.000           20.839            -0.039                       │
# │                              Monocytes_13        0.000            8.898            -0.039                       │
# │                              Monocytes_17        0.000            3.448            -0.039                       │
# │                              MØ_general_0        0.000          219.821            -0.039                       │
# │                              MØ_general_7        0.000           77.078            -0.039                       │
# │                              MØ_general_10       0.000           13.155            -0.039                       │
# │                              NKT_14              0.000            6.455            -0.039                       │
# │                              NK_5                0.000           28.555            -0.039                       │
# │                              Neutrophils_5       0.402          119.029             0.541                       │
# │ conditionT.Ttn_Ctr_MCMV      B_2                 0.000           27.956             0.000                       │
# │                              B_9                 0.000            9.941             0.000                       │
# │                              B_12                0.000           13.232             0.000                       │
# │                              B_13                0.000           12.313             0.000                       │
# │                              B_17                0.000            4.245             0.000                       │
# │                              CD4_3               0.000           16.838             0.000                       │
# │                              CD4_4               0.000           33.908             0.000                       │
# │                              CD4_6               0.000           25.730             0.000                       │
# │                              CD4_8               0.000           14.392             0.000                       │
# │                              CD4_10              0.000           17.316             0.000                       │
# │                              CD4_11              0.000           12.511             0.000                       │
# │                              CD4_15              0.000            8.090             0.000                       │
# │                              CD4_16              0.000            6.473             0.000                       │
# │                              CD8_0               0.000            8.420             0.000                       │
# │                              CD8_1               0.000           10.630             0.000                       │
# │                              CD8_7               0.000           15.373             0.000                       │
# │                              DC_12               0.000           26.833             0.000                       │
# │                              DC_14               0.000            6.812             0.000                       │
# │                              DC_16               0.000            4.156             0.000                       │
# │                              DOCK4+MØ_3          0.000          149.103             0.000                       │
# │                              DOCK4+MØ_9          0.000           53.605             0.000                       │
# │                              LYVE1+MØ_1          0.000          199.665             0.000                       │
# │                              LYVE1+MØ_2          0.000          147.915             0.000                       │
# │                              LYVE1+MØ_4          0.000           83.483             0.000                       │
# │                              LYVE1+MØ_8          0.000           68.077             0.000                       │
# │                              Mast_15             0.000            4.649             0.000                       │
# │                              Monocytes_6         0.000           35.291             0.000                       │
# │                              Monocytes_11        0.000           21.405             0.000                       │
# │                              Monocytes_13        0.000            9.140             0.000                       │
# │                              Monocytes_17        0.000            3.542             0.000                       │
# │                              MØ_general_0        0.000          225.798             0.000                       │
# │                              MØ_general_7        0.000           79.173             0.000                       │
# │                              MØ_general_10       0.000           13.513             0.000                       │
# │                              NKT_14              0.000            6.630             0.000                       │
# │                              NK_5                0.000           29.331             0.000                       │
# │                              Neutrophils_5       0.000           81.830             0.000                       │
# │ conditionT.Ttn_HetKO_MCMV    B_2                 0.000           27.956             0.000                       │
# │                              B_9                 0.000            9.941             0.000                       │
# │                              B_12                0.000           13.232             0.000                       │
# │                              B_13                0.000           12.313             0.000                       │
# │                              B_17                0.000            4.245             0.000                       │
# │                              CD4_3               0.000           16.838             0.000                       │
# │                              CD4_4               0.000           33.908             0.000                       │
# │                              CD4_6               0.000           25.730             0.000                       │
# │                              CD4_8               0.000           14.392             0.000                       │
# │                              CD4_10              0.000           17.316             0.000                       │
# │                              CD4_11              0.000           12.511             0.000                       │
# │                              CD4_15              0.000            8.090             0.000                       │
# │                              CD4_16              0.000            6.473             0.000                       │
# │                              CD8_0               0.000            8.420             0.000                       │
# │                              CD8_1               0.000           10.630             0.000                       │
# │                              CD8_7               0.000           15.373             0.000                       │
# │                              DC_12               0.000           26.833             0.000                       │
# │                              DC_14               0.000            6.812             0.000                       │
# │                              DC_16               0.000            4.156             0.000                       │
# │                              DOCK4+MØ_3          0.000          149.103             0.000                       │
# │                              DOCK4+MØ_9          0.000           53.605             0.000                       │
# │                              LYVE1+MØ_1          0.000          199.665             0.000                       │
# │                              LYVE1+MØ_2          0.000          147.915             0.000                       │
# │                              LYVE1+MØ_4          0.000           83.483             0.000                       │
# │                              LYVE1+MØ_8          0.000           68.077             0.000                       │
# │                              Mast_15             0.000            4.649             0.000                       │
# │                              Monocytes_6         0.000           35.291             0.000                       │
# │                              Monocytes_11        0.000           21.405             0.000                       │
# │                              Monocytes_13        0.000            9.140             0.000                       │
# │                              Monocytes_17        0.000            3.542             0.000                       │
# │                              MØ_general_0        0.000          225.798             0.000                       │
# │                              MØ_general_7        0.000           79.173             0.000                       │
# │                              MØ_general_10       0.000           13.513             0.000                       │
# │                              NKT_14              0.000            6.630             0.000                       │
# │                              NK_5                0.000           29.331             0.000                       │
# │                              Neutrophils_5       0.000           81.830             0.000                       │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Filter out credible effects

# %%
sccoda_model.credible_effects(sccoda_data, modality_key="coda")
# Out:
# Covariate                       Cell Type
# condition[T.Pkp2_HetKO_noninf]  B_2               True
#                                 B_9               True
#                                 B_12             False
#                                 B_13             False
#                                 B_17             False
#                                                  ...
# condition[T.Ttn_HetKO_MCMV]     MØ_general_7     False
#                                 MØ_general_10    False
#                                 NKT_14           False
#                                 NK_5             False
#                                 Neutrophils_5    False
# Name: Final Parameter, Length: 252, dtype: bool

# %%
pt.pl.coda.effects_barplot(sccoda_data, modality_key="coda", parameter="Final Parameter")

# %% [markdown]
# ##### Adjust the "false discovery rate"

# %% [raw]
# #If needed adjust the 'false discovery rate' - default is 0.05, however when no effects are detected it can be incresed to up to 0.2
# sccoda_model.set_fdr(sccoda_data, 0.2)
# sccoda_model.credible_effects(sccoda_data, modality_key="coda")

# %%
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 44616 × 29414
#   2 modalities
#     rna:	44586 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification', 'lineage'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'neighbors', 'umap'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     coda:	30 x 36
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'
#       uns:	'scCODA_params'
#       obsm:	'covariate_matrix', 'sample_counts'
#       varm:	'intercept_df', 'effect_df_condition[T.Pkp2_HetKO_noninf]', 'effect_df_condition[T.Pkp2_Ctr_MCMV]', 'effect_df_condition[T.Pkp2_HetKO_MCMV]', 'effect_df_condition[T.Ttn_Ctr_noninf]', 'effect_df_condition[T.Ttn_HetKO_noninf]', 'effect_df_condition[T.Ttn_Ctr_MCMV]', 'effect_df_condition[T.Ttn_HetKO_MCMV]'

# %%
sccoda_data["coda"].varm["effect_df_condition[T.Pkp2_HetKO_noninf]"]
# Out:
#                Final Parameter  HDI 3%  HDI 97%     SD  Inclusion probability  \
# Cell Type
# B_2                   0.977868   0.511    1.416  0.236                 0.9994
# B_9                   0.996390   0.328    1.640  0.390                 0.9579
# B_12                  0.000000  -1.182    0.243  0.376                 0.5402
# B_13                  0.000000  -1.099    0.351  0.302                 0.4304
# B_17                  0.000000  -0.264    1.427  0.455                 0.6133
# CD4_3                 0.000000  -0.561    0.641  0.187                 0.3478
# CD4_4                 0.000000  -0.116    0.794  0.240                 0.4999
# CD4_6                 0.664914   0.121    1.160  0.325                 0.8916
# CD4_8                 0.000000  -0.277    0.984  0.288                 0.4651
# CD4_10                0.000000  -0.505    0.672  0.188                 0.3583
# CD4_11                0.000000  -0.012    1.206  0.394                 0.7090
# CD4_15                0.000000   0.000    0.000  0.000                 0.0000
# CD4_16                0.000000  -0.608    0.961  0.267                 0.4081
# CD8_0                -0.763514  -1.615    0.077  0.524                 0.7423
# CD8_1                 0.000000  -1.432    0.145  0.452                 0.6237
# CD8_7                 0.000000  -0.612    0.632  0.195                 0.3499
# DC_12                 0.000000  -0.785    0.269  0.210                 0.3770
# DC_14                 0.000000  -1.219    0.474  0.353                 0.4592
# DC_16                 0.000000  -0.440    1.171  0.343                 0.4833
# DOCK4+MØ_3            0.000000  -0.041    0.495  0.151                 0.4532
# DOCK4+MØ_9            0.000000  -0.571    0.254  0.137                 0.3002
# LYVE1+MØ_1            0.000000  -0.594    0.009  0.202                 0.6912
# LYVE1+MØ_2            0.000000  -0.589    0.020  0.174                 0.4640
# LYVE1+MØ_4            1.069359   0.721    1.374  0.170                 1.0000
# LYVE1+MØ_8            0.000000  -0.557    0.198  0.121                 0.2889
# Mast_15               0.000000  -1.159    0.508  0.326                 0.4346
# Monocytes_6           1.362451   0.912    1.759  0.221                 1.0000
# Monocytes_11          1.288966   0.783    1.761  0.257                 1.0000
# Monocytes_13          0.000000  -0.462    0.980  0.289                 0.4511
# Monocytes_17          0.000000  -0.908    0.798  0.285                 0.4099
# MØ_general_0          0.000000  -0.484    0.054  0.147                 0.4250
# MØ_general_7         -0.479600  -0.877    0.004  0.293                 0.7740
# MØ_general_10         1.857738   1.370    2.359  0.258                 1.0000
# NKT_14                0.000000  -0.735    0.888  0.269                 0.3963
# NK_5                  0.000000  -0.419    0.559  0.154                 0.3312
# Neutrophils_5         0.000000  -0.381    0.302  0.093                 0.2538
#
#                Expected Sample  log2-fold change
# Cell Type
# B_2                  57.221980          1.033402
# B_9                  20.727483          1.060124
# B_12                 10.186569         -0.377364
# B_13                  9.478917         -0.377364
# B_17                  3.267647         -0.377364
# CD4_3                12.962624         -0.377364
# CD4_4                26.103519         -0.377364
# CD4_6                38.512539          0.581904
# CD4_8                11.079207         -0.377364
# CD4_10               13.330706         -0.377364
# CD4_11                9.631800         -0.377364
# CD4_15                6.228093         -0.377364
# CD4_16                4.983189         -0.377364
# CD8_0                 3.020904         -1.478882
# CD8_1                 8.183092         -0.377364
# CD8_7                11.835105         -0.377364
# DC_12                20.657328         -0.377364
# DC_14                 5.243924         -0.377364
# DC_16                 3.199742         -0.377364
# DOCK4+MØ_3          114.786068         -0.377364
# DOCK4+MØ_9           41.267287         -0.377364
# LYVE1+MØ_1          153.710369         -0.377364
# LYVE1+MØ_2          113.871442         -0.377364
# LYVE1+MØ_4          187.247132          1.165395
# LYVE1+MØ_8           52.408569         -0.377364
# Mast_15               3.578952         -0.377364
# Monocytes_6         106.114787          1.588238
# Monocytes_11         59.801812          1.482221
# Monocytes_13          7.036213         -0.377364
# Monocytes_17          2.726640         -0.377364
# MØ_general_0        173.828662         -0.377364
# MØ_general_7         37.730558         -1.069280
# MØ_general_10        66.673519          2.302785
# NKT_14                5.104233         -0.377364
# NK_5                 22.580125         -0.377364
# Neutrophils_5        62.995930         -0.377364

# %%
sccoda_data["coda"].varm["effect_df_condition[T.Pkp2_HetKO_MCMV]"]
# Out:
#                Final Parameter  HDI 3%  HDI 97%     SD  Inclusion probability  \
# Cell Type
# B_2                   0.974127   0.569    1.348  0.193                 1.0000
# B_9                   1.190357   0.630    1.714  0.280                 0.9986
# B_12                  0.000000  -1.158    0.108  0.345                 0.4916
# B_13                  0.000000  -1.350    0.032  0.432                 0.6310
# B_17                  0.000000  -0.188    1.335  0.434                 0.5903
# CD4_3                 1.392678   0.963    1.802  0.216                 1.0000
# CD4_4                 0.000000  -0.775    0.096  0.218                 0.4079
# CD4_6                 0.000000  -0.125    0.755  0.200                 0.3715
# CD4_8                 0.876168   0.338    1.392  0.298                 0.9752
# CD4_10                0.000000  -1.026    0.124  0.297                 0.4420
# CD4_11                0.000000  -0.364    0.707  0.176                 0.3186
# CD4_15                0.000000   0.000    0.000  0.000                 0.0000
# CD4_16                0.000000  -0.920    0.449  0.233                 0.3370
# CD8_0                 2.469102   1.941    2.972  0.274                 1.0000
# CD8_1                 2.210990   1.714    2.698  0.254                 1.0000
# CD8_7                 0.887182   0.352    1.363  0.282                 0.9792
# DC_12                 0.000000  -0.375    0.448  0.108                 0.2433
# DC_14                 0.988273   0.306    1.641  0.410                 0.9403
# DC_16                 0.000000  -0.238    1.278  0.385                 0.5155
# DOCK4+MØ_3            0.000000  -0.023    0.396  0.103                 0.3235
# DOCK4+MØ_9            0.000000  -0.439    0.240  0.097                 0.2378
# LYVE1+MØ_1            0.000000  -0.383    0.019  0.096                 0.3081
# LYVE1+MØ_2            0.000000  -0.145    0.290  0.056                 0.1982
# LYVE1+MØ_4            1.079552   0.786    1.333  0.130                 1.0000
# LYVE1+MØ_8            0.000000  -0.051    0.490  0.140                 0.3613
# Mast_15               0.000000  -1.026    0.504  0.275                 0.3654
# Monocytes_6           1.412721   1.049    1.767  0.182                 1.0000
# Monocytes_11          1.272229   0.834    1.713  0.219                 1.0000
# Monocytes_13          0.000000  -1.011    0.417  0.254                 0.3502
# Monocytes_17          0.000000  -0.881    0.655  0.238                 0.3364
# MØ_general_0          0.000000  -0.222    0.133  0.040                 0.1682
# MØ_general_7          0.000000  -0.687    0.003  0.235                 0.6450
# MØ_general_10         2.086178   1.675    2.494  0.212                 1.0000
# NKT_14                0.000000  -0.490    0.908  0.252                 0.3696
# NK_5                  0.000000  -0.310    0.528  0.125                 0.2728
# Neutrophils_5         0.000000  -0.484    0.096  0.119                 0.2890
#
#                Expected Sample  log2-fold change
# Cell Type
# B_2                  48.726967          0.801553
# B_9                  21.508812          1.113507
# B_12                  8.706809         -0.603816
# B_13                  8.101955         -0.603816
# B_17                  2.792969         -0.603816
# CD4_3                44.602214          1.405394
# CD4_4                22.311570         -0.603816
# CD4_6                16.930307         -0.603816
# CD4_8                22.743363          0.660227
# CD4_10               11.394210         -0.603816
# CD4_11                8.232629         -0.603816
# CD4_15                5.323364         -0.603816
# CD4_16                4.259302         -0.603816
# CD8_0                65.444807          2.958345
# CD8_1                63.821838          2.585968
# CD8_7                24.564131          0.676117
# DC_12                17.656524         -0.603816
# DC_14                12.041730          0.821960
# DC_16                 2.734929         -0.603816
# DOCK4+MØ_3           98.111576         -0.603816
# DOCK4+MØ_9           35.272561         -0.603816
# LYVE1+MØ_1          131.381507         -0.603816
# LYVE1+MØ_2           97.329814         -0.603816
# LYVE1+MØ_4          161.686211          0.953648
# LYVE1+MØ_8           44.795396         -0.603816
# Mast_15               3.059053         -0.603816
# Monocytes_6          95.375971          1.434310
# Monocytes_11         50.266264          1.231622
# Monocytes_13          6.014092         -0.603816
# Monocytes_17          2.330552         -0.603816
# MØ_general_0        148.577299         -0.603816
# MØ_general_7         52.096895         -0.603816
# MØ_general_10        71.613504          2.405903
# NKT_14                4.362762         -0.603816
# NK_5                 19.300005         -0.603816
# Neutrophils_5        53.844774         -0.603816

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=sccoda_data["coda"].varm["effect_df_condition[T.Pkp2_HetKO_MCMV]"], x="Cell Type", y="log2-fold change", hue="Cell Type")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=sccoda_data["coda"].varm["effect_df_condition[T.Pkp2_HetKO_noninf]"], x="Cell Type", y="log2-fold change", hue="Cell Type")
plt.xticks(rotation=90)
plt.show()

# %%
pt.pl.coda.effects_barplot(sccoda_data, "coda", "condition")
plt.show()
