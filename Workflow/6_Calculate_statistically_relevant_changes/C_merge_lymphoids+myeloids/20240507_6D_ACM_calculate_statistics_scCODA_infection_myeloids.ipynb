# %% [markdown]
# # Compositional analysis of the ACM cardiac leucocytes 6mpi dataset (Pkp2+Ttn) - myeloids - using scCoda `pertpy`:
# - **Developed by**: Christian Eger
# - **Modified by**: Alexandra Cirnu
# - **Talavera-López Lab - Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg**
# - **Created on**: 231214
# - **Last modified**: 240503

# %% [markdown]
# #### Environment: scCoda
#
# To install `pertpy` on MacOS create a new mamba environment and activte it. Then go int 'github' folder and type 'git clone https://github.com/theislab/pertpy.git'. Change directory to 'pertpy' and type 'pip install .'
#
# Look at website to solve problem at the end: https://www.sc-best-practices.org/conditions/compositional.html

# %%
import warnings
import pandas as pd
warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")
import numpy as np
            #import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import altair as alt
import scanpy as sc
import pertpy as pt
from statannot import add_stat_annotation
from scipy import stats
import muon as mu
from muon import atac as ac
from muon import prot

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.5.post1
# scanpy      1.9.8
# -----
# PIL                         10.2.0
# absl                        NA
# adjustText                  1.0.4
# altair                      4.2.2
# arrow                       1.3.0
# arviz                       0.17.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# blitzgsea                   NA
# certifi                     2024.02.02
# cffi                        1.16.0
# chardet                     5.2.0
# charset_normalizer          3.3.2
# chex                        0.1.85
# colorama                    0.4.6
# comm                        0.2.1
# contextlib2                 NA
# custom_inherit              2.4.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.9.0
# debugpy                     1.8.1
# decorator                   5.1.1
# decoupler                   1.6.0
# docrep                      0.3.2
# entrypoints                 0.4
# etils                       1.7.0
# exceptiongroup              1.2.0
# executing                   2.0.1
# flax                        0.8.1
# fsspec                      2024.2.0
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# importlib_resources         NA
# ipykernel                   6.29.3
# ipywidgets                  8.1.2
# jax                         0.4.25
# jaxlib                      0.4.25
# jaxopt                      NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# lightning                   2.1.4
# lightning_fabric            2.2.0.post0
# lightning_utilities         0.10.1
# llvmlite                    0.42.0
# markupsafe                  2.1.5
# matplotlib                  3.8.3
# ml_collections              NA
# ml_dtypes                   0.3.2
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.8
# mudata                      0.2.3
# multipledispatch            0.6.0
# muon                        0.1.5
# natsort                     8.4.0
# numba                       0.59.0
# numpy                       1.26.4
# numpyro                     0.14.0
# opt_einsum                  v3.3.0
# optax                       0.1.9
# ott                         0.4.5
# packaging                   23.2
# pandas                      2.2.1
# parso                       0.8.3
# patsy                       0.5.6
# pertpy                      0.7.0
# pkg_resources               NA
# platformdirs                4.2.0
# ply                         3.11
# png                         0.20220715.0
# prompt_toolkit              3.0.43
# psutil                      5.9.8
# pubchempy                   1.0.4
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynndescent                 0.5.11
# pyomo                       6.7.1
# pyparsing                   3.1.1
# pyro                        1.9.0
# pytorch_lightning           2.2.0.post0
# pytz                        2024.1
# referencing                 NA
# reportlab                   4.1.0
# requests                    2.31.0
# rich                        NA
# rpds                        NA
# rpy2                        3.5.11
# scipy                       1.12.0
# scvi                        1.1.2
# seaborn                     0.13.2
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.4.1.post1
# skmisc                      0.3.1
# sparsecca                   0.3.1
# stack_data                  0.6.3
# statannot                   0.2.3
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# toolz                       0.12.1
# torch                       2.2.1+cu121
# torchgen                    NA
# torchmetrics                1.3.1
# tornado                     6.4
# toyplot                     1.0.3
# toytree                     2.0.1
# tqdm                        4.66.2
# traitlets                   5.14.1
# typing_extensions           NA
# tzlocal                     NA
# umap                        0.5.5
# urllib3                     2.2.1
# vscode                      NA
# wcwidth                     0.2.13
# xarray                      2024.2.0
# xarray_einstats             0.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-6.8.4-200.fc39.x86_64-x86_64-with-glibc2.38
# -----
# Session information updated at 2024-05-09 11:12

# %% [markdown]
# Manual git installation of pertpy necessary due to Apple silicon
# $ git clone https://github.com/theislab/pertpy.git
# $ cd pertpy
# $ pip install .

# %%
input = '/home/acirnu/data/ACM_cardiac_leuco/5_Leiden_clustering_and_annotation/ACM_myeloids+lymphoids_leiden_clustered_muon_ac240507.raw.h5mu'
mdata_data = mu.read_h5mu(input)
mdata_data
# Out:
# MuData object with n_obs × n_vars = 44586 × 29477
#   var:	'gene_ids', 'feature_types'
#   2 modalities
#     rna:	44586 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification', 'lineage'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'neighbors', 'umap'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     prot:	44586 x 99
#       obs:	'library', 'batch', 'lineage'
#       var:	'gene_ids', 'feature_types'
#       uns:	'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap'
#       varm:	'PCs'
#       layers:	'counts', 'log_norm'

# %%
adata = mdata_data.mod["rna"]
adata
# Out:
# AnnData object with n_obs × n_vars = 44586 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification', 'lineage'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo'
#     uns: 'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'neighbors', 'umap'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#                       cell_source               donor  n_counts  \
# AAACGCTGTTGTGTTG-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1     478.0
# AAACGCTTCTCGCTCA-1-A1   AG_Gerull   Pkp2_Ctr_noninf_1    3581.0
# AAAGGTACAGAACATA-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2   16539.0
# AAAGTCCAGGGACACT-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2   13389.0
# AAAGTCCCAGTAGGAC-1-A1   AG_Gerull   Pkp2_Ctr_noninf_2   12092.0
# ...                           ...                 ...       ...
# TTTGATCAGTATGACA-1-B2   AG_Gerull    Ttn_HetKO_MCMV_1   12119.0
# TTTGGAGAGATTAGCA-1-B2   AG_Gerull      Ttn_Ctr_MCMV_2   20506.0
# TTTGGTTAGCACCTGC-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    3174.0
# TTTGTTGAGACCTCCG-1-B2   AG_Gerull  Ttn_HetKO_noninf_2    4549.0
# TTTGTTGGTAGTAAGT-1-B2   AG_Gerull    Ttn_HetKO_MCMV_2    6564.0
#
#                                    sample seed_labels         condition  \
# AAACGCTGTTGTGTTG-1-A1   Pkp2_Ctr_noninf_1    DOCK4+MØ   Pkp2_Ctr_noninf
# AAACGCTTCTCGCTCA-1-A1   Pkp2_Ctr_noninf_1   Monocytes   Pkp2_Ctr_noninf
# AAAGGTACAGAACATA-1-A1   Pkp2_Ctr_noninf_2   Monocytes   Pkp2_Ctr_noninf
# AAAGTCCAGGGACACT-1-A1   Pkp2_Ctr_noninf_2    LYVE1+MØ   Pkp2_Ctr_noninf
# AAAGTCCCAGTAGGAC-1-A1   Pkp2_Ctr_noninf_2    LYVE1+MØ   Pkp2_Ctr_noninf
# ...                                   ...         ...               ...
# TTTGATCAGTATGACA-1-B2    Ttn_HetKO_MCMV_1     Unknown    Ttn_HetKO_MCMV
# TTTGGAGAGATTAGCA-1-B2      Ttn_Ctr_MCMV_2     Unknown      Ttn_Ctr_MCMV
# TTTGGTTAGCACCTGC-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO_noninf_2     Unknown  Ttn_HetKO_noninf
# TTTGTTGGTAGTAAGT-1-B2    Ttn_HetKO_MCMV_2     Unknown    Ttn_HetKO_MCMV
#
#                         genotype infection library model  ...  XIST-counts  \
# AAACGCTGTTGTGTTG-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...          0.0
# AAACGCTTCTCGCTCA-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...          0.0
# AAAGGTACAGAACATA-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...          0.0
# AAAGTCCAGGGACACT-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...          0.0
# AAAGTCCCAGTAGGAC-1-A1   Pkp2_Ctr    noninf      A1  Pkp2  ...          0.0
# ...                          ...       ...     ...   ...  ...          ...
# TTTGATCAGTATGACA-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...          0.0
# TTTGGAGAGATTAGCA-1-B2    Ttn_Ctr      MCMV      B2   Ttn  ...         23.0
# TTTGGTTAGCACCTGC-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...          0.0
# TTTGTTGAGACCTCCG-1-B2  Ttn_HetKO    noninf      B2   Ttn  ...          0.0
# TTTGTTGGTAGTAAGT-1-B2  Ttn_HetKO      MCMV      B2   Ttn  ...          0.0
#
#                         S_score  G2M_score  _scvi_batch  _scvi_labels  \
# AAACGCTGTTGTGTTG-1-A1 -0.019995  -0.083225            6             1
# AAACGCTTCTCGCTCA-1-A1 -0.169221  -0.390143            6             4
# AAAGGTACAGAACATA-1-A1 -0.317631  -0.578955            7             4
# AAAGTCCAGGGACACT-1-A1 -0.370103  -0.370084            7             2
# AAAGTCCCAGTAGGAC-1-A1 -0.142503  -0.357287            7             2
# ...                         ...        ...          ...           ...
# TTTGATCAGTATGACA-1-B2 -0.267751  -0.531946           25             5
# TTTGGAGAGATTAGCA-1-B2  2.905558   0.470866           21             5
# TTTGGTTAGCACCTGC-1-B2  0.000996  -0.736926           26             5
# TTTGTTGAGACCTCCG-1-B2 -0.428444  -0.362500           29             5
# TTTGTTGGTAGTAAGT-1-B2  0.363058  -0.589437           26             5
#
#                            batch   C_scANVI  leiden  classification   lineage
# AAACGCTGTTGTGTTG-1-A1  reference   DOCK4+MØ       3      DOCK4+MØ_3   myeloid
# AAACGCTTCTCGCTCA-1-A1  reference  Monocytes       3      DOCK4+MØ_3   myeloid
# AAAGGTACAGAACATA-1-A1  reference  Monocytes       6     Monocytes_6   myeloid
# AAAGTCCAGGGACACT-1-A1  reference   LYVE1+MØ       2      LYVE1+MØ_2   myeloid
# AAAGTCCCAGTAGGAC-1-A1  reference   LYVE1+MØ       2      LYVE1+MØ_2   myeloid
# ...                          ...        ...     ...             ...       ...
# TTTGATCAGTATGACA-1-B2      query          B       9             B_9  lymphoid
# TTTGGAGAGATTAGCA-1-B2      query          B       2             B_2  lymphoid
# TTTGGTTAGCACCTGC-1-B2      query        CD8       7           CD8_7  lymphoid
# TTTGTTGAGACCTCCG-1-B2      query          B      13            B_13  lymphoid
# TTTGTTGGTAGTAAGT-1-B2      query        CD8       0           CD8_0  lymphoid
#
# [44586 rows x 29 columns]

# %%
new_order_genotype = ['Pkp2_Ctr', 'Pkp2_HetKO', 'Ttn_Ctr', 'Ttn_HetKO']
adata.obs["genotype"] = adata.obs["genotype"].cat.reorder_categories(new_order_genotype, ordered=True)

adata.obs["genotype"].cat.categories
# Out:
# Index(['Pkp2_Ctr', 'Pkp2_HetKO', 'Ttn_Ctr', 'Ttn_HetKO'], dtype='object')

# %%
new_order_infection = ['noninf', 'MCMV']
adata.obs["infection"] = adata.obs["infection"].cat.reorder_categories(new_order_infection, ordered=True)

adata.obs["infection"].cat.categories
# Out:
# Index(['noninf', 'MCMV'], dtype='object')

# %%
new_order_condition = ['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV', 'Pkp2_HetKO_MCMV', 'Ttn_Ctr_noninf', 'Ttn_HetKO_noninf','Ttn_Ctr_MCMV', 'Ttn_HetKO_MCMV' ]
adata.obs["condition"] = adata.obs["condition"].cat.reorder_categories(new_order_condition, ordered=True)

adata.obs["condition"].cat.categories
# Out:
# Index(['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV',
#        'Pkp2_HetKO_MCMV', 'Ttn_Ctr_noninf', 'Ttn_HetKO_noninf', 'Ttn_Ctr_MCMV',
#        'Ttn_HetKO_MCMV'],
#       dtype='object')

# %% [markdown]
# create notebook for every compartment and compare across cell states
# visualization improvement
# reference to ctrl healthy

# %%
sccoda_model = pt.tl.Sccoda()
sccoda_data = sccoda_model.load(
    adata,
    type="cell_level",
    generate_sample_level=True,
    cell_type_identifier="classification",
    sample_identifier="sample",
    covariate_obs=["genotype", "infection", "condition"],
)
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 44616 × 29414
#   2 modalities
#     rna:	44586 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification', 'lineage'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'neighbors', 'umap'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     coda:	30 x 36
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="infection",
    y_scale="count",
    figsize=(30, 20),
    add_dots=False,
    args_swarmplot={"palette": ["red"]},
)
plt.show()

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="infection",
    plot_facets=True,
    y_scale="log",
    add_dots=True,
    cmap="Reds",
)
plt.xticks(rotation=90)
plt.show()

# %%
pt.pl.coda.stacked_barplot(
    sccoda_data, modality_key="coda", feature_name="infection", figsize=(15, 9) 
)
plt.legend(ncol=3, loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
sccoda_data = sccoda_model.prepare(
    sccoda_data,
    modality_key="coda",
    formula="infection",
    reference_cell_type="automatic",
)
sccoda_data["coda"]
# Out:
# Automatic reference selection! Reference cell type set to CD4_15
# Zero counts encountered in data! Added a pseudocount of 0.5.
# AnnData object with n_obs × n_vars = 30 × 36
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'

# %% [markdown]
# Run No-U-turn HMC sampling (nuts)

# %%
sccoda_model.run_nuts(sccoda_data, modality_key="coda", rng_key=1234)
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# sample: 100%|██████████| 11000/11000 [08:10<00:00, 22.42it/s, 511 steps of size 1.05e-02. acc. prob=0.89]

# %%
sccoda_data["coda"]
# Out:
# AnnData object with n_obs × n_vars = 30 × 36
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'
#     varm: 'intercept_df', 'effect_df_infection[T.MCMV]'

# %% [markdown]
# #### Result interpreteation

# %% [markdown]
# **Intercepts**
#
# The first column of the intercept summary shows the parameters determined by the MCMC inference.
#
# The “Expected sample” column gives some context to the numerical values. If we had a new sample (with no active covariates) with a total number of cells equal to the mean sampling depth of the dataset, then this distribution over the cell types would be most likely.
#
# **Effects**
#
# For the effect summary, the first column again shows the inferred parameters for all combinations of covariates and cell types. Most important is the distinctions between zero and non-zero entries A value of zero means that no statistically credible effect was detected. For a value other than zero, a credible change was detected. A positive sign indicates an increase, a negative sign a decrease in abundance.
#
# Since the numerical values of the “Final Parameter” column are not straightforward to interpret, the “Expected sample” and “log2-fold change” columns give us an idea on the magnitude of the change. The expected sample is calculated for each covariate separately (covariate value = 1, all other covariates = 0), with the same method as for the intercepts. The log-fold change is then calculated between this expected sample and the expected sample with no active covariates from the intercept section. Since the data is compositional, cell types for which no credible change was detected, can still change in abundance as well, as soon as a credible effect is detected on another cell type due to the sum-to-one constraint. If there are no credible effects for a covariate, its expected sample will be identical to the intercept sample, therefore the log2-fold change is 0.

# %%
sccoda_model.summary(sccoda_data, modality_key= "coda")
# Out:
#                                           Compositional Analysis summary
# ┌────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────┐
# │ Name                                       │ Value                                                              │
# ├────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────┤
# │ Data                                       │ Data: 30 samples, 36 cell types                                    │
# │ Reference cell type                        │ CD4_15                                                             │
# │ Formula                                    │ infection                                                          │
# └────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Intercepts                                                                                                      │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                Final Parameter  Expected Sample                                                                 │
# │ Cell Type                                                                                                       │
# │ B_2                 1.261           37.885                                                                      │
# │ B_9                 0.299           14.477                                                                      │
# │ B_12                0.210           13.244                                                                      │
# │ B_13                0.136           12.299                                                                      │
# │ B_17               -0.637            5.678                                                                      │
# │ CD4_3               0.263           13.965                                                                      │
# │ CD4_4               1.312           39.867                                                                      │
# │ CD4_6               1.005           29.328                                                                      │
# │ CD4_8               0.161           12.611                                                                      │
# │ CD4_10              0.478           17.315                                                                      │
# │ CD4_11              0.346           15.174                                                                      │
# │ CD4_15             -0.179            8.976                                                                      │
# │ CD4_16             -0.378            7.356                                                                      │
# │ CD8_0              -0.712            5.267                                                                      │
# │ CD8_1              -0.469            6.716                                                                      │
# │ CD8_7               0.230           13.512                                                                      │
# │ DC_12               0.855           25.243                                                                      │
# │ DC_14              -0.567            6.089                                                                      │
# │ DC_16              -0.703            5.315                                                                      │
# │ DOCK4+MØ_3          2.577          141.253                                                                      │
# │ DOCK4+MØ_9          1.551           50.631                                                                      │
# │ LYVE1+MØ_1          2.805          177.426                                                                      │
# │ LYVE1+MØ_2          2.510          132.099                                                                      │
# │ LYVE1+MØ_4          2.350          112.568                                                                      │
# │ LYVE1+MØ_8          1.795           64.622                                                                      │
# │ Mast_15            -0.683            5.422                                                                      │
# │ Monocytes_6         1.669           56.972                                                                      │
# │ Monocytes_11        1.106           32.445                                                                      │
# │ Monocytes_13       -0.046           10.253                                                                      │
# │ Monocytes_17       -0.882            4.444                                                                      │
# │ MØ_general_0        2.970          209.255                                                                      │
# │ MØ_general_7        1.747           61.593                                                                      │
# │ MØ_general_10       0.821           24.399                                                                      │
# │ NKT_14             -0.276            8.146                                                                      │
# │ NK_5                0.911           26.697                                                                      │
# │ Neutrophils_5       1.993           78.772                                                                      │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Effects                                                                                                         │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                                Final Parameter  Expected Sample  log2-fold change                               │
# │ Covariate       Cell Type                                                                                       │
# │ infectionT.MCMV B_2                 0.000           34.157            -0.149                                    │
# │                 B_9                 0.000           13.052            -0.149                                    │
# │                 B_12                0.000           11.941            -0.149                                    │
# │                 B_13                0.000           11.089            -0.149                                    │
# │                 B_17                0.000            5.119            -0.149                                    │
# │                 CD4_3               1.238           43.430             1.637                                    │
# │                 CD4_4              -0.456           22.792            -0.807                                    │
# │                 CD4_6               0.000           26.442            -0.149                                    │
# │                 CD4_8               0.843           26.425             1.067                                    │
# │                 CD4_10              0.000           15.611            -0.149                                    │
# │                 CD4_11              0.000           13.680            -0.149                                    │
# │                 CD4_15              0.000            8.093            -0.149                                    │
# │                 CD4_16              0.000            6.632            -0.149                                    │
# │                 CD8_0               2.308           47.755             3.180                                    │
# │                 CD8_1               2.141           51.528             2.940                                    │
# │                 CD8_7               0.889           29.648             1.134                                    │
# │                 DC_12               0.000           22.759            -0.149                                    │
# │                 DC_14               0.875           13.164             1.112                                    │
# │                 DC_16               0.000            4.792            -0.149                                    │
# │                 DOCK4+MØ_3          0.000          127.353            -0.149                                    │
# │                 DOCK4+MØ_9          0.000           45.648            -0.149                                    │
# │                 LYVE1+MØ_1          0.000          159.966            -0.149                                    │
# │                 LYVE1+MØ_2          0.000          119.100            -0.149                                    │
# │                 LYVE1+MØ_4          0.000          101.490            -0.149                                    │
# │                 LYVE1+MØ_8          0.000           58.263            -0.149                                    │
# │                 Mast_15             0.000            4.889            -0.149                                    │
# │                 Monocytes_6         0.000           51.365            -0.149                                    │
# │                 Monocytes_11        0.000           29.252            -0.149                                    │
# │                 Monocytes_13        0.000            9.244            -0.149                                    │
# │                 Monocytes_17        0.000            4.007            -0.149                                    │
# │                 MØ_general_0        0.000          188.663            -0.149                                    │
# │                 MØ_general_7        0.000           55.532            -0.149                                    │
# │                 MØ_general_10       0.000           21.998            -0.149                                    │
# │                 NKT_14              0.000            7.345            -0.149                                    │
# │                 NK_5                0.000           24.070            -0.149                                    │
# │                 Neutrophils_5       0.000           71.020            -0.149                                    │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Filter out credible effects

# %%
sccoda_model.credible_effects(sccoda_data, modality_key="coda")
# Out:
# Covariate          Cell Type
# infection[T.MCMV]  B_2              False
#                    B_9              False
#                    B_12             False
#                    B_13             False
#                    B_17             False
#                    CD4_3             True
#                    CD4_4             True
#                    CD4_6            False
#                    CD4_8             True
#                    CD4_10           False
#                    CD4_11           False
#                    CD4_15           False
#                    CD4_16           False
#                    CD8_0             True
#                    CD8_1             True
#                    CD8_7             True
#                    DC_12            False
#                    DC_14             True
#                    DC_16            False
#                    DOCK4+MØ_3       False
#                    DOCK4+MØ_9       False
#                    LYVE1+MØ_1       False
#                    LYVE1+MØ_2       False
#                    LYVE1+MØ_4       False
#                    LYVE1+MØ_8       False
#                    Mast_15          False
#                    Monocytes_6      False
#                    Monocytes_11     False
#                    Monocytes_13     False
#                    Monocytes_17     False
#                    MØ_general_0     False
#                    MØ_general_7     False
#                    MØ_general_10    False
#                    NKT_14           False
#                    NK_5             False
#                    Neutrophils_5    False
# Name: Final Parameter, dtype: bool

# %% [markdown]
# ##### Adjust the "false discovery rate"

# %%
#If needed adjust the 'false discovery rate' - default is 0.05, however when no effects are detected it can be incresed to up to 0.2
sccoda_model.set_fdr(sccoda_data, 0.2)
sccoda_model.credible_effects(sccoda_data, modality_key="coda")
# Out:
# Covariate          Cell Type
# infection[T.MCMV]  B_2              False
#                    B_9              False
#                    B_12             False
#                    B_13             False
#                    B_17             False
#                    CD4_3             True
#                    CD4_4             True
#                    CD4_6             True
#                    CD4_8             True
#                    CD4_10           False
#                    CD4_11            True
#                    CD4_15           False
#                    CD4_16           False
#                    CD8_0             True
#                    CD8_1             True
#                    CD8_7             True
#                    DC_12            False
#                    DC_14             True
#                    DC_16            False
#                    DOCK4+MØ_3       False
#                    DOCK4+MØ_9       False
#                    LYVE1+MØ_1       False
#                    LYVE1+MØ_2       False
#                    LYVE1+MØ_4       False
#                    LYVE1+MØ_8       False
#                    Mast_15          False
#                    Monocytes_6      False
#                    Monocytes_11     False
#                    Monocytes_13     False
#                    Monocytes_17     False
#                    MØ_general_0     False
#                    MØ_general_7     False
#                    MØ_general_10    False
#                    NKT_14           False
#                    NK_5              True
#                    Neutrophils_5    False
# Name: Final Parameter, dtype: bool

# %%
pt.pl.coda.effects_barplot(sccoda_data, modality_key="coda", parameter="Final Parameter")

# %%
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 44616 × 29414
#   2 modalities
#     rna:	44586 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification', 'lineage'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'neighbors', 'umap'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     coda:	30 x 36
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'
#       uns:	'scCODA_params'
#       obsm:	'covariate_matrix', 'sample_counts'
#       varm:	'intercept_df', 'effect_df_infection[T.MCMV]'

# %%
sccoda_data["coda"].varm["effect_df_infection[T.MCMV]"]
# Out:
#                Final Parameter  HDI 3%  HDI 97%     SD  Inclusion probability  \
# Cell Type
# B_2                   0.000000  -0.362    0.272  0.083                 0.2309
# B_9                   0.000000  -0.419    0.545  0.138                 0.2824
# B_12                  0.000000  -0.555    0.428  0.134                 0.2820
# B_13                  0.000000  -0.822    0.233  0.207                 0.3647
# B_17                  0.000000  -0.583    0.602  0.173                 0.3086
# CD4_3                 1.238193   0.752    1.730  0.249                 1.0000
# CD4_4                -0.455564  -0.789    0.003  0.270                 0.7565
# CD4_6                -0.272972  -0.696    0.085  0.201                 0.4230
# CD4_8                 0.843348   0.317    1.380  0.281                 0.9929
# CD4_10                0.000000  -0.705    0.229  0.174                 0.3464
# CD4_11               -0.343809  -0.897    0.109  0.262                 0.4680
# CD4_15                0.000000   0.000    0.000  0.000                 0.0000
# CD4_16                0.000000  -0.565    0.588  0.162                 0.2988
# CD8_0                 2.308117   1.746    2.874  0.299                 1.0000
# CD8_1                 2.141155   1.593    2.670  0.283                 1.0000
# CD8_7                 0.889417   0.386    1.383  0.259                 0.9974
# DC_12                 0.000000  -0.314    0.479  0.108                 0.2522
# DC_14                 0.874530   0.232    1.500  0.376                 0.9438
# DC_16                 0.000000  -0.548    0.687  0.176                 0.3099
# DOCK4+MØ_3            0.000000  -0.230    0.133  0.045                 0.1871
# DOCK4+MØ_9            0.000000  -0.510    0.099  0.134                 0.3237
# LYVE1+MØ_1            0.000000  -0.093    0.243  0.040                 0.1812
# LYVE1+MØ_2            0.000000  -0.252    0.139  0.053                 0.1994
# LYVE1+MØ_4            0.000000  -0.105    0.326  0.065                 0.2160
# LYVE1+MØ_8            0.000000  -0.271    0.223  0.058                 0.2003
# Mast_15               0.000000  -0.553    0.630  0.173                 0.3185
# Monocytes_6           0.000000  -0.252    0.294  0.064                 0.2057
# Monocytes_11          0.000000  -0.363    0.337  0.090                 0.2416
# Monocytes_13          0.000000  -0.832    0.261  0.215                 0.3737
# Monocytes_17          0.000000  -0.711    0.558  0.197                 0.3456
# MØ_general_0          0.000000  -0.086    0.219  0.040                 0.1768
# MØ_general_7          0.000000  -0.498    0.088  0.141                 0.3640
# MØ_general_10         0.000000  -0.327    0.492  0.114                 0.2722
# NKT_14                0.000000  -0.660    0.478  0.162                 0.3039
# NK_5                  0.330478  -0.048    0.763  0.236                 0.5233
# Neutrophils_5         0.000000  -0.367    0.099  0.075                 0.2359
#
#                Expected Sample  log2-fold change
# Cell Type
# B_2                  34.176889         -0.148605
# B_9                  13.059941         -0.148605
# B_12                 11.947830         -0.148605
# B_13                 11.095611         -0.148605
# B_17                  5.122024         -0.148605
# CD4_3                43.455734          1.637730
# CD4_4                22.805123         -0.805845
# CD4_6                20.137368         -0.542421
# CD4_8                26.440515          1.068089
# CD4_10               15.619961         -0.148605
# CD4_11                9.705964         -0.644616
# CD4_15                8.097454         -0.148605
# CD4_16                6.636267         -0.148605
# CD8_0                47.782843          3.181304
# CD8_1                51.557847          2.940429
# CD8_7                29.664968          1.134553
# DC_12                22.772408         -0.148605
# DC_14                13.171826          1.113076
# DC_16                 4.794885         -0.148605
# DOCK4+MØ_3          127.427763         -0.148605
# DOCK4+MØ_9           45.674933         -0.148605
# LYVE1+MØ_1          160.060143         -0.148605
# LYVE1+MØ_2          119.169833         -0.148605
# LYVE1+MØ_4          101.549833         -0.148605
# LYVE1+MØ_8           58.296942         -0.148605
# Mast_15               4.891748         -0.148605
# Monocytes_6          51.395450         -0.148605
# Monocytes_11         29.269606         -0.148605
# Monocytes_13          9.249316         -0.148605
# Monocytes_17          4.009031         -0.148605
# MØ_general_0        188.773832         -0.148605
# MØ_general_7         55.564785         -0.148605
# MØ_general_10        22.011161         -0.148605
# NKT_14                7.348893         -0.148605
# NK_5                 33.516159          0.328174
# Neutrophils_5        71.061780         -0.148605

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=sccoda_data["coda"].varm["effect_df_infection[T.MCMV]"], x="Cell Type", y="log2-fold change", hue="Cell Type")
plt.xticks(rotation=90)
plt.show()

# %%
pt.pl.coda.effects_barplot(sccoda_data, "coda", "infection")
plt.show()
