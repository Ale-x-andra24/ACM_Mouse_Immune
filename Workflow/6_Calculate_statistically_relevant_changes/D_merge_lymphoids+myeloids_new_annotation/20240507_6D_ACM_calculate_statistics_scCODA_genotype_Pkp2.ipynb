# %% [markdown]
# # Compositional analysis of the ACM cardiac leucocytes 6mpi dataset (Pkp2+Ttn) - myeloids - using scCoda `pertpy`:
# - **Developed by**: Christian Eger
# - **Modified by**: Alexandra Cirnu
# - **Talavera-López Lab - Würzburg Institute for Systems Immunology - Faculty of Medicine - Julius Maximilian Universität Würzburg**
# - **Created on**: 231214
# - **Last modified**: 240509

# %% [markdown]
# #### Environment: scCoda
#
# To install `pertpy` on MacOS create a new mamba environment and activte it. Then go int 'github' folder and type 'git clone https://github.com/theislab/pertpy.git'. Change directory to 'pertpy' and type 'pip install .'
#
# Look at website to solve problem at the end: https://www.sc-best-practices.org/conditions/compositional.html

# %%
import warnings
import pandas as pd
warnings.filterwarnings("ignore")
warnings.simplefilter("ignore")
import numpy as np
            #import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import altair as alt
import scanpy as sc
import pertpy as pt
from statannot import add_stat_annotation
from scipy import stats
import muon as mu
from muon import atac as ac
from muon import prot

# %%
sc.logging.print_versions()
# Out:
# -----
# anndata     0.10.5.post1
# scanpy      1.9.8
# -----
# PIL                         10.2.0
# absl                        NA
# adjustText                  1.0.4
# altair                      4.2.2
# arrow                       1.3.0
# arviz                       0.17.0
# asttokens                   NA
# attr                        23.2.0
# attrs                       23.2.0
# blitzgsea                   NA
# certifi                     2024.02.02
# cffi                        1.16.0
# chardet                     5.2.0
# charset_normalizer          3.3.2
# chex                        0.1.85
# colorama                    0.4.6
# comm                        0.2.1
# contextlib2                 NA
# custom_inherit              2.4.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.9.0
# debugpy                     1.8.1
# decorator                   5.1.1
# decoupler                   1.6.0
# docrep                      0.3.2
# entrypoints                 0.4
# etils                       1.7.0
# exceptiongroup              1.2.0
# executing                   2.0.1
# flax                        0.8.1
# fsspec                      2024.2.0
# h5py                        3.10.0
# idna                        3.6
# igraph                      0.11.4
# importlib_resources         NA
# ipykernel                   6.29.3
# ipywidgets                  8.1.2
# jax                         0.4.25
# jaxlib                      0.4.25
# jaxopt                      NA
# jedi                        0.19.1
# jinja2                      3.1.3
# joblib                      1.3.2
# jsonschema                  4.21.1
# jsonschema_specifications   NA
# kiwisolver                  1.4.5
# leidenalg                   0.10.2
# lightning                   2.1.4
# lightning_fabric            2.2.0.post0
# lightning_utilities         0.10.1
# llvmlite                    0.42.0
# markupsafe                  2.1.5
# matplotlib                  3.8.3
# matplotlib_inline           0.1.6
# ml_collections              NA
# ml_dtypes                   0.3.2
# mpl_toolkits                NA
# mpmath                      1.3.0
# msgpack                     1.0.8
# mudata                      0.2.3
# multipledispatch            0.6.0
# muon                        0.1.5
# natsort                     8.4.0
# numba                       0.59.0
# numpy                       1.26.4
# numpyro                     0.14.0
# opt_einsum                  v3.3.0
# optax                       0.1.9
# ott                         0.4.5
# packaging                   23.2
# pandas                      2.2.1
# parso                       0.8.3
# patsy                       0.5.6
# pertpy                      0.7.0
# pkg_resources               NA
# platformdirs                4.2.0
# ply                         3.11
# png                         0.20220715.0
# prompt_toolkit              3.0.43
# psutil                      5.9.8
# pubchempy                   1.0.4
# pure_eval                   0.2.2
# pyarrow                     15.0.0
# pycparser                   2.21
# pydev_ipython               NA
# pydevconsole                NA
# pydevd                      2.9.5
# pydevd_file_utils           NA
# pydevd_plugins              NA
# pydevd_tracing              NA
# pygments                    2.17.2
# pynndescent                 0.5.11
# pyomo                       6.7.1
# pyparsing                   3.1.1
# pyro                        1.9.0
# pytorch_lightning           2.2.0.post0
# pytz                        2024.1
# referencing                 NA
# reportlab                   4.1.0
# requests                    2.31.0
# rich                        NA
# rpds                        NA
# rpy2                        3.5.11
# scipy                       1.12.0
# scvi                        1.1.2
# seaborn                     0.13.2
# session_info                1.0.0
# six                         1.16.0
# sklearn                     1.4.1.post1
# skmisc                      0.3.1
# sparsecca                   0.3.1
# stack_data                  0.6.3
# statannot                   0.2.3
# statsmodels                 0.14.1
# texttable                   1.7.0
# threadpoolctl               3.3.0
# toolz                       0.12.1
# torch                       2.2.1+cu121
# torchgen                    NA
# torchmetrics                1.3.1
# tornado                     6.4
# toyplot                     1.0.3
# toytree                     2.0.1
# tqdm                        4.66.2
# traitlets                   5.14.1
# typing_extensions           NA
# tzlocal                     NA
# umap                        0.5.5
# urllib3                     2.2.1
# vscode                      NA
# wcwidth                     0.2.13
# xarray                      2024.2.0
# xarray_einstats             0.7.0
# yaml                        6.0.1
# zmq                         25.1.2
# zoneinfo                    NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.0
# jupyter_core        5.7.1
# -----
# Python 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# Linux-6.9.7-100.fc39.x86_64-x86_64-with-glibc2.38
# -----
# Session information updated at 2024-07-29 12:46

# %% [markdown]
# Manual git installation of pertpy necessary due to Apple silicon
# $ git clone https://github.com/theislab/pertpy.git
# $ cd pertpy
# $ pip install .

# %%
input = '/home/acirnu/github/ACM_Mouse_Immune/Workflow/5_Leiden_clustering+annotation_on_all_conditions/C_merge_lymphoids+myeloids/ACM_annotated_muon_ac240727.raw.h5mu'
mdata_data = mu.read_h5mu(input)
mdata_data
# Out:
# MuData object with n_obs × n_vars = 44586 × 29477
#   var:	'gene_ids', 'feature_types'
#   2 modalities
#     rna:	44586 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'leiden', 'classification', 'phenotype', 'annotation', 'lineage', 'general_celltype'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       obsm:	'X_pca', 'X_scANVI', 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs'
#       obsp:	'connectivities', 'distances'
#     prot:	44586 x 99
#       obs:	'library', 'batch', 'lineage'
#       var:	'gene_ids', 'feature_types'
#       uns:	'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap'
#       varm:	'PCs'
#       layers:	'counts', 'log_norm'

# %%
adata = mdata_data.mod["rna"]
adata = adata[adata.obs['model'].isin(["Pkp2"]) , :]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 30280 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'sample', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'leiden', 'classification', 'phenotype', 'annotation', 'lineage', 'general_celltype'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo'
#     obsm: 'X_pca', 'X_scANVI', 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#                       cell_source              donor  n_counts  \
# AAACGCTGTTGTGTTG-1-A1   AG_Gerull  Pkp2_Ctr_noninf_1     478.0
# AAACGCTTCTCGCTCA-1-A1   AG_Gerull  Pkp2_Ctr_noninf_1    3581.0
# AAAGGTACAGAACATA-1-A1   AG_Gerull  Pkp2_Ctr_noninf_2   16539.0
# AAAGTCCAGGGACACT-1-A1   AG_Gerull  Pkp2_Ctr_noninf_2   13389.0
# AAAGTCCCAGTAGGAC-1-A1   AG_Gerull  Pkp2_Ctr_noninf_2   12092.0
# ...                           ...                ...       ...
# TTTGATCAGCGGGTTA-1-A4   AG_Gerull    Pkp2_Ctr_MCMV_5    4524.0
# TTTGATCTCTCGCCTA-1-A4   AG_Gerull  Pkp2_HetKO_MCMV_5   17569.0
# TTTGGAGAGATGCGAC-1-A4   AG_Gerull  Pkp2_HetKO_MCMV_5     569.0
# TTTGGAGAGGACGCTA-1-A4   AG_Gerull  Pkp2_HetKO_MCMV_5    7031.0
# TTTGGAGTCTATTGTC-1-A4   AG_Gerull    Pkp2_Ctr_MCMV_6    6782.0
#
#                                   sample        condition    genotype  \
# AAACGCTGTTGTGTTG-1-A1  Pkp2_Ctr_noninf_1  Pkp2_Ctr_noninf    Pkp2_Ctr
# AAACGCTTCTCGCTCA-1-A1  Pkp2_Ctr_noninf_1  Pkp2_Ctr_noninf    Pkp2_Ctr
# AAAGGTACAGAACATA-1-A1  Pkp2_Ctr_noninf_2  Pkp2_Ctr_noninf    Pkp2_Ctr
# AAAGTCCAGGGACACT-1-A1  Pkp2_Ctr_noninf_2  Pkp2_Ctr_noninf    Pkp2_Ctr
# AAAGTCCCAGTAGGAC-1-A1  Pkp2_Ctr_noninf_2  Pkp2_Ctr_noninf    Pkp2_Ctr
# ...                                  ...              ...         ...
# TTTGATCAGCGGGTTA-1-A4    Pkp2_Ctr_MCMV_5    Pkp2_Ctr_MCMV    Pkp2_Ctr
# TTTGATCTCTCGCCTA-1-A4  Pkp2_HetKO_MCMV_5  Pkp2_HetKO_MCMV  Pkp2_HetKO
# TTTGGAGAGATGCGAC-1-A4  Pkp2_HetKO_MCMV_5  Pkp2_HetKO_MCMV  Pkp2_HetKO
# TTTGGAGAGGACGCTA-1-A4  Pkp2_HetKO_MCMV_5  Pkp2_HetKO_MCMV  Pkp2_HetKO
# TTTGGAGTCTATTGTC-1-A4    Pkp2_Ctr_MCMV_6    Pkp2_Ctr_MCMV    Pkp2_Ctr
#
#                       infection library model  n_genes_by_counts  ...  \
# AAACGCTGTTGTGTTG-1-A1    noninf      A1  Pkp2              365.0  ...
# AAACGCTTCTCGCTCA-1-A1    noninf      A1  Pkp2             1599.0  ...
# AAAGGTACAGAACATA-1-A1    noninf      A1  Pkp2             3854.0  ...
# AAAGTCCAGGGACACT-1-A1    noninf      A1  Pkp2             3788.0  ...
# AAAGTCCCAGTAGGAC-1-A1    noninf      A1  Pkp2             3493.0  ...
# ...                         ...     ...   ...                ...  ...
# TTTGATCAGCGGGTTA-1-A4      MCMV      A4  Pkp2             1699.0  ...
# TTTGATCTCTCGCCTA-1-A4      MCMV      A4  Pkp2             4270.0  ...
# TTTGGAGAGATGCGAC-1-A4      MCMV      A4  Pkp2              424.0  ...
# TTTGGAGAGGACGCTA-1-A4      MCMV      A4  Pkp2             2463.0  ...
# TTTGGAGTCTATTGTC-1-A4      MCMV      A4  Pkp2             2162.0  ...
#
#                        G2M_score  _scvi_batch  _scvi_labels      batch  \
# AAACGCTGTTGTGTTG-1-A1  -0.083225            6             8  reference
# AAACGCTTCTCGCTCA-1-A1  -0.390143            6             8  reference
# AAAGGTACAGAACATA-1-A1  -0.578955            7             6  reference
# AAAGTCCAGGGACACT-1-A1  -0.370084            7            10  reference
# AAAGTCCCAGTAGGAC-1-A1  -0.357287            7            10  reference
# ...                          ...          ...           ...        ...
# TTTGATCAGCGGGTTA-1-A4  -0.064866            4            29      query
# TTTGATCTCTCGCCTA-1-A4  -0.076327           14            27      query
# TTTGGAGAGATGCGAC-1-A4  -0.146335           14            29      query
# TTTGGAGAGGACGCTA-1-A4  -0.416546           14            21      query
# TTTGGAGTCTATTGTC-1-A4  -0.217023            5            29      query
#
#                        leiden   classification          phenotype  \
# AAACGCTGTTGTGTTG-1-A1       3        MØ_Elmo1+   pro-inflammatory
# AAACGCTTCTCGCTCA-1-A1       3        MØ_Elmo1+   pro-inflammatory
# AAAGGTACAGAACATA-1-A1       6  Mono_Cd14+Ly6c+   pro-inflammatory
# AAAGTCCAGGGACACT-1-A1       2   MØ_Mertk+Il10+  anti-inflammatory
# AAAGTCCCAGTAGGAC-1-A1       2   MØ_Mertk+Il10+  anti-inflammatory
# ...                       ...              ...                ...
# TTTGATCAGCGGGTTA-1-A4       1     Tem/Trm-Cd8+   pro-inflammatory
# TTTGATCTCTCGCCTA-1-A4       9             cDC2   pro-inflammatory
# TTTGGAGAGATGCGAC-1-A4       3         Th1_Cd4+   pro-inflammatory
# TTTGGAGAGGACGCTA-1-A4       7         Tem_Cd8+   pro-inflammatory
# TTTGGAGTCTATTGTC-1-A4       0     Tem/Trm-Cd8+   pro-inflammatory
#
#                             annotation   lineage  general_celltype
# AAACGCTGTTGTGTTG-1-A1        MØ_Elmo1+   myeloid         Dock4+_MØ
# AAACGCTTCTCGCTCA-1-A1        MØ_Elmo1+   myeloid         Dock4+_MØ
# AAAGGTACAGAACATA-1-A1  Mono_Cd14+Ly6c+   myeloid          Monocyte
# AAAGTCCAGGGACACT-1-A1   MØ_Mertk+Il10+   myeloid        MØ_general
# AAAGTCCCAGTAGGAC-1-A1   MØ_Mertk+Il10+   myeloid        MØ_general
# ...                                ...       ...               ...
# TTTGATCAGCGGGTTA-1-A4     Tem/Trm-Cd8+  lymphoid        Cd8_T_cell
# TTTGATCTCTCGCCTA-1-A4             cDC2   myeloid                DC
# TTTGGAGAGATGCGAC-1-A4         Th1_Cd4+  lymphoid        Cd4_T_cell
# TTTGGAGAGGACGCTA-1-A4         Tem_Cd8+  lymphoid        Cd8_T_cell
# TTTGGAGTCTATTGTC-1-A4     Tem/Trm-Cd8+  lymphoid        Cd8_T_cell
#
# [30280 rows x 30 columns]

# %%
new_order_genotype = ['Pkp2_Ctr', 'Pkp2_HetKO']
adata.obs["genotype"] = adata.obs["genotype"].cat.reorder_categories(new_order_genotype, ordered=True)

adata.obs["genotype"].cat.categories
# Out:
# Index(['Pkp2_Ctr', 'Pkp2_HetKO'], dtype='object')

# %%
new_order_infection = ['noninf', 'MCMV']
adata.obs["infection"] = adata.obs["infection"].cat.reorder_categories(new_order_infection, ordered=True)

adata.obs["infection"].cat.categories
# Out:
# Index(['noninf', 'MCMV'], dtype='object')

# %%
new_order_condition = ['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV', 'Pkp2_HetKO_MCMV']
adata.obs["condition"] = adata.obs["condition"].cat.reorder_categories(new_order_condition, ordered=True)

adata.obs["condition"].cat.categories
# Out:
# Index(['Pkp2_Ctr_noninf', 'Pkp2_HetKO_noninf', 'Pkp2_Ctr_MCMV',
#        'Pkp2_HetKO_MCMV'],
#       dtype='object')

# %% [markdown]
# create notebook for every compartment and compare across cell states
# visualization improvement
# reference to ctrl healthy

# %%
sccoda_model = pt.tl.Sccoda()
sccoda_data = sccoda_model.load(
    adata,
    type="cell_level",
    generate_sample_level=True,
    cell_type_identifier="annotation",
    sample_identifier="sample",
    covariate_obs=["genotype", "infection", "condition"],
)
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 30300 × 29407
#   2 modalities
#     rna:	30280 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'leiden', 'classification', 'phenotype', 'annotation', 'lineage', 'general_celltype'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       obsm:	'X_pca', 'X_scANVI', 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs'
#       obsp:	'connectivities', 'distances'
#     coda:	20 x 29
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="genotype",
    y_scale="count",
    figsize=(30, 20),
    add_dots=False,
    args_swarmplot={"palette": ["red"]},
)
plt.savefig("/home/acirnu/github/ACM_Mouse_Immune/Workflow/6_Calculate_statistically_relevant_changes/D_merge_lymphoids+myeloids_new_annotation/scCODA_genotype_Pkp2_combined_barplot.png", format='png')
plt.show()

# %%
pt.pl.coda.boxplots(
    sccoda_data,
    modality_key="coda",
    feature_name="genotype",
    plot_facets=True,
    y_scale="log",
    add_dots=True,
    cmap="Reds",
)
plt.xticks(rotation=90)
plt.savefig("/home/acirnu/github/ACM_Mouse_Immune/Workflow/6_Calculate_statistically_relevant_changes/D_merge_lymphoids+myeloids_new_annotation/scCODA_genotype_Pkp2_single_barplots.png", format='png')
plt.show()

# %%
pt.pl.coda.stacked_barplot(
    sccoda_data, modality_key="coda", feature_name="genotype", figsize=(15, 9) 
)
plt.legend(ncol=3, loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
sccoda_data = sccoda_model.prepare(
    sccoda_data,
    modality_key="coda",
    formula="genotype",
    reference_cell_type="automatic",
)
sccoda_data["coda"]
# Out:
# Automatic reference selection! Reference cell type set to pDC
# Zero counts encountered in data! Added a pseudocount of 0.5.
# AnnData object with n_obs × n_vars = 20 × 29
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'

# %% [markdown]
# Run No-U-turn HMC sampling (nuts)

# %%
sccoda_model.run_nuts(sccoda_data, modality_key="coda", rng_key=1234)
# Out:
# sample: 100%|██████████| 11000/11000 [03:08<00:00, 58.25it/s, 255 steps of size 1.23e-02. acc. prob=0.94]

# %%
sccoda_data["coda"]
# Out:
# AnnData object with n_obs × n_vars = 20 × 29
#     obs: 'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#     var: 'n_cells'
#     uns: 'scCODA_params'
#     obsm: 'covariate_matrix', 'sample_counts'
#     varm: 'intercept_df', 'effect_df_genotype[T.Pkp2_HetKO]'

# %% [markdown]
# #### Result interpreteation

# %% [markdown]
# **Intercepts**
#
# The first column of the intercept summary shows the parameters determined by the MCMC inference.
#
# The “Expected sample” column gives some context to the numerical values. If we had a new sample (with no active covariates) with a total number of cells equal to the mean sampling depth of the dataset, then this distribution over the cell types would be most likely.
#
# **Effects**
#
# For the effect summary, the first column again shows the inferred parameters for all combinations of covariates and cell types. Most important is the distinctions between zero and non-zero entries A value of zero means that no statistically credible effect was detected. For a value other than zero, a credible change was detected. A positive sign indicates an increase, a negative sign a decrease in abundance.
#
# Since the numerical values of the “Final Parameter” column are not straightforward to interpret, the “Expected sample” and “log2-fold change” columns give us an idea on the magnitude of the change. The expected sample is calculated for each covariate separately (covariate value = 1, all other covariates = 0), with the same method as for the intercepts. The log-fold change is then calculated between this expected sample and the expected sample with no active covariates from the intercept section. Since the data is compositional, cell types for which no credible change was detected, can still change in abundance as well, as soon as a credible effect is detected on another cell type due to the sum-to-one constraint. If there are no credible effects for a covariate, its expected sample will be identical to the intercept sample, therefore the log2-fold change is 0.

# %%
sccoda_model.summary(sccoda_data, modality_key= "coda")
# Out:
#                                           Compositional Analysis summary
# ┌────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────┐
# │ Name                                       │ Value                                                              │
# ├────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────┤
# │ Data                                       │ Data: 20 samples, 29 cell types                                    │
# │ Reference cell type                        │ pDC                                                                │
# │ Formula                                    │ genotype                                                           │
# └────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Intercepts                                                                                                      │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                   Final Parameter  Expected Sample                                                              │
# │ Cell Type                                                                                                       │
# │ B                      0.060           13.205                                                                   │
# │ B-1a                  -0.173           10.460                                                                   │
# │ DCmigr                -0.620            6.690                                                                   │
# │ DCmono-derived         0.965           32.641                                                                   │
# │ ILC2                   0.101           13.757                                                                   │
# │ Mast                  -0.915            4.981                                                                   │
# │ Mono_Cd14+Ly6c+        1.190           40.878                                                                   │
# │ Mono_Cd16+            -0.294            9.268                                                                   │
# │ MØ_Elmo1+              2.477          148.055                                                                   │
# │ MØ_MHC-II+Ccl3+        2.212          113.588                                                                   │
# │ MØ_Mertk+Il10+         2.537          157.210                                                                   │
# │ MØ_Rentla+Il10+        1.706           68.483                                                                   │
# │ MØ_Stab1+              1.310           46.089                                                                   │
# │ MØ_Tgfb1+Il1b+         2.873          219.990                                                                   │
# │ MØtr_Spp1+Trem2+       0.707           25.219                                                                   │
# │ MØtr_TLF+              2.661          177.964                                                                   │
# │ NK                     0.923           31.299                                                                   │
# │ NKT                   -0.016           12.238                                                                   │
# │ Neutrophil             1.762           72.427                                                                   │
# │ Teff_Cd8               0.075           13.404                                                                   │
# │ Tem/Trm-Cd8+           1.185           40.674                                                                   │
# │ Tem_Cd8+               1.333           47.162                                                                   │
# │ Th1_Cd4+               1.414           51.141                                                                   │
# │ Th17_Cd4+              1.134           38.651                                                                   │
# │ Treg                  -0.541            7.240                                                                   │
# │ cDC1                   1.069           36.219                                                                   │
# │ cDC2                   0.256           16.064                                                                   │
# │ pDC                    0.613           22.956                                                                   │
# │ γδT                    1.078           36.546                                                                   │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# ┌─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Effects                                                                                                         │
# ├─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │                                        Final Parameter  Expected Sample  log2-fold change                       │
# │ Covariate            Cell Type                                                                                  │
# │ genotypeT.Pkp2_HetKO B                      0.000           11.233            -0.233                            │
# │                      B-1a                   0.000            8.898            -0.233                            │
# │                      DCmigr                 0.000            5.691            -0.233                            │
# │                      DCmono-derived         0.753           58.967             0.853                            │
# │                      ILC2                   0.000           11.703            -0.233                            │
# │                      Mast                   0.000            4.237            -0.233                            │
# │                      Mono_Cd14+Ly6c+        0.736           72.598             0.829                            │
# │                      Mono_Cd16+             0.000            7.884            -0.233                            │
# │                      MØ_Elmo1+              0.000          125.946            -0.233                            │
# │                      MØ_MHC-II+Ccl3+        0.791          213.029             0.907                            │
# │                      MØ_Mertk+Il10+         0.000          133.734            -0.233                            │
# │                      MØ_Rentla+Il10+        0.000           58.256            -0.233                            │
# │                      MØ_Stab1+              0.000           39.207            -0.233                            │
# │                      MØ_Tgfb1+Il1b+         0.000          187.139            -0.233                            │
# │                      MØtr_Spp1+Trem2+       1.338           81.760             1.697                            │
# │                      MØtr_TLF+             -0.361          105.534            -0.754                            │
# │                      NK                     0.000           26.625            -0.233                            │
# │                      NKT                    0.000           10.411            -0.233                            │
# │                      Neutrophil             0.000           61.612            -0.233                            │
# │                      Teff_Cd8               0.000           11.403            -0.233                            │
# │                      Tem/Trm-Cd8+           0.000           34.600            -0.233                            │
# │                      Tem_Cd8+               0.000           40.119            -0.233                            │
# │                      Th1_Cd4+               0.000           43.504            -0.233                            │
# │                      Th17_Cd4+              0.000           32.880            -0.233                            │
# │                      Treg                   0.000            6.159            -0.233                            │
# │                      cDC1                   0.617           57.092             0.657                            │
# │                      cDC2                   0.000           13.665            -0.233                            │
# │                      pDC                    0.000           19.528            -0.233                            │
# │                      γδT                    0.000           31.089            -0.233                            │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Filter out credible effects

# %%
sccoda_model.credible_effects(sccoda_data, modality_key="coda")
# Out:
# Covariate               Cell Type
# genotype[T.Pkp2_HetKO]  B                   False
#                         B-1a                False
#                         DCmigr              False
#                         DCmono-derived       True
#                         ILC2                False
#                         Mast                False
#                         Mono_Cd14+Ly6c+      True
#                         Mono_Cd16+          False
#                         MØ_Elmo1+           False
#                         MØ_MHC-II+Ccl3+      True
#                         MØ_Mertk+Il10+      False
#                         MØ_Rentla+Il10+     False
#                         MØ_Stab1+           False
#                         MØ_Tgfb1+Il1b+      False
#                         MØtr_Spp1+Trem2+     True
#                         MØtr_TLF+            True
#                         NK                  False
#                         NKT                 False
#                         Neutrophil          False
#                         Teff_Cd8            False
#                         Tem/Trm-Cd8+        False
#                         Tem_Cd8+            False
#                         Th1_Cd4+            False
#                         Th17_Cd4+           False
#                         Treg                False
#                         cDC1                 True
#                         cDC2                False
#                         pDC                 False
#                         γδT                 False
# Name: Final Parameter, dtype: bool

# %%
pt.pl.coda.effects_barplot(sccoda_data, modality_key="coda", parameter="Final Parameter")

# %% [markdown]
# ##### Adjust the "false discovery rate"

# %% [raw]
# #If needed adjust the 'false discovery rate' - default is 0.05, however when no effects are detected it can be incresed to up to 0.2
# sccoda_model.set_fdr(sccoda_data, 0.2)
# sccoda_model.credible_effects(sccoda_data, modality_key="coda")

# %%
sccoda_data
# Out:
# MuData object with n_obs × n_vars = 30300 × 29407
#   2 modalities
#     rna:	30280 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'leiden', 'classification', 'phenotype', 'annotation', 'lineage', 'general_celltype'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       obsm:	'X_pca', 'X_scANVI', 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs'
#       obsp:	'connectivities', 'distances'
#     coda:	20 x 29
#       obs:	'cell_source', 'donor', 'condition', 'genotype', 'infection', 'model', '_scvi_batch', 'batch'
#       var:	'n_cells'
#       uns:	'scCODA_params'
#       obsm:	'covariate_matrix', 'sample_counts'
#       varm:	'intercept_df', 'effect_df_genotype[T.Pkp2_HetKO]'

# %%
sccoda_data["coda"].varm["effect_df_genotype[T.Pkp2_HetKO]"]
# Out:
#                   Final Parameter  HDI 3%  HDI 97%     SD  \
# Cell Type
# B                        0.000000  -0.917    0.235  0.284
# B-1a                     0.000000  -0.806    0.385  0.232
# DCmigr                   0.000000  -0.281    1.029  0.310
# DCmono-derived           0.753129   0.299    1.185  0.243
# ILC2                     0.000000  -0.478    0.648  0.190
# Mast                     0.000000  -0.739    0.590  0.229
# Mono_Cd14+Ly6c+          0.736092   0.324    1.147  0.219
# Mono_Cd16+               0.000000  -0.597    0.661  0.211
# MØ_Elmo1+                0.000000  -0.215    0.318  0.079
# MØ_MHC-II+Ccl3+          0.790578   0.497    1.079  0.149
# MØ_Mertk+Il10+           0.000000  -0.278    0.216  0.069
# MØ_Rentla+Il10+          0.000000  -0.333    0.337  0.098
# MØ_Stab1+                0.000000  -0.400    0.359  0.115
# MØ_Tgfb1+Il1b+           0.000000  -0.495    0.002  0.169
# MØtr_Spp1+Trem2+         1.337936   0.880    1.812  0.247
# MØtr_TLF+               -0.360816  -0.596    0.001  0.188
# NK                       0.000000  -0.462    0.445  0.134
# NKT                      0.000000  -0.882    0.317  0.262
# Neutrophil               0.000000  -0.481    0.183  0.127
# Teff_Cd8                 0.000000  -0.668    0.518  0.205
# Tem/Trm-Cd8+             0.000000  -0.635    0.263  0.173
# Tem_Cd8+                 0.000000  -0.343    0.471  0.129
# Th1_Cd4+                 0.000000  -0.390    0.398  0.119
# Th17_Cd4+                0.000000  -0.191    0.659  0.191
# Treg                     0.000000  -0.465    0.806  0.233
# cDC1                     0.616816   0.149    1.035  0.254
# cDC2                     0.000000  -0.006    1.142  0.363
# pDC                      0.000000   0.000    0.000  0.000
# γδT                      0.000000  -0.507    0.361  0.146
#
#                   Inclusion probability  Expected Sample  log2-fold change
# Cell Type
# B                                0.5248        11.232931         -0.233331
# B-1a                             0.4276         8.898206         -0.233331
# DCmigr                           0.5298         5.690794         -0.233331
# DCmono-derived                   0.9915        58.967037          0.853205
# ILC2                             0.3958        11.703053         -0.233331
# Mast                             0.4172         4.236976         -0.233331
# Mono_Cd14+Ly6c+                  0.9978        72.598297          0.828625
# Mono_Cd16+                       0.4127         7.884113         -0.233331
# MØ_Elmo1+                        0.2799       125.945558         -0.233331
# MØ_MHC-II+Ccl3+                  1.0000       213.028930          0.907233
# MØ_Mertk+Il10+                   0.2560       133.733597         -0.233331
# MØ_Rentla+Il10+                  0.3047        58.256154         -0.233331
# MØ_Stab1+                        0.3283        39.206782         -0.233331
# MØ_Tgfb1+Il1b+                   0.7292       187.138641         -0.233331
# MØtr_Spp1+Trem2+                 1.0000        81.759845          1.696904
# MØtr_TLF+                        0.8539       105.534025         -0.753879
# NK                               0.3294        26.624976         -0.233331
# NKT                              0.4894        10.410863         -0.233331
# Neutrophil                       0.3676        61.611574         -0.233331
# Teff_Cd8                         0.4208        11.402695         -0.233331
# Tem/Trm-Cd8+                     0.4088        34.599863         -0.233331
# Tem_Cd8+                         0.3439        40.118988         -0.233331
# Th1_Cd4+                         0.3312        43.503863         -0.233331
# Th17_Cd4+                        0.4441        32.879512         -0.233331
# Treg                             0.4344         6.158602         -0.233331
# cDC1                             0.9609        57.092090          0.656547
# cDC2                             0.8379        13.665163         -0.233331
# pDC                              0.0000        19.528008         -0.233331
# γδT                              0.3624        31.088866         -0.233331

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=sccoda_data["coda"].varm["effect_df_genotype[T.Pkp2_HetKO]"], x="Cell Type", y="log2-fold change", hue="Cell Type")
plt.xticks(rotation=90)
plt.savefig("/home/acirnu/github/ACM_Mouse_Immune/Workflow/6_Calculate_statistically_relevant_changes/D_merge_lymphoids+myeloids_new_annotation/scCODA_genotype_Pkp2.png", format='png')
plt.show()

# %%
pt.pl.coda.effects_barplot(sccoda_data, "coda", "genotype")
plt.show()
