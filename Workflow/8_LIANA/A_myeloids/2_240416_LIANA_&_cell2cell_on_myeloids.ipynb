# %% [markdown]
# ### Notebook for Intercellular Context Factorization using `LIANA` and `Tensor-Cell2cell`
#
# #### Environment: LIANA
#
# - **Developed by:** Alexandra Cirnu
# - **Modified by:** Alexandra Cirnu
# - **Würzburg Institute for Systems Immunology & Julius-Maximilian-Universität Würzburg**
# - **Date of creation:** 240426
# - **Date of modification:** 240426
#
# `Liana` works with log1p-transformed counts and uses **all genes** (with enough counts)

# %% [markdown]
# ### Load in required modules

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import scanpy as sc
import plotnine as p9
import liana as li
import cell2cell as c2c
import decoupler as dc # needed for pathway enrichment
import muon as mu
from muon import atac as ac
from muon import prot as pt
from scipy.sparse import csr_matrix

import warnings
warnings.filterwarnings('ignore')
from collections import defaultdict

# %matplotlib inline

# %%
# NOTE: to use CPU instead of GPU, set use_gpu = False
use_gpu = True

if use_gpu:
    import torch
    import tensorly as tl

    device = "cuda" if torch.cuda.is_available() else "cpu"
    if device == "cuda":
        tl.set_backend('pytorch')
else:
    device = "cpu"

device
# Out:
# 'cuda'

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()

sc.settings.set_figure_params(dpi = 300, color_map = 'RdPu', dpi_save = 300, vector_friendly = True, format = 'svg')
# Out:
# -----
# anndata     0.10.6
# scanpy      1.9.8
# -----
# PIL                 10.2.0
# asttokens           NA
# cell2cell           0.7.3
# colorama            0.4.6
# comm                0.2.2
# cycler              0.12.1
# cython_runtime      NA
# dateutil            2.9.0
# debugpy             1.8.1
# decorator           5.1.1
# decoupler           1.6.0
# docrep              0.3.2
# exceptiongroup      1.2.0
# executing           2.0.1
# h5py                3.10.0
# ipykernel           6.29.3
# ipywidgets          8.1.2
# jedi                0.19.1
# joblib              1.3.2
# kiwisolver          1.4.5
# kneed               0.8.5
# liana               1.0.5
# llvmlite            0.42.0
# matplotlib          3.8.3
# matplotlib_inline   0.1.6
# mizani              0.11.0
# mpl_toolkits        NA
# mudata              0.2.3
# muon                0.1.6
# natsort             8.4.0
# networkx            3.2.1
# numba               0.59.0
# numpy               1.26.4
# packaging           24.0
# pandas              2.2.1
# parso               0.8.3
# patsy               0.5.6
# pickleshare         0.7.5
# platformdirs        4.2.0
# plotnine            0.13.2
# prompt_toolkit      3.0.42
# psutil              5.9.8
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.17.2
# pynndescent         0.5.11
# pyparsing           3.1.2
# pytz                2024.1
# scipy               1.12.0
# seaborn             0.13.2
# session_info        1.0.0
# six                 1.16.0
# sklearn             1.4.1.post1
# stack_data          0.6.2
# statannotations     0.4.4
# statsmodels         0.14.1
# tensorly            0.8.1
# threadpoolctl       3.4.0
# torch               2.3.0
# torchgen            NA
# tornado             6.4
# tqdm                4.66.2
# traitlets           5.14.2
# typing_extensions   NA
# umap                0.5.5
# vscode              NA
# wcwidth             0.2.13
# yaml                6.0.1
# zmq                 25.1.2
# zoneinfo            NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.1
# jupyter_core        5.7.2
# -----
# Python 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# Linux-6.8.4-200.fc39.x86_64-x86_64-with-glibc2.38
# -----
# Session information updated at 2024-04-27 11:27

# %% [markdown]
# ### Load in the data set

# %%
input = '/home/acirnu/data/ACM_cardiac_leuco/5_Leiden_clustering_and_annotation/ACM_myeloids_clustered_muon_ac240415.raw.h5mu'
mdata = mu.read_h5mu(input)
mdata
# Out:
# MuData object with n_obs × n_vars = 34482 × 29477
#   var:	'gene_ids', 'feature_types'
#   2 modalities
#     rna:	34482 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'dendrogram_leiden', 'leiden_colors', 'log1p', 'rank_genes_groups'
#       obsm:	'X_pca', 'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     prot:	34482 x 99
#       obs:	'library', 'batch'
#       var:	'gene_ids', 'feature_types'
#       uns:	'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap'
#       varm:	'PCs'
#       layers:	'counts', 'log_norm'

# %%
adata = mdata.mod["rna"]

# %%
X_data = adata.X.copy()
X_data_sparse = csr_matrix(X_data)
X_data_df = pd.DataFrame.sparse.from_spmatrix(X_data_sparse, index=adata.obs.index, columns=adata.var.index)
print("Shape of counts DataFrame:", X_data_df.shape)
print(X_data_df)
# Out:
# Shape of counts DataFrame: (34482, 29378)
#                        Xkr4  Gm1992  Gm19938  Gm37381  Rp1  Sox17  Gm37587  \
# AAACGCTGTTGTGTTG-1-A1     0       0        0        0    0      0        0
# AAACGCTTCTCGCTCA-1-A1     0       0        0        0    0      0        0
# AAAGGTACAGAACATA-1-A1     0       0        0        0    0      0        0
# AAAGTCCAGGGACACT-1-A1     0       0        0        0    0      0        0
# AAAGTCCCAGTAGGAC-1-A1     0       0        0        0    0      0        0
# ...                     ...     ...      ...      ...  ...    ...      ...
# TTTGTTGAGGTTAGTA-1-B2     0       0        0        0    0      0        0
# TTTGTTGCAAGCTCTA-1-B2     0       0        0        0    0      0        0
# TTTGTTGGTACAGGTG-1-B2     0       0        0        0    0      0        0
# TTTGTTGTCCCAGGAC-1-B2     0       0        0        0    0      0        0
# TTTGTTGTCCGGGACT-1-B2     0       0        0        0    0      0        0
#
#                        Gm37323  Mrpl15  Lypla1  ...  Vmn2r122  Il11ra2-1  \
# AAACGCTGTTGTGTTG-1-A1        0       0       0  ...         0          0
# AAACGCTTCTCGCTCA-1-A1        0       0       0  ...         0          0
# AAAGGTACAGAACATA-1-A1        0       0     3.0  ...         0          0
# AAAGTCCAGGGACACT-1-A1        0     1.0     2.0  ...         0          0
# AAAGTCCCAGTAGGAC-1-A1        0       0       0  ...         0          0
# ...                        ...     ...     ...  ...       ...        ...
# TTTGTTGAGGTTAGTA-1-B2        0       0       0  ...         0          0
# TTTGTTGCAAGCTCTA-1-B2        0       0       0  ...         0          0
# TTTGTTGGTACAGGTG-1-B2        0       0     1.0  ...         0          0
# TTTGTTGTCCCAGGAC-1-B2        0       0       0  ...         0          0
# TTTGTTGTCCGGGACT-1-B2        0     1.0       0  ...         0          0
#
#                        Ccl27a-1  Ccl21c-1  Ccl27a-2  Il11ra2-2  Ccl19-1  \
# AAACGCTGTTGTGTTG-1-A1         0         0         0          0        0
# AAACGCTTCTCGCTCA-1-A1         0         0         0          0        0
# AAAGGTACAGAACATA-1-A1         0         0         0          0        0
# AAAGTCCAGGGACACT-1-A1         0         0         0          0        0
# AAAGTCCCAGTAGGAC-1-A1         0         0         0          0        0
# ...                         ...       ...       ...        ...      ...
# TTTGTTGAGGTTAGTA-1-B2         0         0         0          0        0
# TTTGTTGCAAGCTCTA-1-B2         0         0         0          0        0
# TTTGTTGGTACAGGTG-1-B2         0         0         0          0        0
# TTTGTTGTCCCAGGAC-1-B2         0         0         0          0        0
# TTTGTTGTCCGGGACT-1-B2         0         0         0          0        0
#
#                        Ccl21a-1  Gm10931  Gm16367
# AAACGCTGTTGTGTTG-1-A1         0        0        0
# AAACGCTTCTCGCTCA-1-A1         0        0        0
# AAAGGTACAGAACATA-1-A1         0        0        0
# AAAGTCCAGGGACACT-1-A1         0        0        0
# AAAGTCCCAGTAGGAC-1-A1         0        0        0
# ...                         ...      ...      ...
# TTTGTTGAGGTTAGTA-1-B2         0        0        0
# TTTGTTGCAAGCTCTA-1-B2         0        0        0
# TTTGTTGGTACAGGTG-1-B2         0        0        0
# TTTGTTGTCCCAGGAC-1-B2         0        0        0
# TTTGTTGTCCGGGACT-1-B2         0        0        0
#
# [34482 rows x 29378 columns]

# %%
adata_raw = adata.copy()

# %% [markdown]
# ### Normalize count matrix

# %%
sc.pp.normalize_total(adata, target_sum = 1e6, exclude_highly_expressed = True)
sc.pp.log1p(adata)
# Out:
# normalizing counts per cell The following highly-expressed genes are not considered during normalization factor computation:
# ['Mapkapk2', 'Il1b', 'Fabp5', 'Fabp4', 'S100a8', 'S100a9', 'Prdx1', 'Cxcl2', 'Spp1', 'Myl2', 'Actb', 'Igkc', 'Apoe', 'Ftl1', 'Hbb-bt', 'Hbb-bs', 'Camp', 'Ngp', 'Slc16a10', 'Lyz2', 'Hba-a1', 'Hba-a2', 'Ccl8', 'Ccl3', 'Ccl4', 'Ctla2a', 'Cma1', 'Mcpt4', 'Retnla', 'Retnlg', 'Cmss1', 'Gm26917', 'Gm42418', 'Cd74', 'Malat1', 'Fth1', 'Tmsb4x']
#     finished (0:00:00)
# WARNING: adata.X seems to be already log-transformed.

# %%
X_data = adata.X.copy()
X_data_sparse = csr_matrix(X_data)
X_data_df = pd.DataFrame.sparse.from_spmatrix(X_data_sparse, index=adata.obs.index, columns=adata.var.index)
print("Shape of counts DataFrame:", X_data_df.shape)
print(X_data_df)
# Out:
# Shape of counts DataFrame: (34482, 29378)
#                        Xkr4  Gm1992  Gm19938  Gm37381  Rp1  Sox17  Gm37587  \
# AAACGCTGTTGTGTTG-1-A1     0       0        0        0    0      0        0
# AAACGCTTCTCGCTCA-1-A1     0       0        0        0    0      0        0
# AAAGGTACAGAACATA-1-A1     0       0        0        0    0      0        0
# AAAGTCCAGGGACACT-1-A1     0       0        0        0    0      0        0
# AAAGTCCCAGTAGGAC-1-A1     0       0        0        0    0      0        0
# ...                     ...     ...      ...      ...  ...    ...      ...
# TTTGTTGAGGTTAGTA-1-B2     0       0        0        0    0      0        0
# TTTGTTGCAAGCTCTA-1-B2     0       0        0        0    0      0        0
# TTTGTTGGTACAGGTG-1-B2     0       0        0        0    0      0        0
# TTTGTTGTCCCAGGAC-1-B2     0       0        0        0    0      0        0
# TTTGTTGTCCGGGACT-1-B2     0       0        0        0    0      0        0
#
#                        Gm37323    Mrpl15    Lypla1  ...  Vmn2r122  Il11ra2-1  \
# AAACGCTGTTGTGTTG-1-A1        0         0         0  ...         0          0
# AAACGCTTCTCGCTCA-1-A1        0         0         0  ...         0          0
# AAAGGTACAGAACATA-1-A1        0         0  5.301714  ...         0          0
# AAAGTCCAGGGACACT-1-A1        0  4.473838  5.161267  ...         0          0
# AAAGTCCCAGTAGGAC-1-A1        0         0         0  ...         0          0
# ...                        ...       ...       ...  ...       ...        ...
# TTTGTTGAGGTTAGTA-1-B2        0         0         0  ...         0          0
# TTTGTTGCAAGCTCTA-1-B2        0         0         0  ...         0          0
# TTTGTTGGTACAGGTG-1-B2        0         0  3.947542  ...         0          0
# TTTGTTGTCCCAGGAC-1-B2        0         0         0  ...         0          0
# TTTGTTGTCCGGGACT-1-B2        0  4.844876         0  ...         0          0
#
#                        Ccl27a-1  Ccl21c-1  Ccl27a-2  Il11ra2-2  Ccl19-1  \
# AAACGCTGTTGTGTTG-1-A1         0         0         0          0        0
# AAACGCTTCTCGCTCA-1-A1         0         0         0          0        0
# AAAGGTACAGAACATA-1-A1         0         0         0          0        0
# AAAGTCCAGGGACACT-1-A1         0         0         0          0        0
# AAAGTCCCAGTAGGAC-1-A1         0         0         0          0        0
# ...                         ...       ...       ...        ...      ...
# TTTGTTGAGGTTAGTA-1-B2         0         0         0          0        0
# TTTGTTGCAAGCTCTA-1-B2         0         0         0          0        0
# TTTGTTGGTACAGGTG-1-B2         0         0         0          0        0
# TTTGTTGTCCCAGGAC-1-B2         0         0         0          0        0
# TTTGTTGTCCGGGACT-1-B2         0         0         0          0        0
#
#                        Ccl21a-1  Gm10931  Gm16367
# AAACGCTGTTGTGTTG-1-A1         0        0        0
# AAACGCTTCTCGCTCA-1-A1         0        0        0
# AAAGGTACAGAACATA-1-A1         0        0        0
# AAAGTCCAGGGACACT-1-A1         0        0        0
# AAAGTCCCAGTAGGAC-1-A1         0        0        0
# ...                         ...      ...      ...
# TTTGTTGAGGTTAGTA-1-B2         0        0        0
# TTTGTTGCAAGCTCTA-1-B2         0        0        0
# TTTGTTGGTACAGGTG-1-B2         0        0        0
# TTTGTTGTCCCAGGAC-1-B2         0        0        0
# TTTGTTGTCCGGGACT-1-B2         0        0        0
#
# [34482 rows x 29378 columns]

# %% [markdown]
# ### Run `LIANA` Ligand-Receptor Inference by Sample

# %% [markdown]
# Before we decompose the CCC patterns across contexts/samples with tensor_cell2cell, we need to run liana on each sample. This is because tensor_cell2cell uses LIANA’s output by sample to build a 4D tensor, that is later decomposed into CCC patterns.

# %%
li.mt.rank_aggregate.by_sample(
    adata, 
    groupby= 'classification',
    sample_key= 'sample',
    expr_prop= 0.1, 
    verbose= True, 
    use_raw= False, 
    resource_name= 'mouseconsensus',
    return_all_lrs=True, # return all LR values
    n_perms=None # exclude permutations for speed
    )
# Out:
# Now running: Pkp2_Ctr_MCMV_1:   0%|          | 0/30 [00:00<?, ?it/s]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_Ctr_MCMV_2:   3%|▎         | 1/30 [00:39<19:03, 39.44s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_Ctr_MCMV_3:   7%|▋         | 2/30 [01:29<21:27, 45.97s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_Ctr_MCMV_4:  10%|█         | 3/30 [01:51<15:35, 34.66s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_Ctr_MCMV_5:  13%|█▎        | 4/30 [02:05<11:35, 26.74s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_Ctr_MCMV_6:  17%|█▋        | 5/30 [02:34<11:22, 27.29s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_Ctr_noninf_1:  20%|██        | 6/30 [02:51<09:34, 23.94s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_Ctr_noninf_2:  23%|██▎       | 7/30 [03:13<08:54, 23.22s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_Ctr_noninf_3:  27%|██▋       | 8/30 [03:50<10:08, 27.66s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_Ctr_noninf_4:  30%|███       | 9/30 [04:07<08:30, 24.32s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_HetKO_MCMV_1:  33%|███▎      | 10/30 [04:41<09:07, 27.38s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_HetKO_MCMV_2:  37%|███▋      | 11/30 [05:33<11:02, 34.87s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_HetKO_MCMV_3:  40%|████      | 12/30 [06:38<13:13, 44.09s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_HetKO_MCMV_4:  43%|████▎     | 13/30 [07:33<13:22, 47.21s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_HetKO_MCMV_5:  47%|████▋     | 14/30 [08:42<14:21, 53.83s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_HetKO_MCMV_6:  50%|█████     | 15/30 [09:32<13:10, 52.67s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_HetKO_noninf_1:  53%|█████▎    | 16/30 [10:35<13:03, 55.96s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_HetKO_noninf_2:  57%|█████▋    | 17/30 [11:20<11:24, 52.62s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_HetKO_noninf_3:  60%|██████    | 18/30 [12:15<10:39, 53.32s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Pkp2_HetKO_noninf_4:  63%|██████▎   | 19/30 [12:40<08:14, 44.92s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Ttn_Ctr_MCMV_1:  67%|██████▋   | 20/30 [13:33<07:51, 47.13s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Ttn_Ctr_MCMV_2:  70%|███████   | 21/30 [13:57<06:02, 40.23s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Ttn_Ctr_MCMV_3:  73%|███████▎  | 22/30 [14:27<04:57, 37.16s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Ttn_Ctr_noninf_1:  77%|███████▋  | 23/30 [15:05<04:23, 37.60s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Ttn_Ctr_noninf_2:  80%|████████  | 24/30 [15:40<03:40, 36.77s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Ttn_HetKO_MCMV_1:  83%|████████▎ | 25/30 [16:21<03:10, 38.00s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Ttn_HetKO_MCMV_2:  87%|████████▋ | 26/30 [17:18<02:54, 43.59s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Ttn_HetKO_MCMV_3:  90%|█████████ | 27/30 [17:49<01:59, 39.85s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Ttn_HetKO_noninf_1:  93%|█████████▎| 28/30 [18:05<01:05, 32.59s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Ttn_HetKO_noninf_2:  97%|█████████▋| 29/30 [18:15<00:25, 25.84s/it]
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# Now running: Ttn_HetKO_noninf_2: 100%|██████████| 30/30 [19:00<00:00, 38.02s/it]

# %%
adata.uns['liana_res'].sort_values("magnitude_rank").head(60)
# Out:
#                        sample         source         target ligand_complex  \
# 18047878    Pkp2_HetKO_MCMV_4   MØ_general_7  Neutrophils_6           Apoe
# 39048110     Ttn_HetKO_MCMV_1  Neutrophils_6  Neutrophils_6           Il1b
# 22604911    Pkp2_HetKO_MCMV_6  Neutrophils_6  Neutrophils_6           Il1b
# 15847188    Pkp2_HetKO_MCMV_3  Neutrophils_6  Neutrophils_6           Il1b
# 11420436    Pkp2_HetKO_MCMV_1  Neutrophils_6  Neutrophils_6           Il1b
# 20549311    Pkp2_HetKO_MCMV_5  Neutrophils_6  Neutrophils_6           Il1b
# 29903317  Pkp2_HetKO_noninf_4  Neutrophils_6  Neutrophils_6           Il1b
# 43716660   Ttn_HetKO_noninf_2  Neutrophils_6  Neutrophils_6           Il1b
# 24863261  Pkp2_HetKO_noninf_1  Neutrophils_6  Neutrophils_6           Il1b
# 0             Pkp2_Ctr_MCMV_1  Neutrophils_6  Neutrophils_6           Il1b
# 7719259     Pkp2_Ctr_noninf_2  Neutrophils_6  Neutrophils_6           Il1b
# 35714637     Ttn_Ctr_noninf_1  Neutrophils_6  Neutrophils_6           Il1b
# 10024401    Pkp2_Ctr_noninf_4  Neutrophils_6  Neutrophils_6           Il1b
# 41439554     Ttn_HetKO_MCMV_2  Neutrophils_6  Neutrophils_6           Il1b
# 32908741       Ttn_Ctr_MCMV_2  Neutrophils_6  Neutrophils_6           Il1b
# 18047879    Pkp2_HetKO_MCMV_4  Neutrophils_6  Neutrophils_6           Il1b
# 4903882       Pkp2_Ctr_MCMV_5  Neutrophils_6  Neutrophils_6           Il1b
# 39048111     Ttn_HetKO_MCMV_1   MØ_general_1  Neutrophils_6           Apoe
# 13514516    Pkp2_HetKO_MCMV_2    LYVE1+MØ_10    Monocytes_9            App
# 13514517    Pkp2_HetKO_MCMV_2  Neutrophils_6  Neutrophils_6           Il1b
# 28770817  Pkp2_HetKO_noninf_3  Neutrophils_6  Neutrophils_6           Il1b
# 22604912    Pkp2_HetKO_MCMV_6   MØ_general_7  Neutrophils_6           Apoe
# 31843717       Ttn_Ctr_MCMV_1  Neutrophils_6  Neutrophils_6           Il1b
# 26726918  Pkp2_HetKO_noninf_2   MØ_general_7  Neutrophils_6           Apoe
# 26726917  Pkp2_HetKO_noninf_2  Neutrophils_6  Neutrophils_6           Il1b
# 24863262  Pkp2_HetKO_noninf_1     LYVE1+MØ_3    Monocytes_9            App
# 1584444       Pkp2_Ctr_MCMV_2     LYVE1+MØ_3    Monocytes_9            App
# 6830539     Pkp2_Ctr_noninf_1  Neutrophils_6   Monocytes_15         S100a9
# 18047880    Pkp2_HetKO_MCMV_4   MØ_general_0  Neutrophils_6           Apoe
# 1             Pkp2_Ctr_MCMV_1   MØ_general_1  Neutrophils_6           Apoe
# 39048112     Ttn_HetKO_MCMV_1   MØ_general_7  Neutrophils_6           Apoe
# 35714638     Ttn_Ctr_noninf_1   MØ_general_0  Neutrophils_6           Apoe
# 13514518    Pkp2_HetKO_MCMV_2    LYVE1+MØ_10     LYVE1+MØ_9            App
# 34166241       Ttn_Ctr_MCMV_3   MØ_general_1  Neutrophils_6           Apoe
# 22604913    Pkp2_HetKO_MCMV_6   MØ_general_1  Neutrophils_6           Apoe
# 11420437    Pkp2_HetKO_MCMV_1    Monocytes_8  Neutrophils_6           Il1b
# 9321601     Pkp2_Ctr_noninf_3   MØ_general_7  Neutrophils_6           Apoe
# 10024402    Pkp2_Ctr_noninf_4  Neutrophils_6   MØ_general_5         S100a9
# 26726919  Pkp2_HetKO_noninf_2     LYVE1+MØ_0  Neutrophils_6           Apoe
# 20549312    Pkp2_HetKO_MCMV_5     LYVE1+MØ_3    Monocytes_1            App
# 41439555     Ttn_HetKO_MCMV_2     LYVE1+MØ_3   MØ_general_4            App
# 29903318  Pkp2_HetKO_noninf_4   MØ_general_7  Neutrophils_6           Apoe
# 43716661   Ttn_HetKO_noninf_2  Neutrophils_6   Monocytes_15         S100a9
# 43716662   Ttn_HetKO_noninf_2   MØ_general_1  Neutrophils_6           Apoe
# 24863263  Pkp2_HetKO_noninf_1     LYVE1+MØ_3    Monocytes_1            App
# 32908742       Ttn_Ctr_MCMV_2   MØ_general_1  Neutrophils_6           Apoe
# 1584445       Pkp2_Ctr_MCMV_2     LYVE1+MØ_3     LYVE1+MØ_9            App
# 18047881    Pkp2_HetKO_MCMV_4     LYVE1+MØ_2  Neutrophils_6           Apoe
# 42752054     Ttn_HetKO_MCMV_3  Neutrophils_6  Neutrophils_6           Il1b
# 13514519    Pkp2_HetKO_MCMV_2    LYVE1+MØ_10    Monocytes_4            App
# 37291261     Ttn_Ctr_noninf_2  MØ_general_17    Monocytes_9            Mif
# 28770818  Pkp2_HetKO_noninf_3    Monocytes_5  Neutrophils_6           Il1b
# 15847189    Pkp2_HetKO_MCMV_3     LYVE1+MØ_3    Monocytes_9            App
# 31843718       Ttn_Ctr_MCMV_1  Neutrophils_6   MØ_general_2         S100a9
# 7719261     Pkp2_Ctr_noninf_2     LYVE1+MØ_3    Monocytes_9            App
# 7719260     Pkp2_Ctr_noninf_2    Monocytes_6  Neutrophils_6           Il1b
# 34166243       Ttn_Ctr_MCMV_3     DOCK4+MØ_9    Monocytes_9            App
# 34166242       Ttn_Ctr_MCMV_3  Neutrophils_6  Neutrophils_6           Il1b
# 26726920  Pkp2_HetKO_noninf_2   MØ_general_0  Neutrophils_6           Apoe
# 20549313    Pkp2_HetKO_MCMV_5     LYVE1+MØ_3    Monocytes_9            App
#
#          receptor_complex  lr_means  expr_prod  scaled_weight  lr_logfc  \
# 18047878            Sorl1  9.068289  80.198822       1.657782  3.914356
# 39048110     Il1r2_Il1rap  8.947151  79.825264       2.268436  5.892633
# 22604911     Il1r2_Il1rap  8.942610  79.948402       2.516556  5.291747
# 15847188     Il1r2_Il1rap  9.028346  81.374290       2.256882  4.831636
# 11420436     Il1r2_Il1rap  9.210358  84.768929       2.181037  4.959343
# 20549311     Il1r2_Il1rap  9.101649  82.581749       2.154657  4.530683
# 29903317     Il1r2_Il1rap  9.063356  81.929428       2.076731  5.015485
# 43716660     Il1r2_Il1rap  9.114004  82.844658       2.521034  6.255741
# 24863261     Il1r2_Il1rap  8.985146  80.322868       2.050560  4.678070
# 0            Il1r2_Il1rap  9.166780  83.807648       2.503216  5.436026
# 7719259      Il1r2_Il1rap  9.092190  82.615219       1.967644  4.967743
# 35714637     Il1r2_Il1rap  8.863329  78.511223       2.403591  5.594900
# 10024401     Il1r2_Il1rap  9.089009  82.150070       2.223846  5.826329
# 41439554     Il1r2_Il1rap  8.966036  80.296303       2.048411  5.461901
# 32908741     Il1r2_Il1rap  8.885269  78.633774       2.449961  5.608683
# 18047879     Il1r2_Il1rap  8.934481  79.618904       1.905919  4.805262
# 4903882      Il1r2_Il1rap  9.002689  80.766914       2.490234  5.767632
# 39048111            Sorl1  8.929245  78.040070       1.847167  3.902860
# 13514516             Cd74  9.033711  79.446716       0.791734  1.254553
# 13514517     Il1r2_Il1rap  8.998178  80.856491       1.890577  4.646251
# 28770817     Il1r2_Il1rap  9.241454  85.161995       1.876030  5.121296
# 22604912            Sorl1  8.864257  77.110886       1.879077  3.763968
# 31843717     Il1r2_Il1rap  8.827014  77.711357       2.030012  5.651240
# 26726918            Sorl1  8.959280  78.641350       1.663615  3.543719
# 26726917     Il1r2_Il1rap  8.903807  79.272957       2.135094  4.994222
# 24863262             Cd74  8.812471  74.707016       0.672618  0.953354
# 1584444              Cd74  9.057834  79.660141       0.724432  1.240579
# 6830539              Cd36  9.127983  79.751320       1.977624  6.433126
# 18047880            Sorl1  8.816339  76.348137       1.524561  3.335629
# 1                   Sorl1  8.931849  78.460663       2.119880  3.845493
# 39048112            Sorl1  8.905551  77.678551       1.833729  3.986639
# 35714638            Sorl1  8.815137  76.235756       1.785562  3.699898
# 13514518             Cd74  8.941072  78.045349       0.744265  1.246260
# 34166241            Sorl1  8.848223  76.475555       1.816178  4.005108
# 22604913            Sorl1  8.814910  76.355461       1.850880  3.756504
# 11420437     Il1r2_Il1rap  8.570789  73.305534       2.008687  4.242775
# 9321601             Sorl1  8.953374  78.403862       2.286488  4.181388
# 10024402             Cd68  9.079811  77.917099       2.011543  6.538204
# 26726919            Sorl1  8.731423  75.139839       1.543287  3.205672
# 20549312             Cd74  8.763636  74.211510       0.621530  1.175681
# 41439555             Cd74  8.912938  76.890083       0.709102  1.072848
# 29903318            Sorl1  8.740090  74.449181       1.611141  3.482816
# 43716661             Cd36  8.970798  77.490921       2.093851  5.954401
# 43716662            Sorl1  8.939668  77.848732       1.910084  3.872890
# 24863263             Cd74  8.744118  73.737190       0.638721  0.857917
# 32908742            Sorl1  8.794410  75.908073       1.909901  3.537542
# 1584445              Cd74  8.988758  78.622116       0.685687  1.108871
# 18047881            Sorl1  8.770883  75.653419       1.500525  3.279279
# 42752054     Il1r2_Il1rap  8.995647  80.567848       2.035883  6.438046
# 13514519             Cd74  8.936216  77.971878       0.741776  1.112995
# 37291261       Cd74_Cxcr4  8.884028  76.772270       1.404930  2.722234
# 28770818     Il1r2_Il1rap  8.656342  74.923660       1.724223  4.444579
# 15847189             Cd74  8.692624  72.746666       0.622725  1.161433
# 31843718             Cd68  8.787895  73.367386       1.750769  6.090569
# 7719261              Cd74  8.968120  77.771355       0.741432  1.223360
# 7719260      Il1r2_Il1rap  8.886801  78.974648       1.913234  4.297743
# 34166243             Cd74  8.877550  76.433380       0.650373  0.886919
# 34166242     Il1r2_Il1rap  8.826506  77.825493       2.164902  5.483183
# 26726920            Sorl1  8.724245  75.029518       1.539496  3.247190
# 20549313             Cd74  8.720406  73.592934       0.597652  1.126029
#
#           spec_weight   lrscore  magnitude_rank
# 18047878     0.005981  0.921400    4.752047e-12
# 39048110     0.026617  0.919997    5.189425e-12
# 22604911     0.034903  0.918767    5.782592e-12
# 15847188     0.016583  0.912198    5.958788e-12
# 11420436     0.020368  0.912264    6.500215e-12
# 20549311     0.019320  0.919631    7.047306e-12
# 29903317     0.026240  0.921231    7.831931e-12
# 43716660     0.032972  0.923320    8.117814e-12
# 24863261     0.018244  0.912923    8.139352e-12
# 0            0.025397  0.915417    1.117201e-11
# 7719259      0.020791  0.919222    1.148793e-11
# 35714637     0.032703  0.919411    1.185954e-11
# 10024401     0.035297  0.920198    1.490527e-11
# 41439554     0.037278  0.918260    1.712569e-11
# 32908741     0.041831  0.915281    1.865075e-11
# 18047879     0.015324  0.921137    1.900818e-11
# 4903882      0.050307  0.918077    2.036763e-11
# 39048111     0.007819  0.919161    2.075769e-11
# 13514516     0.001603  0.914194    2.119605e-11
# 13514517     0.018182  0.914882    2.119605e-11
# 28770817     0.037413  0.917176    2.230653e-11
# 22604912     0.007992  0.917408    2.313035e-11
# 31843717     0.051038  0.917380    2.554570e-11
# 26726918     0.006755  0.910605    2.773835e-11
# 26726917     0.017987  0.910930    2.773835e-11
# 24863262     0.001733  0.909999    3.255739e-11
# 1584444      0.001901  0.913064    3.367323e-11
# 6830539      0.037497  0.913600    3.478342e-11
# 18047880     0.005694  0.919600    4.276839e-11
# 1            0.010190  0.912829    4.468799e-11
# 39048112     0.007782  0.918988    4.670478e-11
# 35714638     0.010782  0.918315    4.743811e-11
# 13514518     0.001575  0.913494    4.769109e-11
# 34166241     0.012923  0.914456    4.894753e-11
# 22604913     0.007914  0.917035    5.204327e-11
# 11420437     0.017613  0.906273    5.850187e-11
# 9321601      0.024462  0.916903    5.902158e-11
# 10024402     0.029008  0.918234    5.962101e-11
# 26726919     0.006454  0.908734    6.241126e-11
# 20549312     0.001638  0.915592    6.342568e-11
# 41439555     0.002459  0.916618    6.850271e-11
# 29903318     0.008377  0.917686    7.048729e-11
# 43716661     0.023327  0.920921    7.306024e-11
# 43716662     0.009073  0.921089    7.306024e-11
# 24863263     0.001710  0.909462    7.325407e-11
# 32908742     0.012018  0.913903    7.460292e-11
# 1584445      0.001876  0.912543    7.576472e-11
# 18047881     0.005642  0.919261    7.603265e-11
# 42752054     0.089575  0.918159    7.613812e-11
# 13514519     0.001574  0.913456    8.478411e-11
# 37291261     0.004344  0.918285    8.658256e-11
# 28770818     0.032915  0.912179    8.922603e-11
# 15847189     0.001552  0.907605    9.534045e-11
# 31843718     0.030745  0.915174    1.021827e-10
# 7719261      0.002217  0.916950    1.033912e-10
# 7719260      0.019875  0.917533    1.033912e-10
# 34166243     0.002204  0.914435    1.101319e-10
# 34166242     0.036328  0.915138    1.101319e-10
# 26726920     0.006445  0.908673    1.109533e-10
# 20549313     0.001625  0.915268    1.127567e-10

# %% [markdown]
# ### Building a Tensor
#
# Before we can decompose the tensor, we need to build it. To do so, we will use the to_tensor_c2c function from liana. This function takes as input the pandas.DataFrame with the results from liana.by_sample, and returns a cell2cell.tensor.PrebuiltTensor object. This object contains the tensor, as well as other useful utility functions.

# %%
tensor = li.multi.to_tensor_c2c(adata,
                                sample_key= "sample",
                                score_key='magnitude_rank', # can be any score from liana
                                how='outer_cells' # how to join the samples
                                )
# Out:
# 100%|██████████| 30/30 [23:51<00:00, 47.70s/it]

# %%
tensor.tensor.shape
# Out:
# torch.Size([30, 891, 43, 43])

# %%
#Save the Tensor to disk
c2c.io.export_variable_with_pickle(tensor, "/home/acirnu/data/ACM_cardiac_leuco/Cell2cell/Tensor_myeloids_20240426.pkl")
# Out:
# /home/acirnu/data/ACM_cardiac_leuco/Cell2cell/Tensor_myeloids_20240426.pkl  was correctly saved.

# %%
#Build meta data
context_dict = adata.obs[['sample', 'condition']].drop_duplicates()
context_dict = dict(zip(context_dict['sample'], context_dict['condition']))
context_dict = defaultdict(lambda: 'Unknown', context_dict)

tensor_meta = c2c.tensor.generate_tensor_metadata(interaction_tensor=tensor,
                                                  metadata_dicts=[context_dict, None, None, None],
                                                  fill_with_order_elements=True
                                                  )

# %% [markdown]
# Plot the most ‘relevant’ interactions ordered to the magnitude_rank results from aggregated_rank

# %%
sc.set_figure_params(dpi =100)
li.pl.dotplot(adata = adata,
              colour='magnitude_rank',
              inverse_colour=True,              
              size='specificity_rank',
              inverse_size=True,
              source_labels=['DOCK4+MØ_11', 'MØ_general_7', 'Neutrophils_6', 'LYVE1+MØ_5'],
              target_labels=['Monocytes_9', 'Neutrophils_6', 'Monocytes_1', 'MØ_general_11', 'Monocytes_4', 'Monocytes_2', 'LYVE1+MØ_8', 'LYVE1+MØ_4', 'LYVE1+MØ_9', 'MØ_general_4'],
              top_n=10,
              orderby='magnitude_rank',
              orderby_ascending=True,
              figure_size=(15, 8),
              cmap= "inferno"
             )

# %% [markdown]
# Similarly, we can also treat the ranks provided by RRA as a probability distribution to which we can filter interactions according to how robustly and highly ranked they are across the different methods.

# %%
my_plot = li.pl.dotplot(adata = adata,
                        colour='magnitude_rank',
                        inverse_colour=True,
                        size='specificity_rank',
                        inverse_size=True,
                        source_labels=['DOCK4+MØ_11', 'MØ_general_7', 'Neutrophils_6', 'LYVE1+MØ_5'],
                        target_labels=['Monocytes_9', 'Neutrophils_6', 'Monocytes_1', 'MØ_general_11', 'Monocytes_4', 'Monocytes_2', 'LYVE1+MØ_8', 'LYVE1+MØ_4', 'LYVE1+MØ_9', 'MØ_general_4'],
                        filter_fun=lambda x: x['specificity_rank'] <= 0.01,
                        figure_size=(20, 25),
                        cmap= "inferno"
                       )
my_plot
