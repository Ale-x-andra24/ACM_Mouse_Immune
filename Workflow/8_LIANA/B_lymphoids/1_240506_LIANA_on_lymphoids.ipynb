# %% [markdown]
# ### Notebook for assessment of lignad-receptor interactions using `LIANA`
#
# #### Environment: LIANA
#
# - **Developed by:** Alexandra Cirnu
# - **Modified by:** Alexandra Cirnu
# - **Würzburg Institute for Systems Immunology & Julius-Maximilian-Universität Würzburg**
# - **Date of creation:** 240416
# - **Date of modification:** 240416
#
# `Liana` works with log1p-transformed counts and uses **all genes** (with enough counts)

# %% [markdown]
# ### Load in required modules

# %%
import numpy as np
import scanpy as sc
import pandas as pd
import seaborn as sns
import liana as li
import matplotlib.pyplot as plt
import muon as mu
from muon import atac as ac
from muon import prot as pt
from scipy.sparse import csr_matrix

# %% [raw]
# from torch.utils.data import TensorDataset, DataLoader , WeightedRandomSampler
# import torch
# import torch.optim as optim
# device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()

sc.settings.set_figure_params(dpi = 300, color_map = 'RdPu', dpi_save = 300, vector_friendly = True, format = 'svg')
# %matplotlib inline
# Out:
# -----
# anndata     0.10.6
# scanpy      1.9.8
# -----
# PIL                 10.2.0
# asttokens           NA
# colorama            0.4.6
# comm                0.2.2
# cycler              0.12.1
# cython_runtime      NA
# dateutil            2.9.0
# debugpy             1.8.1
# decorator           5.1.1
# docrep              0.3.2
# exceptiongroup      1.2.0
# executing           2.0.1
# h5py                3.10.0
# ipykernel           6.29.3
# ipywidgets          8.1.2
# jedi                0.19.1
# joblib              1.3.2
# kiwisolver          1.4.5
# liana               1.0.5
# llvmlite            0.42.0
# matplotlib          3.8.3
# matplotlib_inline   0.1.6
# mizani              0.11.0
# mpl_toolkits        NA
# mudata              0.2.3
# muon                0.1.6
# natsort             8.4.0
# numba               0.59.0
# numpy               1.26.4
# packaging           24.0
# pandas              2.2.1
# parso               0.8.3
# patsy               0.5.6
# pickleshare         0.7.5
# platformdirs        4.2.0
# plotnine            0.13.2
# prompt_toolkit      3.0.42
# psutil              5.9.8
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.17.2
# pynndescent         0.5.11
# pyparsing           3.1.2
# pytz                2024.1
# scipy               1.12.0
# seaborn             0.11.0
# session_info        1.0.0
# setuptools          69.2.0
# six                 1.16.0
# sklearn             1.4.1.post1
# stack_data          0.6.2
# statsmodels         0.14.1
# threadpoolctl       3.4.0
# torch               2.3.0
# torchgen            NA
# tornado             6.4
# tqdm                4.66.2
# traitlets           5.14.2
# typing_extensions   NA
# umap                0.5.5
# vscode              NA
# wcwidth             0.2.13
# yaml                6.0.1
# zmq                 25.1.2
# zoneinfo            NA
# -----
# IPython             8.22.2
# jupyter_client      8.6.1
# jupyter_core        5.7.2
# -----
# Python 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# Linux-6.8.4-200.fc39.x86_64-x86_64-with-glibc2.38
# -----
# Session information updated at 2024-05-06 12:07

# %% [markdown]
# ### Load in the data set

# %%
input = '/home/acirnu/data/ACM_cardiac_leuco/5_Leiden_clustering_and_annotation/ACM_myeloids_clustered_muon_ac240502.raw.h5mu'
mdata = mu.read_h5mu(input)
mdata
# Out:
# /home/acirnu/miniforge3/envs/LIANA/lib/python3.10/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
# /home/acirnu/miniforge3/envs/LIANA/lib/python3.10/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
# MuData object with n_obs × n_vars = 34482 × 29477
#   var:	'gene_ids', 'feature_types'
#   2 modalities
#     rna:	34482 x 29378
#       obs:	'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#       var:	'gene_ids', 'feature_types', 'mt', 'ribo'
#       uns:	'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#       obsm:	'X_scANVI', 'X_scVI', 'X_umap'
#       obsp:	'connectivities', 'distances'
#     prot:	34482 x 99
#       obs:	'library', 'batch'
#       var:	'gene_ids', 'feature_types'
#       uns:	'neighbors', 'pca', 'umap'
#       obsm:	'X_pca', 'X_umap'
#       varm:	'PCs'
#       layers:	'counts', 'log_norm'

# %%
adata = mdata.mod["rna"]

# %%
X_data = adata.X.copy()
X_data_sparse = csr_matrix(X_data)
X_data_df = pd.DataFrame.sparse.from_spmatrix(X_data_sparse, index=adata.obs.index, columns=adata.var.index)
print("Shape of counts DataFrame:", X_data_df.shape)
print(X_data_df)
# Out:
# Shape of counts DataFrame: (34482, 29378)
#                        Xkr4  Gm1992  Gm19938  Gm37381  Rp1  Sox17  Gm37587  \
# AAACGCTGTTGTGTTG-1-A1     0       0        0        0    0      0        0
# AAACGCTTCTCGCTCA-1-A1     0       0        0        0    0      0        0
# AAAGGTACAGAACATA-1-A1     0       0        0        0    0      0        0
# AAAGTCCAGGGACACT-1-A1     0       0        0        0    0      0        0
# AAAGTCCCAGTAGGAC-1-A1     0       0        0        0    0      0        0
# ...                     ...     ...      ...      ...  ...    ...      ...
# TTTGTTGAGGTTAGTA-1-B2     0       0        0        0    0      0        0
# TTTGTTGCAAGCTCTA-1-B2     0       0        0        0    0      0        0
# TTTGTTGGTACAGGTG-1-B2     0       0        0        0    0      0        0
# TTTGTTGTCCCAGGAC-1-B2     0       0        0        0    0      0        0
# TTTGTTGTCCGGGACT-1-B2     0       0        0        0    0      0        0
#
#                        Gm37323  Mrpl15  Lypla1  ...  Vmn2r122  Il11ra2-1  \
# AAACGCTGTTGTGTTG-1-A1        0       0       0  ...         0          0
# AAACGCTTCTCGCTCA-1-A1        0       0       0  ...         0          0
# AAAGGTACAGAACATA-1-A1        0       0     3.0  ...         0          0
# AAAGTCCAGGGACACT-1-A1        0     1.0     2.0  ...         0          0
# AAAGTCCCAGTAGGAC-1-A1        0       0       0  ...         0          0
# ...                        ...     ...     ...  ...       ...        ...
# TTTGTTGAGGTTAGTA-1-B2        0       0       0  ...         0          0
# TTTGTTGCAAGCTCTA-1-B2        0       0       0  ...         0          0
# TTTGTTGGTACAGGTG-1-B2        0       0     1.0  ...         0          0
# TTTGTTGTCCCAGGAC-1-B2        0       0       0  ...         0          0
# TTTGTTGTCCGGGACT-1-B2        0     1.0       0  ...         0          0
#
#                        Ccl27a-1  Ccl21c-1  Ccl27a-2  Il11ra2-2  Ccl19-1  \
# AAACGCTGTTGTGTTG-1-A1         0         0         0          0        0
# AAACGCTTCTCGCTCA-1-A1         0         0         0          0        0
# AAAGGTACAGAACATA-1-A1         0         0         0          0        0
# AAAGTCCAGGGACACT-1-A1         0         0         0          0        0
# AAAGTCCCAGTAGGAC-1-A1         0         0         0          0        0
# ...                         ...       ...       ...        ...      ...
# TTTGTTGAGGTTAGTA-1-B2         0         0         0          0        0
# TTTGTTGCAAGCTCTA-1-B2         0         0         0          0        0
# TTTGTTGGTACAGGTG-1-B2         0         0         0          0        0
# TTTGTTGTCCCAGGAC-1-B2         0         0         0          0        0
# TTTGTTGTCCGGGACT-1-B2         0         0         0          0        0
#
#                        Ccl21a-1  Gm10931  Gm16367
# AAACGCTGTTGTGTTG-1-A1         0        0        0
# AAACGCTTCTCGCTCA-1-A1         0        0        0
# AAAGGTACAGAACATA-1-A1         0        0        0
# AAAGTCCAGGGACACT-1-A1         0        0        0
# AAAGTCCCAGTAGGAC-1-A1         0        0        0
# ...                         ...      ...      ...
# TTTGTTGAGGTTAGTA-1-B2         0        0        0
# TTTGTTGCAAGCTCTA-1-B2         0        0        0
# TTTGTTGGTACAGGTG-1-B2         0        0        0
# TTTGTTGTCCCAGGAC-1-B2         0        0        0
# TTTGTTGTCCGGGACT-1-B2         0        0        0
#
# [34482 rows x 29378 columns]

# %%
adata_raw = adata.copy()

# %% [markdown]
# ### Normalize count matrix

# %%
sc.pp.normalize_total(adata, target_sum = 1e6, exclude_highly_expressed = True)
sc.pp.log1p(adata)
# Out:
# normalizing counts per cell The following highly-expressed genes are not considered during normalization factor computation:
# ['Mapkapk2', 'Il1b', 'Fabp5', 'Fabp4', 'S100a8', 'S100a9', 'Prdx1', 'Cxcl2', 'Spp1', 'Myl2', 'Actb', 'Igkc', 'Apoe', 'Ftl1', 'Hbb-bt', 'Hbb-bs', 'Camp', 'Ngp', 'Slc16a10', 'Lyz2', 'Hba-a1', 'Hba-a2', 'Ccl8', 'Ccl3', 'Ccl4', 'Ctla2a', 'Cma1', 'Mcpt4', 'Retnla', 'Retnlg', 'Cmss1', 'Gm26917', 'Gm42418', 'Cd74', 'Malat1', 'Fth1', 'Tmsb4x']
#     finished (0:00:00)
# WARNING: adata.X seems to be already log-transformed.

# %%
X_data = adata.X.copy()
X_data_sparse = csr_matrix(X_data)
X_data_df = pd.DataFrame.sparse.from_spmatrix(X_data_sparse, index=adata.obs.index, columns=adata.var.index)
print("Shape of counts DataFrame:", X_data_df.shape)
print(X_data_df)
# Out:
# Shape of counts DataFrame: (34482, 29378)
#                        Xkr4  Gm1992  Gm19938  Gm37381  Rp1  Sox17  Gm37587  \
# AAACGCTGTTGTGTTG-1-A1     0       0        0        0    0      0        0
# AAACGCTTCTCGCTCA-1-A1     0       0        0        0    0      0        0
# AAAGGTACAGAACATA-1-A1     0       0        0        0    0      0        0
# AAAGTCCAGGGACACT-1-A1     0       0        0        0    0      0        0
# AAAGTCCCAGTAGGAC-1-A1     0       0        0        0    0      0        0
# ...                     ...     ...      ...      ...  ...    ...      ...
# TTTGTTGAGGTTAGTA-1-B2     0       0        0        0    0      0        0
# TTTGTTGCAAGCTCTA-1-B2     0       0        0        0    0      0        0
# TTTGTTGGTACAGGTG-1-B2     0       0        0        0    0      0        0
# TTTGTTGTCCCAGGAC-1-B2     0       0        0        0    0      0        0
# TTTGTTGTCCGGGACT-1-B2     0       0        0        0    0      0        0
#
#                        Gm37323    Mrpl15    Lypla1  ...  Vmn2r122  Il11ra2-1  \
# AAACGCTGTTGTGTTG-1-A1        0         0         0  ...         0          0
# AAACGCTTCTCGCTCA-1-A1        0         0         0  ...         0          0
# AAAGGTACAGAACATA-1-A1        0         0  5.301714  ...         0          0
# AAAGTCCAGGGACACT-1-A1        0  4.473838  5.161267  ...         0          0
# AAAGTCCCAGTAGGAC-1-A1        0         0         0  ...         0          0
# ...                        ...       ...       ...  ...       ...        ...
# TTTGTTGAGGTTAGTA-1-B2        0         0         0  ...         0          0
# TTTGTTGCAAGCTCTA-1-B2        0         0         0  ...         0          0
# TTTGTTGGTACAGGTG-1-B2        0         0  3.947542  ...         0          0
# TTTGTTGTCCCAGGAC-1-B2        0         0         0  ...         0          0
# TTTGTTGTCCGGGACT-1-B2        0  4.844876         0  ...         0          0
#
#                        Ccl27a-1  Ccl21c-1  Ccl27a-2  Il11ra2-2  Ccl19-1  \
# AAACGCTGTTGTGTTG-1-A1         0         0         0          0        0
# AAACGCTTCTCGCTCA-1-A1         0         0         0          0        0
# AAAGGTACAGAACATA-1-A1         0         0         0          0        0
# AAAGTCCAGGGACACT-1-A1         0         0         0          0        0
# AAAGTCCCAGTAGGAC-1-A1         0         0         0          0        0
# ...                         ...       ...       ...        ...      ...
# TTTGTTGAGGTTAGTA-1-B2         0         0         0          0        0
# TTTGTTGCAAGCTCTA-1-B2         0         0         0          0        0
# TTTGTTGGTACAGGTG-1-B2         0         0         0          0        0
# TTTGTTGTCCCAGGAC-1-B2         0         0         0          0        0
# TTTGTTGTCCGGGACT-1-B2         0         0         0          0        0
#
#                        Ccl21a-1  Gm10931  Gm16367
# AAACGCTGTTGTGTTG-1-A1         0        0        0
# AAACGCTTCTCGCTCA-1-A1         0        0        0
# AAAGGTACAGAACATA-1-A1         0        0        0
# AAAGTCCAGGGACACT-1-A1         0        0        0
# AAAGTCCCAGTAGGAC-1-A1         0        0        0
# ...                         ...      ...      ...
# TTTGTTGAGGTTAGTA-1-B2         0        0        0
# TTTGTTGCAAGCTCTA-1-B2         0        0        0
# TTTGTTGGTACAGGTG-1-B2         0        0        0
# TTTGTTGTCCCAGGAC-1-B2         0        0        0
# TTTGTTGTCCGGGACT-1-B2         0        0        0
#
# [34482 rows x 29378 columns]

# %% [markdown]
# ### Show the methods covered by `LIANA`

# %% [markdown]
# Each method infers relevant ligand-receptor interactions relying on different assumptions and each method returns different ligand-receptor scores, typically a pair per method.
#
# One score corresponding to the magnitude (strength) of interaction and the other reflecting specificity of a given interaction to a pair cell identities.

# %%
li.mt.show_methods()
# Out:
#          Method Name Magnitude Score Specificity Score  \
# 0        CellPhoneDB        lr_means   cellphone_pvals
# 0         Connectome       expr_prod     scaled_weight
# 0             log2FC            None          lr_logfc
# 0              NATMI       expr_prod       spec_weight
# 0  SingleCellSignalR         lrscore              None
# 0     Rank_Aggregate  magnitude_rank  specificity_rank
# 0     Geometric Mean       lr_gmeans       gmean_pvals
# 0          scSeqComm     inter_score              None
# 0           CellChat        lr_probs    cellchat_pvals
#
#                                            Reference
# 0  Efremova, M., Vento-Tormo, M., Teichmann, S.A....
# 0  Raredon, M.S.B., Yang, J., Garritano, J., Wang...
# 0  Dimitrov, D., Türei, D., Garrido-Rodriguez, M....
# 0  Hou, R., Denisenko, E., Ong, H.T., Ramilowski,...
# 0  Cabello-Aguilar, S., Alame, M., Kon-Sun-Tack, ...
# 0  Dimitrov, D., Türei, D., Garrido-Rodriguez, M....
# 0  CellPhoneDBv2's permutation approach applied t...
# 0  Baruzzo, G., Cesaro, G., Di Camillo, B. 2022. ...
# 0  Jin, S., Guerrero-Juarez, C.F., Zhang, L., Cha...

# %% [markdown]
# #### Import all individual methods

# %%
from liana.method import cellphonedb, connectome, logfc, natmi, singlecellsignalr, rank_aggregate, geometric_mean, scseqcomm, cellchat

# %% [markdown]
# ### Run CellPhoneDB

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 34482 × 29378
#     obs: 'cell_source', 'donor', 'n_counts', 'sample', 'seed_labels', 'condition', 'genotype', 'infection', 'library', 'model', 'n_genes_by_counts', 'total_counts', 'doublet_scores', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', '_scvi_batch', '_scvi_labels', 'batch', 'C_scANVI', 'leiden', 'classification'
#     var: 'gene_ids', 'feature_types', 'mt', 'ribo'
#     uns: 'C_scANVI_colors', 'classification_colors', 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'rank_genes_groups'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %%
cellphonedb(adata, groupby='classification', expr_prop=0.1, resource_name='mouseconsensus', verbose=True, use_raw= False, key_added='cpdb_res')
# Out:
# Using `.X`!
# /home/acirnu/miniforge3/envs/LIANA/lib/python3.10/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
# 6087 features of mat are empty, they will be removed.
# /home/acirnu/miniforge3/envs/LIANA/lib/python3.10/site-packages/liana/method/_pipe_utils/_pre.py:148: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
# /home/acirnu/miniforge3/envs/LIANA/lib/python3.10/site-packages/liana/method/_pipe_utils/_pre.py:151: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Using resource `mouseconsensus`.
# 0.08 of entities in the resource are missing from the data.
# Generating ligand-receptor stats for 34482 samples and 1451 features
# 100%|██████████| 1000/1000 [00:35<00:00, 28.24it/s]

# %%
adata.uns["cpdb_res"].head(20)
# Out:
#        ligand ligand_complex  ligand_means  ligand_props receptor  \
# 68837  S100a9         S100a9     10.488156      0.981748     Cd68
# 71111    Apoe           Apoe      9.678244      0.999488    Sorl1
# 71271    Apoe           Apoe      9.660369      1.000000    Sorl1
# 71463    Apoe           Apoe      9.449452      1.000000    Sorl1
# 34625     App            App      6.660326      0.987197     Cd74
# 69998    Apoe           Apoe      9.356489      0.996612    Sorl1
# 34920     App            App      6.591236      0.985722     Cd74
# 24955     App            App      6.660326      0.987197     Cd74
# 68833  S100a8         S100a8      9.986200      0.975024     Cd68
# 25233     App            App      6.591236      0.985722     Cd74
# 49685     App            App      6.660326      0.987197     Cd74
# 49982     App            App      6.591236      0.985722     Cd74
# 32656     App            App      6.369162      0.962210     Cd74
# 69839    Apoe           Apoe      9.124606      0.999019    Sorl1
# 29791     App            App      6.660326      0.987197     Cd74
# 70323    Apoe           Apoe      9.030025      0.971880    Sorl1
# 31926     App            App      6.264552      0.864801     Cd74
# 32366     App            App      6.230159      0.964496     Cd74
# 23077     App            App      6.369162      0.962210     Cd74
# 30095     App            App      6.591236      0.985722     Cd74
#
#       receptor_complex  receptor_means  receptor_props         source  \
# 68837             Cd68        6.714415        0.987421  Neutrophils_5
# 71111            Sorl1        7.460152        0.981268   MØ_general_0
# 71271            Sorl1        7.460152        0.981268   MØ_general_7
# 71463            Sorl1        7.460152        0.981268  MØ_general_10
# 34625             Cd74       10.222328        0.999723   MØ_general_0
# 69998            Sorl1        7.460152        0.981268     LYVE1+MØ_2
# 34920             Cd74       10.222328        0.999723   MØ_general_7
# 24955             Cd74       10.081182        0.999019   MØ_general_0
# 68833             Cd68        6.714415        0.987421  Neutrophils_5
# 25233             Cd74       10.081182        0.999019   MØ_general_7
# 49685             Cd74       10.006419        0.998043   MØ_general_0
# 49982             Cd74       10.006419        0.998043   MØ_general_7
# 32656             Cd74       10.222328        0.999723     LYVE1+MØ_2
# 69839            Sorl1        7.460152        0.981268     LYVE1+MØ_1
# 29791             Cd74        9.845660        0.996873   MØ_general_0
# 70323            Sorl1        7.460152        0.981268     LYVE1+MØ_8
# 31926             Cd74       10.222328        0.999723     DOCK4+MØ_3
# 32366             Cd74       10.222328        0.999723     LYVE1+MØ_1
# 23077             Cd74       10.081182        0.999019     LYVE1+MØ_2
# 30095             Cd74        9.845660        0.996873   MØ_general_7
#
#               target  lr_means  cellphone_pvals
# 68837  MØ_general_10  8.601286              0.0
# 71111  Neutrophils_5  8.569198              0.0
# 71271  Neutrophils_5  8.560261              0.0
# 71463  Neutrophils_5  8.454802              0.0
# 34625     LYVE1+MØ_4  8.441327              0.0
# 69998  Neutrophils_5  8.408320              0.0
# 34920     LYVE1+MØ_4  8.406782              0.0
# 24955     LYVE1+MØ_1  8.370754              0.0
# 68833  MØ_general_10  8.350307              0.0
# 25233     LYVE1+MØ_1  8.336209              0.0
# 49685   Monocytes_11  8.333372              0.0
# 49982   Monocytes_11  8.298827              0.0
# 32656     LYVE1+MØ_4  8.295745              0.0
# 69839  Neutrophils_5  8.292379              0.0
# 29791     LYVE1+MØ_2  8.252993              0.0
# 70323  Neutrophils_5  8.245089              0.0
# 31926     LYVE1+MØ_4  8.243440              0.0
# 32366     LYVE1+MØ_4  8.226244              0.0
# 23077     LYVE1+MØ_1  8.225172              0.0
# 30095     LYVE1+MØ_2  8.218448              0.0

# %%
cpdb_res_df = adata.uns["cpdb_res"].astype('category')
source_counts = cpdb_res_df['source'].cat.categories
source_counts
# Out:
# Index(['DC_12', 'DC_14', 'DC_16', 'DOCK4+MØ_3', 'DOCK4+MØ_9', 'LYVE1+MØ_1',
#        'LYVE1+MØ_2', 'LYVE1+MØ_4', 'LYVE1+MØ_8', 'Mast_15', 'Monocytes_11',
#        'Monocytes_13', 'Monocytes_17', 'Monocytes_6', 'MØ_general_0',
#        'MØ_general_10', 'MØ_general_7', 'Neutrophils_5'],
#       dtype='object')

# %%
target_counts = cpdb_res_df['target'].cat.categories
target_counts
# Out:
# Index(['DC_12', 'DC_14', 'DC_16', 'DOCK4+MØ_3', 'DOCK4+MØ_9', 'LYVE1+MØ_1',
#        'LYVE1+MØ_2', 'LYVE1+MØ_4', 'LYVE1+MØ_8', 'Mast_15', 'Monocytes_11',
#        'Monocytes_13', 'Monocytes_17', 'Monocytes_6', 'MØ_general_0',
#        'MØ_general_10', 'MØ_general_7', 'Neutrophils_5'],
#       dtype='object')

# %% [markdown]
# #### Visualization - Dotplot

# %%
sc.set_figure_params(dpi =50)

li.pl.dotplot(adata = adata,
              colour='lr_means',
              size='cellphone_pvals',
              inverse_size=True, # we inverse sign since we want small p-values to have large sizes
              source_labels=['Neutrophils_5', 'MØ_general_0', 'MØ_general_7', 'MØ_general_10'],
              target_labels=['MØ_general_10', 'Neutrophils_5','LYVE1+MØ_4'],
              figure_size=(15, 25),
              filter_fun=lambda x: x['cellphone_pvals'] <= 0.05,   #finally, since cpdbv2 suggests using a filter to FPs, we filter the pvals column to <= 0.05
              uns_key='cpdb_res', # uns_key to use, default is 'liana_res'
              cmap= 'inferno'
             )
# Out:
# Fontsize 0.00 < 1.0 pt not allowed by FreeType. Setting fontsize = 1 pt

# %% [markdown]
# #### Visualization - Tileplot

# %%
my_plot = li.pl.tileplot(adata = adata,
                         # NOTE: fill & label need to exist for both ligand_ and receptor_ columns
                         fill='means',
                         label='props',
                         label_fun=lambda x: f'{x:.2f}',
                         top_n=10,
                         orderby='cellphone_pvals',
                         orderby_ascending=True,
                         source_labels=['Neutrophils_5', 'MØ_general_0', 'MØ_general_7', 'MØ_general_10'],
                         target_labels=['MØ_general_10', 'Neutrophils_5','LYVE1+MØ_4'],
                         uns_key='cpdb_res', # NOTE: default is 'liana_res'
                         source_title='Ligand',
                         target_title='Receptor',
                         figure_size=(8, 7)
                         )
my_plot
# Out:
# /home/acirnu/miniforge3/envs/LIANA/lib/python3.10/site-packages/liana/plotting/_common.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 my_plot = li.pl.tileplot(adata = adata,
#       2                          # NOTE: fill & label need to exist for both ligand_ and receptor_ columns
#       3                          fill='means',
#       4                          label='props',
#       5                          label_fun=lambda x: f'{x:.2f}',
#       6                          top_n=10,
#       7                          orderby='cellphone_pvals',
#       8                          orderby_ascending=True,
#       9                          source_labels=['Neutrophils_5', 'MØ_general_0', 'MØ_general_7', 'MØ_general_10'],
#      10                          target_labels=['MØ_general_10', 'Neutrophils_5','LYVE1+MØ_4'],
#      11                          uns_key='cpdb_res', # NOTE: default is 'liana_res'
#      12                          source_title='Ligand',
#      13                          target_title='Receptor',
#      14                          figure_size=(8, 7)
#      15                          )
#      16 my_plot
#
# File ~/miniforge3/envs/LIANA/lib/python3.10/site-packages/liana/plotting/_tileplot.py:109, in tileplot(adata, liana_res, fill, label, label_fun, source_labels, target_labels, ligand_complex, receptor_complex, uns_key, top_n, orderby, orderby_ascending, orderby_absolute, filter_fun, source_title, target_title, cmap, figure_size, label_size, return_fig)
#     102 if label_fun is not None:
#     103     liana_res[label] = liana_res[label].apply(label_fun)
#     105 p = (
#     106     p9.ggplot(liana_res, p9.aes(x='cell_type', y='interaction', fill=fill)) +
#     107     p9.geom_tile() +
#     108     p9.geom_text(p9.aes(label=label), size=label_size, color='white') +
# --> 109     p9.facet_grid(facets='~ type', scales='free') +
#     110     p9.theme_bw(base_size=14) +
#     111     p9.theme(
#     112         axis_text_x=p9.element_text(angle=90),
#     113         figure_size=figure_size,
#     114         strip_background=p9.element_rect(colour="black", fill="#fdfff4"),
#     115     ) +
#     116     p9.scale_fill_cmap(cmap) +
#     117     p9.labs(x='Cell type', y='Interaction', fill=str.capitalize(fill))
#     118 )
#     120 if return_fig:
#     121     return p
#
# TypeError: facet_grid.__init__() got an unexpected keyword argument 'facets'

# %% [markdown]
# ## Rank Aggregate - use all methods and integrate results
#
# In addition to the individual methods, LIANA also provides a consensus that integrates the predictions of individual methods. This is done by ranking and aggregating (RRA) the ligand-receptor interaction predictions from all methods.

# %%
li.mt.rank_aggregate(adata, groupby='classification', expr_prop=0.1, verbose=True, use_raw= False, resource_name='mouseconsensus')
# Out:
# Using `.X`!
# /home/acirnu/miniforge3/envs/LIANA/lib/python3.10/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
# 6087 features of mat are empty, they will be removed.
# /home/acirnu/miniforge3/envs/LIANA/lib/python3.10/site-packages/liana/method/_pipe_utils/_pre.py:148: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
# /home/acirnu/miniforge3/envs/LIANA/lib/python3.10/site-packages/liana/method/_pipe_utils/_pre.py:151: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# Using resource `mouseconsensus`.
# 0.08 of entities in the resource are missing from the data.
# Generating ligand-receptor stats for 34482 samples and 1451 features
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# /home/acirnu/miniforge3/envs/LIANA/lib/python3.10/site-packages/liana/method/sc/_liana_pipe.py:256: ImplicitModificationWarning: Setting element `.layers['scaled']` of view, initializing view as actual.
# Assuming that counts were `natural` log-normalized!
# Running CellPhoneDB
# 100%|██████████| 1000/1000 [00:24<00:00, 40.37it/s]
# Running Connectome
# Running log2FC
# Running NATMI
# Running SingleCellSignalR

# %%
adata.uns['liana_res'].head(20)
# Out:
#               source         target ligand_complex receptor_complex  lr_means  \
# 54311   MØ_general_0  Neutrophils_5           Apoe            Sorl1  8.569198
# 63221   MØ_general_7  Neutrophils_5           Apoe            Sorl1  8.560261
# 66397  Neutrophils_5  MØ_general_10         S100a9             Cd68  8.601286
# 59182  MØ_general_10  Neutrophils_5           Apoe            Sorl1  8.454802
# 26707     LYVE1+MØ_2  Neutrophils_5           Apoe            Sorl1  8.408320
# 52154   MØ_general_0     LYVE1+MØ_4            App             Cd74  8.441327
# 61127   MØ_general_7     LYVE1+MØ_4            App             Cd74  8.406782
# 51604   MØ_general_0     LYVE1+MØ_1            App             Cd74  8.370754
# 66393  Neutrophils_5  MØ_general_10         S100a8             Cd68  8.350307
# 52725   MØ_general_0   Monocytes_11            App             Cd74  8.333372
# 60593   MØ_general_7     LYVE1+MØ_1            App             Cd74  8.336209
# 22739     LYVE1+MØ_1  Neutrophils_5           Apoe            Sorl1  8.292379
# 61680   MØ_general_7   Monocytes_11            App             Cd74  8.298827
# 51871   MØ_general_0     LYVE1+MØ_2            App             Cd74  8.252993
# 34373     LYVE1+MØ_8  Neutrophils_5           Apoe            Sorl1  8.245089
# 24631     LYVE1+MØ_2     LYVE1+MØ_4            App             Cd74  8.295745
# 60852   MØ_general_7     LYVE1+MØ_2            App             Cd74  8.218448
# 24099     LYVE1+MØ_2     LYVE1+MØ_1            App             Cd74  8.225172
# 14134     DOCK4+MØ_3     LYVE1+MØ_4            App             Cd74  8.243440
# 50881   MØ_general_0          DC_16            App             Cd74  8.212753
#
#        cellphone_pvals  expr_prod  scaled_weight  lr_logfc  spec_weight  \
# 54311              0.0  72.201164       1.568794  3.383570     0.019531
# 63221              0.0  72.067818       1.564085  3.320984     0.019495
# 66397              0.0  70.421829       2.022228  6.012231     0.053691
# 59182              0.0  70.494347       1.508489  3.538809     0.019069
# 26707              0.0  69.800827       1.483985  3.249174     0.018882
# 52154              0.0  68.084038       0.500892  0.568575     0.005886
# 61127              0.0  67.377777       0.484691  0.491229     0.005825
# 51604              0.0  67.143959       0.469588  0.555827     0.005805
# 66393              0.0  67.051491       2.067718  6.005134     0.059384
# 52725              0.0  66.646011       0.453010  0.434344     0.005762
# 60593              0.0  66.447449       0.453387  0.478481     0.005745
# 22739              0.0  68.070946       1.422866  3.074234     0.018414
# 61680              0.0  65.954666       0.436809  0.356998     0.005702
# 51871              0.0  65.575310       0.417360  0.462690     0.005669
# 34373              0.0  67.365356       1.397933  3.179776     0.018223
# 24631              0.0  65.107658       0.432606  0.480254     0.005629
# 60852              0.0  64.895065       0.401159  0.385344     0.005611
# 24099              0.0  64.208679       0.401302  0.467506     0.005551
# 14134              0.0  64.038300       0.408075  0.993100     0.005536
# 50881              0.0  65.039284       0.399514  0.138345     0.005623
#
#         lrscore  specificity_rank  magnitude_rank
# 54311  0.934479          0.004117    8.058847e-09
# 63221  0.934423          0.004139    1.813223e-08
# 66397  0.933711          0.000083    3.223475e-08
# 59182  0.933743          0.004510    3.223475e-08
# 26707  0.933436          0.004716    7.252673e-08
# 52154  0.932659          0.072922    7.252673e-08
# 61127  0.932330          0.077343    1.289338e-07
# 51604  0.932221          0.078893    2.014551e-07
# 66393  0.932177          0.000078    2.437583e-07
# 52725  0.931985          0.082338    2.900896e-07
# 60593  0.931890          0.083712    3.404489e-07
# 22739  0.932653          0.005231    3.948363e-07
# 61680  0.931654          0.087639    3.948363e-07
# 51871  0.931470          0.090425    4.532514e-07
# 34373  0.932325          0.005447    5.156942e-07
# 24631  0.931241          0.094239    5.156942e-07
# 60852  0.931136          0.096139    8.057401e-07
# 24099  0.930795          0.102180    8.057401e-07
# 14134  0.930709          0.103640    8.883195e-07
# 50881  0.931208          0.094931    8.883195e-07

# %%
rank_aggregate.describe()
# Out:
# Rank_Aggregate returns `magnitude_rank`, `specificity_rank`. magnitude_rank and specificity_rank respectively represent an aggregate of the `magnitude`- and `specificity`-related scoring functions from the different methods.

# %% [markdown]
# Plot the most ‘relevant’ interactions ordered to the magnitude_rank results from aggregated_rank

# %%
sc.set_figure_params(dpi =100)
li.pl.dotplot(adata = adata,
              colour='magnitude_rank',
              inverse_colour=True,              
              size='specificity_rank',
              inverse_size=True,
              source_labels=['Neutrophils_5', 'MØ_general_0', 'MØ_general_7', 'MØ_general_10'],
              target_labels=['MØ_general_10', 'Neutrophils_5','LYVE1+MØ_4'],
              top_n=10,
              orderby='magnitude_rank',
              orderby_ascending=True,
              figure_size=(10, 8),
              cmap= "inferno"
             )
# Out:
# /home/acirnu/miniforge3/envs/LIANA/lib/python3.10/site-packages/liana/plotting/_common.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Fontsize 0.00 < 1.0 pt not allowed by FreeType. Setting fontsize = 1 pt

# %% [markdown]
# Similarly, we can also treat the ranks provided by RRA as a probability distribution to which we can filter interactions according to how robustly and highly ranked they are across the different methods.

# %%
my_plot = li.pl.dotplot(adata = adata,
                        colour='magnitude_rank',
                        inverse_colour=True,
                        size='specificity_rank',
                        inverse_size=True,
                        source_labels=['Neutrophils_5', 'MØ_general_0', 'MØ_general_7', 'MØ_general_10'],
                        target_labels=['MØ_general_10', 'Neutrophils_5','LYVE1+MØ_4'],
                        filter_fun=lambda x: x['specificity_rank'] <= 0.01,
                        figure_size=(10, 25),
                        cmap= "inferno"
                       )
my_plot
# Out:
# Fontsize 0.00 < 1.0 pt not allowed by FreeType. Setting fontsize = 1 pt
